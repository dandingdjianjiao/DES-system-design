# %% [markdown]
# # Test Query Team Execution
#
# This notebook demonstrates two ways to run the query team workflow:
# 1. **Using QueryManager**: Simulates the standard way of submitting a query and getting the final result.
# 2. **Using Direct Graph Stream**: Directly interacts with the LangGraph instance to observe intermediate steps.

# %% [markdown]
# ## Part 0: Setup (Imports and Ontology)

# %%
import sys
import os
sys.path.append(r"D:\\CursorProj\\Chem-Ontology-Constructor")
os.environ["PROJECT_ROOT"] = "D:\\\\CursorProj\\\\Chem-Ontology-Constructor\\\\"

from owlready2 import get_ontology
# 从 config.settings 导入 ONTOLOGY_SETTINGS 而不是 ONTOLOGY_CONFIG
from config.settings import ONTOLOGY_SETTINGS
# 本体现在在 ONTOLOGY_SETTINGS 初始化时加载，如果需要，可以通过 ONTOLOGY_SETTINGS.ontology 访问
# 例如: onto = ONTOLOGY_SETTINGS.ontology
# onto_additional = get_ontology("data/ontology/test.owl").load() # 可选的第二个本体
# Out:
# Setting owlready2.JAVA_EXE globally from settings.yaml: C:\Program Files\Java\jdk-23\bin\java.exe

# %%
import dotenv
dotenv.load_dotenv(override=True)
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_community.chat_models.tongyi import ChatTongyi
from langchain_ollama import ChatOllama


answer_llm = ChatOpenAI(
            model_name="gpt-4.1",
            temperature=0,
            max_tokens=10000,
        )

ty_llm = ChatTongyi(
            model_name="qwen3-14b",
            model_kwargs={
                "temperature": 0,
                "enable_thinking": False,
                "max_tokens":8192,
            }
        )

ollama_llm = ChatOllama(
            model="myaniu/qwen2.5-1m:14b",
            base_url="https://30a6-36-5-153-246.ngrok-free.app",
            temperature=0,
            max_tokens=8192,
        )

answer_llm = answer_llm

# %%
# Required Imports
import sys
import os
import json
import time
from typing import Dict, Any, List
from owlready2 import *
import asyncio # Needed for owlready2 async operations in some envs

# Import the OntologySettings class
from config.settings import OntologySettings # Keep ONTOLOGY_SETTINGS import for potential base_iri access

# Import necessary LLM and Query Team components
try:
    from autology_constructor.idea.query_team import QueryManager, Query, QueryStatus, create_query_graph
    from autology_constructor.idea.query_team.ontology_tools import OntologyTools
    from autology_constructor.idea.common.llm_provider import get_cached_default_llm
    print("Modules imported successfully.")
except ModuleNotFoundError as e:
    print(f"Error importing modules: {e}")
    print(f"Current sys.path: {sys.path}")

# Ensure LLM Provider is configured
try:
    llm = get_cached_default_llm()
    def get_model_name(obj):
        return getattr(obj, "model_name", getattr(obj, "model", None))
    print(f"LLM: {get_model_name(llm)}. \nAnsewr LLM: {get_model_name(answer_llm)}")
    print("LLM Provider initialized successfully.")
except Exception as e:
    print(f"Error initializing LLM Provider: {e}\nPlease ensure API keys or necessary configurations are set.")
    llm = None

# --- Ontology Setup ---
print("Setting up test ontology using a new OntologySettings instance...")

# Define parameters for the new OntologySettings instance
# Assuming 'backup-2.owl' and 'backup-2-closed.owl' exist in 'data/ontology'
# Use the project root defined in the previous cell
project_root_path = os.environ.get("PROJECT_ROOT", ".")
ontology_dir = os.path.join(project_root_path, "data", "ontology")
# You might want to use the base_iri from the default settings or define a specific one for testing
test_base_iri = ONTOLOGY_SETTINGS.base_iri if 'ONTOLOGY_SETTINGS' in locals() else "http://www.test.org/chem_ontologies/backup-2"

try:
    # Instantiate OntologySettings directly
    # test_ontology_settings = ONTOLOGY_SETTINGS
    test_ontology_settings = OntologySettings(
        base_iri=test_base_iri,
        ontology_file_name="final.owl",  # Use the desired ontology file
        directory_path=ontology_dir,
        closed_ontology_file_name="IDA-closed.owl" # Adjust if your closed file has a different name pattern
    )
    # Access the loaded ontology via the instance's property
    test_onto = test_ontology_settings.ontology
    print(f"Successfully loaded ontology: {test_onto.base_iri}")
    print(f"From file: {test_ontology_settings.ontology_file_name} in {test_ontology_settings.directory_path}")

    # Optional: Print some details about the loaded ontology
    # print(f"Test Ontology '{test_onto.base_iri}' loaded with:")
    # print(f"- Classes ({len(list(test_onto.classes()))}): {[c.name for c in list(test_onto.classes())[:5]]}...") # Print first 5
    # print(f"- Individuals ({len(list(test_onto.individuals()))}): {[i.name for i in list(test_onto.individuals())[:5]]}...")
    # print(f"- Object Properties ({len(list(test_onto.object_properties()))}): {[p.name for p in list(test_onto.object_properties())[:5]]}...")
    # print(f"- Data Properties ({len(list(test_onto.data_properties()))}): {[p.name for p in list(test_onto.data_properties())[:5]]}...")

except Exception as e:
    print(f"Error creating OntologySettings or loading ontology 'backup-2.owl': {e}")
    print(f"Please ensure 'backup-2.owl' exists in '{ontology_dir}' and settings are correct.")
    test_onto = None # Set to None if loading failed

# # --- Old way (commented out) ---
# # print("Creating a simple in-memory ontology...")
# # # It's good practice to clear existing ontologies from the default world if running cells repeatedly
# # for o in list(default_world.ontologies.values()):
# #     if callable(getattr(o, '__destroy__', None)):
# #         try:
# #             destroy_entity(o)
# #         except Exception as destroy_err:
# #             print(f"Error destroying {o.base_iri}: {destroy_err}")
# #     else:
# #         print(f"Skipping destroy for non-callable __destroy__ or missing: {o.base_iri}")
# # test_onto_old = get_ontology("data/ontology/test.owl").load()
# # for o in list(default_world.ontologies.values()):
# #     print(f"has：{o.base_iri}")
# # print(f"Test Ontology '{test_onto_old.base_iri}' created with:\\n- Classes: {[c.name for c in test_onto_old.classes()]}\\n- Individuals: {[i.name for i in test_onto_old.individuals()]}\\n- Object Properties: {[p.name for p in test_onto_old.object_properties()]}\\n- Data Properties: {[p.name for p in test_onto_old.data_properties()]}\")

# Run async tasks if needed by owlready2 backend (usually not necessary for simple loading)
# try:
#     loop = asyncio.get_event_loop()
# except RuntimeError:
#     loop = asyncio.new_event_loop()
#     asyncio.set_event_loop(loop)
# loop.run_until_complete(asyncio.sleep(0)) # Run pending async tasks
# Out:
# Modules imported successfully.
# LLM: gpt-4.1.
# Ansewr LLM: gpt-4.1
# LLM Provider initialized successfully.
# Setting up test ontology using a new OntologySettings instance...
# Successfully loaded ontology: http://www.test.org/chem_ontologies/chem_ontology.owl#
# From file: final.owl in D:\\CursorProj\\Chem-Ontology-Constructor\\data\ontology

# %% [markdown]
# ## Part 1: Execution via QueryManager

# %%
qas = {
  "query_format_QA": [
    {
      "difficulty_level": 1,
      "query": "Quinine definition?",
      "answer": "Quinine is an alkaloid derived from cinchona tree bark, used historically for malaria and now as a bittering agent, but associated with adverse health effects like thrombocytopenia."
    },
    {
      "difficulty_level": 1,
      "query": "Indicator Displacement Assay (IDA) definition?",
      "answer": "An IDA is a sensing strategy based on host-guest recognition, often utilizing non-covalent interactions where an analyte displaces an indicator from a receptor, causing a detectable signal change (e.g., fluorescence or absorbance)."
    },
    {
      "difficulty_level": 2,
      "query": "What analyzes Quinine?",
      "answer": "Quinine is analyzed by techniques including Electrochemical Technique, High Performance Liquid Chromatography (HPLC), Colorimetric Assay, Fluorescence Assay, and High Resolution Mass Spectrometry (HRMS)."
    },
    {
      "difficulty_level": 2,
      "query": "List components of Indicator Displacement Assay (IDA).",
      "answer": "Components include beta-Cyclodextrin (beta-CD), Poly(N-acetylaniline), and Graphene."
    },
    {
      "difficulty_level": 3,
      "query": "Find electrochemical sensors based on Indicator Displacement Assay (IDA) used for Quinine detection.",
      "answer": "The Electrochemical Sensor constructed via IDA (Indicator Displacement Assay) has the detection target Quinine."
    },
    {
      "difficulty_level": 3,
      "query": "Which hosts use host-guest recognition and are integrated with electrochemical assays?",
      "answer": "Host-Guest Recognition is integrated with an Electrochemical Sensor. Beta-Cyclodextrin (β-CD) is a host involved in Host-Guest Recognition."
    },
    {
      "difficulty_level": 4,
      "query": "Compare the stability and reproducibility properties of the Electrochemical Sensor.",
      "answer": "The Electrochemical Sensor has high stability (acceptable peak current decrease within 21 days, 86.47% retained) and good reproducibility (RSD of 2.06% across seven electrodes)."
    },
    {
      "difficulty_level": 4,
      "query": "What techniques verify the Electrochemical Sensor based on IDA?",
      "answer": "The Electrochemical Sensor is verified by Differential Pulse Voltammetry (DPV), Cyclic Voltammetry (CV), Proton Nuclear Magnetic Resonance (H_NMR), Scanning Electron Microscopy (SEM), Electrochemical Impedance Analysis (EIS), and Fourier Transform Infrared (FTIR)."
    },
    {
      "difficulty_level": 5,
      "query": "Explain the sensing mechanism involving Methylene Blue (MB) displacement by Quinine from beta-Cyclodextrin (beta-CD).",
      "answer": "Methylene Blue (MB) forms an inclusion complex with beta-Cyclodextrin (beta-CD). Quinine, having a higher binding affinity, competitively displaces MB from the beta-CD cavity. This displacement causes a change in the electrochemical signal (e.g., DPV peak current) which is used for Quinine detection. Poly(N-acetylaniline) inhibits non-specific adsorption of MB, contributing to the assay's selectivity."
    },
    {
      "difficulty_level": 5,
      "query": "Summarize the role of Graphene in the described electrochemical sensor.",
      "answer": "Graphene (specifically reduced graphene oxide, rGO) is used as an electrode material in the sensor. It enhances electron transfer properties due to its superior electrical conductivity and large specific surface area, improving the sensor's performance. It serves as a platform onto which other components like Poly(N-acetylaniline) and beta-Cyclodextrin are deposited."
    }
  ],
  "question_format_QA": [
    {
      "difficulty_level": 1,
      "question": "Tell me about Quinine.",
      "answer": "Quinine is an alkaloid derived from cinchona tree bark, used historically for malaria and now as a bittering agent, but associated with adverse health effects like thrombocytopenia."
    },
    {
      "difficulty_level": 1,
      "question": "What is an Indicator Displacement Assay?",
      "answer": "An IDA is a sensing strategy based on host-guest recognition, often utilizing non-covalent interactions where an analyte displaces an indicator from a receptor, causing a detectable signal change (e.g., fluorescence or absorbance)."
    },
    {
      "difficulty_level": 2,
      "question": "What techniques are used to analyze Quinine?",
      "answer": "Quinine is analyzed by techniques including Electrochemical Technique, High Performance Liquid Chromatography (HPLC), Colorimetric Assay, Fluorescence Assay, and High Resolution Mass Spectrometry (HRMS)."
    },
    {
      "difficulty_level": 2,
      "question": "What are the components of an Indicator Displacement Assay?",
      "answer": "Components include beta-Cyclodextrin (beta-CD), Poly(N-acetylaniline), and Graphene."
    },
    {
      "difficulty_level": 3,
      "question": "Are there electrochemical sensors using Indicator Displacement Assay (IDA) to detect Quinine?",
      "answer": "The Electrochemical Sensor constructed via IDA (Indicator Displacement Assay) has the detection target Quinine."
    },
    {
      "difficulty_level": 3,
      "question": "Which host molecules use host-guest recognition in electrochemical assays?",
      "answer": "Host-Guest Recognition is integrated with an Electrochemical Sensor. Beta-Cyclodextrin (β-CD) is a host involved in Host-Guest Recognition."
    },
    {
      "difficulty_level": 4,
      "question": "How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?",
      "answer": "The Electrochemical Sensor has high stability (acceptable peak current decrease within 21 days, 86.47% retained) and good reproducibility (RSD of 2.06% across seven electrodes)."
    },
    {
      "difficulty_level": 4,
      "question": "How is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine verified?",
      "answer": "The Electrochemical Sensor is verified by Differential Pulse Voltammetry (DPV), Cyclic Voltammetry (CV), Proton Nuclear Magnetic Resonance (H_NMR), Scanning Electron Microscopy (SEM), Electrochemical Impedance Analysis (EIS), and Fourier Transform Infrared (FTIR)."
    },
    {
      "difficulty_level": 5,
      "question": "In the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine, how does Quinine displace Methylene Blue from beta-Cyclodextrin?",
      "answer": "Methylene Blue (MB) forms an inclusion complex with beta-Cyclodextrin (beta-CD). Quinine, having a higher binding affinity, competitively displaces MB from the beta-CD cavity. This displacement causes a change in the electrochemical signal (e.g., DPV peak current) which is used for Quinine detection. Poly(N-acetylaniline) inhibits non-specific adsorption of MB, contributing to the assay's selectivity."
    },
    {
      "difficulty_level": 5,
      "question": "What does Graphene do in the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?",
      "answer": "Graphene (specifically reduced graphene oxide, rGO) is used as an electrode material in the sensor. It enhances electron transfer properties due to its superior electrical conductivity and large specific surface area, improving the sensor's performance. It serves as a platform onto which other components like Poly(N-acetylaniline) and beta-Cyclodextrin are deposited."
    }
  ]
}

# %%
new_qas = [
  {
    "question": "What is a cryptand?",
    "query": "Retrieve the definition or description associated with the chemical class 'Cryptand'. Look for annotations like rdfs:comment, skos:definition, or specific meta-properties on the 'Cryptand' class definition.",
    "answer": "A cryptand is a type of macrocyclic ligand, specifically a supramolecular host, featuring a three-dimensional cavity that allows it to form stable complexes by encapsulating guest ions or molecules.",
    "difficulty_level": 1
  },
  {
    "question": "Is pyrrole considered an aromatic system?",
    "query": "Verify if an `rdfs:subClassOf` axiom exists where 'Pyrrole' is declared as a subclass of the 'AromaticSystem' class within the ontology.",
    "answer": "Yes, pyrrole is classified as an aromatic system.",
    "difficulty_level": 1
  },
  {
    "question": "What types of molecules typically act as guests for supramolecular hosts?",
    "query": "Identify the `rdfs:range` axiom defined for the object property 'binds_guest'. This indicates the general class of entities that can be bound by entities that are in the domain of 'binds_guest' (typically 'SupramolecularHost').",
    "answer": "Typically, molecules classified as 'GuestMolecule' (which can include anions, cations, or neutral molecules) act as guests for supramolecular hosts.",
    "difficulty_level": 2
  },
  {
    "question": "What are some specific types of macrocycles?",
    "query": "List all `owl:Class` entities for which an `rdfs:subClassOf` axiom exists, explicitly stating 'Macrocycle' as the direct parent class.",
    "answer": "Specific types of macrocycles include cryptands, calixarenes, pillararenes, and cyclodextrins.",
    "difficulty_level": 2
  },
  {
    "question": "When a calixarene containing pyrrole groups binds an anion, what specific non-covalent interactions are typically involved?",
    "query": "Analyze OWL axioms or property restrictions associated with the 'Calixarene' class, particularly when it 'has_functional_group' 'Pyrrole' and 'binds_guest' an 'Anion'. Identify the specific subclasses of 'InteractionType' (e.g., 'HydrogenBond', 'AnionPiInteraction') that are linked via 'interacts_via' in these defined scenarios.",
    "answer": "When a calixarene containing pyrrole groups binds an anion, non-covalent interactions such as HydrogenBond (often from the pyrrole NH) and AnionPiInteraction (between the anion and the pyrrole ring) are typically involved.",
    "difficulty_level": 3
  },
  {
    "question": "Are there known supramolecular hosts that are derivatives of calixarenes and also feature pyrrole functional groups?",
    "query": "Search for 'SupramolecularHost' classes or typical instances that are described as being 'is_derivative_of' the 'Calixarene' class AND are also associated with the 'Pyrrole' class via the 'has_functional_group' property.",
    "answer": "Yes, supramolecular hosts that are derivatives of calixarenes and feature pyrrole functional groups are known, a prominent example being calix[n]pyrroles.",
    "difficulty_level": 3
  },
  {
    "question": "What are common applications for cage molecules compared to macrocycles, and do they have any overlapping uses?",
    "query": "1. Identify 'Application' subclasses (e.g., 'Sensing', 'Catalysis', 'DrugDelivery', 'Separation') linked to the 'CageMolecule' class via the 'has_application' property (possibly through class axioms or restrictions). 2. Perform the same analysis for the 'Macrocycle' class. 3. Compare these sets of 'Application' subclasses to identify distinct and common areas.",
    "answer": "Cage molecules are commonly utilized in applications like catalysis and chemical separation. Macrocycles frequently find use in areas such as molecular sensing and drug delivery. An example of an overlapping application could be sensing, where both classes of compounds might be employed.",
    "difficulty_level": 4
  },
  {
    "question": "What types of supramolecular hosts are known to bind anions primarily through anion-π interactions?",
    "query": "Find 'SupramolecularHost' subclasses or characteristic descriptions where OWL axioms (e.g., `owl:equivalentClass` or `rdfs:subClassOf` involving restrictions on 'binds_guest' with 'Anion', and 'interacts_via' with 'AnionPiInteraction') define this specific binding mode.",
    "answer": "Supramolecular hosts that possess electron-deficient aromatic systems, such as certain calixarene derivatives (like calix[n]pyrroles) or other specifically designed π-acidic macrocycles, are known to bind anions primarily through AnionPiInteraction.",
    "difficulty_level": 4
  },
  {
    "question": "Why are supramolecular hosts containing pyrrole units generally effective at binding anions?",
    "query": "Analyze the defined properties of the 'Pyrrole' class (e.g., its classification as an 'AromaticSystem', its NH group) and its typical involvement in 'InteractionType' classes like 'HydrogenBond' and 'AnionPiInteraction' when 'Pyrrole' is a 'FunctionalGroup' of a 'SupramolecularHost' binding an 'Anion'. Synthesize an explanation for this effectiveness based on these defined chemical characteristics and interaction capabilities.",
    "answer": "Supramolecular hosts with pyrrole units are effective for anion binding due to two main features of pyrrole: its NH group can act as a hydrogen bond donor, forming HydrogenBond interactions with anions, and its electron-deficient aromatic π-system can engage in favorable AnionPiInteractions with anions. This combination enhances binding affinity and selectivity.",
    "difficulty_level": 5
  },
  {
    "question": "What is the role of non-covalent interactions like hydrogen bonds and anion-π interactions in the formation of supramolecular host-guest complexes?",
    "query": "Examine how 'InteractionType' subclasses (e.g., 'HydrogenBond', 'AnionPiInteraction') are axiomatically linked via the 'interacts_via' property in scenarios where 'SupramolecularHost' classes bind 'GuestMolecule' classes (often described by 'binds_guest' relationships). Summarize their function based on these defined ontological roles.",
    "answer": "Non-covalent interactions, such as hydrogen bonds and anion-π interactions, are crucial for molecular recognition between hosts and guests. They act as the primary driving forces that determine the stability, selectivity, and overall formation of supramolecular host-guest complexes.",
    "difficulty_level": 5
  }
]

# %%
IDA_qas = [
    {
    "question": "Regarding the system described in the paragraph below, please first attempt to verify if it is a documented Indicator Displacement Assay (IDA) system. If it cannot be directly confirmed, then provide an assessment of its potential to function as an IDA system based on the given details.\nThis chemical system utilizes WP6, a water-soluble carboxylato pillar[6]arene, as the synthetic receptor, belonging to the pillararene macrocycle family. Safranine T (ST), a phenazine-based dye, serves as the fluorophore indicator. Caffeine, a xanthine alkaloid, is the selected analyte competitor. This setup suggests a host-guest system designed for molecular recognition of Caffeine by the WP6 receptor, with binding events monitored through changes in the fluorescence of Safranine T."
  },
  {
    "question": "Regarding the system described in the paragraph below, please first attempt to verify if it is a documented Indicator Displacement Assay (IDA) system. If it cannot be directly confirmed, then provide an assessment of its potential to function as an IDA system based on the given details.\nThe image displays a supramolecular assembly featuring β-cyclodextrin (β-CD), a cyclic oligosaccharide, as the synthetic receptor. Methylene Blue (MB), a well-known phenothiazine dye, acts as the fluorophore indicator. Quinine, a quinoline-derived alkaloid, is presented as the selected analyte competitor. This system is characteristic of host-guest chemistry aimed at studying the interaction between β-cyclodextrin and Quinine, where Methylene Blue signals the binding or displacement."
  },
  {
    "question": "Regarding the system described in the paragraph below, please first attempt to verify if it is a documented Indicator Displacement Assay (IDA) system. If it cannot be directly confirmed, then provide an assessment of its potential to function as an IDA system based on the given details.\nThis chemical architecture involves a synthetic receptor TCC, which is a resorcinarene-based cavitand functionalized with four imidazole-acetic acid sodium salt arms. The fluorophore indicator is DSMI, a styryl-pyridinium dye. The selected analyte competitor, labeled 'Choline(Cho)' but structurally depicted as Acetylcholine, is a quaternary ammonium ester. This system is likely designed for the molecular recognition of Acetylcholine by the TCC receptor, with interactions reported by the DSMI fluorescent probe."
  },
  {
    "question": "Regarding the system described in the paragraph below, please first attempt to verify if it is a documented Indicator Displacement Assay (IDA) system. If it cannot be directly confirmed, then provide an assessment of its potential to function as an IDA system based on the given details.\nThe synthetic receptor in this system is TCC, specified as a macrocyclic cavitand with R1 groups being CH2CO2Na (carboxymethyl sodium salt) and R2 groups being Et (ethyl) on its benzimidazole units. DTMI, a cyanine-type styryl benzothiazole dye (with iodide as counterion), functions as the fluorophore indicator. Butyrylcholine (Bucho), an ester of choline, serves as the selected analyte competitor. This assembly is designed for investigating the host-guest interactions between the specific TCC receptor and Butyrylcholine, using the DTMI dye to signal these events."
  },
  {
    "question": "Regarding the system described in the paragraph below, please first attempt to verify if it is a documented Indicator Displacement Assay (IDA) system. If it cannot be directly confirmed, then provide an assessment of its potential to function as an IDA system based on the given details.\nThis chemical system features Cucurbit[8]uril, abbreviated as CB[8], acting as a synthetic receptor from the cucurbituril family. The system employs Proflavine, or PF, an acridine dye, as the fluorophore indicator. Gefitinib, labeled GEF, an anilinoquinazoline compound and EGFR inhibitor, is the selected analyte competitor. This assembly is characteristic of a supramolecular host-guest system designed for molecular recognition studies, where CB[8] interacts with Gefitinib, and this interaction is potentially signaled by changes in the fluorescence of Proflavine, possibly through competitive binding or allosteric effects."
  },
  {
    "question": "Regarding the system described in the paragraph below, please first attempt to verify if it is a documented Indicator Displacement Assay (IDA) system. If it cannot be directly confirmed, then provide an assessment of its potential to function as an IDA system based on the given details.\nThis image depicts a supramolecular assembly involving Cucurbit[8]uril (CB[8]) as a synthetic receptor, which is a macrocyclic host compound. Methylene Blue (MB), a phenothiazine dye, functions as the fluorophore indicator. Amantadine (AMA), an antiviral drug with a tricyclic adamantane structure, serves as the selected analyte competitor. The system suggests a host-guest chemistry approach for the potential detection or binding study of Amantadine with Cucurbit[8]uril, utilizing the signaling properties of Methylene Blue."
  },
  {
    "question": "Regarding the system described in the paragraph below, please first attempt to verify if it is a documented Indicator Displacement Assay (IDA) system. If it cannot be directly confirmed, then provide an assessment of its potential to function as an IDA system based on the given details.\nThe chemical architecture shown consists of p-sulfonatocalix[4]arene, or SCX4, a macrocyclic compound from the calixarene family, acting as the synthetic receptor. An Acridine dye, shown in its protonated form (AcH$^+$), is utilized as the fluorophore indicator. Acetylcholine (AcCh), a neurotransmitter, is presented as the selected analyte competitor. This setup describes a potential sensing ensemble where the p-sulfonatocalix[4]arene receptor binds Acetylcholine, and this molecular recognition event is reported by changes in the fluorescence characteristics of the Acridine dye."
  },
]

# %%
fake_ida_qas = [
  {
    "question": "Regarding the system described in the paragraph below, please first attempt to verify if it is a documented Indicator Displacement Assay (IDA) system. If it cannot be directly confirmed, then provide an assessment of its potential to function as an IDA system based on the given details.\nThis chemical system features Cucurbit[8]uril (CB[8]) as the synthetic receptor, a member of the cucurbituril macrocycle family. The fluorophore indicator is Safranine T (ST), a phenazine-based dye. Acetylcholine (AcCh), a neurotransmitter, is presented as the selected analyte competitor. This assembly suggests a host-guest system designed for the molecular recognition of Acetylcholine by the CB[8] receptor, with binding events monitored through changes in the fluorescence of Safranine T.\nYou should carefully analyze the binding affinities of both the indicator and the competitor to the host, and critically assess whether the given combination is truly capable of displacement. Please maintain sufficient neutrality and caution in your evaluation. You may consult reported binding affinities or documented cases involving the relevant host and guest molecules to support your analysis, or make reasoned predictions based on molecular structure, querying any necessary information for your inference chain."
  },
  {
    "question": "Regarding the system described in the paragraph below, please first attempt to verify if it is a documented Indicator Displacement Assay (IDA) system. If it cannot be directly confirmed, then provide an assessment of its potential to function as an IDA system based on the given details.\nThis system utilizes a water-soluble carboxylato pillar[6]arene (WP6) as the synthetic receptor. The fluorophore indicator is DSMI, a styryl-pyridinium dye. The selected analyte competitor is Amantadine (AMA), an antiviral drug with an adamantane structure. The setup describes a potential sensing ensemble where the WP6 receptor binds Amantadine, and this molecular recognition event is reported by the DSMI fluorescent probe.\nYou should carefully analyze the binding affinities of both the indicator and the competitor to the host, and critically assess whether the given combination is truly capable of displacement. Please maintain sufficient neutrality and caution in your evaluation. You may consult reported binding affinities or documented cases involving the relevant host and guest molecules to support your analysis, or make reasoned predictions based on molecular structure, querying any necessary information for your inference chain."
  },
  {
    "question": "Regarding the system described in the paragraph below, please first attempt to verify if it is a documented Indicator Displacement Assay (IDA) system. If it cannot be directly confirmed, then provide an assessment of its potential to function as an IDA system based on the given details.\nThis chemical architecture employs a water-soluble carboxylato pillar[6]arene, WP6, as the synthetic receptor. Safranine T (ST), a phenazine-based dye, acts as the fluorophore indicator. Gefitinib (GEF), an anilinoquinazoline compound, serves as the selected analyte competitor. The system suggests a host-guest chemistry approach for the potential detection or binding study of Gefitinib with the WP6 host, using the signaling properties of Safranine T.\nYou should carefully analyze the binding affinities of both the indicator and the competitor to the host, and critically assess whether the given combination is truly capable of displacement. Please maintain sufficient neutrality and caution in your evaluation. You may consult reported binding affinities or documented cases involving the relevant host and guest molecules to support your analysis, or make reasoned predictions based on molecular structure, querying any necessary information for your inference chain."
  },
  {
    "question": "Regarding the system described in the paragraph below, please first attempt to verify if it is a documented Indicator Displacement Assay (IDA) system. If it cannot be directly confirmed, then provide an assessment of its potential to function as an IDA system based on the given details.\nThe image displays a supramolecular assembly featuring p-sulfonatocalix[4]arene (SCX4), a macrocyclic host, as the synthetic receptor. An Acridine dye (AcH$^+$) is utilized as the fluorophore indicator. Caffeine, a xanthine alkaloid, is presented as the selected analyte competitor. This system is characteristic of host-guest chemistry aimed at studying the interaction between SCX4 and Caffeine, where the Acridine dye signals the binding or displacement.\nYou should carefully analyze the binding affinities of both the indicator and the competitor to the host, and critically assess whether the given combination is truly capable of displacement. Please maintain sufficient neutrality and caution in your evaluation. You may consult reported binding affinities or documented cases involving the relevant host and guest molecules to support your analysis, or make reasoned predictions based on molecular structure, querying any necessary information for your inference chain."
  },
  {
    "question": "Regarding the system described in the paragraph below, please first attempt to verify if it is a documented Indicator Displacement Assay (IDA) system. If it cannot be directly confirmed, then provide an assessment of its potential to function as an IDA system based on the given details.\nThis chemical system features Cucurbit[8]uril (CB[8]) acting as the synthetic receptor. The fluorophore indicator for this assembly is Gefitinib (GEF), an EGFR inhibitor. The selected analyte competitor is Proflavine (PF), an acridine dye. This setup describes a potential supramolecular system for the recognition of Gefitinib by the CB[8] host, where binding events would be reported through the fluorescent response of Proflavine.\nYou should carefully analyze the binding affinities of both the indicator and the competitor to the host, and critically assess whether the given combination is truly capable of displacement. Please maintain sufficient neutrality and caution in your evaluation. You may consult reported binding affinities or documented cases involving the relevant host and guest molecules to support your analysis, or make reasoned predictions based on molecular structure, querying any necessary information for your inference chain."
  },
  {
    "question": "Regarding the system described in the paragraph below, please first attempt to verify if it is a documented Indicator Displacement Assay (IDA) system. If it cannot be directly confirmed, then provide an assessment of its potential to function as an IDA system based on the given details.\nThis system is based on a water-soluble carboxylato pillar[6]arene (WP6) acting as the synthetic receptor. The fluorophore indicator is Caffeine, a well-known xanthine alkaloid. The selected analyte competitor is Safranine T (ST), a phenazine dye. This assembly suggests a potential host-guest sensor where the WP6 macrocycle binds to Caffeine, and this interaction is signaled by changes in the fluorescence of the Safranine T indicator.\nYou should carefully analyze the binding affinities of both the indicator and the competitor to the host, and critically assess whether the given combination is truly capable of displacement. Please maintain sufficient neutrality and caution in your evaluation. You may consult reported binding affinities or documented cases involving the relevant host and guest molecules to support your analysis, or make reasoned predictions based on molecular structure, querying any necessary information for your inference chain."
  }
]

# %%
expert_qas = [
    {
        "question": "What types of molecules can be detected by IDA?"
    },
    {
        "question": "What types of host-guest interaction can be used to design IDA-based electrochemical sensors?"
    },
    {
        "question": "What types of host-guest interaction can be used to design IDA using optical detection?"
    },
    {
        "question": "What types of host-guest interaction can induce changes in optical signals?"
    },
    {
        "question": "What types of host-guest interaction can induce changes in electrochemical signals?"
    },
    {
        "question": "What types of supramolecular hosts are known to bind to their guests primarily through cation-π interactions?"
    },
    {
        "question": "What are the main factors controlling host-guest interaction?"
    }
]

# %%
total_qas = [
    {
      "difficulty_level": 1,
      "question": "Tell me about Quinine.",
      "answer": "Quinine is an alkaloid derived from cinchona tree bark, used historically for malaria and now as a bittering agent, but associated with adverse health effects like thrombocytopenia."
    },
    {
      "difficulty_level": 1,
      "question": "What is an Indicator Displacement Assay?",
      "answer": "An IDA is a sensing strategy based on host-guest recognition, often utilizing non-covalent interactions where an analyte displaces an indicator from a receptor, causing a detectable signal change (e.g., fluorescence or absorbance)."
    },
    {
      "difficulty_level": 2,
      "question": "What techniques are used to analyze Quinine?",
      "answer": "Quinine is analyzed by techniques including Electrochemical Technique, High Performance Liquid Chromatography (HPLC), Colorimetric Assay, Fluorescence Assay, and High Resolution Mass Spectrometry (HRMS)."
    },
    {
      "difficulty_level": 2,
      "question": "What are the components of an Indicator Displacement Assay?",
      "answer": "Components include beta-Cyclodextrin (beta-CD), Poly(N-acetylaniline), and Graphene."
    },
    {
      "difficulty_level": 3,
      "question": "Are there electrochemical sensors using Indicator Displacement Assay (IDA) to detect Quinine?",
      "answer": "The Electrochemical Sensor constructed via IDA (Indicator Displacement Assay) has the detection target Quinine."
    },
    {
      "difficulty_level": 3,
      "question": "Which host molecules use host-guest recognition in electrochemical assays?",
      "answer": "Host-Guest Recognition is integrated with an Electrochemical Sensor. Beta-Cyclodextrin (β-CD) is a host involved in Host-Guest Recognition."
    },
    {
      "difficulty_level": 4,
      "question": "How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?",
      "answer": "The Electrochemical Sensor has high stability (acceptable peak current decrease within 21 days, 86.47% retained) and good reproducibility (RSD of 2.06% across seven electrodes)."
    },
    {
      "difficulty_level": 4,
      "question": "How is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine verified?",
      "answer": "The Electrochemical Sensor is verified by Differential Pulse Voltammetry (DPV), Cyclic Voltammetry (CV), Proton Nuclear Magnetic Resonance (H_NMR), Scanning Electron Microscopy (SEM), Electrochemical Impedance Analysis (EIS), and Fourier Transform Infrared (FTIR)."
    },
    {
      "difficulty_level": 5,
      "question": "In the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine, how does Quinine displace Methylene Blue from beta-Cyclodextrin?",
      "answer": "Methylene Blue (MB) forms an inclusion complex with beta-Cyclodextrin (beta-CD). Quinine, having a higher binding affinity, competitively displaces MB from the beta-CD cavity. This displacement causes a change in the electrochemical signal (e.g., DPV peak current) which is used for Quinine detection. Poly(N-acetylaniline) inhibits non-specific adsorption of MB, contributing to the assay's selectivity."
    },
    {
      "difficulty_level": 5,
      "question": "What does Graphene do in the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?",
      "answer": "Graphene (specifically reduced graphene oxide, rGO) is used as an electrode material in the sensor. It enhances electron transfer properties due to its superior electrical conductivity and large specific surface area, improving the sensor's performance. It serves as a platform onto which other components like Poly(N-acetylaniline) and beta-Cyclodextrin are deposited."
    },
    {
    "question": "What is a cryptand?",
    "query": "Retrieve the definition or description associated with the chemical class 'Cryptand'. Look for annotations like rdfs:comment, skos:definition, or specific meta-properties on the 'Cryptand' class definition.",
    "answer": "A cryptand is a type of macrocyclic ligand, specifically a supramolecular host, featuring a three-dimensional cavity that allows it to form stable complexes by encapsulating guest ions or molecules.",
    "difficulty_level": 1
  },
  {
    "question": "Is pyrrole considered an aromatic system?",
    "query": "Verify if an `rdfs:subClassOf` axiom exists where 'Pyrrole' is declared as a subclass of the 'AromaticSystem' class within the ontology.",
    "answer": "Yes, pyrrole is classified as an aromatic system.",
    "difficulty_level": 1
  },
  {
    "question": "What types of molecules typically act as guests for supramolecular hosts?",
    "query": "Identify the `rdfs:range` axiom defined for the object property 'binds_guest'. This indicates the general class of entities that can be bound by entities that are in the domain of 'binds_guest' (typically 'SupramolecularHost').",
    "answer": "Typically, molecules classified as 'GuestMolecule' (which can include anions, cations, or neutral molecules) act as guests for supramolecular hosts.",
    "difficulty_level": 2
  },
  {
    "question": "What are some specific types of macrocycles?",
    "query": "List all `owl:Class` entities for which an `rdfs:subClassOf` axiom exists, explicitly stating 'Macrocycle' as the direct parent class.",
    "answer": "Specific types of macrocycles include cryptands, calixarenes, pillararenes, and cyclodextrins.",
    "difficulty_level": 2
  },
  {
    "question": "When a calixarene containing pyrrole groups binds an anion, what specific non-covalent interactions are typically involved?",
    "query": "Analyze OWL axioms or property restrictions associated with the 'Calixarene' class, particularly when it 'has_functional_group' 'Pyrrole' and 'binds_guest' an 'Anion'. Identify the specific subclasses of 'InteractionType' (e.g., 'HydrogenBond', 'AnionPiInteraction') that are linked via 'interacts_via' in these defined scenarios.",
    "answer": "When a calixarene containing pyrrole groups binds an anion, non-covalent interactions such as HydrogenBond (often from the pyrrole NH) and AnionPiInteraction (between the anion and the pyrrole ring) are typically involved.",
    "difficulty_level": 3
  },
  {
    "question": "Are there known supramolecular hosts that are derivatives of calixarenes and also feature pyrrole functional groups?",
    "query": "Search for 'SupramolecularHost' classes or typical instances that are described as being 'is_derivative_of' the 'Calixarene' class AND are also associated with the 'Pyrrole' class via the 'has_functional_group' property.",
    "answer": "Yes, supramolecular hosts that are derivatives of calixarenes and feature pyrrole functional groups are known, a prominent example being calix[n]pyrroles.",
    "difficulty_level": 3
  },
  {
    "question": "What are common applications for cage molecules compared to macrocycles, and do they have any overlapping uses?",
    "query": "1. Identify 'Application' subclasses (e.g., 'Sensing', 'Catalysis', 'DrugDelivery', 'Separation') linked to the 'CageMolecule' class via the 'has_application' property (possibly through class axioms or restrictions). 2. Perform the same analysis for the 'Macrocycle' class. 3. Compare these sets of 'Application' subclasses to identify distinct and common areas.",
    "answer": "Cage molecules are commonly utilized in applications like catalysis and chemical separation. Macrocycles frequently find use in areas such as molecular sensing and drug delivery. An example of an overlapping application could be sensing, where both classes of compounds might be employed.",
    "difficulty_level": 4
  },
  {
    "question": "What types of supramolecular hosts are known to bind anions primarily through anion-π interactions?",
    "query": "Find 'SupramolecularHost' subclasses or characteristic descriptions where OWL axioms (e.g., `owl:equivalentClass` or `rdfs:subClassOf` involving restrictions on 'binds_guest' with 'Anion', and 'interacts_via' with 'AnionPiInteraction') define this specific binding mode.",
    "answer": "Supramolecular hosts that possess electron-deficient aromatic systems, such as certain calixarene derivatives (like calix[n]pyrroles) or other specifically designed π-acidic macrocycles, are known to bind anions primarily through AnionPiInteraction.",
    "difficulty_level": 4
  },
  {
    "question": "Why are supramolecular hosts containing pyrrole units generally effective at binding anions?",
    "query": "Analyze the defined properties of the 'Pyrrole' class (e.g., its classification as an 'AromaticSystem', its NH group) and its typical involvement in 'InteractionType' classes like 'HydrogenBond' and 'AnionPiInteraction' when 'Pyrrole' is a 'FunctionalGroup' of a 'SupramolecularHost' binding an 'Anion'. Synthesize an explanation for this effectiveness based on these defined chemical characteristics and interaction capabilities.",
    "answer": "Supramolecular hosts with pyrrole units are effective for anion binding due to two main features of pyrrole: its NH group can act as a hydrogen bond donor, forming HydrogenBond interactions with anions, and its electron-deficient aromatic π-system can engage in favorable AnionPiInteractions with anions. This combination enhances binding affinity and selectivity.",
    "difficulty_level": 5
  },
  {
    "question": "What is the role of non-covalent interactions like hydrogen bonds and anion-π interactions in the formation of supramolecular host-guest complexes?",
    "query": "Examine how 'InteractionType' subclasses (e.g., 'HydrogenBond', 'AnionPiInteraction') are axiomatically linked via the 'interacts_via' property in scenarios where 'SupramolecularHost' classes bind 'GuestMolecule' classes (often described by 'binds_guest' relationships). Summarize their function based on these defined ontological roles.",
    "answer": "Non-covalent interactions, such as hydrogen bonds and anion-π interactions, are crucial for molecular recognition between hosts and guests. They act as the primary driving forces that determine the stability, selectivity, and overall formation of supramolecular host-guest complexes.",
    "difficulty_level": 5
  },
  {
        "question": "What types of molecules can be detected by IDA?"
    },
    {
        "question": "What types of host-guest interaction can be used to design IDA-based electrochemical sensors?"
    },
    {
        "question": "What types of host-guest interaction can be used to design IDA using optical detection?"
    },
    {
        "question": "What types of host-guest interaction can induce changes in optical signals?"
    },
    {
        "question": "What types of host-guest interaction can induce changes in electrochemical signals?"
    },
    {
        "question": "What types of supramolecular hosts are known to bind to their guests primarily through cation-π interactions?"
    },
    {
        "question": "What are the main factors controlling host-guest interaction?"
    }
]

# %%
import json

def generate_questions_from_config(config_path='IDA.json'):
    """
    从JSON配置文件加载所有数据并生成多选题。
    """
    # 1. 读取并解析JSON配置文件
    try:
        with open(config_path, 'r', encoding='utf-8') as f:
            config = json.load(f)
    except FileNotFoundError:
        print(f"错误：配置文件 '{config_path}' 未找到。")
        return
    except json.JSONDecodeError as e:
        print(f"错误：配置文件 '{config_path}' 格式不正确，请检查JSON语法。\n{e}")
        return

    # 2. 从配置中提取数据
    # 直接使用模板字符串，不再需要join
    question_template = config.get('template')
    descriptions = config.get('descriptions', {})
    combinations = config.get('combinations', [])

    if not all([question_template, descriptions, combinations]):
        print("错误：配置文件中缺少 'template', 'descriptions', 或 'combinations' 的数据。")
        return

    # 3. 循环并生成题目
    generated_questions = []
    for i, combo in enumerate(combinations):
        question_number = i + 1
        
        # 从描述字典中获取全名和描述
        def get_desc(key):
            return descriptions.get(key, f"【描述未找到: {key}】")

        host_name = get_desc(combo['host'])
        indicator_name = get_desc(combo['indicator'])
        analyte_name = get_desc(combo['analyte'])

        unknown_role = combo['unknown'].capitalize() # e.g., "Analyte"
        
        # 动态确定已知和未知组件
        components = {
            "Host": f"{host_name} (Host A)",
            "Indicator": f"{indicator_name} (Indicator B)",
            "Analyte": f"{analyte_name} (Analyte C)"
        }
        
        # 移除未知的那个，剩下就是已知的
        known_components = [v for k, v in components.items() if k != unknown_role]
        
        # 生成选项列表
        option_texts = []
        for opt_key in combo['options']:
            option_texts.append(f"* {get_desc(opt_key)}")
        options_str = "\n".join(option_texts)

        # 填充模板
        full_question = question_template.format(
            question_number=f" #{question_number}",
            known_comp1_name_and_role=known_components[0],
            known_comp2_name_and_role=known_components[1],
            unknown_comp_role=f"{unknown_role} ({components[unknown_role][-2]})", # e.g., "Analyte (C)"
            options=options_str
        )
        generated_questions.append(full_question)

    # 4. 保存结果到文件
    output_filename = 'generated_ida_questions.md' # 保存为.md文件，格式更美观
    try:
        with open(output_filename, 'w', encoding='utf-8') as f:
            for i, question in enumerate(generated_questions):
                f.write(question)
                # 在每个问题后添加分页符，以便打印或分隔
                if i < len(generated_questions) - 1:
                    f.write("\n\n---\n\n")
        
        print(f"任务完成！成功生成 {len(generated_questions)} 道题目。")
        print(f"结果已保存到文件: '{output_filename}'")
    # 将 generated_questions 序列化为文件，便于后续加载和使用
        serialized_filename = 'generated_ida_questions.json'
        try:
            with open(serialized_filename, 'w', encoding='utf-8') as f_json:
                json.dump(generated_questions, f_json, ensure_ascii=False, indent=2)
            print(f"已将 generated_questions 序列化保存到: '{serialized_filename}'")
        except Exception as e:
            print(f"序列化 generated_questions 时出错: {e}")
    except IOError as e:
        print(f"错误：无法写入输出文件。原因: {e}")

    return generated_questions


# --- 主程序入口 ---
# if __name__ == '__main__':
#     generate_questions_from_config()
ida_choice = generate_questions_from_config()
# Out:
# 任务完成！成功生成 21 道题目。
# 结果已保存到文件: 'generated_ida_questions.md'
# 已将 generated_questions 序列化保存到: 'generated_ida_questions.json'

# %%
queries = ida_choice
revised_queries = ida_choice
query_context = {
    "ontology": test_ontology_settings,
    "originating_team": "test_notebook",
    "originating_stage": "manual_test",
    "query_type": "analytical_reasoning" # 对所有查询使用信息检索类型
}

# %%
num = 10
# 定义新的十个查询
queries = [item["question"] for item in qas["question_format_QA"][:num]]

revised_queries = [item["question"] for item in qas["question_format_QA"][:num]]

# 为所有查询定义统一的上下文
query_context = {
    "ontology": test_ontology_settings,
    "originating_team": "test_notebook",
    "originating_stage": "manual_test",
    "query_type": "information_retrieval" # 对所有查询使用信息检索类型
}

print(len(queries),len(revised_queries))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 num = 10
#       2 # 定义新的十个查询
# ----> 3 queries = [item["question"] for item in qas["question_format_QA"][:num]]
#       5 revised_queries = [item["question"] for item in qas["question_format_QA"][:num]]
#       7 # 为所有查询定义统一的上下文
#
# NameError: name 'qas' is not defined

# %%
temp_qas = total_qas

num = len(temp_qas)

queries = [item["question"] for item in temp_qas[:num]]

revised_queries = [item["question"] for item in temp_qas[:num]]

query_context = {
    "ontology": test_ontology_settings,
    "originating_team": "test_notebook",
    "originating_stage": "manual_test",
    "query_type": "information_retrieval" # 对所有查询使用信息检索类型
}

print(len(queries),len(revised_queries))
# Out:
# 27 27

# %%
queries = [queries[6]]

revised_queries = [revised_queries[6]]

print(len(queries),len(revised_queries))
# Out:
# 1 1

# %%
from sparkai.llm.llm import ChatSparkLLM, ChunkPrintHandler
from sparkai.core.messages import ChatMessage

#星火认知大模型Spark Max的URL值，其他版本大模型URL值请前往文档（https://www.xfyun.cn/doc/spark/Web.html）查看
SPARKAI_URL = 'wss://spark-openapi-n.cn-huabei-1.xf-yun.com/v1.1/chat'
#星火认知大模型调用秘钥信息，请前往讯飞开放平台控制台（https://console.xfyun.cn/services/bm35）查看
SPARKAI_APP_ID = '82d8eb1c'
SPARKAI_API_SECRET = 'Yzc4MDNjOWRiZTI4OGMzYjgzYWRjZjZm'
SPARKAI_API_KEY = 'bfb2cf09d7b8789b154f7567a8bfed56'
#星火认知大模型Spark Max的domain值，其他版本大模型domain值请前往文档（https://www.xfyun.cn/doc/spark/Web.html）查看
SPARKAI_DOMAIN = 'chemistry'

spark = ChatSparkLLM(
    spark_api_url=SPARKAI_URL,
    spark_app_id=SPARKAI_APP_ID,
    spark_api_key=SPARKAI_API_KEY,
    spark_api_secret=SPARKAI_API_SECRET,
    spark_llm_domain=SPARKAI_DOMAIN,
    streaming=False,
)
handler = ChunkPrintHandler()

    
messages = [[ChatMessage(
    role="user",
    content=query
)] for query in queries]

messages
# Out:
# [[ChatMessage(content='Tell me about Quinine.', role='user')],
#  [ChatMessage(content='What is an Indicator Displacement Assay?', role='user')],
#  [ChatMessage(content='What techniques are used to analyze Quinine?', role='user')],
#  [ChatMessage(content='What are the components of an Indicator Displacement Assay?', role='user')],
#  [ChatMessage(content='Are there electrochemical sensors using Indicator Displacement Assay (IDA) to detect Quinine?', role='user')],
#  [ChatMessage(content='Which host molecules use host-guest recognition in electrochemical assays?', role='user')],
#  [ChatMessage(content='How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?', role='user')],
#  [ChatMessage(content='How is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine verified?', role='user')],
#  [ChatMessage(content='In the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine, how does Quinine displace Methylene Blue from beta-Cyclodextrin?', role='user')],
#  [ChatMessage(content='What does Graphene do in the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?', role='user')],
#  [ChatMessage(content='What is a cryptand?', role='user')],
#  [ChatMessage(content='Is pyrrole considered an aromatic system?', role='user')],
#  [ChatMessage(content='What types of molecules typically act as guests for supramolecular hosts?', role='user')],
#  [ChatMessage(content='What are some specific types of macrocycles?', role='user')],
#  [ChatMessage(content='When a calixarene containing pyrrole groups binds an anion, what specific non-covalent interactions are typically involved?', role='user')],
#  [ChatMessage(content='Are there known supramolecular hosts that are derivatives of calixarenes and also feature pyrrole functional groups?', role='user')],
#  [ChatMessage(content='What are common applications for cage molecules compared to macrocycles, and do they have any overlapping uses?', role='user')],
#  [ChatMessage(content='What types of supramolecular hosts are known to bind anions primarily through anion-π interactions?', role='user')],
#  [ChatMessage(content='Why are supramolecular hosts containing pyrrole units generally effective at binding anions?', role='user')],
#  [ChatMessage(content='What is the role of non-covalent interactions like hydrogen bonds and anion-π interactions in the formation of supramolecular host-guest complexes?', role='user')],
#  [ChatMessage(content='What types of molecules can be detected by IDA?', role='user')],
#  [ChatMessage(content='What types of host-guest interaction can be used to design IDA-based electrochemical sensors?', role='user')],
#  [ChatMessage(content='What types of host-guest interaction can be used to design IDA using optical detection?', role='user')],
#  [ChatMessage(content='What types of host-guest interaction can induce changes in optical signals?', role='user')],
#  [ChatMessage(content='What types of host-guest interaction can induce changes in electrochemical signals?', role='user')],
#  [ChatMessage(content='What types of supramolecular hosts are known to bind to their guests primarily through cation-π interactions?', role='user')],
#  [ChatMessage(content='What are the main factors controlling host-guest interaction?', role='user')]]

# %%
msg = messages[0]
response = spark.generate([msg], callbacks=[handler])
print(response.generations[0][0].text)
# Out:
# nine is a natural from the bark of the been used for centuries as an anti isolated in 1848 by but its use is limited due to sideus (ringing in the ears), visual disturbances, and cardiac arrhythmias.

# %%
print(response.generations[0][0].text)
# Out:
# A cryptand is a containing several donor atoms form complexes with cations by encap Cryptands are often used agents in chemical reactions.

# %%
query_response_pairs = []

for i, msg in enumerate(messages):
    response = spark.generate([msg], callbacks=[handler])
    query_response_pairs.append({
        "query": queries[i],
        "response": response
    })
    print(f"query: {queries[i]}")
query_response_pairs
# Out:
# query: Tell me about Quinine.
# query: What is an Indicator Displacement Assay?
# query: What techniques are used to analyze Quinine?
# query: What are the components of an Indicator Displacement Assay?
# query: Are there electrochemical sensors using Indicator Displacement Assay (IDA) to detect Quinine?
# query: Which host molecules use host-guest recognition in electrochemical assays?
# query: How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?
# query: How is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine verified?
# query: In the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine, how does Quinine displace Methylene Blue from beta-Cyclodextrin?
# query: What does Graphene do in the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?
# query: What is a cryptand?
# query: Is pyrrole considered an aromatic system?
# query: What types of molecules typically act as guests for supramolecular hosts?
# query: What are some specific types of macrocycles?
# query: When a calixarene containing pyrrole groups binds an anion, what specific non-covalent interactions are typically involved?
# query: Are there known supramolecular hosts that are derivatives of calixarenes and also feature pyrrole functional groups?
# query: What are common applications for cage molecules compared to macrocycles, and do they have any overlapping uses?
# query: What types of supramolecular hosts are known to bind anions primarily through anion-π interactions?
# query: Why are supramolecular hosts containing pyrrole units generally effective at binding anions?
# query: What is the role of non-covalent interactions like hydrogen bonds and anion-π interactions in the formation of supramolecular host-guest complexes?
# query: What types of molecules can be detected by IDA?
# query: What types of host-guest interaction can be used to design IDA-based electrochemical sensors?
# query: What types of host-guest interaction can be used to design IDA using optical detection?
# query: What types of host-guest interaction can induce changes in optical signals?
# query: What types of host-guest interaction can induce changes in electrochemical signals?
# query: What types of supramolecular hosts are known to bind to their guests primarily through cation-π interactions?
# query: What are the main factors controlling host-guest interaction?
# [{'query': 'Tell me about Quinine.',
#   'response': LLMResult(generations=[[ChatGeneration(text='nine is an al bark of the South American was first isolated in 1848 and has been used to treatth century. Quinine is also found in tonic water, which was originally developed as a means of delivering \nThe therapeutic effects of quinine are due to its ability to kill the. Quinine works by interfering with the parasite’s ability to digest hemoglobin, which is necessary for its survival. This causes the parasite to die and be eliminated from the body.\n\nIn addition to itsquinine has also been studied for its potential benefits in treating other conditions such as arthritis, lupus, and nocturnal leg cramps. However, more research is needed before about these potential uses.', message=AIMessage(content='nine is an al bark of the South American was first isolated in 1848 and has been used to treatth century. Quinine is also found in tonic water, which was originally developed as a means of delivering \nThe therapeutic effects of quinine are due to its ability to kill the. Quinine works by interfering with the parasite’s ability to digest hemoglobin, which is necessary for its survival. This causes the parasite to die and be eliminated from the body.\n\nIn addition to itsquinine has also been studied for its potential benefits in treating other conditions such as arthritis, lupus, and nocturnal leg cramps. However, more research is needed before about these potential uses.'))]], llm_output={'token_usage': {'question_tokens': 15, 'prompt_tokens': 15, 'completion_tokens': 210, 'total_tokens': 225}}, run=[RunInfo(run_id=UUID('e49a5832-eb61-4783-b073-0608d19d3b38'))])},
#  {'query': 'What is an Indicator Displacement Assay?',
#   'response': LLMResult(generations=[[ChatGeneration(text="An indicator displacement) is a type of biochemical assay used to measure the concentration of a target molecule in a sample. It involves the use of an indicator molecule that binds to the target molecule, causing a change in the indicator's properties, such as its absorbance or fluorescence. The amount of indicator bound to the target molecule can then be measured and used to calculate the concentration of the target molecule in the sample. This type of assay is commonly used for the detection and quantification.", message=AIMessage(content="An indicator displacement) is a type of biochemical assay used to measure the concentration of a target molecule in a sample. It involves the use of an indicator molecule that binds to the target molecule, causing a change in the indicator's properties, such as its absorbance or fluorescence. The amount of indicator bound to the target molecule can then be measured and used to calculate the concentration of the target molecule in the sample. This type of assay is commonly used for the detection and quantification."))]], llm_output={'token_usage': {'question_tokens': 20, 'prompt_tokens': 20, 'completion_tokens': 126, 'total_tokens': 146}}, run=[RunInfo(run_id=UUID('42650a00-a02f-4957-976b-9a0fd93a27fb'))])},
#  {'query': 'What techniques are used to analyze Quinine?',
#   'response': LLMResult(generations=[[ChatGeneration(text='The solution I propose is Spectrophotometry. Refer KDT 6/e p431 Quinoline ring gives UV absorption at 258nm which is used to estimate quinine content in tonic waters and bitters.', message=AIMessage(content='The solution I propose is Spectrophotometry. Refer KDT 6/e p431 Quinoline ring gives UV absorption at 258nm which is used to estimate quinine content in tonic waters and bitters.'))]], llm_output={'token_usage': {'question_tokens': 18, 'prompt_tokens': 18, 'completion_tokens': 53, 'total_tokens': 71}}, run=[RunInfo(run_id=UUID('405d05ec-4396-4c7b-8c8a-531b1da89f3b'))])},
#  {'query': 'What are the components of an Indicator Displacement Assay?',
#   'response': LLMResult(generations=[[ChatGeneration(text='Antor Displaced Assay ( used to determine the concentration of\n\n1. Analyte: The substance that is being measured or analyzed in the assay.\n\n2. color or fluorescence depending on the concentration. Displacer: A compound thatplaces the indicator, causing a change in color or fluorescence.\n\n4. Buffer: A solution that maintains the pH of the assay at a constant level.\n\n5. Reference solution: A solution with a to create a standard curve for comparison with the sample.\n\n6.  that is being analyzed.\n\n7. Cuvette: A small container used to hold the sample and reagents during the assay.\n\n8. Spectrophotometer: An instrument used to measure the absorbance or fluorescence of the sample and reference solution.', message=AIMessage(content='Antor Displaced Assay ( used to determine the concentration of\n\n1. Analyte: The substance that is being measured or analyzed in the assay.\n\n2. color or fluorescence depending on the concentration. Displacer: A compound thatplaces the indicator, causing a change in color or fluorescence.\n\n4. Buffer: A solution that maintains the pH of the assay at a constant level.\n\n5. Reference solution: A solution with a to create a standard curve for comparison with the sample.\n\n6.  that is being analyzed.\n\n7. Cuvette: A small container used to hold the sample and reagents during the assay.\n\n8. Spectrophotometer: An instrument used to measure the absorbance or fluorescence of the sample and reference solution.'))]], llm_output={'token_usage': {'question_tokens': 23, 'prompt_tokens': 23, 'completion_tokens': 237, 'total_tokens': 260}}, run=[RunInfo(run_id=UUID('e6840349-14f0-4892-956a-76144ca0b823'))])},
#  {'query': 'Are there electrochemical sensors using Indicator Displacement Assay (IDA) to detect Quinine?',
#   'response': LLMResult(generations=[[ChatGeneration(text='Yes, there are electrochemical sensors that use) to detect Quinine. One such sensor is based on a molecularly imprinted polymer (MIP) and an indicator displacement assay. The MIP is synthesized using methacrylic acid as the functional monomer and quinine as the template. The sensor is fabricated by modifying a glassy carbon electrode with a MIP layer and an electropolymerized polydopamine film. The sensor exhibits high selectivity and sensitivity for quinine detection in real samples. Another sensor uses a molecularlyped with multi-walled carbon nanotubes and fabricated on a glassy carbon electrode. The sensor is based on the indicator displacement assay and exhibits high selectivity and sensitivity for quinine detection in real samples.', message=AIMessage(content='Yes, there are electrochemical sensors that use) to detect Quinine. One such sensor is based on a molecularly imprinted polymer (MIP) and an indicator displacement assay. The MIP is synthesized using methacrylic acid as the functional monomer and quinine as the template. The sensor is fabricated by modifying a glassy carbon electrode with a MIP layer and an electropolymerized polydopamine film. The sensor exhibits high selectivity and sensitivity for quinine detection in real samples. Another sensor uses a molecularlyped with multi-walled carbon nanotubes and fabricated on a glassy carbon electrode. The sensor is based on the indicator displacement assay and exhibits high selectivity and sensitivity for quinine detection in real samples.'))]], llm_output={'token_usage': {'question_tokens': 33, 'prompt_tokens': 33, 'completion_tokens': 187, 'total_tokens': 220}}, run=[RunInfo(run_id=UUID('2b5fee9e-d25c-404c-9942-754a63fb1a1c'))])},
#  {'query': 'Which host molecules use host-guest recognition in electrochemical assays?',
#   'response': LLMResult(generations=[[ChatGeneration(text='As for my answer, itchemical assays is used by  cyclic oligosaccharides with a hydrophilic shell and a hydrophobic core that can host a variety of guest molecules. They have been used as pharmaceutical carriers, enzyme models, molecular receptors,  Supramolecular Chemistry (2013) By Jo, page 189', message=AIMessage(content='As for my answer, itchemical assays is used by  cyclic oligosaccharides with a hydrophilic shell and a hydrophobic core that can host a variety of guest molecules. They have been used as pharmaceutical carriers, enzyme models, molecular receptors,  Supramolecular Chemistry (2013) By Jo, page 189'))]], llm_output={'token_usage': {'question_tokens': 23, 'prompt_tokens': 23, 'completion_tokens': 131, 'total_tokens': 154}}, run=[RunInfo(run_id=UUID('94878852-5c5b-44a3-88e6-5ff859f2b0e8'))])},
#  {'query': 'How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?',
#   'response': LLMResult(generations=[[ChatGeneration(text="The stability and of an electrochemicaltor Displacement Assayinine depends on several factors, including the design of the sensor, the quality of the materials used, and the experimental conditions. \n\nIn general, electrochemical sensors can be quite stable-designed and fabricated with high-quality materials. The use of an selectivity and sensitivity, as it allows their ability to displace a colored indicator from a binding site. This approach can minimize interference from other substances that may be present in the sample.\n\n of the sensor can be affected by various factors, such as:\n\n1. Temperature: Changes in temperature can affect the electrochemical reactions and the indicator, leading to variations in the sensor's response.\n\n2. pH: The pH of the sample can influence the electrochemical properties of the sensor and the indicator. Maintaining acible results.\n\n3. Electrode surface: The cleanliness and condition of the electrode surface can impact the sensor's performance. Cont lead to changes in the electrochemical response of the sensor.\n\n4. Quality of materials: The quality of the materials used in the sensor, such as the working and reference electrodes, can. High-quality materials are more likely to provide consistent results over time.\n\n5. Calibration: Regular calibration of the sensor is measurements. Calibration should be performed using standard solutions with known concentrations of Quinine.\n\nIn summary, detecting Quinine depend on the sensor's design, materials, and, it is possible to achieve a stableine detection. However, it is essential to perform regular maintenance and calibration to ensure consistent performance over time.", message=AIMessage(content="The stability and of an electrochemicaltor Displacement Assayinine depends on several factors, including the design of the sensor, the quality of the materials used, and the experimental conditions. \n\nIn general, electrochemical sensors can be quite stable-designed and fabricated with high-quality materials. The use of an selectivity and sensitivity, as it allows their ability to displace a colored indicator from a binding site. This approach can minimize interference from other substances that may be present in the sample.\n\n of the sensor can be affected by various factors, such as:\n\n1. Temperature: Changes in temperature can affect the electrochemical reactions and the indicator, leading to variations in the sensor's response.\n\n2. pH: The pH of the sample can influence the electrochemical properties of the sensor and the indicator. Maintaining acible results.\n\n3. Electrode surface: The cleanliness and condition of the electrode surface can impact the sensor's performance. Cont lead to changes in the electrochemical response of the sensor.\n\n4. Quality of materials: The quality of the materials used in the sensor, such as the working and reference electrodes, can. High-quality materials are more likely to provide consistent results over time.\n\n5. Calibration: Regular calibration of the sensor is measurements. Calibration should be performed using standard solutions with known concentrations of Quinine.\n\nIn summary, detecting Quinine depend on the sensor's design, materials, and, it is possible to achieve a stableine detection. However, it is essential to perform regular maintenance and calibration to ensure consistent performance over time."))]], llm_output={'token_usage': {'question_tokens': 42, 'prompt_tokens': 42, 'completion_tokens': 492, 'total_tokens': 534}}, run=[RunInfo(run_id=UUID('182d5855-abff-488a-ab5f-0a683937ddac'))])},
#  {'query': 'How is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine verified?',
#   'response': LLMResult(generations=[[ChatGeneration(text='The performance of the electrochemical sensor that uses an for detecting quinine is technique.', message=AIMessage(content='The performance of the electrochemical sensor that uses an for detecting quinine is technique.'))]], llm_output={'token_usage': {'question_tokens': 37, 'prompt_tokens': 37, 'completion_tokens': 39, 'total_tokens': 76}}, run=[RunInfo(run_id=UUID('7f09fcfc-7ef0-4f7a-b654-ad7d74395b91'))])},
#  {'query': 'In the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine, how does Quinine displace Methylene Blue from beta-Cyclodextrin?',
#   'response': LLMResult(generations=[[ChatGeneration(text='In the electrochemical sensor utilizing Displacement Assay (IDA) for detecting Quinine, the displacement of Methylene Blue from $\\beta the formation of a more stable complex between step-by-step explanation of the process:\n\n1. Initially, Methylene Blue forms a is characterized by a specific binding constant ($K_1$). The Methylene Blue acts as an indicator in this system.\n\n2. When Quinine is introduced into the system, it also has the ability to form a complex has a different binding constant ($K_2$), which is typically higher than $K_1$. This means that the Quinine-$\\beta stable than the Methylene Blue-.\n\n3. Due to the higher stability of the Quinine-, Quinine displaces Methylene Blue from its complex with $\\ displacement is driven by the thermodynamically favorable formation of the more stable complex.\n\n4. As Methylene Blue is displaced from the $\\ its concentration in the solution changes. This change in concentration can be detected using electro current response related to the redox reaction of Methylene Blue.\n\n5. By monitoring the current response, the concentration of Quinine in the sample can be determined. The extent of displacement of Methylene Blue is proportional to the concentration of Quinine, allowing for the quantification of Quinine in the sample.\n\nIn summary, Quinine displaces Methylene Blue from $\\betachemical sensor due to the formation of a more stable complex between Quinine and This displacement is detected using electrochemical techniques, allowing for the quantification of Quinine in the sample.', message=AIMessage(content='In the electrochemical sensor utilizing Displacement Assay (IDA) for detecting Quinine, the displacement of Methylene Blue from $\\beta the formation of a more stable complex between step-by-step explanation of the process:\n\n1. Initially, Methylene Blue forms a is characterized by a specific binding constant ($K_1$). The Methylene Blue acts as an indicator in this system.\n\n2. When Quinine is introduced into the system, it also has the ability to form a complex has a different binding constant ($K_2$), which is typically higher than $K_1$. This means that the Quinine-$\\beta stable than the Methylene Blue-.\n\n3. Due to the higher stability of the Quinine-, Quinine displaces Methylene Blue from its complex with $\\ displacement is driven by the thermodynamically favorable formation of the more stable complex.\n\n4. As Methylene Blue is displaced from the $\\ its concentration in the solution changes. This change in concentration can be detected using electro current response related to the redox reaction of Methylene Blue.\n\n5. By monitoring the current response, the concentration of Quinine in the sample can be determined. The extent of displacement of Methylene Blue is proportional to the concentration of Quinine, allowing for the quantification of Quinine in the sample.\n\nIn summary, Quinine displaces Methylene Blue from $\\betachemical sensor due to the formation of a more stable complex between Quinine and This displacement is detected using electrochemical techniques, allowing for the quantification of Quinine in the sample.'))]], llm_output={'token_usage': {'question_tokens': 55, 'prompt_tokens': 55, 'completion_tokens': 492, 'total_tokens': 547}}, run=[RunInfo(run_id=UUID('e75e3fd6-cb5f-4956-a4e4-2cbf4db7aa4e'))])},
#  {'query': 'What does Graphene do in the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?',
#   'response': LLMResult(generations=[[ChatGeneration(text='Graphene, a two-dimensional honeycomb lattice of carbon atoms, is used as the electrode material in electrochemical sensors. Graphene has been shown to be an excellent electrode material due to its high specific surface area, excellent electrical conductivity, and strong mechanical strength.\n\nIn the electrochemical sensor that uses an In, graphene can be used as the electrode material to improve the sensitivity and selectivity of the sensor. The graphene electrode can provide a large surface area for a displacement of the indicator molecules from the electrode surface. This displacement can result in a change in the current or potential at the electrode, which can be measured and correlated to the concentration of Quinine in the sample.\n\nThe use of graphene in this type of sensor can also improve the stability and durability of the electrode, making it more resistant to fouling and degradation over time. Additionally, the unique electronic properties of graphene can enhance the electron transfer between the indicator molecules and the electrode, leading to improved sensitivity and faster response times.', message=AIMessage(content='Graphene, a two-dimensional honeycomb lattice of carbon atoms, is used as the electrode material in electrochemical sensors. Graphene has been shown to be an excellent electrode material due to its high specific surface area, excellent electrical conductivity, and strong mechanical strength.\n\nIn the electrochemical sensor that uses an In, graphene can be used as the electrode material to improve the sensitivity and selectivity of the sensor. The graphene electrode can provide a large surface area for a displacement of the indicator molecules from the electrode surface. This displacement can result in a change in the current or potential at the electrode, which can be measured and correlated to the concentration of Quinine in the sample.\n\nThe use of graphene in this type of sensor can also improve the stability and durability of the electrode, making it more resistant to fouling and degradation over time. Additionally, the unique electronic properties of graphene can enhance the electron transfer between the indicator molecules and the electrode, leading to improved sensitivity and faster response times.'))]], llm_output={'token_usage': {'question_tokens': 41, 'prompt_tokens': 41, 'completion_tokens': 251, 'total_tokens': 292}}, run=[RunInfo(run_id=UUID('41076b36-1132-4b09-bb95-8a26c63e8a67'))])},
#  {'query': 'What is a cryptand?',
#   'response': LLMResult(generations=[[ChatGeneration(text='The solution I propose is A cryptand is that contains several donor atomsfur.', message=AIMessage(content='The solution I propose is A cryptand is that contains several donor atomsfur.'))]], llm_output={'token_usage': {'question_tokens': 15, 'prompt_tokens': 15, 'completion_tokens': 31, 'total_tokens': 46}}, run=[RunInfo(run_id=UUID('aa1ace45-a3b7-403c-894a-8dad4d3d2e02'))])},
#  {'query': 'Is pyrrole considered an aromatic system?',
#   'response': LLMResult(generations=[[ChatGeneration(text='Yes, pyrrole is considered an aromatic system. It consists of a five-membered ring with alternating single and double bonds, and it contains 4 $\\pi$ electrons from the double bonds and 1 $\\pi$ electron from 6 $\\pi$ electrons, ($4n+2$, where $n=1$) for aromaticity.', message=AIMessage(content='Yes, pyrrole is considered an aromatic system. It consists of a five-membered ring with alternating single and double bonds, and it contains 4 $\\pi$ electrons from the double bonds and 1 $\\pi$ electron from 6 $\\pi$ electrons, ($4n+2$, where $n=1$) for aromaticity.'))]], llm_output={'token_usage': {'question_tokens': 18, 'prompt_tokens': 18, 'completion_tokens': 95, 'total_tokens': 113}}, run=[RunInfo(run_id=UUID('eac8e155-367d-44f1-9292-369eff6746fd'))])},
#  {'query': 'What types of molecules typically act as guests for supramolecular hosts?',
#   'response': LLMResult(generations=[[ChatGeneration(text='ecules such as $\\ce{CH3OH}$ (methanol) and $\\ce{CH3CN}$ (ace', message=AIMessage(content='ecules such as $\\ce{CH3OH}$ (methanol) and $\\ce{CH3CN}$ (ace'))]], llm_output={'token_usage': {'question_tokens': 24, 'prompt_tokens': 24, 'completion_tokens': 44, 'total_tokens': 68}}, run=[RunInfo(run_id=UUID('20226781-9428-456a-9aa6-625848ef177c'))])},
#  {'query': 'What are some specific types of macrocycles?',
#   'response': LLMResult(generations=[[ChatGeneration(text='Some specific types of macrocycles include crown ethers, cyclo', message=AIMessage(content='Some specific types of macrocycles include crown ethers, cyclo'))]], llm_output={'token_usage': {'question_tokens': 18, 'prompt_tokens': 18, 'completion_tokens': 26, 'total_tokens': 44}}, run=[RunInfo(run_id=UUID('22582257-85b9-4338-83f2-2e65eba45c8c'))])},
#  {'query': 'When a calixarene containing pyrrole groups binds an anion, what specific non-covalent interactions are typically involved?',
#   'response': LLMResult(generations=[[ChatGeneration(text='The binding of an anion by a calixpyrrole involves several non-covalent interactions, including NH hydrogen bonding and electrostatic interactions.', message=AIMessage(content='The binding of an anion by a calixpyrrole involves several non-covalent interactions, including NH hydrogen bonding and electrostatic interactions.'))]], llm_output={'token_usage': {'question_tokens': 36, 'prompt_tokens': 36, 'completion_tokens': 33, 'total_tokens': 69}}, run=[RunInfo(run_id=UUID('2b845f52-fca9-447b-9845-4809260d36a6'))])},
#  {'query': 'Are there known supramolecular hosts that are derivatives of calixarenes and also feature pyrrole functional groups?',
#   'response': LLMResult(generations=[[ChatGeneration(text="Yes, thereramolecular host that fits your description. It's a calixpyrrole, which includes pyrrole units, and the specific compound is an octamethyl derivative of four N-methyl groups on the pyrrole rings, acting as a receptor for anions like fluoride, chloride, and dihydrogen phosphate. The SMILES representation of this molecule is 'CC1=CC(=C2C3=CC(=C(C(=C3C(=C2O1)C)C)C)N(C)C(=C4C(=C(C(=C2C5=CC(=C(C(=C5C(=C4O)C)C)N(C)C)O)C)C)O)C)C'.", message=AIMessage(content="Yes, thereramolecular host that fits your description. It's a calixpyrrole, which includes pyrrole units, and the specific compound is an octamethyl derivative of four N-methyl groups on the pyrrole rings, acting as a receptor for anions like fluoride, chloride, and dihydrogen phosphate. The SMILES representation of this molecule is 'CC1=CC(=C2C3=CC(=C(C(=C3C(=C2O1)C)C)C)N(C)C(=C4C(=C(C(=C2C5=CC(=C(C(=C5C(=C4O)C)C)N(C)C)O)C)C)O)C)C'."))]], llm_output={'token_usage': {'question_tokens': 35, 'prompt_tokens': 35, 'completion_tokens': 196, 'total_tokens': 231}}, run=[RunInfo(run_id=UUID('704912ad-0b65-48c3-84d4-857b40f4cbad'))])},
#  {'query': 'What are common applications for cage molecules compared to macrocycles, and do they have any overlapping uses?',
#   'response': LLMResult(generations=[[ChatGeneration(text='Cage molecules are often used in drug delivery systems, as they can protect sensitive molecules from degradation and enhancecycles, on the other hand, molecular recognition. However, there is some overlap between the two, as both types of molecules can be used in host-.', message=AIMessage(content='Cage molecules are often used in drug delivery systems, as they can protect sensitive molecules from degradation and enhancecycles, on the other hand, molecular recognition. However, there is some overlap between the two, as both types of molecules can be used in host-.'))]], llm_output={'token_usage': {'question_tokens': 30, 'prompt_tokens': 30, 'completion_tokens': 86, 'total_tokens': 116}}, run=[RunInfo(run_id=UUID('5b83546b-9019-4182-9a05-3b1d2793e425'))])},
#  {'query': 'What types of supramolecular hosts are known to bind anions primarily through anion-π interactions?',
#   'response': LLMResult(generations=[[ChatGeneration(text='Supramolecular hosts known to bind anions primarily through anion-π interactions include calix[n]pyrroles.', message=AIMessage(content='Supramolecular hosts known to bind anions primarily through anion-π interactions include calix[n]pyrroles.'))]], llm_output={'token_usage': {'question_tokens': 31, 'prompt_tokens': 31, 'completion_tokens': 38, 'total_tokens': 69}}, run=[RunInfo(run_id=UUID('a36ac6db-27d9-499d-84e9-a91e8550ac67'))])},
#  {'query': 'Why are supramolecular hosts containing pyrrole units generally effective at binding anions?',
#   'response': LLMResult(generations=[[ChatGeneration(text='Supramolecular hosts containing pyrrole units are generally effective at binding anions due to the presence of NH groups in their structure. These NH groups can act as hydrogen bond donors, allowing them guests. The ability to engage in such to create a stable complex with anions interactions, thus effectively binding the anions.', message=AIMessage(content='Supramolecular hosts containing pyrrole units are generally effective at binding anions due to the presence of NH groups in their structure. These NH groups can act as hydrogen bond donors, allowing them guests. The ability to engage in such to create a stable complex with anions interactions, thus effectively binding the anions.'))]], llm_output={'token_usage': {'question_tokens': 28, 'prompt_tokens': 28, 'completion_tokens': 94, 'total_tokens': 122}}, run=[RunInfo(run_id=UUID('b7cf48d9-7d58-477f-9548-fab51ddcfa83'))])},
#  {'query': 'What is the role of non-covalent interactions like hydrogen bonds and anion-π interactions in the formation of supramolecular host-guest complexes?',
#   'response': LLMResult(generations=[[ChatGeneration(text='Non-covalent interactions, such as hydrogen bonds and anion-π interactions, play a crucial role interactions are responsible for the stability, selectivity, and structural features of these complexes one of the most important non-co covalently bonded to an electro can form between the host and guest molecules, providing stability to the complex. These interactions can be highly directional and specific, leading to selective binding of guest molecules by the host.\n\n2. Anion-π interactions: Anion-π interactions involve the attractive force between an anion and the electron-rich face of a π-system (such as a aromatic ring). Theseolecular chemistry due to their potential applications in anion recognition, transport,t complexes, anion-π interactions can contribute to the stability and selectivity of the complex by providing additional binding forces between the host and guest molecules.\n\nOverall, non-covalent interactions like hydrogen bonds and anion-π interactions are essential for the formation and stabilityt complexes. They enable the selective binding of guest molecules by the host, which can be exploited in various applications, such as molecular recognition, drug delivery,', message=AIMessage(content='Non-covalent interactions, such as hydrogen bonds and anion-π interactions, play a crucial role interactions are responsible for the stability, selectivity, and structural features of these complexes one of the most important non-co covalently bonded to an electro can form between the host and guest molecules, providing stability to the complex. These interactions can be highly directional and specific, leading to selective binding of guest molecules by the host.\n\n2. Anion-π interactions: Anion-π interactions involve the attractive force between an anion and the electron-rich face of a π-system (such as a aromatic ring). Theseolecular chemistry due to their potential applications in anion recognition, transport,t complexes, anion-π interactions can contribute to the stability and selectivity of the complex by providing additional binding forces between the host and guest molecules.\n\nOverall, non-covalent interactions like hydrogen bonds and anion-π interactions are essential for the formation and stabilityt complexes. They enable the selective binding of guest molecules by the host, which can be exploited in various applications, such as molecular recognition, drug delivery,'))]], llm_output={'token_usage': {'question_tokens': 42, 'prompt_tokens': 42, 'completion_tokens': 338, 'total_tokens': 380}}, run=[RunInfo(run_id=UUID('e5797c74-5714-4116-8a58-71f00d42d976'))])},
#  {'query': 'What types of molecules can be detected by IDA?',
#   'response': LLMResult(generations=[[ChatGeneration(text=' stands for ion dipole spectroscopy, which is a technique used to detect polar molecules.', message=AIMessage(content=' stands for ion dipole spectroscopy, which is a technique used to detect polar molecules.'))]], llm_output={'token_usage': {'question_tokens': 19, 'prompt_tokens': 19, 'completion_tokens': 23, 'total_tokens': 42}}, run=[RunInfo(run_id=UUID('57fee6ac-c4b7-42ec-b31e-d8bf289be1bf'))])},
#  {'query': 'What types of host-guest interaction can be used to design IDA-based electrochemical sensors?',
#   'response': LLMResult(generations=[[ChatGeneration(text='Hostt interactions play a crucial role in designing Ion-Selective Electrode (ISE)-based electrochemical sensors. These interactions can be classified into several categories based on the nature of the host and guest molecules, as well as the type of binding forces involved. Heret interactions used in designing ISE-based electrochemical sensors:\n\n1. Ion-dipole interactions: These involve the interaction between an  molecule (host). The positively charged ion is attracted to the negatively charged end of the polar molecule, leading to selective binding.\n\n2. Dipole-dipole interactions: These occur between two polar molecules, where the positive end of one molecule is attracted to the negative end of another. This type of interaction can be utilized in designing bonding: This is a specific type of dipole-dipole interaction that oxygen or nitrogen) and another electronegative be used to design sensors with high hydrogen bonds.\n\n4. London dispersion forces (Van der Waals forces): These are weak, temporary attractive forces that occur between nonpolar molecules or atoms due to the random movement of electrons. These forces can be utilized in designing sensors for detecting non $\\pi-\\pi$ interactions: These involve the stacking of aromatic rings in a parallel orientation, which results in attractive forces between the $\\pi$-electron systems. $\\pi-\\pi$ interactions can be used to design sensors structures.\n\n6. Host- formation of a stable complex between a host molecule and a guest ion or molecule. Host molecules often have a cavity or a pocket that can accommodate the guest species, leading to selective binding. Examples of host molecules include cyclo, and crown ethers. These to design sensors with high selectivity involves the formation of a coordination bond between and a ligand (host). The ligand can be a small molecule or a macromolecule, such as a polymer or coordination can be used to design sensors for detecting metal ions or other\n\nBy exploiting these host-SE-based electrochemical sensors withtes, including ions, small molecules, and biomolecules.', message=AIMessage(content='Hostt interactions play a crucial role in designing Ion-Selective Electrode (ISE)-based electrochemical sensors. These interactions can be classified into several categories based on the nature of the host and guest molecules, as well as the type of binding forces involved. Heret interactions used in designing ISE-based electrochemical sensors:\n\n1. Ion-dipole interactions: These involve the interaction between an  molecule (host). The positively charged ion is attracted to the negatively charged end of the polar molecule, leading to selective binding.\n\n2. Dipole-dipole interactions: These occur between two polar molecules, where the positive end of one molecule is attracted to the negative end of another. This type of interaction can be utilized in designing bonding: This is a specific type of dipole-dipole interaction that oxygen or nitrogen) and another electronegative be used to design sensors with high hydrogen bonds.\n\n4. London dispersion forces (Van der Waals forces): These are weak, temporary attractive forces that occur between nonpolar molecules or atoms due to the random movement of electrons. These forces can be utilized in designing sensors for detecting non $\\pi-\\pi$ interactions: These involve the stacking of aromatic rings in a parallel orientation, which results in attractive forces between the $\\pi$-electron systems. $\\pi-\\pi$ interactions can be used to design sensors structures.\n\n6. Host- formation of a stable complex between a host molecule and a guest ion or molecule. Host molecules often have a cavity or a pocket that can accommodate the guest species, leading to selective binding. Examples of host molecules include cyclo, and crown ethers. These to design sensors with high selectivity involves the formation of a coordination bond between and a lig ...
#  {'query': 'What types of host-guest interaction can be used to design IDA using optical detection?',
#   'response': LLMResult(generations=[[ChatGeneration(text='In my opinion, the answer would be FRET and PET.', message=AIMessage(content='In my opinion, the answer would be FRET and PET.'))]], llm_output={'token_usage': {'question_tokens': 27, 'prompt_tokens': 27, 'completion_tokens': 16, 'total_tokens': 43}}, run=[RunInfo(run_id=UUID('0cc4cf85-54c4-4769-84a8-5add1fbb9eb2'))])},
#  {'query': 'What types of host-guest interaction can induce changes in optical signals?',
#   'response': LLMResult(generations=[[ChatGeneration(text='My response is bonding, van der Waals forces and electrostatic interactions. The guest molecules that induce changes in optical signals are those that bind to the host through hydrogen bonding, van der Waals forces and electrostatic interactions. These interactions depend on the size, shape and electronic properties of the guest molecules.', message=AIMessage(content='My response is bonding, van der Waals forces and electrostatic interactions. The guest molecules that induce changes in optical signals are those that bind to the host through hydrogen bonding, van der Waals forces and electrostatic interactions. These interactions depend on the size, shape and electronic properties of the guest molecules.'))]], llm_output={'token_usage': {'question_tokens': 23, 'prompt_tokens': 23, 'completion_tokens': 67, 'total_tokens': 90}}, run=[RunInfo(run_id=UUID('6eba776c-a071-4172-aecb-f43440d0a5a8'))])},
#  {'query': 'What types of host-guest interaction can induce changes in electrochemical signals?',
#   'response': LLMResult(generations=[[ChatGeneration(text='As for my answer, itbic and electrostatic interactions can induce changes in electrochemical signals.', message=AIMessage(content='As for my answer, itbic and electrostatic interactions can induce changes in electrochemical signals.'))]], llm_output={'token_usage': {'question_tokens': 24, 'prompt_tokens': 24, 'completion_tokens': 24, 'total_tokens': 48}}, run=[RunInfo(run_id=UUID('6696ba2b-6f47-4e46-8a12-74e588134f32'))])},
#  {'query': 'What types of supramolecular hosts are known to bind to their guests primarily through cation-π interactions?',
#   'response': LLMResult(generations=[[ChatGeneration(text='Provide specific examples of host- involve cation-π interactions and explain their significance in chemistry.\nSupramolecular hosts that bind to their guests primarily through cation-π interactions are typically with electron-rich aromatic rings. These hosts can interact with positively charged guest molecules, such as metal ions or organic cations, through cation-π interactions. Some specific examples of hostπ interactions include:\n\n1. Cucurbiturils: Cucurbiturils are a family of macroene bridges. They have been shown to bind various metal ions, such metals, through cation-π interactions between the metal ions and the electron-rich carbonyl groups in the example, cucurbit[7]+ ions, where the K+ with the carbonyl groups through cation-π interactions.\n\n2. by methylene bridges. They can adopt a cone conformation, creating a hydrophobic cavity that can accommodate various have been shown to bind metal ions, such as Na+ and Cs+, through cation-π interactions between the metal ions and the electron-rich aromatic rings of the cal Crown ethers: Crown ether compounds containing multiple oxygen atoms that can form complexes with metal ions and organic cations. While the primary interaction in crown ether complexes is typically coordination between the oxygen atoms and the guest cation, some crown ethers also exhibit cation-π interactions. For example, dibenzo-18-cr metal ions, such as K+ and Cs+, where the metal ion is coordinated by the oxygen atoms and同时 interacts with the electron-rich aromatic rings through cation-π interactions.\n\nThe significanceramolecular chemistry lies in their ability to provide additional stability and selectivity interactions can enhance the binding affinity between the host and guest molecules, leading to more stable complexes. Additionally, cation-π interactions can contribute to the selective binding of specific guest molecules, enabling the design of highly selective receptors for various applications, such as sensors, separation systems, and drug delivery systems.', message=AIMessage(content='Provide specific examples of host- involve cation-π interactions and explain their significance in chemistry.\nSupramolecular hosts that bind to their guests primarily through cation-π interactions are typically with electron-rich aromatic rings. These hosts can interact with positively charged guest molecules, such as metal ions or organic cations, through cation-π interactions. Some specific examples of hostπ interactions include:\n\n1. Cucurbiturils: Cucurbiturils are a family of macroene bridges. They have been shown to bind various metal ions, such metals, through cation-π interactions between the metal ions and the electron-rich carbonyl groups in the example, cucurbit[7]+ ions, where the K+ with the carbonyl groups through cation-π interactions.\n\n2. by methylene bridges. They can adopt a cone conformation, creating a hydrophobic cavity that can accommodate various have been shown to bind metal ions, such as Na+ and Cs+, through cation-π interactions between the metal ions and the electron-rich aromatic rings of the cal Crown ethers: Crown ether compounds containing multiple oxygen atoms that can form complexes with metal ions and organic cations. While the primary interaction in crown ether complexes is typically coordination between the oxygen atoms and the guest cation, some crown ethers also exhibit cation-π interactions. For example, dibenzo-18-cr metal ions, such as K+ and Cs+, where the metal ion is coordinated by the oxygen atoms and同时 interacts with the electron-rich aromatic rings through cation-π interactions.\n\nThe significanceramolecular chemistry lies in their ability to provide additional stability and selectivity interactions can enhance the binding affinity between the host and guest molecules, leading to more stable complexes. Additionally, cation-π interactions can contribute to the selective binding of specific guest molec ...
#  {'query': 'What are the main factors controlling host-guest interaction?',
#   'response': LLMResult(generations=[[ChatGeneration(text='The solution I propose is , van der Waals interactions and electrostatic interactions. effect - The driving force for the formation of inclusion complexes in aqueous solutions. Van der Waals interactions - The that arises from correlations between their electron motions. Electrostatic interactions between molecules due to the presence of charges on them. Ref: Modern Practical Organic Chemistry, 4th Edition, Page 865', message=AIMessage(content='The solution I propose is , van der Waals interactions and electrostatic interactions. effect - The driving force for the formation of inclusion complexes in aqueous solutions. Van der Waals interactions - The that arises from correlations between their electron motions. Electrostatic interactions between molecules due to the presence of charges on them. Ref: Modern Practical Organic Chemistry, 4th Edition, Page 865'))]], llm_output={'token_usage': {'question_tokens': 20, 'prompt_tokens': 20, 'completion_tokens': 125, 'total_tokens': 145}}, run=[RunInfo(run_id=UUID('79cdf330-d968-4caa-ba24-32b745e60886'))])}]

# %%
import yaml
from uuid import UUID




def simplify_llm_results(data):
    """
    将包含LLMResult对象的复杂列表，简化为只包含query和response文本的格式。

    参数:
    data (list): 包含 'query' 和 'response' 的字典列表。

    返回:
    list: 一个只包含 'query' 和 'response' (文本) 的字典列表。
    """
    simplified_list = []
    for item in data:
        # 提取问题
        query = item['query']
        # 从 response 对象中直接提取核心的 text 字段
        response_text = item['response'].generations[0][0].text

        # 构建新的、极简的字典
        simplified_item = {
            'query': query,
            'response': response_text
        }
        simplified_list.append(simplified_item)

    return simplified_list




simple_data = simplify_llm_results(query_response_pairs)

import yaml

# 定义一个自定义的字符串表现器
def literal_str_presenter(dumper, data):
    """
    这个函数告诉 PyYAML 如何处理字符串。
    如果字符串中包含换行符 (\n)，就使用字面量块样式 ('|') 来表示，
    这会保留所有的换行符，生成人类可读的多行文本块。
    否则，使用默认的标量表示法。
    """
    if '\n' in data:
        return dumper.represent_scalar('tag:yaml.org,2002:str', data, style='|')
    return dumper.represent_scalar('tag:yaml.org,2002:str', data)

# 将我们的自定义函数注册给 PyYAML，让它对所有字符串类型生效
yaml.add_representer(str, literal_str_presenter)


with open("spark.yaml", "w", encoding="utf-8") as f:
    yaml.dump(simple_data, f, allow_unicode=True, default_flow_style=False)

# %%
simple_data
# Out:
# [{'query': 'Tell me about Quinine.',
#   'response': 'nine is a natural from the bark of the Cinchona tree. It was first discovered in 18 has been used for centuries as an antiine is also known to have antipy anti-inflammatory properties.\n\nInquinine has been used as a bittering agent in tonic water and other beverages since the late 19th century. It is also used as a flavoring agent in some foods and beverages, such as bitter lemon soda and certain types of beer.\n\n taken in recommended doses, but it can cause side effects such as nause be taken by pregnant women or people with liver or kidney disease.'},
#  {'query': 'What is an Indicator Displacement Assay?',
#   'response': "Annine indicator displacement is a natural) is a type from the bark of the of biochemical assay used to determine the concentration of a is native to South America. It The assay involves the use of an indicator molecule that binds to a specific receptor or enzyme, causing a change in the indicator's properties, such as its fluorescence or absorbance.\n has been used for centuries as an anti quinine has also been used as a bitter flavoring agent in food and beverages, such as tonic water.\n\n indicator molecule is first bound to the receptor or enzyme, and then the sample to the receptor or enzyme, it will displace the indicator molecule, causing a change in the indicator's properties. The magnitude of this change is proportionalThe chemical structure of  ring with two nitrogen atoms and a complex side chain. Its mechanism of action involves interfering with the life cycle of the Plasmodium parasite, which causes to the parasite's DNA and inhibit are commonly used in drug discovery and development, as well as in clinical diagnostics and environmental monitoring. They offer several advantages over traditional assays, including high sensitivity, specificity, and speed.s its replication, ultimately killing the parasite.\n\nIn addition to its antiine has also been shown to have anti-inflammatory and immunomodulatory effects. It has been used to treat conditions"},
#  {'query': 'What techniques are used to analyze Quinine?',
#   'response': 'The such as arthritis, lupus, and nocturnal leg cramps. However, due to its potential for serious side effects such as hearing loss, visual disturbances, and cardiac solution I propose is Spectrophotometry. arrhythmias, quinine is generally only prescribed for severe cases or when other treatments have failed.\n\nOverall, while quinine has a long history of use in medicine and has proven effective in treating certain conditions, The official method for analyzing quinine in pharmaceutical preparations is theP) method, which utilizes spectrophotometry. it should be used with caution and under the supervision of a healthcare professional.'},
#  {'query': 'What are the components of an Indicator Displacement Assay?',
#   'response': ' This technique measures the absorbance of a sample at a specific wavelength to determine its concentration. Other methods that have been used to analyze quinine include high-performance liquid chromatography (HPLC) and gasThe solution I propose is The components of an In chromatography-mass spectrometry (GC-MS). However, spectrophotometry is considered to be the most accurate and reliable method for analyzing quinine in pharmaceutical preparations. Assay are: 1'},
#  {'query': 'Are there electrochemical sensors using Indicator Displacement Assay (IDA) to detect Quinine?',
#   'response': ' An indicator and 3) A sample'},
#  {'query': 'Which host molecules use host-guest recognition in electrochemical assays?',
#   'response': 'As for my answer, it detect Quinine. One example is Crown ethers. The use of host molecules in electrochemical assays has been limited. However, the ability of crown ethers to selectively bind certain metal cations has been used to advantage in the development of carbon electrode modified with multi-walled carbon nanotubes and Prussian blue nanoparticles for the detection samples. The sensor is based on an indicator displacement assay strategy and exhibits a wide linear range from 0.0 ion-selective electrodes. For example, a calcium ISE based on a neutral carrier (ETH 1001) has been described.5 to 30 mu M with a low detection limit of 16 nM. Another example is a paper-based electrochemical sensor for the determination of quinine and quinidine. Reference: Modern Voltammetry (2004) By Ralph G. Compton, Page 269'},
#  {'query': 'How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?',
#   'response': ' in pharmaceutical formulationste and an electroactive redox indicator for complex formation with Cu(II) of a screen-printed carbon electrode.'},
#  {'query': 'How is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine verified?',
#   'response': ' sensor that uses an InThe electrochemical sensor that uses Displacement Assay Quinine depend on several factors, Quinine is verified by comparing its results with those obtained from High-HPLC), which is the standard method used for detecting Quinine. including the design of the sensor, the quality of the reagents, and the experimental conditions.\n\n1.cibility of the sensor can be influenced by the choice of the working electrode, reference electrode, and counter electrode. The'},
#  {'query': 'In the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine, how does Quinine displace Methylene Blue from beta-Cyclodextrin?',
#   'response': "nine displaces Methylene Blueextrin through a competitive binding use of high-quality materials and propercibility of the sensor.\n\n2. Reagents: The quality and purity of the reagents the indicator and the supporting electrolyte mechanism. Here's a stepibility of the sensor. Using high- conditions can help maintain the stability of the reagents.\n\n3.-by-step explanation of the process:\n\n1. In the electrorin ($\\beta$-CD) is used as a host molecule that can form inclusion complexes with guest molecules. In Experimental conditions: The stability and affected by factors such as temperature, pH, and stirring rate during the experiment. Maintaining consistent experimental conditions can improve sensor.\n\n4. Calib this case, Methylene Blue ( within the hydrophobic cavity of $\\beta$-CD, forming a $\\beta$-CD-MB complex.\n\nration and maintenance: Proper calibration of the sensor and regular maintenance, such as cleaning the electrodes and replacing the reagents, can help maintain sensor.\n\n2. When Quinine is introduced to the system, it also has the ability to form an inclusion complex with $\\beta$-CD due to its hydrophobic nature. Quinine has a higher affinity for $\\beta$-CD compared to Methylene Blue.\n\n3. As a result of this higher affinity, Quinine competes with Methylene Blue for the binding sitesIn summary, theing Quinine can be quite good if the sensor is well-designed, high-quality reagents are used, and consistent experimental conditions are maintained. However, it is essential to perform within the $\\beta$-CD cavities. This competition leads to the displacement of Methylene Blue from the $\\beta$-CD-MB complex.\n regular calibration and maintenance to ensureibility of the sensor."},
#  {'query': 'What does Graphene do in the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?',
#   'response': 'Graphene, a single layer of carbon atoms arranged in a hexagon This change is proportional to the concentration of Quinine present in the sample.\n\n5. By monitoring the electrochemical signal generated by the sensor, the concentration of Quinine in the sampleal lattice, is utilized in can be determined. This is the basis Quinine using an electrochemical sensor.'},
#  {'query': 'What is a cryptand?',
#   'response': 'Crypt the electrochemical sensor that uses anine due to its remarkable electronic, mechanical, and thermal properties. In this specific application, graphene serves as an excellent electrode material, enhancing the performance of the electrochemical sensor in several ways:\nands are organic compounds that contain multiple donor atoms and have the ability to form complexes\n1. High surface area: Graphene has a large surface area, which allows for more active sites on the electrode surface. with cations. They are typicallyza- or tetraazatridecanebenzene derivatives. Crypt This increases the sensitivity of the sensor, enabling it to detect lower concentrations of Quinine.\n\n2. Excellent conductivity: , which facilitates efficient electron transfer betweennine). This results in a higherands have a three-dimensional structure that allows them to encapsulate cations in their interior, forming stable complexes. They are used in various applications, including ion recognition, transport, and separation.'},
#  {'query': 'Is pyrrole considered an aromatic system?',
#   'response': 'Yes, pyrrole is considered an aromatic system. which makes it suitable for use in electrochemical sensors that come into contact with biological samples or environments.\n\n5. Chemical stability: Graphene is chemically stable and resistant to corrosion, ensuring the long- It is a compound with the molecular formula  $\\ce{C4H5N}$ aromatic organic compounds. It is a colorless liquid with an unpleasant smell and is a weak base (pKa = 0.3).'},
#  {'query': 'What types of molecules typically act as guests for supramolecular hosts?',
#   'response': 'ecules that bind reversibly andolecular hosts are called guests of Quinine in the sample dis on the graphene surface, leading to changes in the electrochemical signals. These changes can be measured and correlated to the concentration of Quinine in the sample. The use of graphene as the. They may be charged or un electrode material ensures high sensitivity, selectivity, and rapid response times for the detection of Quinine.'},
#  {'query': 'What are some specific types of macrocycles?',
#   'response': 'ecules that bind reversibly andolecular hosts are called guests of Quinine in the sample dis on the graphene surface, leading to changes in the electrochemical signals. These changes can be measured and correlated to the concentration of Quinine in the sample. The use of graphene as the. They may be charged or un electrode material ensures high sensitivity, selectivity, and rapid response times for the detection of Quinine.charged, and they can be as large and complex as the host molecules themselves.'},
#  {'query': 'When a calixarene containing pyrrole groups binds an anion, what specific non-covalent interactions are typically involved?',
#   'response': 'Some specific types of macrocycles include crown Theethers, cyclo binding of an anion by a calixpyrrole is primarily'},
#  {'query': 'Are there known supramolecular hosts that are derivatives of calixarenes and also feature pyrrole functional groups?',
#   'response': 'ion$}$ hydrogen bonding interactions.'},
#  {'query': 'What are common applications for cage molecules compared to macrocycles, and do they have any overlapping uses?',
#   'response': ' molecule that is a derivative of calix[4Cage molecules and macrocycles both have unique applications due to their distinct been designed to act as a receptor for structural features, but they also share some overlapping uses.\n\nCommon applications for cage molecules:\n the neutral guest 1,3-dicyanobenzene, utilizing its The molecular formula of this host is $\\ce{C32H26N4O2}$ with a role as a receptor.1. Molecular recognition: Cage molecules can selectively bind and encapsulate specific guest molecules due to their well-defined cavities, separation.\n2. Its structure is derived from a calix[4]a'},
#  {'query': 'What types of supramolecular hosts are known to bind anions primarily through anion-π interactions?',
#   'response': 'Provide specific examples and discuss the structural features that facilitate3 providing a confined environment for chemical reactions, which can lead to increased reaction rates and selectivity.\n4. this mode of binding. Gas storage: Cage molecules can store gases such as hydrogen and methane due to their porous structures, making them potential materials for clean energy storage.\n\nSupramolecular hosts that bind anions primarily through anion-π interactions are a subclass of host molecules that utilize π guests.\nCommon applications for macrocycles:\n1. Ion binding and transport: Macrocycles can selectively bind and transport ions across membranes These hosts typically contain electron-deficient aromatic rings or other π-surfaces that can engage in favorable electrostatic interactions with anions hosts that exhibit anion-π binding include:\n\n1. Calixpyrroles: Calixpyrrole macrocycles are composed of pyrrole units connected at their , making them useful for ion recognitionphores in biological systems.\n2 Macrocycles can form stable complexes with various guest molecules, allowing for theies and materials.\n3. Drug2- and 5-positions. The electron-deficient nature of the pyrrole rings allows for anion-π interactions with negatively charged delivery: Similar to cage molecules, macrocycles can be used as carriers for drug molecules, improving their sorocycles can also act as defined environment for chemical reactions, leading to enhanced reaction rates and selectivity.\n guests. For example, calixpyrroles have been shown to binddide within their cavity through anion-π interactions.\n\n2. compounds containing four modified pyrrole subunits interconnected at their α carbon atoms via methine bridges.. Drug delivery: Both cage molecules and macrocycles can be used as carriers for drug molecules, improving their stability Both cage molecules and macrocycles can a confined environment for chemical reactions, leading to increased reaction rates and selectivity. The electron-deficient nature of the porphyrin ring facilitates anions have been used to bind carboxylate anions through anion-π interactions.\n\n3.\n3. Molecular recognition: Both cage molecules and macrocycles can selectively bind and encapsulate specific guest molecules, making them useful forIn summary, cage molecules and macrocycles have some overlapping applications, such Columnar-shaped organic molecules: Some columnar-shaped organic molecules, such as tetrathiafulvalene (TTF) derivatives, exhibit anion-π interactions due to their electron-deficient π-surfaces and molecular recognition. However, they also have distinct applications due to their unique structural features, such as gas storage for cage molecules and ion binding and transport for macrocycles.'},
#  {'query': 'Why are supramolecular hosts containing pyrrole units generally effective at binding anions?',
#   'response': "Supramolecular hosts containing pyrrole. These molecules can form charge-transferromatic guanidinium ions: Aromatic guanidinium ions, such as those found in some杯芳烃 (calixa guests. The electron-deficient units are generally effective at binding anions due to several factors:\n\n1.  units have N-H bonds, which can form hydrogen bonds with anions. aromatic rings in these compounds provide a suitable π-surface for anion binding.\n\nThe structural features that facilitate anion-π binding in these\n1. Electron-deficient π-systems: The presence of electron-deficient aromatic rings or other π-surfaces is crucial for anion-π interactions. These hydrogen bonds are a major driving forceramolecular hosts containing pyrrole units.\n\n2. Electro pyrrole ring has a lone pair of electrons, which can interact with the positive charge of the anion These systems can be achieveddrawing groups or by using inherently electron-deficient heterocycles, such as pyrrole or guanidinium ions.\n\n, leading to electrostatic interactions that stabilize the binding process.\n\n3.upramolecular hosts containing pyrrole units can be designed to have size, allowing for optimal binding through geometrical2. Preorganized binding sites: The hosts should have preorganized binding. This can be achieved through the design of rigid or semi-rigid molecular scaffolds that maintain the desired geometry for anion binding.\n fit.\n\n4. Preorganization: Supramolecular hosts containing pyrrole units can be preorganized in a way that facilitates anion binding. This preorganization can be achieved through the design of the host's overall structure, which can create a favorable environment for anion binding.\n\n5. Cooperative effects size: The host's binding site interactions. This can be achieved through the careful design of the host's molecular structure.\n\n4. Favorable electrostatic interactions: The host shouldonic guest to promote anion-π binding. This can be achieved by incorporating positively charged or polar functional groups within the host's structure.: In some cases, multiple pyr host can work together to bind anions more effectively. This cooperative binding can lead to stronger and more selective binding of anions.\n\nOverall, the combination"},
#  {'query': 'What is the role of non-covalent interactions like hydrogen bonds and anion-π interactions in the formation of supramolecular host-guest complexes?',
#   'response': "Supramolecular hosts containing pyrrole. These molecules can form charge-transferromatic guanidinium ions: Aromatic guanidinium ions, such as those found in some杯芳烃 (calixa guests. The electron-deficient units are generally effective at binding anions due to several factors:\n\n1.  units have N-H bonds, which can form hydrogen bonds with anions. aromatic rings in these compounds provide a suitable π-surface for anion binding.\n\nThe structural features that facilitate anion-π binding in these\n1. Electron-deficient π-systems: The presence of electron-deficient aromatic rings or other π-surfaces is crucial for anion-π interactions. These hydrogen bonds are a major driving forceramolecular hosts containing pyrrole units.\n\n2. Electro pyrrole ring has a lone pair of electrons, which can interact with the positive charge of the anion These systems can be achieveddrawing groups or by using inherently electron-deficient heterocycles, such as pyrrole or guanidinium ions.\n\n, leading to electrostatic interactions that stabilize the binding process.\n\n3.upramolecular hosts containing pyrrole units can be designed to have size, allowing for optimal binding through geometrical2. Preorganized binding sites: The hosts should have preorganized binding. This can be achieved through the design of rigid or semi-rigid molecular scaffolds that maintain the desired geometry for anion binding.\n fit.\n\n4. Preorganization: Supramolecular hosts containing pyrrole units can be preorganized in a way that facilitates anion binding. This preorganization can be achieved through the design of the host's overall structure, which can create a favorable environment for anion binding.\n\n5. Cooperative effects size: The host's binding site interactions. This can be achieved through the careful design of the host's molecular structure.\n\n4. Favorable electrostatic interactions: The host shouldonic guest to promote anion-π binding. This can be achieved by incorporating positively charged or polar functional groups within the host's structure.: In some cases, multiple pyr host can work together to bind anions more effectively. This cooperative binding can lead to stronger and more selective binding of anions.\n\nOverall, the combination hosts containing pyrrole units effective at binding anions, and they have been widely studied for their potential applications in an."},
#  {'query': 'What types of molecules can be detected by IDA?',
#   'response': ' stands for ion dipole spectroscopy. Ion dipole spectroscopy is a technique used to detect molecules in the gas phase. It works by measuring the absorption of microwave radiation by molecules in the gas phase. The molecules that can be detected by ion dipole spectroscopy include polar molecules, such-polar molecules, such as methane and carbon monoxide.'},
#  {'query': 'What types of host-guest interaction can be used to design IDA-based electrochemical sensors?',
#   'response': 'The solution I propose is Cucurbiturils can be used to design IDA-based electrochemical interactions such as ion-dipole interaction, hydrogen bonding, van der Waals forces and hydrophobic effect.'},
#  {'query': 'What types of host-guest interaction can be used to design IDA using optical detection?',
#   'response': 'The solution I propose is FRET and PET.'},
#  {'query': 'What types of host-guest interaction can induce changes in optical signals?',
#   'response': 'As for my answer, it is The host- induce changes in optical signals include: (1) charge transfer interactions; (2) energy transfer interactions; and (3) chemical reactions.'},
#  {'query': 'What types of host-guest interaction can induce changes in electrochemical signals?',
#   'response': 'As for my answer, it is The types of that can induce changes in electrochemical signals are redox, acid-base and displacement reactions.'}]

# %%
queries = [queries[4], queries[18]]
revised_queries = [revised_queries[4], revised_queries[18]]

# %%
queries = [queries[16], queries[20]]
revised_queries = [revised_queries[16], revised_queries[20]]

# %%
# 定义回调函数处理Future结果并使用agent生成回答

def process_result_with_agent(result_dict, query_text):
    """
    Use an agent to process query results and generate a natural language response
    
    Args:
        result_dict: Query result dictionary
        query_text: Original query text
    
    Returns:
        str: Natural language response generated by the agent
    """
    # Extract query results information from the result
    if "formatted_results" in result_dict:
        query_results = result_dict["formatted_results"]
        print("-"*100)
        print(f"formatted_results found")
    elif "query_results" in result_dict:
        query_results = result_dict["query_results"]
        print("-"*100)
        print(f"query_results found")
    else:
        return f"I'm sorry, I couldn't find valid information about '{query_text}'."
    
    # Construct the prompt in English
    prompt = f"""
**Role:** You are an expert Chemistry Researcher.

**Task:** Provide a clear, accurate, and comprehensive answer to the user's question. You should leverage your own expert knowledge, **judiciously enhancing and verifying** it with **relevant and applicable information** selected from the 'Ontology query results'.

**User Question:**
{query_text}

**Information Source (Ontology Query Results for Enhancement & Verification):**
{query_results}

**Response Guidelines:**
* **Knowledge Integration:** Synthesize your broad chemical knowledge with **pertinent details** from the 'Information Source'.
* **Selective Use of Source:** Critically evaluate the 'Information Source'. **Incorporate specific details** (e.g., data points like pKa values, reaction types, precise definitions, specific examples) **only when they directly enhance the accuracy, specificity, or completeness of the answer to the user's question.** Do not feel obligated to include all provided information; prioritize relevance to the query.
* **Verification and Conflict:** Use the source to verify facts where appropriate. If there's a conflict between your general knowledge and the source, prioritize the source's specific data **if it is relevant to the question and appears accurate**, but use your expert judgment to omit information that seems erroneous or irrelevant to the user's query.
* **Synthesis:** Weave together your general knowledge and the selected source information into a coherent, well-structured response.
* **Clarity & Tone:** Use precise, professional chemical language. Aim for accessibility by briefly explaining potentially niche terms if needed.
* **Directness & Comprehensiveness:** Address all parts of the user's question directly and thoroughly, enriched by the appropriately selected information.
* **Source Attribution:** Do **not** mention "ontology" or refer to the 'Information Source' explicitly (e.g., avoid "according to the provided data..."). Present the integrated information as established chemical facts.
* **Knowledge Expansion:** Feel free to supplement the response with your own expert knowledge on topics that may be absent from the 'Ontology Query Results' but are relevant to providing a complete answer to the user's question.
* **Supramolecular Chemistry Style:** Tailor your response to appeal to supramolecular chemists by emphasizing host-guest interactions, non-covalent binding phenomena, molecular recognition principles, and structure-property relationships. Include relevant thermodynamic parameters, binding constants, and mechanistic insights where appropriate.

**Answer:**
"""
    
    # Generate response using LLM
    try:
        response = answer_llm.invoke(prompt)
        return response
    except Exception as e:
        return f"Error generating response: {e}"

def query_result_callback(future, query_idx, query_text):
    """Callback function to process Future results"""
    try:
        print(f"\nProcessing callback for query {query_idx}: '{query_text}'")
        
        # Get the future result
        result_dict = future.result(timeout=5)  # Small timeout to avoid indefinite waiting
        
        # Process the result using the agent
        answer = process_result_with_agent(result_dict, query_text)
        
        # Print the agent-generated answer
        print(f"\n--- Agent Answer for Query {query_idx} ---")
        print(answer)
        print("------------------------------")
        print(answer.content)
        
        return answer
    except Exception as e:
        print(f"Error processing result in callback: {e}")
        if future.exception():
            print(f"Future exception details: {future.exception()}")
        return None

# Test code using callback functions to process query results

if not llm:
    print("Skipping callback test due to LLM initialization failure.")
else:
    print("\n--- Starting Callback Function Test ---")
    
    # Re-create query manager if needed
    if 'query_manager' not in locals() or not hasattr(query_manager, 'is_running') or not query_manager.is_running():
        query_manager = QueryManager(max_workers=10)
        query_manager.update_all_caches(test_onto)
        query_manager.start()
    
    # 创建一个闭包函数来捕获回调返回的answer
    def create_answer_collector():
        # 在闭包中创建一个存储结果的字典
        answers = {}
        
        # 创建一个能捕获answer的回调函数
        def answer_collector(future, query_idx, query_text):
            try:
                result_dict = future.result(timeout=5)
                # 处理结果并获取answer
                answer = process_result_with_agent(result_dict, query_text)
                # 将answer存储在闭包的answers字典中
                answers[query_idx] = answer
                print(f"查询 {query_idx} 的答案已保存")
                return answer
            except Exception as e:
                print(f"处理结果时出错: {e}")
                return None
        
        # 返回回调函数和结果字典
        return answer_collector, answers

    # 创建回调函数和结果存储字典
    callback_collector, answers = create_answer_collector()

    # 提交查询并注册回调
    callback_futures = []
    for i, query_text in enumerate(queries):
        question = revised_queries[i]
        print(f"提交查询 {i+1}: '{query_text}'")
        future = query_manager.submit_query(query_text=query_text, query_context=query_context)
        
        # 使用functools.partial创建带参数的回调函数
        from functools import partial
        callback_func = partial(callback_collector, query_idx=i+1, query_text=question)
        
        # 注册回调函数
        future.add_done_callback(callback_func)
        callback_futures.append((i+1, query_text, future))
    
    # Wait for all Futures to complete (optional but ensures all callbacks execute)
    import concurrent.futures
    import time
    
    # Non-blocking check
    all_done = False
    wait_time = 0
    max_wait_time = 1200  # Maximum wait time
    check_interval = 5  # Check interval
    
    print("\nWaiting for callbacks to execute...")
    while not all_done and wait_time < max_wait_time:
        all_done = all(future[2].done() for future in callback_futures)
        if not all_done:
            print(f"Waited {wait_time} seconds, continuing to wait for callbacks...")
            time.sleep(check_interval)
            wait_time += check_interval
    
    if all_done:
        print("\nAll callbacks have completed!")
    else:
        print(f"\nTimeout waiting, some queries may not have completed. Waited {wait_time} seconds.")
    
    # Stop query manager
    print("\nStopping QueryManager...")
    query_manager.stop()
    print("QueryManager stopped.")
    
    print("--- Callback Function Test Finished ---")
# Out:
# --- Starting Callback Function Test ---
# Class name cache updated with 13364 classes.
# 数据属性缓存更新完成，共 5859 个属性
# 对象属性缓存更新完成，共 4557 个属性
# 所有本体缓存更新完成
# Dispatcher loop started on thread QueryDispatcherThread
# Query Manager dispatcher started.
# 提交查询 1: 'How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?'
#
# Waiting for callbacks to execute...
# Waited 0 seconds, continuing to wait for callbacks...
# Waited 5 seconds, continuing to wait for callbacks...
# Waited 10 seconds, continuing to wait for callbacks...
# Retry count: 0
# Waited 15 seconds, continuing to wait for callbacks...
# Waited 20 seconds, continuing to wait for callbacks...
# Retry count: 1
# Retry count: 1
# http://www.test.org/chem_ontologies/meta/
# http://www.test.org/chem_ontologies/classes/
# http://www.test.org/chem_ontologies/object_properties/
# http://www.test.org/chem_ontologies/data_properties/
# Retry count: 1
# {
#   "results": [
#     {
#       "tool": "get_class_info",
#       "params": {
#         "class_names": [
#           "electrochemical_sensor",
#           "indicator_displacement_assay",
#           "indicator_displacement_assay(IDA)",
#           "quinine",
#           "stability",
#           "reproducibility",
#           "reproducibility_study"
#         ]
#       },
#       "result": {
#         "electrochemical_sensor": {
#           "name": "electrochemical_sensor",
#           "information": [
#             "Nanocomposite based electrochemical sensor properties of polyaniline decorated with silver nanoparticles were utilized for the determination of 5-FU.",
#             "Electrochemical sensors belong to the established methods of nucleotide detection.",
#             "An electrochemical sensor employing host-guest interactions of Q(8) was applied to the determination of tryptophan in real samples."
#           ]
#         },
#         "indicator_displacement_assay": {
#           "name": "indicator_displacement_assay",
#           "information": [
#             "Indicator displacement assay, coupled with differential sensing, enables ultrasensitive and specific detection of LPA.",
#             "Post-translational modifications in proteins are mainly detected using indicator displacement assays.",
#             "An indicator displacement assay is a sensing method where a dye is displaced from a host molecule by an analyte, resulting in a measurable signal.",
#             "Indicator displacement assays are analytical techniques in which a host molecule binds to an indicator dye, and the displacement of the dye by a guest molecule is used to detect the presence of the guest.",
#             "Several more recent studies also measured the affinity of these complexes, using indicator displacement assays, in different conditions."
#           ]
#         },
#         "indicator_displacement_assay(IDA)": {
#           "name": "indicator_displacement_assay(IDA)",
#           "information": [
#             "Through IDA coupled with differential sensing, we achieved the ultrasensitive and specific detection of LPA.",
#             "Indicator displacement assay (IDA) is a method used for ultrasensitive fluorescence detection of LPA in aqueous media."
#           ]
#         },
#         "quinine": {
#           "name": "quinine",
#           "information": []
#         },
#         "stability": {
#           "name": "stability",
#           "information": [
#             "Stability describes the persistence and robustness of the host-guest complexes under various conditions.",
#             "Other positive features include improved stability."
#           ]
#         },
#         "reproducibility": {
#           "name": "reproducibility",
#           "information": []
#         },
#         "reproducibility_study": {
#           "name": "reproducibility_study",
#           "information": []
#         }
#       }
#     },
#     {
#       "tool": "get_class_properties",
#       "params": {
#         "class_names": [
#           "electrochemical_sensor",
#           "indicator_displacement_assay",
#           "indicator_displacement_assay(IDA)",
#           "quinine",
#           "stability",
#           "reproducibility",
#           "reproducibility_study"
#         ]
#       },
#       "result": {
#         "electrochemical_sensor": {
#           "stability": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "high stability with acceptable peak current decrease within 21 days",
#                 "raw_value": "high stability with acceptable peak current decrease within 21 days"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "Negligible change in DPV signal during first 7 days at 4°C; 86.47% of original value retained up to 21 days.",
#                 "raw_value": "Negligible change in DPV signal during first 7 days at 4°C; 86.47% of original value retained up to 21 days."
#               },
#               {
#                 "type": "VALUE",
#                 "value": "high stability with acceptable peak current decrease within 21 days",
#                 "raw_value": "high stability with acceptable peak current decrease within 21 days"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "Negligible change in DPV signal during first 7 days at 4°C; 86.47% of original value retained up to 21 days.",
#                 "raw_value": "Negligible change in DPV signal during first 7 days at 4°C; 86.47% of original value retained up to 21 days."
#               }
#             ],
#             "descriptions": []
#           },
#           "is_used_for_detection_of": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "tryptophan(Trp)",
#                 "raw_value": "classes.tryptophan(Trp)"
#               },
#               {
#                 "type": "SOME",
#                 "value": "tryptophan(Trp)",
#                 "raw_value": "classes.tryptophan(Trp)"
#               }
#             ],
#             "descriptions": [
#               {
#                 "content": "single(tryptophan(Trp))",
#                 "source": "10.1016/j.aca.2020.09.028",
#                 "file_path": null
#               }
#             ]
#           },
#           "simplicity": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "simple",
#                 "raw_value": "simple"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "simple",
#                 "raw_value": "simple"
#               }
#             ],
#             "descriptions": []
#           },
#           "has_detection_target": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "quinine",
#                 "raw_value": "classes.quinine"
#               },
#               {
#                 "type": "SOME",
#                 "value": "quinine",
#                 "raw_value": "classes.quinine"
#               }
#             ],
#             "descriptions": []
#           },
#           "repeatability": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "Five independent electrodes displayed similar signals when detecting 30 μM quinine.",
#                 "raw_value": "Five independent electrodes displayed similar signals when detecting 30 μM quinine."
#               },
#               {
#                 "type": "VALUE",
#                 "value": "Five independent electrodes displayed similar signals when detecting 30 μM quinine.",
#                 "raw_value": "Five independent electrodes displayed similar signals when detecting 30 μM quinine."
#               }
#             ],
#             "descriptions": []
#           },
#           "is_realized_as": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "sensing_platform",
#                 "raw_value": "classes.sensing_platform"
#               },
#               {
#                 "type": "SOME",
#                 "value": "sensing_platform",
#                 "raw_value": "classes.sensing_platform"
#               }
#             ],
#             "descriptions": []
#           },
#           "value_retention": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "86.47% of original DPV signal value retained up to 21 days.",
#                 "raw_value": "86.47% of original DPV signal value retained up to 21 days."
#               },
#               {
#                 "type": "VALUE",
#                 "value": "86.47% of original DPV signal value retained up to 21 days.",
#                 "raw_value": "86.47% of original DPV signal value retained up to 21 days."
#               }
#             ],
#             "descriptions": []
#           },
#           "is_based_on": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "nanocomposite",
#                 "raw_value": "classes.nanocomposite"
#               },
#               {
#                 "type": "SOME",
#                 "value": "nanocomposite",
#                 "raw_value": "classes.nanocomposite"
#               }
#             ],
#             "descriptions": [
#               {
#                 "content": "single(nanocomposite)",
#                 "source": "10.1007/s00706-021-02736-4",
#                 "file_path": null
#               }
#             ]
#           },
#           "reproducibility": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "good reproducibility",
#                 "raw_value": "good reproducibility"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "Relative standard deviation of 2.06% across seven identical electrodes.",
#                 "raw_value": "Relative standard deviation of 2.06% across seven identical electrodes."
#               },
#               {
#                 "type": "VALUE",
#                 "value": "good reproducibility",
#                 "raw_value": "good reproducibility"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "Relative standard deviation of 2.06% across seven identical electrodes.",
#                 "raw_value": "Relative standard deviation of 2.06% across seven identical electrodes."
#               }
#             ],
#             "descriptions": []
#           },
#           "cost_effectiveness": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "cost-effective",
#                 "raw_value": "cost-effective"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "cost-effective",
#                 "raw_value": "cost-effective"
#               }
#             ],
#             "descriptions": []
#           },
#           "is_verified_by": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "None",
#                 "raw_value": null
#               },
#               {
#                 "type": "SOME",
#                 "value": "differential_pulse_voltammetry(DPV) OR cyclic_voltammetry(CV) OR proton_nuclear_magnetic_resonance(H_NMR) OR scanning_electron_microscopy(SEM) OR electrochemical_impedance_analysis(EIS) OR fourier_transform_infrared(FTIR)",
#                 "raw_value": "classes.differential_pulse_voltammetry(DPV) | classes.cyclic_voltammetry(CV) | classes.proton_nuclear_magnetic_resonance(H_NMR) | classes.scanning_electron_microscopy(SEM) | classes.electrochemical_impedance_analysis(EIS) | classes.fourier_transform_infrared(FTIR)"
#               }
#             ],
#             "descriptions": []
#           },
#           "is_used_for": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "nucleotide",
#                 "raw_value": "classes.nucleotide"
#               },
#               {
#                 "type": "SOME",
#                 "value": "nucleotide",
#                 "raw_value": "classes.nucleotide"
#               }
#             ],
#             "descriptions": [
#               {
#                 "content": "single(nucleotide)",
#                 "source": null,
#                 "file_path": null
#               }
#             ]
#           },
#           "reusability": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "reusable",
#                 "raw_value": "reusable"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "reusable",
#                 "raw_value": "reusable"
#               }
#             ],
#             "descriptions": []
#           },
#           "selectivity": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "superior selectivity over common interfering molecules",
#                 "raw_value": "superior selectivity over common interfering molecules"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "superior selectivity over common interfering molecules",
#                 "raw_value": "superior selectivity over common interfering molecules"
#               }
#             ],
#             "descriptions": []
#           },
#           "is_constructed_by": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "indicator_displacement_assay(IDA)",
#                 "raw_value": "classes.indicator_displacement_assay(IDA)"
#               },
#               {
#                 "type": "SOME",
#                 "value": "indicator_displacement_assay(IDA)",
#                 "raw_value": "classes.indicator_displacement_assay(IDA)"
#               }
#             ],
#             "descriptions": []
#           },
#           "precision": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "reasonable",
#                 "raw_value": "reasonable"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "reasonable",
#                 "raw_value": "reasonable"
#               }
#             ],
#             "descriptions": [
#               {
#                 "content": "reasonable",
#                 "source": "10.1016/j.aca.2020.09.028",
#                 "file_path": null
#               }
#             ]
#           },
#           "has_property": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "None",
#                 "raw_value": null
#               },
#               {
#                 "type": "SOME",
#                 "value": "sensor_selectivity OR sensor_reusability OR sensor_reproducibility OR sensor_stability",
#                 "raw_value": "classes.sensor_selectivity | classes.sensor_reusability | classes.sensor_reproducibility | classes.sensor_stability"
#               }
#             ],
#             "descriptions": []
#           },
#           "accuracy": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "reasonable",
#                 "raw_value": "reasonable"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "reasonable",
#                 "raw_value": "reasonable"
#               }
#             ],
#             "descriptions": [
#               {
#                 "content": "reasonable",
#                 "source": "10.1016/j.aca.2020.09.028",
#                 "file_path": null
#               }
#             ]
#           }
#         },
#         "indicator_displacement_assay": {
#           "detects": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "trimethylated_lysine",
#                 "raw_value": "classes.trimethylated_lysine"
#               },
#               {
#                 "type": "SOME",
#                 "value": "trimethylated_lysine",
#                 "raw_value": "classes.trimethylated_lysine"
#               }
#             ],
#             "descriptions": [
#               {
#                 "content": "single(trimethylated_lysine)",
#                 "source": "10.1039/C7NR02491F",
#                 "file_path": null
#               }
#             ]
#           },
#           "uses_as_recognition_element": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "deep_cavitand",
#                 "raw_value": "classes.deep_cavitand"
#               },
#               {
#                 "type": "SOME",
#                 "value": "deep_cavitand",
#                 "raw_value": "classes.deep_cavitand"
#               }
#             ],
#             "descriptions": [
#               {
#                 "content": "single(deep_cavitand)",
#                 "source": "10.1039/C7NR02491F",
#                 "file_path": null
#               }
#             ]
#           },
#           "has_component": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "None",
#                 "raw_value": null
#               },
#               {
#                 "type": "SOME",
#                 "value": "carboxylato_pillar(6)_arene(WP6) OR safranine_T(ST)",
#                 "raw_value": "classes.carboxylato_pillar(6)_arene(WP6) | classes.safranine_T(ST)"
#               }
#             ],
#             "descriptions": []
#           },
#           "assay_location": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "lipid membrane constructs, living cells",
#                 "raw_value": "lipid membrane constructs, living cells"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "lipid membrane constructs, living cells",
#                 "raw_value": "lipid membrane constructs, living cells"
#               }
#             ],
#             "descriptions": [
#               {
#                 "content": "lipid membrane constructs, living cells",
#                 "source": "10.1039/c6cc04771hHost",
#                 "file_path": null
#               }
#             ]
#           },
#           "indicator_dye": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "lucigenin",
#                 "raw_value": "lucigenin"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "dye_28",
#                 "raw_value": "dye_28"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "lucigenin",
#                 "raw_value": "lucigenin"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "dye_28",
#                 "raw_value": "dye_28"
#               }
#             ],
#             "descriptions": [
#               {
#                 "content": "(lucigenin, dye_28)",
#                 "source": "10.1039/c6cc04771hHost",
#                 "file_path": null
#               }
#             ]
#           },
#           "selectivity": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "caffeine",
#                 "raw_value": "caffeine"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "caffeine",
#                 "raw_value": "caffeine"
#               }
#             ],
#             "descriptions": []
#           },
#           "is_applied_for": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "caffeine_sensing",
#                 "raw_value": "classes.caffeine_sensing"
#               },
#               {
#                 "type": "SOME",
#                 "value": "caffeine_sensing",
#                 "raw_value": "classes.caffeine_sensing"
#               }
#             ],
#             "descriptions": []
#           }
#         },
#         "indicator_displacement_assay(IDA)": {
#           "has_analyte": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "analyte",
#                 "raw_value": "classes.analyte"
#               },
#               {
#                 "type": "SOME",
#                 "value": "analyte",
#                 "raw_value": "classes.analyte"
#               }
#             ],
#             "descriptions": []
#           },
#           "has_receptor": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "synthetic_receptor",
#                 "raw_value": "classes.synthetic_receptor"
#               },
#               {
#                 "type": "SOME",
#                 "value": "synthetic_receptor",
#                 "raw_value": "classes.synthetic_receptor"
#               }
#             ],
#             "descriptions": []
#           },
#           "has_indicator": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "indicator",
#                 "raw_value": "classes.indicator"
#               },
#               {
#                 "type": "SOME",
#                 "value": "indicator",
#                 "raw_value": "classes.indicator"
#               }
#             ],
#             "descriptions": []
#           },
#           "biological_location": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "inside live cells",
#                 "raw_value": "inside live cells"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "inside live cells",
#                 "raw_value": "inside live cells"
#               }
#             ],
#             "descriptions": []
#           },
#           "has_component": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "None",
#                 "raw_value": null
#               },
#               {
#                 "type": "SOME",
#                 "value": "beta-cyclodextrin(beta-CD) OR poly(N-acetylaniline) OR graphene",
#                 "raw_value": "classes.beta-cyclodextrin(beta-CD) | classes.poly(N-acetylaniline) | classes.graphene"
#               }
#             ],
#             "descriptions": []
#           },
#           "is_performed_in": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "live_cell",
#                 "raw_value": "classes.live_cell"
#               },
#               {
#                 "type": "SOME",
#                 "value": "live_cell",
#                 "raw_value": "classes.live_cell"
#               }
#             ],
#             "descriptions": []
#           },
#           "has_monitoring_target": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "hypoxia",
#                 "raw_value": "classes.hypoxia"
#               },
#               {
#                 "type": "SOME",
#                 "value": "hypoxia",
#                 "raw_value": "classes.hypoxia"
#               }
#             ],
#             "descriptions": []
#           },
#           "is_coupled_with": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "differential_sensing",
#                 "raw_value": "classes.differential_sensing"
#               },
#               {
#                 "type": "SOME",
#                 "value": "differential_sensing",
#                 "raw_value": "classes.differential_sensing"
#               }
#             ],
#             "descriptions": [
#               {
#                 "content": "single(differential_sensing)",
#                 "source": "10.1039/C7SC04989G",
#                 "file_path": null
#               }
#             ]
#           },
#           "assay_type": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "indicator displacement assay",
#                 "raw_value": "indicator displacement assay"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "indicator displacement assay",
#                 "raw_value": "indicator displacement assay"
#               }
#             ],
#             "descriptions": []
#           },
#           "has_sensor_output": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "optical_sensor",
#                 "raw_value": "classes.optical_sensor"
#               },
#               {
#                 "type": "SOME",
#                 "value": "optical_sensor",
#                 "raw_value": "classes.optical_sensor"
#               }
#             ],
#             "descriptions": []
#           },
#           "interaction_type": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "non-covalent",
#                 "raw_value": "non-covalent"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "non-covalent",
#                 "raw_value": "non-covalent"
#               }
#             ],
#             "descriptions": []
#           },
#           "has_sensing_target": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "None",
#                 "raw_value": null
#               },
#               {
#                 "type": "SOME",
#                 "value": "analyte OR metal_cation OR anion OR drug OR biological_molecule",
#                 "raw_value": "classes.analyte | classes.metal_cation | classes.anion | classes.drug | classes.biological_molecule"
#               }
#             ],
#             "descriptions": []
#           },
#           "has_signaling_unit": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "signaling_unit",
#                 "raw_value": "classes.signaling_unit"
#               },
#               {
#                 "type": "SOME",
#                 "value": "signaling_unit",
#                 "raw_value": "classes.signaling_unit"
#               }
#             ],
#             "descriptions": []
#           },
#           "sensor_conversion_capability": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "yes",
#                 "raw_value": "yes"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "yes",
#                 "raw_value": "yes"
#               }
#             ],
#             "descriptions": []
#           }
#         },
#         "quinine": {
#           "is_diluted_in": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "phosphate_buffer_solution(pbs)",
#                 "raw_value": "classes.phosphate_buffer_solution(pbs)"
#               },
#               {
#                 "type": "SOME",
#                 "value": "phosphate_buffer_solution(pbs)",
#                 "raw_value": "classes.phosphate_buffer_solution(pbs)"
#               }
#             ],
#             "descriptions": []
#           },
#           "is_detected_by": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "quantitative_electrochemical_method",
#                 "raw_value": "classes.quantitative_electrochemical_method"
#               },
#               {
#                 "type": "SOME",
#                 "value": "ion_transfer_voltammetry(itv)",
#                 "raw_value": "classes.ion_transfer_voltammetry(itv)"
#               },
#               {
#                 "type": "SOME",
#                 "value": "electrochemiluminescence_biosensor",
#                 "raw_value": "classes.electrochemiluminescence_biosensor"
#               },
#               {
#                 "type": "SOME",
#                 "value": "quantitative_electrochemical_method",
#                 "raw_value": "classes.quantitative_electrochemical_method"
#               },
#               {
#                 "type": "SOME",
#                 "value": "ion_transfer_voltammetry(itv)",
#                 "raw_value": "classes.ion_transfer_voltammetry(itv)"
#               },
#               {
#                 "type": "SOME",
#                 "value": "electrochemiluminescence_biosensor",
#                 "raw_value": "classes.electrochemiluminescence_biosensor"
#               }
#             ],
#             "descriptions": []
#           },
#           "stock_solution_concentration": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "10 mM",
#                 "raw_value": "10 mM"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "10 mM",
#                 "raw_value": "10 mM"
#               }
#             ],
#             "descriptions": []
#           },
#           "use_as_bittering_agent": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "bittering_agent",
#                 "raw_value": "bittering_agent"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "bittering_agent",
#                 "raw_value": "bittering_agent"
#               }
#             ],
#             "descriptions": []
#           },
#           "is_analyzed_by": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "electrochemical_technique",
#                 "raw_value": "classes.electrochemical_technique"
#               },
#               {
#                 "type": "SOME",
#                 "value": "high_performance_liquid_chromatography(hplc)",
#                 "raw_value": "classes.high_performance_liquid_chromatography(hplc)"
#               },
#               {
#                 "type": "SOME",
#                 "value": "colorimetric_assay",
#                 "raw_value": "classes.colorimetric_assay"
#               },
#               {
#                 "type": "SOME",
#                 "value": "fluorescence_assay",
#                 "raw_value": "classes.fluorescence_assay"
#               },
#               {
#                 "type": "SOME",
#                 "value": "high_resolution_mass_spectrometry(hrms)",
#                 "raw_value": "classes.high_resolution_mass_spectrometry(hrms)"
#               },
#               {
#                 "type": "SOME",
#                 "value": "electrochemical_technique",
#                 "raw_value": "classes.electrochemical_technique"
#               },
#               {
#                 "type": "SOME",
#                 "value": "high_performance_liquid_chromatography(hplc)",
#                 "raw_value": "classes.high_performance_liquid_chromatography(hplc)"
#               },
#               {
#                 "type": "SOME",
#                 "value": "colorimetric_assay",
#                 "raw_value": "classes.colorimetric_assay"
#               },
#               {
#                 "type": "SOME",
#                 "value": "fluorescence_assay",
#                 "raw_value": "classes.fluorescence_assay"
#               },
#               {
#                 "type": "SOME",
#                 "value": "high_resolution_mass_spectrometry(hrms)",
#                 "raw_value": "classes.high_resolution_mass_spectrometry(hrms)"
#               }
#             ],
#             "descriptions": []
#           },
#           "has_component": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "alkaloid",
#                 "raw_value": "classes.alkaloid"
#               },
#               {
#                 "type": "SOME",
#                 "value": "cinchona_tree_bark",
#                 "raw_value": "classes.cinchona_tree_bark"
#               },
#               {
#                 "type": "SOME",
#                 "value": "alkaloid",
#                 "raw_value": "classes.alkaloid"
#               },
#               {
#                 "type": "SOME",
#                 "value": "cinchona_tree_bark",
#                 "raw_value": "classes.cinchona_tree_bark"
#               }
#             ],
#             "descriptions": []
#           },
#           "solvent_for_stock_solution": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "ethanol",
#                 "raw_value": "ethanol"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "ethanol",
#                 "raw_value": "ethanol"
#               }
#             ],
#             "descriptions": []
#           },
#           "proton_peak_shift": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "slight shift",
#                 "raw_value": "slight shift"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "slight shift",
#                 "raw_value": "slight shift"
#               }
#             ],
#             "descriptions": []
#           },
#           "solubility_in_water": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "low",
#                 "raw_value": "low"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "low",
#                 "raw_value": "low"
#               }
#             ],
#             "descriptions": []
#           },
#           "hydrophobicity": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "hydrophobic",
#                 "raw_value": "hydrophobic"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "hydrophobic",
#                 "raw_value": "hydrophobic"
#               }
#             ],
#             "descriptions": []
#           },
#           "application": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "malaria",
#                 "raw_value": "malaria"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "lupus",
#                 "raw_value": "lupus"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "arthritis",
#                 "raw_value": "arthritis"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "muscle_cramp",
#                 "raw_value": "muscle_cramp"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "malaria",
#                 "raw_value": "malaria"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "lupus",
#                 "raw_value": "lupus"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "arthritis",
#                 "raw_value": "arthritis"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "muscle_cramp",
#                 "raw_value": "muscle_cramp"
#               }
#             ],
#             "descriptions": []
#           },
#           "role_in_detection_scheme": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "target",
#                 "raw_value": "target"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "target",
#                 "raw_value": "target"
#               }
#             ],
#             "descriptions": []
#           },
#           "is_determined_by": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "differential_pulse_voltammetry(DPV)",
#                 "raw_value": "classes.differential_pulse_voltammetry(DPV)"
#               },
#               {
#                 "type": "SOME",
#                 "value": "differential_pulse_voltammetry(DPV)",
#                 "raw_value": "classes.differential_pulse_voltammetry(DPV)"
#               }
#             ],
#             "descriptions": []
#           },
#           "adverse_health_effect": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "thrombocytopenia",
#                 "raw_value": "thrombocytopenia"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "thrombotic_microangiopathy",
#                 "raw_value": "thrombotic_microangiopathy"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "blindness",
#                 "raw_value": "blindness"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "acute_kidney_injury",
#                 "raw_value": "acute_kidney_injury"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "thrombocytopenia",
#                 "raw_value": "thrombocytopenia"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "thrombotic_microangiopathy",
#                 "raw_value": "thrombotic_microangiopathy"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "blindness",
#                 "raw_value": "blindness"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "acute_kidney_injury",
#                 "raw_value": "acute_kidney_injury"
#               }
#             ],
#             "descriptions": []
#           },
#           "is_used_for": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "malaria",
#                 "raw_value": "classes.malaria"
#               },
#               {
#                 "type": "SOME",
#                 "value": "lupus",
#                 "raw_value": "classes.lupus"
#               },
#               {
#                 "type": "SOME",
#                 "value": "arthritis",
#                 "raw_value": "classes.arthritis"
#               },
#               {
#                 "type": "SOME",
#                 "value": "muscle_cramp",
#                 "raw_value": "classes.muscle_cramp"
#               },
#               {
#                 "type": "SOME",
#                 "value": "bittering_agent",
#                 "raw_value": "classes.bittering_agent"
#               },
#               {
#                 "type": "SOME",
#                 "value": "malaria",
#                 "raw_value": "classes.malaria"
#               },
#               {
#                 "type": "SOME",
#                 "value": "lupus",
#                 "raw_value": "classes.lupus"
#               },
#               {
#                 "type": "SOME",
#                 "value": "arthritis",
#                 "raw_value": "classes.arthritis"
#               },
#               {
#                 "type": "SOME",
#                 "value": "muscle_cramp",
#                 "raw_value": "classes.muscle_cramp"
#               },
#               {
#                 "type": "SOME",
#                 "value": "bittering_agent",
#                 "raw_value": "classes.bittering_agent"
#               }
#             ],
#             "descriptions": []
#           },
#           "recovery": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "98.3% to 109.3%",
#                 "raw_value": "98.3% to 109.3%"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "98.3% to 109.3%",
#                 "raw_value": "98.3% to 109.3%"
#               }
#             ],
#             "descriptions": []
#           },
#           "induces": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "thrombocytopenia",
#                 "raw_value": "classes.thrombocytopenia"
#               },
#               {
#                 "type": "SOME",
#                 "value": "thrombotic_microangiopathy",
#                 "raw_value": "classes.thrombotic_microangiopathy"
#               },
#               {
#                 "type": "SOME",
#                 "value": "blindness",
#                 "raw_value": "classes.blindness"
#               },
#               {
#                 "type": "SOME",
#                 "value": "acute_kidney_injury",
#                 "raw_value": "classes.acute_kidney_injury"
#               },
#               {
#                 "type": "SOME",
#                 "value": "thrombocytopenia",
#                 "raw_value": "classes.thrombocytopenia"
#               },
#               {
#                 "type": "SOME",
#                 "value": "thrombotic_microangiopathy",
#                 "raw_value": "classes.thrombotic_microangiopathy"
#               },
#               {
#                 "type": "SOME",
#                 "value": "blindness",
#                 "raw_value": "classes.blindness"
#               },
#               {
#                 "type": "SOME",
#                 "value": "acute_kidney_injury",
#                 "raw_value": "classes.acute_kidney_injury"
#               }
#             ],
#             "descriptions": []
#           },
#           "molar_ratio": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "1:1 (with β-CD)",
#                 "raw_value": "1:1 (with β-CD)"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "1:1 (with β-CD)",
#                 "raw_value": "1:1 (with β-CD)"
#               }
#             ],
#             "descriptions": []
#           },
#           "is_dissolved_in": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "ethanol",
#                 "raw_value": "classes.ethanol"
#               },
#               {
#                 "type": "SOME",
#                 "value": "ethanol",
#                 "raw_value": "classes.ethanol"
#               }
#             ],
#             "descriptions": []
#           },
#           "incubation_time": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "40 min",
#                 "raw_value": "40 min"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "40",
#                 "raw_value": 40
#               },
#               {
#                 "type": "VALUE",
#                 "value": "40 min",
#                 "raw_value": "40 min"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "40",
#                 "raw_value": 40
#               }
#             ],
#             "descriptions": []
#           }
#         },
#         "stability": {
#           "assesses_stability_by": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "peak_current",
#                 "raw_value": "classes.peak_current"
#               },
#               {
#                 "type": "SOME",
#                 "value": "peak_current",
#                 "raw_value": "classes.peak_current"
#               }
#             ],
#             "descriptions": []
#           }
#         },
#         "reproducibility": {
#           "achieves_reproducibility_by": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "fabrication_method",
#                 "raw_value": "classes.fabrication_method"
#               },
#               {
#                 "type": "SOME",
#                 "value": "fabrication_method",
#                 "raw_value": "classes.fabrication_method"
#               }
#             ],
#             "descriptions": []
#           }
#         },
#         "reproducibility_study": {}
#       }
#     }
#   ]
# }
# Waited 25 seconds, continuing to wait for callbacks...
# Waited 30 seconds, continuing to wait for callbacks...
# Retry count: 1
# In retry logic, Retry count: 1
# Enhanced Feedback Got
# Waited 35 seconds, continuing to wait for callbacks...
# Waited 40 seconds, continuing to wait for callbacks...
# Retry count: 2
# Retry count: 2
# http://www.test.org/chem_ontologies/meta/
# http://www.test.org/chem_ontologies/classes/
# http://www.test.org/chem_ontologies/object_properties/
# http://www.test.org/chem_ontologies/data_properties/
# Retry count: 2
# {
#   "results": [
#     {
#       "tool": "get_class_info",
#       "params": {
#         "class_names": [
#           "electrochemical_sensor",
#           "indicator_displacement_assay",
#           "indicator_displacement_assay(IDA)",
#           "indicator_displacement_assay(ida)",
#           "quinine",
#           "stability",
#           "reproducibility",
#           "reproducibility_study"
#         ]
#       },
#       "result": {
#         "electrochemical_sensor": {
#           "name": "electrochemical_sensor",
#           "information": [
#             "Nanocomposite based electrochemical sensor properties of polyaniline decorated with silver nanoparticles were utilized for the determination of 5-FU.",
#             "Electrochemical sensors belong to the established methods of nucleotide detection.",
#             "An electrochemical sensor employing host-guest interactions of Q(8) was applied to the determination of tryptophan in real samples."
#           ]
#         },
#         "indicator_displacement_assay": {
#           "name": "indicator_displacement_assay",
#           "information": [
#             "Indicator displacement assay, coupled with differential sensing, enables ultrasensitive and specific detection of LPA.",
#             "Post-translational modifications in proteins are mainly detected using indicator displacement assays.",
#             "An indicator displacement assay is a sensing method where a dye is displaced from a host molecule by an analyte, resulting in a measurable signal.",
#             "Indicator displacement assays are analytical techniques in which a host molecule binds to an indicator dye, and the displacement of the dye by a guest molecule is used to detect the presence of the guest.",
#             "Several more recent studies also measured the affinity of these complexes, using indicator displacement assays, in different conditions."
#           ]
#         },
#         "indicator_displacement_assay(IDA)": {
#           "name": "indicator_displacement_assay(IDA)",
#           "information": [
#             "Through IDA coupled with differential sensing, we achieved the ultrasensitive and specific detection of LPA.",
#             "Indicator displacement assay (IDA) is a method used for ultrasensitive fluorescence detection of LPA in aqueous media."
#           ]
#         },
#         "indicator_displacement_assay(ida)": {
#           "name": "indicator_displacement_assay(ida)",
#           "information": [
#             "IDA is an approach compatible with differential sensing, as arrays can be easily constructed by combining multiple receptors and multiple indicators."
#           ]
#         },
#         "quinine": {
#           "name": "quinine",
#           "information": []
#         },
#         "stability": {
#           "name": "stability",
#           "information": [
#             "Stability describes the persistence and robustness of the host-guest complexes under various conditions.",
#             "Other positive features include improved stability."
#           ]
#         },
#         "reproducibility": {
#           "name": "reproducibility",
#           "information": []
#         },
#         "reproducibility_study": {
#           "name": "reproducibility_study",
#           "information": []
#         }
#       }
#     }
#   ]
# }
# Waited 45 seconds, continuing to wait for callbacks...
# Retry count: 2
# In retry logic, Retry count: 2
# Enhanced Feedback Got
# Waited 50 seconds, continuing to wait for callbacks...
# Waited 55 seconds, continuing to wait for callbacks...
# Waited 60 seconds, continuing to wait for callbacks...
# Retry count: 3
# Retry count: 3
# http://www.test.org/chem_ontologies/meta/
# http://www.test.org/chem_ontologies/classes/
# http://www.test.org/chem_ontologies/object_properties/
# http://www.test.org/chem_ontologies/data_properties/
# Retry count: 3
# {
#   "results": [
#     {
#       "tool": "get_class_info",
#       "params": {
#         "class_names": [
#           "electrochemical_sensor",
#           "indicator_displacement_assay",
#           "quinine",
#           "stability",
#           "reproducibility",
#           "reproducibility_study"
#         ]
#       },
#       "result": {
#         "electrochemical_sensor": {
#           "name": "electrochemical_sensor",
#           "information": [
#             "Nanocomposite based electrochemical sensor properties of polyaniline decorated with silver nanoparticles were utilized for the determination of 5-FU.",
# ...
#               },
#               {
#                 "type": "SOME",
#                 "value": "fluorescence_assay",
#                 "raw_value": "classes.fluorescence_assay"
#               },
#               {
#                 "type": "SOME",
#                 "value": "high_resolution_mass_spectrometry(hrms)",
#                 "raw_value": "classes.high_resolution_mass_spectrometry(hrms)"
#               },
#               {
#                 "type": "SOME",
#                 "value": "electrochemical_technique",
#                 "raw_value": "classes.electrochemical_technique"
#               },
#               {
#                 "type": "SOME",
#                 "value": "high_performance_liquid_chromatography(hplc)",
#                 "raw_value": "classes.high_performance_liquid_chromatography(hplc)"
#               },
#               {
#                 "type": "SOME",
#                 "value": "colorimetric_assay",
#                 "raw_value": "classes.colorimetric_assay"
#               },
#               {
#                 "type": "SOME",
#                 "value": "fluorescence_assay",
#                 "raw_value": "classes.fluorescence_assay"
#               },
#               {
#                 "type": "SOME",
#                 "value": "high_resolution_mass_spectrometry(hrms)",
#                 "raw_value": "classes.high_resolution_mass_spectrometry(hrms)"
#               }
#             ],
#             "descriptions": []
#           },
#           "has_component": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "alkaloid",
#                 "raw_value": "classes.alkaloid"
#               },
#               {
#                 "type": "SOME",
#                 "value": "cinchona_tree_bark",
#                 "raw_value": "classes.cinchona_tree_bark"
#               },
#               {
#                 "type": "SOME",
#                 "value": "alkaloid",
#                 "raw_value": "classes.alkaloid"
#               },
#               {
#                 "type": "SOME",
#                 "value": "cinchona_tree_bark",
#                 "raw_value": "classes.cinchona_tree_bark"
#               }
#             ],
#             "descriptions": []
#           },
#           "solvent_for_stock_solution": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "ethanol",
#                 "raw_value": "ethanol"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "ethanol",
#                 "raw_value": "ethanol"
#               }
#             ],
#             "descriptions": []
#           },
#           "proton_peak_shift": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "slight shift",
#                 "raw_value": "slight shift"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "slight shift",
#                 "raw_value": "slight shift"
#               }
#             ],
#             "descriptions": []
#           },
#           "solubility_in_water": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "low",
#                 "raw_value": "low"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "low",
#                 "raw_value": "low"
#               }
#             ],
#             "descriptions": []
#           },
#           "hydrophobicity": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "hydrophobic",
#                 "raw_value": "hydrophobic"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "hydrophobic",
#                 "raw_value": "hydrophobic"
#               }
#             ],
#             "descriptions": []
#           },
#           "application": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "malaria",
#                 "raw_value": "malaria"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "lupus",
#                 "raw_value": "lupus"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "arthritis",
#                 "raw_value": "arthritis"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "muscle_cramp",
#                 "raw_value": "muscle_cramp"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "malaria",
#                 "raw_value": "malaria"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "lupus",
#                 "raw_value": "lupus"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "arthritis",
#                 "raw_value": "arthritis"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "muscle_cramp",
#                 "raw_value": "muscle_cramp"
#               }
#             ],
#             "descriptions": []
#           },
#           "role_in_detection_scheme": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "target",
#                 "raw_value": "target"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "target",
#                 "raw_value": "target"
#               }
#             ],
#             "descriptions": []
#           },
#           "is_determined_by": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "differential_pulse_voltammetry(DPV)",
#                 "raw_value": "classes.differential_pulse_voltammetry(DPV)"
#               },
#               {
#                 "type": "SOME",
#                 "value": "differential_pulse_voltammetry(DPV)",
#                 "raw_value": "classes.differential_pulse_voltammetry(DPV)"
#               }
#             ],
#             "descriptions": []
#           },
#           "adverse_health_effect": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "thrombocytopenia",
#                 "raw_value": "thrombocytopenia"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "thrombotic_microangiopathy",
#                 "raw_value": "thrombotic_microangiopathy"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "blindness",
#                 "raw_value": "blindness"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "acute_kidney_injury",
#                 "raw_value": "acute_kidney_injury"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "thrombocytopenia",
#                 "raw_value": "thrombocytopenia"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "thrombotic_microangiopathy",
#                 "raw_value": "thrombotic_microangiopathy"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "blindness",
#                 "raw_value": "blindness"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "acute_kidney_injury",
#                 "raw_value": "acute_kidney_injury"
#               }
#             ],
#             "descriptions": []
#           },
#           "is_used_for": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "malaria",
#                 "raw_value": "classes.malaria"
#               },
#               {
#                 "type": "SOME",
#                 "value": "lupus",
#                 "raw_value": "classes.lupus"
#               },
#               {
#                 "type": "SOME",
#                 "value": "arthritis",
#                 "raw_value": "classes.arthritis"
#               },
#               {
#                 "type": "SOME",
#                 "value": "muscle_cramp",
#                 "raw_value": "classes.muscle_cramp"
#               },
#               {
#                 "type": "SOME",
#                 "value": "bittering_agent",
#                 "raw_value": "classes.bittering_agent"
#               },
#               {
#                 "type": "SOME",
#                 "value": "malaria",
#                 "raw_value": "classes.malaria"
#               },
#               {
#                 "type": "SOME",
#                 "value": "lupus",
#                 "raw_value": "classes.lupus"
#               },
#               {
#                 "type": "SOME",
#                 "value": "arthritis",
#                 "raw_value": "classes.arthritis"
#               },
#               {
#                 "type": "SOME",
#                 "value": "muscle_cramp",
#                 "raw_value": "classes.muscle_cramp"
#               },
#               {
#                 "type": "SOME",
#                 "value": "bittering_agent",
#                 "raw_value": "classes.bittering_agent"
#               }
#             ],
#             "descriptions": []
#           },
#           "recovery": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "98.3% to 109.3%",
#                 "raw_value": "98.3% to 109.3%"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "98.3% to 109.3%",
#                 "raw_value": "98.3% to 109.3%"
#               }
#             ],
#             "descriptions": []
#           },
#           "induces": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "thrombocytopenia",
#                 "raw_value": "classes.thrombocytopenia"
#               },
#               {
#                 "type": "SOME",
#                 "value": "thrombotic_microangiopathy",
#                 "raw_value": "classes.thrombotic_microangiopathy"
#               },
#               {
#                 "type": "SOME",
#                 "value": "blindness",
#                 "raw_value": "classes.blindness"
#               },
#               {
#                 "type": "SOME",
#                 "value": "acute_kidney_injury",
#                 "raw_value": "classes.acute_kidney_injury"
#               },
#               {
#                 "type": "SOME",
#                 "value": "thrombocytopenia",
#                 "raw_value": "classes.thrombocytopenia"
#               },
#               {
#                 "type": "SOME",
#                 "value": "thrombotic_microangiopathy",
#                 "raw_value": "classes.thrombotic_microangiopathy"
#               },
#               {
#                 "type": "SOME",
#                 "value": "blindness",
#                 "raw_value": "classes.blindness"
#               },
#               {
#                 "type": "SOME",
#                 "value": "acute_kidney_injury",
#                 "raw_value": "classes.acute_kidney_injury"
#               }
#             ],
#             "descriptions": []
#           },
#           "molar_ratio": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "1:1 (with β-CD)",
#                 "raw_value": "1:1 (with β-CD)"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "1:1 (with β-CD)",
#                 "raw_value": "1:1 (with β-CD)"
#               }
#             ],
#             "descriptions": []
#           },
#           "is_dissolved_in": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "ethanol",
#                 "raw_value": "classes.ethanol"
#               },
#               {
#                 "type": "SOME",
#                 "value": "ethanol",
#                 "raw_value": "classes.ethanol"
#               }
#             ],
#             "descriptions": []
#           },
#           "incubation_time": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "40 min",
#                 "raw_value": "40 min"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "40",
#                 "raw_value": 40
#               },
#               {
#                 "type": "VALUE",
#                 "value": "40 min",
#                 "raw_value": "40 min"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "40",
#                 "raw_value": 40
#               }
#             ],
#             "descriptions": []
#           }
#         }
#       }
#     },
#     {
#       "tool": "get_related_classes",
#       "params": {
#         "class_names": [
#           "electrochemical_sensor",
#           "indicator_displacement_assay",
#           "quinine"
#         ]
#       },
#       "result": {
#         "electrochemical_sensor": {
#           "is_used_for_detection_of": [
#             "tryptophan(Trp)"
#           ],
#           "has_detection_target": [
#             "quinine"
#           ],
#           "is_realized_as": [
#             "sensing_platform"
#           ],
#           "is_based_on": [
#             "nanocomposite"
#           ],
#           "is_verified_by": [
#             "cyclic_voltammetry(CV)",
#             "differential_pulse_voltammetry(DPV)",
#             "electrochemical_impedance_analysis(EIS)",
#             "fourier_transform_infrared(FTIR)",
#             "proton_nuclear_magnetic_resonance(H_NMR)",
#             "scanning_electron_microscopy(SEM)"
#           ],
#           "is_used_for": [
#             "nucleotide"
#           ],
#           "is_constructed_by": [
#             "indicator_displacement_assay(IDA)"
#           ],
#           "has_property": [
#             "sensor_reproducibility",
#             "sensor_reusability",
#             "sensor_selectivity",
#             "sensor_stability"
#           ]
#         },
#         "indicator_displacement_assay": {
#           "detects": [
#             "trimethylated_lysine"
#           ],
#           "uses_as_recognition_element": [
#             "deep_cavitand"
#           ],
#           "has_component": [
#             "carboxylato_pillar(6)_arene(WP6)",
#             "safranine_T(ST)"
#           ],
#           "is_applied_for": [
#             "caffeine_sensing"
#           ]
#         },
#         "quinine": {
#           "is_diluted_in": [
#             "phosphate_buffer_solution(pbs)"
#           ],
#           "is_detected_by": [
#             "electrochemiluminescence_biosensor",
#             "ion_transfer_voltammetry(itv)",
#             "quantitative_electrochemical_method"
#           ],
#           "is_analyzed_by": [
#             "colorimetric_assay",
#             "electrochemical_technique",
#             "fluorescence_assay",
#             "high_performance_liquid_chromatography(hplc)",
#             "high_resolution_mass_spectrometry(hrms)"
#           ],
#           "has_component": [
#             "alkaloid",
#             "cinchona_tree_bark"
#           ],
#           "is_determined_by": [
#             "differential_pulse_voltammetry(DPV)"
#           ],
#           "is_used_for": [
#             "arthritis",
#             "bittering_agent",
#             "lupus",
#             "malaria",
#             "muscle_cramp"
#           ],
#           "induces": [
#             "acute_kidney_injury",
#             "blindness",
#             "thrombocytopenia",
#             "thrombotic_microangiopathy"
#           ],
#           "is_dissolved_in": [
#             "ethanol"
#           ]
#         }
#       }
#     }
#   ]
# }
# Waited 100 seconds, continuing to wait for callbacks...
# Waited 105 seconds, continuing to wait for callbacks...
# Retry count: 4
# In retry logic, Retry count: 4
# Exceeded maximum retry attempts (4)
# Waited 110 seconds, continuing to wait for callbacks...
# Waited 115 seconds, continuing to wait for callbacks...
# Retry count: 4
# ----------------------------------------------------------------------------------------------------
# formatted_results found
#
# All callbacks have completed!
#
# Stopping QueryManager...
# Stopping Query Manager...
# Dispatcher loop exiting.
# Shutting down query executor...
# 查询 1 的答案已保存
# Query Manager stopped.
# QueryManager stopped.
# --- Callback Function Test Finished ---

# %%
future_list = [future[2].result() for future in callback_futures]
future_list
# Out:
# [{'query': 'How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?',
#   'source_ontology': OntologySettings(base_iri='http://www.test.org/chem_ontologies/', ontology_file_name='final.owl', directory_path='D:\\\\CursorProj\\\\Chem-Ontology-Constructor\\\\data\\ontology', closed_ontology_file_name='IDA-closed.owl'),
#   'query_type': 'information_retrieval',
#   'query_strategy': 'tool_sequence',
#   'originating_team': 'test_notebook',
#   'originating_stage': 'manual_test',
#   'available_classes': ['(2)pseudorotaxane',
#    '(3)pseudorotaxane',
#    '(4)(cl)3',
#    '(4)(pf6)3',
#    '(M + H)+',
#    '(Nb6Cl12(H2O)6)@(gamma-CD)2)2+',
#    '(Ta6Br12(H2O)6)@(gamma-CD)2)Br2.14H2O',
#    '(bmim)',
#    '(bmim)(octs)',
#    '(cl)-',
#    '(cu4)(cl)·5',
#    '(ethylamino)carbonyl-2-pyridinecarboxylic_acid',
#    '(h4)(pf6)2',
#    '(nb6br12)n+',
#    '(nb6cl12)n+',
#    '(nb6i12)n+',
#    '(octs)',
#    '(pf6)-',
#    '(ta6br12)n+',
#    '(ta6cl12)n+',
#    '(ta6i12)n+',
#    '1,1-butane(1,4-diyl)bis(2-aminopyridine)_bromide(DPAD)',
#    '1,1-ferrocenedicarboxylic_acid',
#    '1,2-bis(pyridium)thane_g15',
#    '1,3-benzenediacetic_acid',
#    '1,3-benzenediacetyl_dichloride',
#    '1,4-butane_sultone',
#    '1,4-dimethylcyclohexane',
#    '1,4-dioxane',
#    '1,4-ditert-butylbenzene',
#    '1,6-dibromopyrene',
#    '1,8-ANS',
#    '1,8-ans',
#    '1,8-dibromopyrene',
#    '1-adamantanecarbonitrile',
#    '1-alkyl-6-alkoxy-quinolinium',
#    '1-alkyl_substituent',
#    '1-anilinonaphthalene-8-sulfonate(Ans)',
#    '1-butyl-3-methylimidazolium_octyl_sulfate((BMIM)(OctS))',
#    '1-butyl-3-methylimidazolium_octyl_sulfate(BMIM(OctS))',
#    '1-decyl_substituent',
#    '1-dodecene',
#    '1-heptadecyne',
#    '1-iodoalkyne',
#    '1-naphthylamine',
#    '1-tetradecyl_substituent',
#    '12,13-dihydro-11h-4,7,11,14,17-pentaaza-1(2,6)-benzo(de)isoquinolina-9(1,6)pyrenacycloheptadecaphane-11,13-dione',
#    '12_cb(8)',
#    '13-3-3_protein',
#    '13C_NMR',
#    '13_c(1_h)_nmr_spectrum',
#    '13_c-nmr',
#    '13_c_nmr',
#    '13_cnmr',
#    '13c-nmr',
#    '13c_1h_nmr_spectroscopy',
#    '13c_nmr',
#    '13c_nmr_spectroscopy',
#    '13c_nmr_spectrum',
#    '14-3-3_protein',
#    '14-3-3σ',
#    '14_3_3beta_protein',
#    '14_3_3sigma_protein',
#    '188W_188Re_generator',
#    '19_f_nmr_spectrum',
#    '19f_nmr_spectroscopy',
#    '1:1_complex',
#    '1:1_complexation',
#    '1:2.5_bsp_cb(7)_ratio',
#    '1:2_complex',
#    '1:2_host-guest_interaction',
#    '1H-1H_ROESY_spectrum',
#    '1H-NMR',
#    '1H_NMR',
#    '1H_NMR_spectra',
#    '1H_NMR_spectroscopy',
#    '1H_NMR_titration',
#    '1H_chemical_shift',
#    '1H_nmr',
#    '1_1_1_complex',
#    '1_1_1_heteroternary_inclusion_complex',
#    '1_1_adduct',
#    '1_1_complex',
#    '1_1_complex_of_5·cb(8)',
#    '1_1_complexation',
#    '1_1_ferrocenedicarboxylic_acid',
#    '1_1_model',
#    '1_2-dichloroethane',
#    '1_2_3_triazole',
#    '1_2_alternate_conformation',
#    '1_2_complex',
#    '1_2_epoxyethylbenzene',
#    '1_2_host-guest_complex',
#    '1_2pd',
#    '1_3-o_to_n_acyl_transfer',
#    '1_3_alternate_conformation',
#    '1_3_dimethylimidazolium',
#    '1_3_phenylene_unit',
#    '1_3_phenylenediacetic_acid',
#    '1_4-ditert-butylbenzene',
#    '1_4_diaryl_triazole_oligomer',
#    '1_4_diazabicyclooctanetriethylenediamine',
#    '1_4_dibromobutane',
#    '1_4_dichlorobutane',
#    '1_4_dihalogenated_butane',
#    '1_4_diiodobutane',
#    '1_4_dioxane',
#    '1_4_ditert_butylbenzene',
#    '1_HNMR_spectroscopy',
#    '1_H_NMR_spectroscopy',
#    '1_adamantanecarbonitrile',
#    '1_adamantanol',
#    '1_alkyl_6_alkoxyquinolinium_salt',
#    '1_alkyl_6_methoxy_quinolium',
#    '1_alkyl_6_methoxy_quinolium_bromide',
#    '1_alkyl_6_methoxyquinolinium',
#    '1_butyl_3_methylimidazolium_octyl_sulfate(BMIM(OctS))',
#    '1_butyl_3_methylimidazolium_octyl_sulfate_BMIM(OctS)',
#    '1_butyl_3_methylimidazolium_octylsulphate(BMIM(OctS))',
#    '1_butyl_3_methylimidazolium_octylsulphate(BMIM)(OctS)',
#    '1_butyl_3_methylimidazolium_octylsulphate_BMIM_OctS',
#    '1_h_nmr',
#    '1_h_nmr_spectrum',
#    '1_heptadecyne',
#    '1_hnmr',
#    '1_hnmr_spectra',
#    '1_hnmr_spectroscopy',
#    '1_lambda_5-stibaindole',
#    '1_methyl_3_tetradecyl_imidazolium(c14mim+)',
#    '1_methyl_6_alkoxy_quinolium_iodide',
#    '1_methyl_6_alkoxyquinolinium',
#    '1_methyl_homopiperazine',
#    '1_methyl_piperazine',
#    '1_methylpicolinium(NMPic)',
#    '1_methylpiperazine',
#    '1_methylpyridinium(NMpy)',
#    '1_tetradecyl_6_methoxy_quinolium_bromide(C14C1OQ(+)Br(-))',
#    '1_to_1_binding_stoichiometry',
#    '1_to_1_complex',
#    '1a',
#    '1a-d',
#    '1a_capsule',
#    '1ah',
#    '1b',
#    '1c',
#    '1c-4c-appended_host-guest_complex',
#    '1d',
#    '1d_nmr_spectrum',
#    '1h-1h_cosy_spectrum',
#    '1h-1h_noesy',
#    '1h-1h_roesy_spectrum',
#    '1h-nmr',
#    '1h_15n_hsqc',
#    '1h_1h_noesy',
#    '1h_1h_roesy_nmr_experiment',
#    '1h_nmr',
#    '1h_nmr_chemical_shift',
#    '1h_nmr_spectra',
#    '1h_nmr_spectral_data',
#    '1h_nmr_spectroscopy',
#    '1h_nmr_spectrum',
#    '1h_nmr_titration',
#    '1h_nmr_titration_experiment',
#    '1h_nuclear_magnetic_resonance_spectroscopy(1H_NMR)',
#    '1h_roesy_experiment',
#    '1h_roesy_spectrum',
#    '1h_signal',
#    "2,2'aracyclophane",
#    '2,2-(ethyne-1,2-diyl)dibenzoic_acid(45)',
#    '2,2_(ethyne-1,2-diyl)dibenzodicarbonyl_chloride',
#    '2,2_(ethyne-1,2-diyl)dibenzoic_acid',
#    '2,3-diazabicyclo(2.2.2)oct-2-ene(DBO)',
#    '2,4_pentadione',
#    '2,6-ANS',
#    '2,6-ans',
#    '2,6-helic(6)arene',
#    '2,6-helic(6)arene_derivative',
#    '2,6-helix(6)arene',
#    '2,6-lutidine',
#    '2,6-pyridinecarboxamide_spacer',
#    '2,6_helic(6)arene_rac_1',
#    '2,7-dimethyl-diazaphenanthrenium(DPT)',
#    '2,7-dimethyl-diazaphenanthrenium(dpt)',
#    '2-(4-(2-hydroxy_ethyl)-1-piperazinyl)-ethanesulfonic_acid(HEPES)_buffer',
#    '2-aminobenzimidazole',
#    '2-aminobenzimidazoles',
#    '2-aminoethanol',
#    '2-arachidonylglycerol',
#    '2-methylpentane',
#    '2013',
#    '2014',
#    '250-ml_round-bottom_flask',
#    '25_degree_celsius',
#    '2:1_complexation',
#    '2:1_homoternary_complex',
#    '2:1_host_guest_complex',
#    '2:2_binding_mode',
#    '2:3_binding_mode',
#    '2PF@Q(8)_complex',
#    '2_1_adduct',
#    '2_1_complex',
#    '2_1_complex_of_12·cb(8)',
#    '2_1_complex_of_1·cb(8)',
#    '2_1_complexation',
#    '2_1_homoternary_inclusion_complex',
#    '2_1_host_guest_complex',
#    '2_2_(ethyne_1_2_diyl)dibenzoic_acid',
#    '2_2_4_trimethylpentane',
#    '2_2_binding_mode',
#    '2_2_complex',
#    '2_2_dimethylhexane',
#    '2_2_dimethylpentane',
#    '2_3_complex',
#    '2_4_pentadione',
#    '2_aminomethylbenzimidazole',
#    '2_methylhexane',
#    '2_methylpentane',
#    '2_te',
#    '2_to_1_binding_stoichiometry',
#    '2d-roesy_nmr_spectrum',
#    '2d_13c_spectrum',
#    '2d_1h_spectrum',
#    '2d_exsy_experiment',
#    '2d_ir_vibrational_echo_chemical_exchange_spectroscopy',
#    '2d_nmr',
#    '2d_nmr_spectra',
#    '2d_nmr_spectrum',
#    '2d_noesy_nmr',
#    '2d_noesy_nmr_spectroscopy',
#    '2d_noesy_spectra',
#    '2d_noesy_spectrum',
#    '2h1_n_epsilon_me_lys_hcl',
#    '2i',
#    '2pf@cucurbit(8)uril',
#    '2pf@cucurbit(8)uril(Q(8))',
#    '2pf@cucurbituril_8(q(8))',
#    '2pf@cucurbituril_8(q(8))+gef',
#    '2pf@q(8)',
#    '2pf@q(8)_complex',
#    '2phe_gly_gly_cucurbit(8)uril_complex(2phe_gly_gly_CB(8))',
#    '2pyrene_derivative@cucurbit(8)uril(2PF@Q(8))',
#    '2te',
#    '2te_capsule',
#    '2x-protonated_receptor',
#    '3,5_heptadione',
#    '3-(2-phenylhydrazono)pentane-2,4-dione',
#    '3-aminopropanoic_acid_b-alanine_spacer',
#    '3-fma',
#    '3-iodopyridinium_unit',
#    '3-methoxyphenol',
#    '31p_nmr',
#    '31p_nmr_spectra',
#    '3_5_heptadione',
#    '3_fluoromethamphetamine(3_fma)',
#    '3_pseudorotaxane(h+)(2)_bsp_cb(7)(2)',
#    '3d_colloidal_crystal_of_t-rex_bead',
#    '4',
#    '4(cl)3',
#    '4(dodecyloxy)benzamido_terminated_methoxy_peg',
#    "4,4'-bipyridinium_salt",
#    "4,4'-diaminodiphenylmethane",
#    '4,4-benzidine_dihydrochloride',
#    '4,4-bipyridyl_derivative',
#    '4,4-dimethylstilbene',
#    '4,4-methylbiphenyl',
#    '4,4_prime_bipyridinium_salt',
#    '4-(anthracen-2-yl)pyridine-2,6-dicarboxylic_acid',
#    '4-(boc-aminomethyl)benzylamine',
#    '4-(boc-aminomethyl)benzylamine(43)',
#    '4-bromo-1,8-naphthalic_anhydride',
#    '4-bromo-naphthanhydride',
#    '4-dimethylaminopyridine(DMAP)',
#    '4-hydroxyacetophenone',
#    '4-n,n-dimethylamino-1,8-naphthalimide',
#    '4-nitrobenzoyl_chloride',
#    '4_4_bipyridine_prime_derivative',
#    '4_4_dimethylamino_styryl_1_phenylpyridiniumiodide(phst)',
#    '4_4_dimethylbiphenyl',
#    '4_4_prime_bipyridinium',
#    '4_7_di_2_thienyl_2_1_3_benzothiadiazole',
#    '4_amino_1_8_naphthalene_imide_fluorophore',
#    '4_aminonaphthaleneimide',
#    '4_hydroxyproline(4-hyp)',
#    '4_hydroxyproline(4_hyp)',
#    '4_phenylazophenol',
#    '4_sulfonatocalix(4)arene(SCX4)',
#    '4_sulfonatocalix(6)arene(SCX6)',
#    '4_sulfonatocalix(n)arene(SCXn)',
#    '4_sulfonatocalix(n)arene(scxn)',
#    '4a',
#    '4sulfonatocalix(4_or_6)arene',
#    '5,10,15,20-tetraphenylporphyrin(H2TPP)',
#    "5,6_carboxy_2',7'_dichlorofluoresceindiacetate(DCFH-DA)",
#    '5-(methyltellanyl)_triazole',
#    '5-FU_drug',
#    '5-fluorouracil(5-FU)',
#    '5-fluorouracil(5-FU)_molecule',
#    '5-fu',
#    '5-iodo-1,2,3-triazole',
#    '50-ml_round-bottom_flask',
#    '5_cb(8)',
#    '5_fluorouracil(5-FU)',
#    '5_fluorouracil(5_FU)_molecule',
#    '5_formylcytosine',
#    '5_fu',
#    '5_iodotriazole',
#    '5_methyltellanyl_triazole',
#    '5_organotellanyl1h_1,2,3_triazole',
#    '5c-6c-based_opv_2+_-h_guest',
#    '5c-6c-based_opv_2+_-me_guest',
#    '6-(ethylamino)carbonyl-2-pyridinecarboxylic_acid(44)',
#    '6-(ethylcarbamoyl)pyridine-2-carboxylic_acid',
#    '6-state',
#    '6:0_lpa',
#    '6:0_lysophosphatidic_acid(6:0_LPA)',
#    '6_31g(d,p)_basis_set',
#    '6_anilinonaphthalene_2_sulfonate(2,6-ANS)',
#    '6_methoxy_1_methylquinolinium(c1c1oq+)',
#    '6_p_toluidinonaphthalene_2_sulfonate(TNS)',
#    '6_well_cell_culture_plate',
#    '6a',
#    '6p_toluidinonaphthalene_2_sulfonate(TNS)',
#    '7-(diethylamino)coumarin-3-carboxylic_acid_n-succinimidyl_ester(7-DCCAE)',
#    '7-(diethylamino)coumarin-3-carboxylic_acid_n-succinimidyl_ester(7DCCAE)',
#    '7-dccae',
#    '7-dccae-cb7',
#    '7-dccae-cb7_complex',
#    '7-dccae-cb7_reverse_complex',
#    '7-dccae-cb8',
#    '7-dccae-cb8_complex',
#    '7-dccae-cb8_reverse_complex',
#    '7-dccae-cd',
#    '7-diethylaminocoumarin-3-carboxylic_acid_ethyl_ester(7-DCCAE)',
#    '7-methoxycoumarin_derivative_4',
#    '7_dccae',
#    '7_dccae_beta_cd_complex',
#    '7_dccae_cb7_complex',
#    '7_dccae_cb8_complex',
#    '7_dccae_cucurbituril_8_complex(7DCCAE-CB8_complex)',
#    '7_dccae_gamma_cd_complex',
#    '7_dccae_molecule',
#    '7_dccea',
#    '7_dicyanomethylene_2_cyanoacrylate_ethyl_ester(7DCCAE)',
#    '7_diethylamino_coumarin_3_carboxylic_acid_n_succinimidyl_ester(7_DCCAE)',
#    '7_methoxycoumarin_moiety',
#    '7c-9c_appended_guest',
#    '7dccae',
#    '7mer_sequence',
#    '8-anilinonaphthalene-1-sulfonic_acid(ANS)',
#    '8_anilino_1naphthalenesulfonic_acid',
#    '8_anilinonaphthalene_1_sulfonate(1,8-ANS)',
#    '9-anthrylmethyl_methyl_ammonium_chloride',
#    '9-fluorenylmethyl_oxycarbonyl(Fmoc)_solid_phase_synthesis',
#    '96-well_cell_culture_treated_plate',
#    '96-well_plate',
#    '973_program(2011CB932502)',
#    '99Mo_99mTc_generator',
#    '99Tc',
#    '9_ethyladenine',
#    'AA)',
#    'ABAM_cucurbit(7)uril',
#    'AC',
#    'ADDATRX',
#    'AIE_active_scaffold',
#    'AIE_characteristic',
#    'AIE_luminogen(AIEgen)',
#    'AR-Kme_1-STGGK',
#    'AR-Kme_2-STGGK',
#    'AR-Kme_3-STGGK',
#    'ATP',
#    'A_grade_glassware',
#    'Ac',
#    'Ac-D-Glu-D-Glu-D-Glu-D-Glu-OH',
#    'Ac-Kmex_GGY-NH2',
#    'AcCh',
#    'AcCh_SCX4_complex',
#    'AcH+_SCX4',
#    'AcH+_SCX4_AcCh',
#    'AcH_+',
#    'AcH_plus_SCX4_AcCh_ternary_system',
#    'AcH_plus_SCX4_complex',
#    'AcOEt',
#    'AcOH',
#    'Ac_SCX4',
#    'Ag(AgCl)_reference_electrode',
#    'AgNO3',
#    'Ag_plus(Ag)_reference_electrode',
#    'B3LYP_6-31G*_basis_set',
#    'BER',
#    'BODIPY_moiety',
#    'BPC10',
#    'BPC2',
#    'BPC4',
#    'BPC6',
#    'BPC8',
#    'BPX',
#    'BPicC4',
#    'BSA',
#    'Bruker_Avance_spectrometer',
#    'Bruker_BIFLEX_III_mass_spectrometer',
#    'Bruker_ULTRASHIELD_400',
#    'C-H_pi-interaction',
#    'C-H_pi_interaction',
#    'C-RafpS259',
#    'C13H10NCl',
#    'C14C1OQ_plus',
#    'C14C1OQ_plus_SCX6_nanoparticle',
#    'C14mim_plus',
#    'C1C10OQ+I-',
#    'C1C10OQ_plus',
#    'C1C12OQ+I-',
#    'C1C12OQ_plus',
#    'C1C8OQ_plus',
#    'C1CmOQ(+)_homologue',
#    'C21H25BrN3O4',
#    'C2C12_cell',
#    'C4A',
#    'C4TS',
#    'C5A',
#    'C6A',
#    'C8A',
#    'CA-based_assembly',
#    'CB(7)',
#    'CB(7)-grafted_hyaluronic_acid(HA)',
#    'CB(7)_FGG_complex',
#    'CB(7)_FGX_complex',
#    'CB(8)',
#    'CB(8)-induced_intertubular_aggregation',
#    'CB-based_biomacromolecular_assembly',
#    'CB-tubulin_supramolecular_assembly',
#    'CB6',
#    'CB7',
#    'CB8',
#    'CB8_mediated_heteroternary_complex',
#    'CB8_mediated_homoternary_complex',
#    'CB_based_device',
#    'CB_n_hydrophobic_cavity',
#    'CBn',
#    'CBs',
#    'CD-based_assembly',
#    'CD3CN',
#    'CDCl3',
#    'CD_spectrum',
#    'CENMe3',
#    'CH2Cl2',
#    'CH3CN',
#    'CHCl3',
#    'CHI_1040C_electrochemical_workstation',
#    'CHI_660E_electrochemical_workstation',
#    'CH_pi_interaction',
#    'CHp_interaction',
#    'COSY',
#    'CWP6',
#    'C_H_S_hydrogen_bond',
#    'C_H_pi_interaction',
#    'C_terminal',
#    'Cav(R1,R2,R3)',
#    'CmC1OQ(+)_cation',
#    'CmC1OQ_plus',
#    'D-Ala',
#    'D-Lac',
#    'D2O',
#    'DFT_calculation',
#    'DNA',
#    'DNA_secondary_structure',
#    'DOSY',
#    'DOSY_NMR_spectroscopy',
#    'DSMI',
#    'DSMI_TCC_premixed_complex',
#    'DTMI',
#    'D_acetyl_aspartate(D-Ac-Asp)',
#    'D_isomer',
#    'Dox',
#    'E-AAP-1',
#    'EKAA',
#    'EPR_effect',
#    'EPR_spectroscopy',
#    'ESI_MS',
#    'E_Z_isomerization',
#    'E_isomer',
#    'Ebola',
#    'ExoS',
#    'F-IDA',
#    'F-IDA_system',
#    'FGE',
#    'FGE)',
#    'FGG',
#    'FGG)',
#    'FGK',
#    'FGK)',
#    'FGL',
#    'FGL)',
#    'FGR',
#    'FGR)',
#    'FGS',
#    'FGS)',
#    'FGX',
#    'F_IDA',
#    'F_atom',
#    'Fmoc-NH-SAL(rink_amide_resin)',
#    'Fmoc_amino_acid',
#    'G1',
#    'G2',
#    'G3',
#    'G4',
#    'GC5A·AlPcS4_reporter_pair',
#    'Gaussian_03',
#    'GlcNAc-beta-OMe',
#    'Gly_Phe_Gly',
#    'Gly_Trp_Gly',
#    'H-bond',
#    'H1_proton',
#    'H2G_complex',
#    'H2O',
#    'H3K27',
#    'H3K27me3',
#    'H3K4me3',
#    'H3K9me3',
#    'H3_histone_tail',
#    'H3_proton',
#    'H4_proton',
#    'HACD',
#    'HEPES',
#    'HEPES_buffer',
#    'HG_complex',
#    'HIV',
#    'HIV_inhibitory_activity',
#    'HNO3',
#    'HP1',
#    'HPLC_MS',
#    'HSCT_interaction',
#    'H_atom',
#    'H_bond',
#    'HeLa_cell',
#    'ID8_cell',
#    'IDA_protocol',
#    'IGM_isosurface_analysis',
#    'IGM_result',
#    'ING2',
#    'IR_spectroscopy',
#    'ITC',
#    'ITC_measurement',
#    'JASCO_J-725_spectrodichrometer',
#    'JASCO_V-570_spectrometer',
#    'JASCO_V650_double-beam_spectrophotometer',
#    'K2CO3',
#    'K_assoc',
#    'Kme0',
#    'Kme0_Kme3_selectivity',
#    'Kme0_over_Kmex_selectivity',
#    'Kme3',
#    'L-Ala-D-Glu-OH',
#    'L-Lys_residue',
#    'L-asparagine(L-Asn)',
#    'L-lysine',
#    'L_Phe',
#    'L_arginine',
#    'L_histidine',
#    'L_isomer',
#    'L_lysine',
#    'L_tryptophan',
#    'MALDI-TOF-MS',
#    'MALDI-TOF_MS',
#    'MB',
#    'MCT',
#    'MDMA',
#    'MLL5',
#    'MPT',
#    'MitP-MNPs',
#    'MitP-grafted_HA',
#    'MitoView650',
#    "N,N'-bis-tert-butoxycarbonylthiourea",
#    'N-(4-(aminomethyl)benzyl)-1(anthracen-9-yl)methanamine(ABAM)',
#    'N-(aminophenyl)-piperidine',
#    'N-H-1,2,3-triazole',
#    'N-H_O-hydrogen_bond',
#    'N-heterocyclic_analog',
#    'N-heterocyclic_salt',
#    'N-methyl-1,2,3-triazole',
#    'N-methyl_group',
#    'N-terminal_-NH3_plus',
#    'N-terminal_Phe_residue',
#    'N-terminal_phenylalanine(F)_residue',
#    'NARCl_4a',
#    'NARX_family',
#    'NARXs',
#    'NBA-CB7_complex',
#    'NBA_CB7_complex',
#    'NH-donor_site',
#    'NH_group',
#    'NH···X_hydrogen_bond',
#    'NIR_irradiation',
#    'NMR',
#    'NMR_chemical_shift',
#    'NMR_data',
#    'NMR_experiment',
#    'NMR_measurement',
#    'NMR_shift',
#    'NMR_spectroscopy',
#    'NMR_spectrum',
#    'NMR_study',
#    'NMR_timescale',
#    'NMR_titration',
#    'NMR_titration_experiment',
#    'N_N_N_trimethylbenzeneammonium_salt(G5)',
#    'N_alkyl_moiety',
#    'N_atom',
#    'N_terminal',
#    'N_terminal_aromatic_residue',
#    'Na2HPO4',
#    'NaCl',
#    'NaH2PO4',
#    'Nɛ_methyl_group',
#    'O-GlcNAc',
#    'O-GlcNAc_glycopeptide_39',
#    'OA',
#    'OA_1',
#    'OCH3_moiety',
#    'OH_group',
#    'OPV_2+_-2Me_7C-9C',
#    'OPV_2+_-2Me_7C-9C_aqueous_solution',
#    'OPV_2+_-H_5C-6C',
#    'OPV_2+_-Me_5C',
#    'OPV_2+_derivative',
#    'O_atom',
#    'OriginPro_9.1G',
#    'PATGGV-Kme_1-KPHRY',
#    'PATGGV-Kme_2-KPHRY',
#    'PATGGV-Kme_3-KPHRY',
#    'PET_probe',
#    'PF6_counterion',
#    'PMI1',
#    'PMI1(CB8)',
#    'PMMA_cuvette',
#    'POPC_vesicle',
#    'PQ',
#    'P_2p_band',
#    'PerkinElmer_Spectrum_100_FT-IR_spectrometer',
#    'Q(7)',
#    'Q(8)',
#    'Q(8)-based_host-guest_interaction',
#    'Q(8)-chromophore_system',
#    'R1',
#    'R2',
#    'R3',
#    'R5_group',
#    'RBr',
#    'RNA',
#    'ROESY',
#    'R_value',
#    'SC4',
#    'SC4A_system',
#    'SC6',
#    'SC8',
#    'SCX4',
#    'SCX4_macrocyclic_host',
#    'SCX6',
#    'SCXn',
#    'SCXn_complex',
#    'SCXn_containing_supramolecular_amphiphile',
#    'SCXn_macrocycle',
#    'SCn',
#    'SO3-_group',
#    'SR4A5',
#    'Senshu_Pak_PEGASIL_C4_SP100_column',
#    'Shimadzu_CLASS-VP_system',
#    'SnCl4',
#    'SourcedInformation',
#    'Spectra_Manager_version_2.08.04',
#    'Sunset_Yellow(SY)',
#    'TCC',
#    'TCNQ',
#    'TEMOA',
#    'THC',
#    'THF',
#    'THF-d8',
#    'TNS',
#    'TSiiii',
#    'TeCPh',
#    'Tiiii',
#    'Tiiii-Si-MC',
#    'Tiiii-grafted_microcantilever',
#    'Tobias_Gruber',
#    'TsO-TEG-OH',
#    'Tyr_residue',
#    'U-shaped_conformation',
#    'UV-light',
#    'UV_light',
#    'UV_vis_spectroscopy',
#    'Z-AAP-1',
#    'Z-azobenzene',
#    'Z_isomer',
#    'Zeiss_Supra55',
#    'Zika',
#    'a1',
#    'a2',
#    'a_1',
#    'a_2',
#    'a_3',
#    'a_a_alekseyenko',
#    'a_a_gorchakov',
#    'a_beta_40_fibrillation',
#    'a_hennig',
#    'a_johnson',
#    'a_l',
#    'a_minoda',
#    'a_motta',
#    'a_n_nesmeyanov_institute_of_organoelement_compounds_of_russian_academy_of_sciences',
#    'a_p_davis',
#    'a_r_._urbach',
#    'a_shaurya',
#    'aa_motif',
#    'aake',
#    'aap',
#    'aap(AAP)',
#    'aap-1',
#    'aap-10',
#    'aap-11',
#    'aap-12',
#    'aap-13',
#    'aap-14',
#    'aap-15',
#    'aap-16',
#    'aap-2',
#    'aap-3',
#    'aap-4',
#    'aap-5',
#    'aap-6',
#    'aap-7',
#    'aap_1',
#    'aap_1(AAP-1)',
#    'aap_10',
#    'aap_11',
#    'aap_12',
#    'aap_12_p_ome',
#    'aap_13',
#    'aap_13(pi_opr)',
#    'aap_13_p_opr',
#    'aap_14',
#    'aap_15',
#    'aap_16',
#    'aap_17',
#    'aap_18',
#    'aap_19',
#    'aap_1_19',
#    'aap_2',
#    'aap_2(AAP-2)',
#    'aap_3',
#    'aap_3(AAP-3)',
#    'aap_3_m_me',
#    'aap_4',
#    'aap_4(AAP-4)',
#    'aap_5',
#    'aap_5(AAP-5)',
#    'aap_6',
#    'aap_6(AAP-6)',
#    'aap_7',
#    'aap_8',
#    'aap_9',
#    'aap_core',
#    'aap_solution',
#    'aaps',
#    'abiotic_probe',
#    'abiotic_receptor',
#    'absolute_configuration',
#    'absolute_configuration_determination',
#    'absolute_configuration_of_side_chain',
#    'absorbance',
#    'absorbance_amplitude_1',
#    'absorbance_amplitude_2',
#    'absorbance_change',
#    'absorbance_component',
#    'absorbance_intensity',
#    'absorbance_maximum',
#    'absorbance_measurement',
#    'absorbance_peak',
#    'absorbance_spectral_feature',
#    'absorbed_water',
#    'absorption',
#    'absorption_band',
#    'absorption_band_280_nm',
#    'absorption_characteristic',
#    'absorption_difference',
#    'absorption_maximum',
#    'absorption_measurement',
#    'absorption_peak',
#    'absorption_spectra',
#    'absorption_spectra_measurement',
#    'absorption_spectroscopy',
#    'absorption_spectrum',
#    'absorption_study',
#    'absorption_titration_method',
#    'absorption_titration_spectra',
#    'ac',
#    'ac(ac)',
#    'ac-lys-ome_33',
#    'acH_plus_form',
#    'ac_2@q(8)',
#    'ac_2@q(8)_homo-ternary_complex',
#    'ac_ala_trp_trp_nh2',
#    'ac_ala_trp_trp_nh_2',
#    'ac_arg_ome',
#    'ac_form',
#    'ac_his_ome',
#    'ac_lys',
#    'ac_lys_ome',
#    'ac_q(8)',
#    'ac_q(8)_complex',
#    'ac_scx4',
#    'ac_scx4_complex',
#    'ac_scx4_system',
#    'ac_trp_ala_trp_nh2',
#    'ac_trp_ala_trp_nh_2',
#    'ac_trp_trp_ala_nh2',
#    'ac_trp_trp_ala_nh_2',
#    'ac_trp_trp_gly_nh2',
#    'ac_trp_tyr_ala_nh2',
#    'acc_chem_res',
#    'acceleration_reaction',
#    'acceptance',
#    'accepted_date',
#    'acceptor',
#    'acch',
#    'acch(AcCh)',
#    'accounts_of_chemical_research',
#    'accounts_of_chemical_research(Acc._Chem._Res.)',
#    'accounts_of_chemical_research(acc._chem._res.)',
#    'acetal_proton',
#    'acetate',
#    'acetate(Ac)',
#    'acetate(ch3coo)-',
#    'acetate_buffer',
#    'acetate_ion(Ac)',
#    'acetic_acid(AcH)',
#    'acetic_acid(AcOH)',
#    'acetic_acid(CH3COOH)',
#    'acetic_acid(ac)',
#    'acetic_acid_protonated(AcH+)',
#    'acetone',
#    'acetone-d6',
#    'acetone_d',
#    'acetone_d6',
#    'acetonitrile',
#    'acetonitrile(ACN)',
#    'acetonitrile(MeCN)',
#    'acetonitrile(ch3cn)',
#    'acetonitrile_d3(CD_CN_3)',
#    'acetonitrile_solution',
#    'acetonitrile_water',
#    'acetonitrile_water_solvent_system',
#    'acetyl_cation(AcH+)',
#    'acetyl_choline',
#    'acetyl_choline(G1)',
#    'acetyl_group',
#    'acetyl_n-protected_calix(6)tren',
#    'acetyl_proton',
#    'acetyl_thiocholine(G2)',
#    'acetylated_histone_h4kac',
#    'acetylated_l-ala',
#    'acetylated_l_ala',
#    'acetylation',
#    'acetylcholine',
#    'acetylcholine(ACh)',
#    'acetylcholine(AcCh)',
#    'acetylcholine(ach)',
#    'acetylcholine_cation(AcH+)',
#    'acetylcholine_cation_sulfonatocalix(4)arene_acetylcholine_complex(AcH+-SCX4-AcCh complex)',
#    'acetylcholine_cation_sulfonatocalix(4)arene_complex(AcH+-SCX4 complex)',
#    'acetylcholine_chloride(acch)',
#    'acetylcholine_sulfonatocalix(4)arene_binding_interaction(AcCh-SCX4 binding interaction)',
#    'acetylenic_telluride',
#    'acetylhistidine(AcH+)',
#    'acetylhydrazine_cation(AcH+)',
#    'ach',
#    'ach(AcH)',
#    'ach+',
#    'ach_plus',
#    'ach_plus(AcH+)',
#    'ach_plus_scx4',
#    'ach_plus_scx4_acch_mixture',
#    'ach_plus_scx4_acch_system',
#    'ach_plus_scx4_complex',
#    'ach_plus_scx4_dye_complex',
#    'ach_plus_scx4_system',
#    'acid',
#    'acid-base_property',
#    'acid_amino_acid',
#    'acid_base_equilibrium',
#    'acid_base_stability',
#    'acid_catalyzed_condensation',
#    'acid_chloride',
#    'acid_dissociation_constant(ka)',
#    'acid_dissociation_constant(pKa)',
#    'acidic_amino_acid',
#    'acidic_condition',
#    'acidic_conditions',
#    'acidic_environment',
#    'acidic_ethanolic_solution_of_ninhydrin',
#    'acidic_function',
#    'acidic_matrix',
#    'acidic_pH_condition',
#    'aco_minus',
#    'acquisition_of_data',
#    'acridine',
#    'acridine(AC)',
#    'acridine(Ac)',
#    'acridine(ac)',
#    'acridine_derivative',
#    'acridine_dye',
#    'acridine_dye(Ac)',
#    'acridine_hydrochloride(AC)',
#    'acridine_hydrochloride(ac)',
#    'acridine_orange(AO)',
#    'acridine_ring',
#    'acridine_scx4_system(ac_scx4_system)',
#    'acridinium_ion(acH+)',
#    'acridinium_ion_scx4_system(ach_plus_scx4_system)',
#    'acros',
#    'acs_applied_materials_and_interfaces(ACS_Appl._Mater._Interfaces)',
#    'acs_applied_materials_interfaces(acs_appl_mater_interfaces)',
#    'acs_chemical_biology(acs_chem_biol.)',
#    'acs_macromolecules_letters(ACS Macro. Lett.)',
#    'acs_nano',
#    'acs_sensors',
#    'acscx4_dye_complex',
#    'actin-binding_peptide',
#    'actin-cytoskeleton-targeting_multivalent_supramolecular_assembly',
#    'actin_binding_peptide(ABP)',
#    'actin_cytoskeleton',
#    'actinomycin',
#    'activation_barrier_for_thermal_relaxation',
#    'activation_energy',
#    'active_pharmaceutical_ingredient(API)',
#    'activity_coefficient',
#    'acute_kidney_injury',
#    'acute_toxicity',
#    'acyclic_CB',
#    'acyclic_alkane',
#    'acyclic_analogue',
#    'acyclic_carboxylic_acid',
#    'acyclic_hydrocarbon',
#    'acyclic_receptor',
#    'acyclic_small_molecule',
#    'acyl-2-amino-benzimidazoles',
#    'acyl_chain_conformation',
#    'acylamino_moiety',
#    'acylated_residue',
#    'acylation',
#    'ada-bsa',
#    'adamantanamine',
#    'adamantane',
#    'adamantane(Ada)',
#    'adamantane-grafted_bovine_serum_albumin(ada-bsa)',
#    'adamantane-grafted_polyamidoamine_dendrimer',
#    'adamantane-modified_polyethylene_glycol(PEG)',
#    'adamantane-modified_polylysine',
#    'adamantane_modified_cyclic_arginine_glycine_aspartate_peptide',
#    'adamantanol',
#    'adamantanyl-modified_diphenylalanine',
#    'adamantyl_benzenesulfonamide',
#    'adamantyl_group',
#    'adamantyl_moiety',
#    'adamantylamine',
#    'adamantylcarboxamido-benzenesulfonamide',
#    'adamas_beta',
#    'adapter_protein',
#    'addiction',
#    'addictive_drug',
#    'addition',
#    'addition_of_other_functionality',
#    'addition_of_other_protein_or_peptide',
#    'addition_procedure',
#    'adduct',
#    'adenine',
#    'adenine_derivative',
#    'adenosine',
#    'adenosine_monophosphate(AMP)',
#    'adenosine_triphosphate(ATP)',
#    'adenosine_triphosphate(atp)',
#    'adma_containing_peptide(aDMA)',
#    'adrenic_acid',
#    'adsorbate',
#    'adsorbed_residual_solvent',
#    'adsorption',
#    'adsorption_energy',
#    'adsorption_enthalpy',
#    'adsorption_of_ions',
#    'adsorption_process',
#    'adsorption_study',
#    'advanced_drug_delivery_review(adv_drug_deliver_rev)',
#    'advanced_drug_delivery_reviews(Adv._Drug_Delivery_Rev.)',
#    'advanced_functional_materials',
#    'advanced_functional_materials(adv_functl_mater)',
#    'advanced_materials',
#    'advanced_materials(Adv._Mater.)',
#    'advanced_materials(adv_mater)',
#    'advanced_science(Adv. Sci.)',
#    'advanced_therapeutics(adv._therap.)',
#    'affinity',
#    'affinity_chromatography',
#    ...],
#   'available_data_properties': ['13c_1h_nmr_chemical_shifts',
#    '13c_nmr_chemical_shifts',
#    '1h_nmr_chemical_shift',
#    '1h_nmr_chemical_shifts',
#    'a1',
#    'a1_percent',
#    'a1_percentage',
#    'a2',
#    'a2_percent',
#    'a2_percentage',
#    'a_1',
#    'a_2',
#    'ability_to_disrupt_complex',
#    'ability_to_establish_ionic_interaction',
#    'ability_to_function_in_cells',
#    'ability_to_modify_or_detect_analyte',
#    'ability_to_monitor_kinase_activity',
#    'ability_to_monitor_phosphatase_activity',
#    'ability_to_perform_indicator_displacement_assay',
#    'ability_to_rotate_rapidly',
#    'ability_to_solubilize',
#    'ability_to_target_complex_biological_molecules_in_physiologically_relevant_media',
#    'ablation_status',
#    'absolute_configuration',
#    'absolute_configuration_determinability',
#    'absolute_configuration_target',
#    'absolute_enthalpy_change',
#    'absorbance_amplitude_1_percentage',
#    'absorbance_amplitude_2_percentage',
#    'absorbance_at_355nm',
#    'absorbance_at_520_nm',
#    'absorbance_at_wavelength_greater_500nm',
#    'absorbance_change',
#    'absorbance_component_a1_percentage',
#    'absorbance_concentration_relationship',
#    'absorbance_intensity_change',
#    'absorbance_maxima_shift',
#    'absorbance_maximum',
#    'absorbance_maximum_shift',
#    'absorbance_maximum_wavelength',
#    'absorbance_monitoring_range',
#    'absorbance_peak_disappearance',
#    'absorbance_separation',
#    'absorbance_shift_type',
#    'absorbance_spectral_feature',
#    'absorbance_standard_deviation',
#    'absorbance_value_trend',
#    'absorbance_wavelength',
#    'absorbed_water_presence',
#    'absorption_band',
#    'absorption_band_center',
#    'absorption_band_range',
#    'absorption_band_shift',
#    'absorption_band_shift_nm',
#    'absorption_band_similarity',
#    'absorption_band_wavelength',
#    'absorption_coefficient',
#    'absorption_emission_redshift',
#    'absorption_inhibition',
#    'absorption_intensity',
#    'absorption_intensity_change',
#    'absorption_linearity',
#    'absorption_maximum',
#    'absorption_maximum_acetonitrile',
#    'absorption_maximum_final',
#    'absorption_maximum_initial',
#    'absorption_maximum_water',
#    'absorption_maximum_wavelength',
#    'absorption_measurement_wavelength',
#    'absorption_peak_position',
#    'absorption_peak_shift',
#    'absorption_peak_wavelength',
#    'absorption_peak_wavelength_nm',
#    'absorption_property_presence',
#    'absorption_range',
#    'absorption_range_nm',
#    'absorption_shift',
#    'absorption_spectra_shift',
#    'absorption_spectra_similarity',
#    'absorption_spectrum_obtained',
#    'absorption_spectrum_variation',
#    'absorption_wavelength',
#    'absorption_wavelength_nm',
#    'abundance',
#    'abundance_after_selection',
#    'abundance_before_selection',
#    'abundance_in_histone',
#    'acceptance_date',
#    'accepted_date',
#    'accepted_manuscript_policy',
#    'access_method',
#    'access_url',
#    'accessibility',
#    'acch_concentration',
#    'accommodated_alkyldiammonium_cation_number',
#    'accommodated_guest_length_range',
#    'accommodation_depth',
#    'accumulates_at_tumor_site',
#    'accumulation',
#    'accumulation_in_cells',
#    'accumulation_mechanism',
#    'accumulation_region',
#    'accuracy',
#    'acetate_concentration',
#    'acetone_volume_addition',
#    'acetone_volume_suspension',
#    'acetone_volume_wash',
#    'acetylcholine_hydrolysis_inhibition',
#    'ach_plus_concentration',
#    'acid_base_stability_ph_range',
#    'acid_state_in_solution',
#    'acquisition_frequency',
#    'acquisition_temperature',
#    'activation_barrier_order',
#    'activation_energy',
#    'active_cell_volume',
#    'active_form',
#    'active_medium',
#    'activity',
#    'activity_coefficient_in_aqueous_solution',
#    'activity_coefficient_value',
#    'activity_in_disrupting_heterochromatin_marker',
#    'activity_in_fret_biosensor_assay',
#    'activity_state',
#    'acute_toxicity_threshold',
#    'ad_equivalent_added',
#    'adaptability',
#    'adaptive_capacity',
#    'adaptiveness',
#    'added_concentration',
#    'added_volume',
#    'addition_method',
#    'addition_volume_sequence',
#    'additional_alkyl_groups_at_methylene_bridges',
#    'address',
#    'addressability',
#    'adduct_content_inside_cells',
#    'adduct_content_percent',
#    'adjacency',
#    'adjustable_size_and_shape',
#    'adopts_beta_fold',
#    'adsorbed_residual_solvent_percentage',
#    'adsorption',
#    'adsorption_behavior',
#    'adsorption_energy',
#    'adsorption_energy_change',
#    'adsorption_energy_difference_solvent_gas',
#    'adsorption_energy_in_solvent',
#    'adsorption_energy_value',
#    'adsorption_enthalpy',
#    'adsorption_occurred',
#    'adverse_health_effect',
#    'affected_biological_function',
#    'affected_by',
#    'affects_hydrogen_bonding',
#    'affects_water_dynamics',
#    'affiliation',
#    'affinity',
#    'affinity_change_in_acidic_conditions',
#    'affinity_comparable_to_natural_lectin',
#    'affinity_comparable_to_physiological_targets',
#    'affinity_comparison',
#    'affinity_constant',
#    'affinity_constant_change',
#    'affinity_constant_comparison',
#    'affinity_decrease_due_to_ion_concentration',
#    'affinity_dependence_on_degree_of_methylation',
#    'affinity_dependence_on_guest_size',
#    'affinity_dependence_on_r5_group_nature',
#    'affinity_exceeds_nis',
#    'affinity_for_DNA',
#    'affinity_for_anion',
#    'affinity_for_anion_binding',
#    'affinity_for_basic_peptide',
#    'affinity_for_cavitand',
#    'affinity_for_cavitand_1',
#    'affinity_for_cavity',
#    'affinity_for_chloride',
#    'affinity_for_dimethyllysine',
#    'affinity_for_folded_nucleic_acid_strand',
#    'affinity_for_glucose',
#    'affinity_for_kme3_peptide',
#    'affinity_for_peptide',
#    'affinity_for_peptide_sequences',
#    'affinity_for_perrhenate_anion',
#    'affinity_for_primary_amine',
#    'affinity_for_primary_amines',
#    'affinity_for_r_kme3_s_t_peptide_relative_to_trimethyllysine',
#    'affinity_for_target',
#    'affinity_for_trimethylated_peptide',
#    'affinity_for_trimethyllysine',
#    'affinity_for_trimethyllysine_relative_to_other_amino_acids',
#    'affinity_for_trimethyllysine_relative_to_trimethylanilinium',
#    'affinity_improvement_fold',
#    'affinity_increase_for_trimethyllysine',
#    'affinity_kd',
#    'affinity_level',
#    'affinity_measurement_method',
#    'affinity_range',
#    'affinity_relative_to_lysine',
#    'affinity_relative_to_neutral_amino_acid',
#    'affinity_retention',
#    'affinity_to_acetylcholine',
#    'affinity_to_cavity',
#    'affinity_to_fl',
#    'affinity_to_methyllysine_peptides',
#    'affinity_to_tetrasulfonatocalix(4)arene',
#    'affinity_toward_guest',
#    'affinity_towards_acetylated_l-ala',
#    'affinity_towards_acetylated_l_ala',
#    'affinity_towards_aromatic_amino_acid',
#    'affinity_towards_basic_amino_acid',
#    'affinity_towards_guest_molecule',
#    'affinity_towards_nba',
#    'affinity_value',
#    'affinity_with_functionalized_macrocyclic_compound',
#    'affinity_with_macrocycle',
#    'aggregate_formation',
#    'aggregate_presence_broad_absorption',
#    'aggregate_structure',
#    'aggregation_ability',
#    'aggregation_behavior',
#    'aggregation_carbon_chain_length_requirement',
#    'aggregation_control',
#    'aggregation_effect_on_fluorescence',
#    'aggregation_exothermicity_dependence_on_hydrophobic_tail_orientation',
#    'aggregation_induced_emission_behavior',
#    'aggregation_mediator',
#    'aggregation_protection',
#    'aggregation_stability_enhancement',
#    'aggregation_state',
#    'aggregation_suppression',
#    'aggregation_tendency',
#    'agreement_between_methods',
#    'aie_enhancement',
#    'air_stability',
#    'ala_substitution',
#    'aliphatic_chain_conformation',
#    'aliphatic_chain_length',
#    'aliquot_volume',
#    'alkali_metal_binding_site_presence',
#    'alkane_chain_length_range',
#    'alkoxy_group_orientation',
#    'alkyl_chain_flexibility',
#    'alkyl_chain_function',
#    'alkyl_chain_length',
#    'alkyl_chain_length_c',
#    'alkyl_chain_length_effect',
#    'alkyl_chain_orientation',
#    'alkyl_chain_type',
#    'alkyl_content',
#    'alkyl_residue_at_r1',
#    'alkyl_residue_at_r2',
#    'alkyl_spacer_length',
#    'alkyl_substituent_carbon_number_range',
#    'alkylammonium_ion_affinity',
#    'alkylated_at_rim',
#    'alkylation_yield',
#    'all_data_r1_index',
#    'all_data_wr2_index',
#    'all_n_methyl_groups_involved_in_interaction',
#    'alpha_proton_shift',
#    'alpha_value',
#    'amenable_to_biomarker_displacement',
#    'amidated_c_terminus',
#    'amide_count',
#    'amide_group_distance',
#    'amide_nh_signal_shift',
#    'amine_absorption_shift',
#    'amine_equivalents_added',
#    'amine_type',
#    'amino_acid_detection_capability',
#    'amino_acid_sequence',
#    'amino_acid_solution_aliquot_volume',
#    'amino_acid_solution_concentration',
#    'amino_guest_transformation',
#    'amino_substituent_position',
#    'ammonium_group_orientation',
#    'ammonium_group_position',
#    'ammonium_group_type',
#    'amount',
#    'amount_added',
#    'amount_drop',
#    'amount_gram',
#    'amount_millimole',
#    'amount_mmol',
#    'amount_of_amino_acids_added',
#    'amount_of_positive_charge',
#    'amount_substance',
#    'amount_used_mmol',
#    'amphiphilic_character',
#    'amphiphilic_characteristic',
#    'amphiphilic_complementarity',
#    'amphiphilic_state',
#    'amphiphilicity',
#    'amphiphilicity_source',
#    'amphiphilicity_type',
#    'amplification_factor',
#    'amplification_in_presence_of_symmetric_dimethylarginine_peptide',
#    'amplitude_1',
#    'amplitude_2',
#    'amplitude_3',
#    'amplitude_a1_percent',
#    'amplitude_a2_percent',
#    'amyloid_fibrillation_inhibition',
#    'analogy_to_interface_desolvation',
#    'analysis_capability',
#    'analysis_environment',
#    'analysis_performed',
#    'analysis_ph_range',
#    'analysis_software',
#    'analysis_temperature',
#    'analysis_type',
#    'analyte',
#    'analyte_detected',
#    'analyte_detection',
#    'analyte_fluorescence',
#    'analyte_role',
#    'analytical_method',
#    'analytical_method_dissociation_constant',
#    'analytical_performance',
#    'analytical_signal_conversion',
#    'analytical_technique',
#    'analyzed_by',
#    'analyzed_entity',
#    'analyzed_with',
#    'anchoring_point',
#    'anchoring_point_provision',
#    'angle',
#    'angle_cutoff',
#    'angle_with_coordinating_guest_molecule',
#    'animal_free_production',
#    'anion_affinity',
#    'anion_affinity_average',
#    'anion_affinity_range',
#    'anion_affinity_similarity',
#    'anion_binding_affinity',
#    'anion_binding_capability',
#    'anion_binding_preference',
#    'anion_binding_propensity',
#    'anion_binding_property',
#    'anion_binding_selectivity',
#    'anion_binding_selectivity_trend',
#    'anion_coordinated_per_binding_site',
#    'anion_coordination_participation',
#    'anion_metathesis_method',
#    'anion_pi_interaction_capability',
#    'anion_recognition_site_familiarity',
#    'anion_selectivity',
#    'anion_sensing_capability',
#    'anionic_charge_at_upper_rim',
#    'anionic_moiety_type',
#    'anionic_nature',
#    'anisotropic_effect_strength',
#    'anisotropy_decay_fit_function',
#    'anisotropy_decay_fitting_function',
#    'anisotropy_decay_profile',
#    'anisotropy_decay_rate',
#    'annealing_atmosphere',
#    'annealing_temperature',
#    'annealing_time',
#    'annular_amide_count',
#    'antenna_effect',
#    'antenna_effect_ultrahigh',
#    'anticancer_activity',
#    'anticoagulant_property',
#    'antimetastasis_activity',
#    'antithrombotic_property',
#    'antitumor_performance',
#    'apolar_chain_effect_on_recognition',
#    'apolar_nature',
#    'apolar_surface_complementarity',
#    'apoptosis_achieved',
#    'apoptosis_intensity',
#    'apoptosis_observation',
#    'apparent_volume_value',
#    'appearance',
#    'applicability_in_physiological_condition',
#    'applicability_in_water',
#    'application',
#    'application_amino_acid_detection',
#    'application_area',
#    'application_as_chemosensor',
#    'application_bioconjugate_blue_fluorescence_generation',
#    'application_cell_labeling',
#    'application_context',
#    'application_domain',
#    'application_field',
#    'application_hindrance',
#    'application_in_5_fu_complex_formation',
#    'application_in_acetylcholine_sensing',
#    'application_in_amine_drug_detection',
#    'application_in_aqueous_solution',
#    'application_in_caspase_3_determination',
#    'application_in_drug_contamination_removal',
#    'application_in_drug_detection',
#    'application_in_flutamide_detection',
#    'application_in_living_cells',
#    'application_in_norfloxacin_detection',
#    'application_in_rocuronium_monitoring',
#    'application_in_supramolecular_affinity_chromatography',
#    'application_industry',
#    'application_location',
#    'application_potential',
#    'application_promise',
#    'application_prospect',
#    'application_scope',
#    'application_success',
#    'application_timeframe',
#    'applied_in',
#    'applied_in_photonic_logic_computation',
#    'approval_status',
#    'aqueous_compatibility',
#    'architecture_type',
#    'area',
#    'arm_shape',
#    'aromatic_cage_preference',
#    'aromatic_character_extent',
#    'aromatic_moiety_presence',
#    'aromatic_panel_substitution',
#    'aromatic_proton_chemical_shift_change',
#    'aromatic_proton_chemical_shift_range',
#    'aromatic_proton_delta_shift',
#    'aromatic_proton_peak_shape',
#    'aromatic_proton_shift_direction',
#    'aromatic_proton_signal_broadening',
#    'aromatic_proton_signals_at_253K',
#    'aromatic_residue_abundance',
#    'aromatic_residue_count',
#    'aromatic_residue_n_terminal',
#    'aromatic_residue_presence',
#    'aromatic_residue_type',
#    'aromatic_ring_distance',
#    'aromatic_ring_presence',
#    'aromatic_ring_proton_signal_shift',
#    'aromatic_side_chain_orientation',
#    'aromatic_signal_shift',
#    'aromatic_stacking',
#    'aromatic_surface_exposure',
#    'aromatic_surface_extension',
#    'aromatic_surface_presence',
#    'aromatic_unit_capacity',
#    'aromatic_wall_electronic_property',
#    'aromatic_wall_extension',
#    'aromaticity',
#    'arrangement_label',
#    'array_size',
#    'article_number',
#    'aryl_c-h_signal_sharpness_after_heating_and_sonication',
#    'assay_location',
#    'assay_purpose',
#    'assay_suitability',
#    'assay_type',
#    'assembly_behavior',
#    'assembly_enthalpy_change',
#    'assembly_environment',
#    'assembly_formation_phase',
#    'assembly_mechanism',
#    'assembly_method',
#    'assembly_mode',
#    'assembly_mode_control_factor',
#    'assembly_stability',
#    'assembly_state',
#    'assembly_step',
#    'assembly_stoichiometry',
#    'assembly_strength_under_high_salt',
#    'assembly_type',
#    'assembly_with_quinolinium_cations',
#    'associated_state',
#    'association_constant',
#    'association_constant_GlcNAc_beta_OMe',
#    'association_constant_GlcNAc_beta_OMe_wheat_germ_agglutinin',
#    'association_constant_Ka',
#    'association_constant_O_GlcNAc_glycopeptide_39',
#    'association_constant_beta2',
#    'association_constant_determination',
#    'association_constant_for_trimethyllysine',
#    'association_constant_itc',
#    'association_constant_k1',
#    'association_constant_k1_uncertainty',
#    'association_constant_k2',
#    'association_constant_ka',
#    'association_constant_ka_standard_deviation',
#    'association_constant_log_k',
#    'association_constant_logk',
#    'association_constant_nmr',
#    'association_constant_range',
#    'association_constant_value',
#    'association_constant_with_g2',
#    'association_constant_with_g3',
#    'association_constant_with_tcnq',
#    'association_dependence_on_ion_pairing',
#    'association_dependence_on_solvation',
#    'association_strength',
#    'association_thermodynamics_in_methanol',
#    'association_thermodynamics_in_water',
#    'association_with_disease',
#    'association_with_oxidative_stress',
#    'assumed_localization',
#    'atmosphere',
#    'atom_color_scheme',
#    'atoms_relaxed',
#    'atp_concentration',
#    'attachment_position',
#    'attractive_for_applications',
#    'author_count',
#    'author_name',
#    'author_names',
#    'author_order',
#    'autofluorescence_elimination',
#    'autofluorescence_emission_range_nm',
#    'autofluorescence_excitation_wavelength_nm',
#    'autofluorescence_interference_minimization',
#    'automation_application_scope',
#    'automation_resistance_level',
#    'auxiliary_electrode_material',
#    'availability',
#    'availability_free_of_charge',
#    'availability_status',
#    'availability_url',
#    'available_spectra',
#    'average_c_n_bond_distance_to_phenyl',
#    'average_c_n_bond_distance_to_triazine',
#    'average_cavity_count_per_100_amino_acids',
#    'average_entropic_penalty',
#    'average_fluorescence_lifetime',
#    'average_hydrogen_bond_energy',
#    'average_hydrogen_bond_number',
#    'average_lifetime_trend',
#    'average_number_of_chb_interactions',
#    'average_number_of_water_molecules_in_cavity',
#    'average_omega_torsion_angle',
#    'average_rotational_relaxation_time',
#    'average_symmetry',
#    'average_water_number',
#    'average_xb_angle',
#    'average_xb_distance',
#    'averaged_intensity_ratio',
#    'avogadro_constant',
#    'b_tau_f_n_a_ps',
#    'background_interference',
#    'band_broadening',
#    'band_gap_reduction_after_adsorption',
#    'band_ratio_concentration_range',
#    'bandpass_filter',
#    'bandwidth',
#    'barrier_to_unfolding',
#    'barthochromic_shift_observed',
#    'base_system',
#    'based_on_organic_scaffold',
#    'baseline_correction_software',
#    'basic_character',
#    'basicity',
#    'basis_function_dependence',
#    'basis_of_aggregate_construction',
#    'basis_set',
#    'batch_reproducibility_liability',
#    'batch_to_batch_reproducibility',
#    'bathochromic_shift',
#    'bathochromic_shift_range',
#    'bathochromic_shift_value',
#    'bc_loop_is_modified',
#    'bc_loop_residue',
#    'behavioral_effect_reversed',
#    'benchmark_role',
#    'bending_orientation',
#    'benzene_ring_twist_angle',
#    'benzyl_group_location',
#    'beta_2',
#    'betaine_effect_on_dye_fluorescence',
#    'bimolecular_quenching_constant',
#    'binding_ability',
#    'binding_affinity',
#    'binding_affinity_1_8_ANS',
#    'binding_affinity_2_6_ANS',
#    'binding_affinity_TNS',
#    'binding_affinity_beta2',
#    'binding_affinity_cb8',
#    'binding_affinity_change',
#    'binding_affinity_change_by_gly_insertion',
#    'binding_affinity_change_by_sequence_reversal',
#    'binding_affinity_change_in_acidic_condition',
#    'binding_affinity_comparison',
#    'binding_affinity_competition',
#    'binding_affinity_decrease',
#    'binding_affinity_decrease_order',
#    'binding_affinity_dependence_on_length',
#    'binding_affinity_dropoff',
#    'binding_affinity_e_isomer',
#    'binding_affinity_effect_of_wall_mobility',
#    'binding_affinity_for_alkylammonium_ions',
#    'binding_affinity_for_histone',
#    'binding_affinity_for_hydrophilic_guests',
#    'binding_affinity_for_hydrophobic_guests',
#    'binding_affinity_in_ch3cn',
#    'binding_affinity_in_specific_cases',
#    'binding_affinity_in_water',
#    'binding_affinity_influence_by_cationic_side_chain',
#    'binding_affinity_influence_by_cationic_side_chain_position',
#    'binding_affinity_ionic_strength_dependence',
#    'binding_affinity_k_assoc',
#    'binding_affinity_ka',
#    'binding_affinity_kd',
#    'binding_affinity_level',
#    'binding_affinity_myoglobin',
#    'binding_affinity_pH_dependence',
#    'binding_affinity_ph_range',
#    'binding_affinity_rank',
#    'binding_affinity_ratio',
#    'binding_affinity_reduction_for_neutral_ligand',
#    'binding_affinity_relative',
#    'binding_affinity_relative_to_kme3',
#    'binding_affinity_relative_to_native',
#    'binding_affinity_state',
#    'binding_affinity_strength',
#    'binding_affinity_to_LPA',
#    'binding_affinity_to_aromatic_amino_acid',
#    'binding_affinity_to_beta_cyclodextrin',
#    'binding_affinity_to_compound_8',
#    'binding_affinity_to_methylated_target',
#    'binding_affinity_to_mutant_sequence',
#    'binding_affinity_to_unmethylated_amino_acid',
#    'binding_affinity_trend',
#    'binding_affinity_tunability',
#    'binding_affinity_value',
#    'binding_affinity_variability_in_water_and_cellular_media',
#    'binding_affinity_z_isomer',
#    'binding_and_reactivity_modification_mechanism',
#    'binding_arrangement',
#    'binding_arrangement_type',
#    'binding_behavior',
#    'binding_bonus',
#    'binding_capability',
#    'binding_capacity',
#    'binding_characteristic',
#    'binding_competition',
#    'binding_conditions',
#    'binding_conformation',
#    'binding_constant',
#    'binding_constant_Ka',
#    'binding_constant_absorbance',
#    'binding_constant_beta2',
#    'binding_constant_beta_2',
#    'binding_constant_comparison',
#    'binding_constant_dependence_on_salt',
#    'binding_constant_difference_orders_of_magnitude',
#    'binding_constant_enhancement',
#    'binding_constant_equation',
#    'binding_constant_fluorescence',
#    'binding_constant_k1',
#    'binding_constant_k_1',
#    'binding_constant_k_2',
#    'binding_constant_ka',
#    'binding_constant_limit',
#    'binding_constant_logK',
#    'binding_constant_log_k',
#    'binding_constant_logk',
#    'binding_constant_m_inverse',
#    'binding_constant_method_agreement',
#    'binding_constant_pH',
#    'binding_constant_r_squared',
#    'binding_constant_range',
#    'binding_constant_ratio',
#    'binding_constant_relative',
#    'binding_constant_temperature',
#    'binding_constant_trend',
#    'binding_constant_value',
#    'binding_context',
#    'binding_cooperativity',
#    'binding_depth',
#    'binding_detectability_after_sonication',
#    'binding_driven_by_enthalpy',
#    'binding_driving_force',
#    'binding_effectiveness',
#    'binding_efficiency',
#    'binding_energy',
#    'binding_energy_in_water',
#    'binding_enthalpy',
#    'binding_enthalpy_decomposition',
#    'binding_enthalpy_driven',
#    'binding_enthalpy_strength_relation',
#    'binding_entropy',
#    'binding_environment',
#    'binding_exclusivity',
#    'binding_favored_at_n_terminus',
#    'binding_force_type',
#    'binding_free_energy',
#    'binding_free_energy_increase',
#    'binding_free_energy_temperature',
#    'binding_function',
#    'binding_geometry',
#    'binding_geometry_similarity',
#    'binding_independence_of_substitution',
#    'binding_interaction',
#    'binding_interaction_type',
#    'binding_isotherm_data',
#    'binding_kinetics',
#    'binding_location_at_pH_3',
#    'binding_location_at_pH_7',
#    'binding_manner',
#    'binding_mechanism',
#    'binding_medium',
#    'binding_mode',
#    'binding_mode_characterization',
#    'binding_mode_count',
#    'binding_mode_dependence',
#    'binding_mode_similarity',
#    'binding_model',
#    'binding_model_type',
#    'binding_model_used',
#    'binding_observation',
#    'binding_orientation',
#    'binding_orientation_influences_reactivity',
#    'binding_partner',
#    'binding_pocket_acceptance',
#    'binding_pocket_capacity',
#    'binding_pocket_depth',
#    'binding_preference',
#    'binding_process_driving_force',
#    'binding_promiscuity',
#    'binding_promiscuity_to_cationic_patch',
#    'binding_property',
#    'binding_property_modulation',
#    'binding_property_tunability',
#    'binding_range',
#    'binding_release_mechanism',
#    'binding_selectivity',
#    'binding_selectivity_controlled_by',
#    'binding_selectivity_to_aromatic_amino_acid',
#    'binding_site',
#    'binding_site_amphiphilicity',
#    'binding_site_competition',
#    'binding_site_count',
#    'binding_site_creation',
#    'binding_site_geometry_tunability',
#    'binding_site_location',
#    'binding_site_number',
#    'binding_site_residue_adjacency',
# ...
#            {'type': 'SOME',
#             'value': 'thrombotic_microangiopathy',
#             'raw_value': classes.thrombotic_microangiopathy},
#            {'type': 'SOME',
#             'value': 'blindness',
#             'raw_value': classes.blindness},
#            {'type': 'SOME',
#             'value': 'acute_kidney_injury',
#             'raw_value': classes.acute_kidney_injury}],
#           'descriptions': []},
#          'molar_ratio': {'restrictions': [{'type': 'VALUE',
#             'value': '1:1 (with β-CD)',
#             'raw_value': '1:1 (with β-CD)'},
#            {'type': 'VALUE',
#             'value': '1:1 (with β-CD)',
#             'raw_value': '1:1 (with β-CD)'}],
#           'descriptions': []},
#          'is_dissolved_in': {'restrictions': [{'type': 'SOME',
#             'value': 'ethanol',
#             'raw_value': classes.ethanol},
#            {'type': 'SOME', 'value': 'ethanol', 'raw_value': classes.ethanol}],
#           'descriptions': []},
#          'incubation_time': {'restrictions': [{'type': 'VALUE',
#             'value': '40 min',
#             'raw_value': '40 min'},
#            {'type': 'VALUE', 'value': '40', 'raw_value': 40},
#            {'type': 'VALUE', 'value': '40 min', 'raw_value': '40 min'},
#            {'type': 'VALUE', 'value': '40', 'raw_value': 40}],
#           'descriptions': []}}}},
#       {'tool': 'get_related_classes',
#        'params': {'class_names': ['electrochemical_sensor',
#          'indicator_displacement_assay',
#          'quinine']},
#        'result': {'electrochemical_sensor': {'is_used_for_detection_of': ['tryptophan(Trp)'],
#          'has_detection_target': ['quinine'],
#          'is_realized_as': ['sensing_platform'],
#          'is_based_on': ['nanocomposite'],
#          'is_verified_by': ['cyclic_voltammetry(CV)',
#           'differential_pulse_voltammetry(DPV)',
#           'electrochemical_impedance_analysis(EIS)',
#           'fourier_transform_infrared(FTIR)',
#           'proton_nuclear_magnetic_resonance(H_NMR)',
#           'scanning_electron_microscopy(SEM)'],
#          'is_used_for': ['nucleotide'],
#          'is_constructed_by': ['indicator_displacement_assay(IDA)'],
#          'has_property': ['sensor_reproducibility',
#           'sensor_reusability',
#           'sensor_selectivity',
#           'sensor_stability']},
#         'indicator_displacement_assay': {'detects': ['trimethylated_lysine'],
#          'uses_as_recognition_element': ['deep_cavitand'],
#          'has_component': ['carboxylato_pillar(6)_arene(WP6)',
#           'safranine_T(ST)'],
#          'is_applied_for': ['caffeine_sensing']},
#         'quinine': {'is_diluted_in': ['phosphate_buffer_solution(pbs)'],
#          'is_detected_by': ['electrochemiluminescence_biosensor',
#           'ion_transfer_voltammetry(itv)',
#           'quantitative_electrochemical_method'],
#          'is_analyzed_by': ['colorimetric_assay',
#           'electrochemical_technique',
#           'fluorescence_assay',
#           'high_performance_liquid_chromatography(hplc)',
#           'high_resolution_mass_spectrometry(hrms)'],
#          'has_component': ['alkaloid', 'cinchona_tree_bark'],
#          'is_determined_by': ['differential_pulse_voltammetry(DPV)'],
#          'is_used_for': ['arthritis',
#           'bittering_agent',
#           'lupus',
#           'malaria',
#           'muscle_cramp'],
#          'induces': ['acute_kidney_injury',
#           'blindness',
#           'thrombocytopenia',
#           'thrombotic_microangiopathy'],
#          'is_dissolved_in': ['ethanol']}}}]},
#     'validation_report': ValidationReport(valid=False, details=[DimensionReport(dimension='completeness', message="The results provide substantial information about the stability and reproducibility of electrochemical sensors in general, including specific property values and restrictions. However, there is a lack of explicit linkage between the electrochemical sensor, the use of indicator displacement assay (IDA), and the detection of quinine in the context of stability and reproducibility. The 'information' fields for 'reproducibility', 'reproducibility_study', and 'quinine' are empty, and there is no direct evidence or summary tying together all three entities (sensor, IDA, quinine) for the queried properties. The results do not explicitly state the stability and reproducibility of the electrochemical sensor specifically when using IDA for quinine detection."), DimensionReport(dimension='consistency', message="The data is internally consistent: properties and relationships for each class are coherent and do not contradict each other. The relationships between 'electrochemical_sensor', 'indicator_displacement_assay', and 'quinine' are present in the related classes and properties, and there is no conflicting information."), DimensionReport(dimension='accuracy', message="The property values and relationships are accurate and relevant to the entities. However, the answer does not directly address the query's focus: the stability and reproducibility of the electrochemical sensor specifically when using IDA for quinine detection. The information is fragmented and requires the user to infer the connection, rather than providing a direct, synthesized answer.")], message="The query results are consistent and accurate in the information they provide, but they are incomplete with respect to the specific query intent. The results do not directly synthesize or explicitly state the stability and reproducibility of the electrochemical sensor using IDA for quinine detection. Key information is missing or not directly linked, and some relevant 'information' fields are empty.", improvement_suggestions=['Explicitly link the stability and reproducibility properties of the electrochemical sensor to its use of indicator displacement assay (IDA) for quinine detection.', 'Provide a synthesized summary or evidence that directly addresses the stability and reproducibility of the sensor in the specific context of IDA and quinine.', "Populate the 'information' fields for 'reproducibility', 'reproducibility_study', and 'quinine' with relevant data or explanations.", 'If available, include experimental results or literature references that specifically evaluate the stability and reproducibility of the electrochemical sensor using IDA for quinine detection.']),
#     'timestamp': '2025-07-28T18:53:49.568341',
#     'messages': [SystemMessage(content='Generated hypothetical document to aid in query understanding: The query is asking about the performance characteristics—specifically, the stability and reproducib...', additional_kwargs={}, response_metadata={}, id='7f421734-f6ed-49d6-b7aa-0e0d1ce4433e'),
#      SystemMessage(content='Query normalized: How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?', additional_kwargs={}, response_metadata={}, id='8159fb13-a82f-4e3e-bcb9-bdf6b60c2c4a'),
#      SystemMessage(content='Query strategy determined: tool_sequence', additional_kwargs={}, response_metadata={}, id='548a3521-e3a6-44d4-ac81-6bfa8936b5e6'),
#      SystemMessage(content='Tool-based query executed.', additional_kwargs={}, response_metadata={}, id='26e502e5-03f5-4a77-bc23-e40fe226e28d'),
#      SystemMessage(content='Results validation warning: The query results provide relevant and generally accurate information about the stability and reproducibility of electrochemical sensors, IDA, and quinine. However, they lack explicit linkage and evidence that the reported stability and reproducibility data specifically pertain to the electrochemical sensor using an Indicator Displacement Assay (IDA) for quinine detection. Some relevant information fields are also empty, reducing completeness.', additional_kwargs={}, response_metadata={}, id='b0e66f46-7eb3-4f6a-91f9-ff84655cee78'),
#      SystemMessage(content='Query normalized: How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?', additional_kwargs={}, response_metadata={}, id='c8669067-70f5-4b66-8a92-1cd9ae4c9fe5'),
#      SystemMessage(content='Query strategy determined: tool_sequence', additional_kwargs={}, response_metadata={}, id='db20f620-8dbb-46e9-97d7-8892b233a9a8'),
#      SystemMessage(content='Tool-based query executed.', additional_kwargs={}, response_metadata={}, id='be5d4f10-f4e2-4674-9a4f-2ca13808003c'),
#      SystemMessage(content='Results validation warning: Validation failed: The query results are incomplete and do not accurately address the specific question about the stability and reproducibility of an electrochemical sensor using an indicator displacement assay (IDA) for quinine detection. Key entities and properties are missing or lack relevant information.', additional_kwargs={}, response_metadata={}, id='58f67215-e2c3-4e65-8b9a-77b8430fcbd5'),
#      SystemMessage(content='Query normalized: How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?', additional_kwargs={}, response_metadata={}, id='fdd273a8-dea4-4967-987d-9485fc822d25'),
#      SystemMessage(content='Query strategy determined: tool_sequence', additional_kwargs={}, response_metadata={}, id='0c061827-9390-445c-bbbe-389aa0ac0493'),
#      SystemMessage(content='Tool-based query executed.', additional_kwargs={}, response_metadata={}, id='ec9a549f-e586-435e-b827-f33d9c2768b5'),
#      SystemMessage(content="Results validation warning: The query results are incomplete and do not directly address the user's intent. Key aspects—stability and reproducibility of electrochemical sensors using IDA for quinine detection—are missing or only addressed in a generic way. No information is provided for 'quinine', 'reproducibility', or 'reproducibility_study', and there is no synthesis of information across the relevant entities.", additional_kwargs={}, response_metadata={}, id='5877961c-fc8a-4bb7-a1fc-3edb22cff337'),
#      SystemMessage(content='Generated hypothetical document to aid in query understanding: Could not parse structured response....', additional_kwargs={}, response_metadata={}, id='e8926a06-7f84-4d59-9ae5-20f461a1e0bf'),
#      SystemMessage(content='Query normalized: How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?', additional_kwargs={}, response_metadata={}, id='909bb7f5-9913-4d69-a64e-9403b961ba1f'),
#      SystemMessage(content='Query strategy determined: tool_sequence', additional_kwargs={}, response_metadata={}, id='d3e247a4-3a39-4e81-be6b-2274092c29a4'),
#      SystemMessage(content='Tool-based query executed.', additional_kwargs={}, response_metadata={}, id='f52efc78-6376-4bbd-8088-f58f780f7b7f')]}],
#   'messages': [SystemMessage(content='Generated hypothetical document to aid in query understanding: The query is asking about the performance characteristics—specifically, the stability and reproducib...', additional_kwargs={}, response_metadata={}, id='7f421734-f6ed-49d6-b7aa-0e0d1ce4433e'),
#    SystemMessage(content='Query normalized: How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?', additional_kwargs={}, response_metadata={}, id='8159fb13-a82f-4e3e-bcb9-bdf6b60c2c4a'),
#    SystemMessage(content='Query strategy determined: tool_sequence', additional_kwargs={}, response_metadata={}, id='548a3521-e3a6-44d4-ac81-6bfa8936b5e6'),
#    SystemMessage(content='Tool-based query executed.', additional_kwargs={}, response_metadata={}, id='26e502e5-03f5-4a77-bc23-e40fe226e28d'),
#    SystemMessage(content='Results validation warning: The query results provide relevant and generally accurate information about the stability and reproducibility of electrochemical sensors, IDA, and quinine. However, they lack explicit linkage and evidence that the reported stability and reproducibility data specifically pertain to the electrochemical sensor using an Indicator Displacement Assay (IDA) for quinine detection. Some relevant information fields are also empty, reducing completeness.', additional_kwargs={}, response_metadata={}, id='b0e66f46-7eb3-4f6a-91f9-ff84655cee78'),
#    SystemMessage(content='Query normalized: How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?', additional_kwargs={}, response_metadata={}, id='c8669067-70f5-4b66-8a92-1cd9ae4c9fe5'),
#    SystemMessage(content='Query strategy determined: tool_sequence', additional_kwargs={}, response_metadata={}, id='db20f620-8dbb-46e9-97d7-8892b233a9a8'),
#    SystemMessage(content='Tool-based query executed.', additional_kwargs={}, response_metadata={}, id='be5d4f10-f4e2-4674-9a4f-2ca13808003c'),
#    SystemMessage(content='Results validation warning: Validation failed: The query results are incomplete and do not accurately address the specific question about the stability and reproducibility of an electrochemical sensor using an indicator displacement assay (IDA) for quinine detection. Key entities and properties are missing or lack relevant information.', additional_kwargs={}, response_metadata={}, id='58f67215-e2c3-4e65-8b9a-77b8430fcbd5'),
#    SystemMessage(content='Query normalized: How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?', additional_kwargs={}, response_metadata={}, id='fdd273a8-dea4-4967-987d-9485fc822d25'),
#    SystemMessage(content='Query strategy determined: tool_sequence', additional_kwargs={}, response_metadata={}, id='0c061827-9390-445c-bbbe-389aa0ac0493'),
#    SystemMessage(content='Tool-based query executed.', additional_kwargs={}, response_metadata={}, id='ec9a549f-e586-435e-b827-f33d9c2768b5'),
#    SystemMessage(content="Results validation warning: The query results are incomplete and do not directly address the user's intent. Key aspects—stability and reproducibility of electrochemical sensors using IDA for quinine detection—are missing or only addressed in a generic way. No information is provided for 'quinine', 'reproducibility', or 'reproducibility_study', and there is no synthesis of information across the relevant entities.", additional_kwargs={}, response_metadata={}, id='5877961c-fc8a-4bb7-a1fc-3edb22cff337'),
#    SystemMessage(content='Generated hypothetical document to aid in query understanding: Could not parse structured response....', additional_kwargs={}, response_metadata={}, id='e8926a06-7f84-4d59-9ae5-20f461a1e0bf'),
#    SystemMessage(content='Query normalized: How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?', additional_kwargs={}, response_metadata={}, id='909bb7f5-9913-4d69-a64e-9403b961ba1f'),
#    SystemMessage(content='Query strategy determined: tool_sequence', additional_kwargs={}, response_metadata={}, id='d3e247a4-3a39-4e81-be6b-2274092c29a4'),
#    SystemMessage(content='Tool-based query executed.', additional_kwargs={}, response_metadata={}, id='f52efc78-6376-4bbd-8088-f58f780f7b7f'),
#    SystemMessage(content="Results validation warning: The query results are consistent and accurate in the information they provide, but they are incomplete with respect to the specific query intent. The results do not directly synthesize or explicitly state the stability and reproducibility of the electrochemical sensor using IDA for quinine detection. Key information is missing or not directly linked, and some relevant 'information' fields are empty.", additional_kwargs={}, response_metadata={}, id='ec95bf8b-6e9e-4ba8-9595-9d7c83c382a8'),
#    SystemMessage(content='Results formatted: Electrochemical sensors using an Indicator Displacement Assay (IDA) for quinine detection demonstrate high stability and good reproducibility, retaining over 86% of their original signal after 21 days and showing low variability between electrodes.', additional_kwargs={}, response_metadata={}, id='5142f4ac-30fe-425a-99d2-1c4285726cb2')]}]

# %%
future_list[0]['iteration_history']
# Out:
# [{'retry_count': 1,
#   'hypothetical_document': {'interpretation': "This query is a chemistry reasoning problem focused on the design and function of an Indicator Displacement Assay (IDA) system. The question provides two known components: a host molecule (p-sulfonatocalix[4]arene, SCX4) and an analyte (acetylcholine, AcCh), and asks the respondent to select the most suitable indicator (the unknown component) from a list of chemical substances. The core of the question is to analyze the chemical compatibility and functional requirements for the indicator in the context of the IDA mechanism, considering the host's and analyte's properties. The respondent must use their knowledge of supramolecular chemistry, host-guest interactions, and the physical/chemical properties of the options to justify their choice. The ambiguity lies in the need to connect the structural and physicochemical features of the options to the specific requirements of an IDA indicator in this system.",
#    'hypothetical_answer': "1. Analysis of Known Components:\n\n- Host (A): p-sulfonatocalix[4]arene (SCX4)\n  - Structure: Cyclic tetramer of phenol units, each para-substituted with a sulfonate group (-SO3-), forming a cup-shaped, anionic, water-soluble macrocycle.\n  - Properties: Highly water-soluble due to sulfonate groups; negatively charged rim; cavity size suitable for binding small cationic guests via electrostatic and cation-π interactions; typical host for quaternary ammonium ions.\n\n- Analyte (C): Acetylcholine (AcCh)\n  - Structure: Small, flexible molecule with a quaternary ammonium head (permanently positively charged) and an acetoxyethyl tail.\n  - Properties: Hydrophilic, cationic, fits well into the SCX4 cavity; known to bind SCX4 via electrostatic and hydrophobic interactions.\n\n2. Requirements for the Unknown Component (Indicator, B):\n\n- Must be a cationic (positively charged) small molecule to bind to the anionic SCX4 host via electrostatic and cation-π interactions.\n- Should be water-soluble to function in the aqueous environment of SCX4 and AcCh.\n- Must possess a strong, easily detectable signal (e.g., fluorescence or color) that changes upon binding to SCX4 (e.g., quenching or shift).\n- Its binding affinity to SCX4 should be significant, but less than that of AcCh, so that AcCh can displace it upon addition.\n- Should not be too large or too hydrophobic, as this would hinder binding or solubility.\n\n3. Evaluation of Each Option:\n\n- Acridine Dye (AcH+):\n  - Structure: Planar, aromatic, tricyclic, protonated (cationic) heterocycle.\n  - Properties: Water-soluble as a salt; strong fluorescence; cationic, allowing binding to anionic SCX4; size and shape compatible with SCX4 cavity; known to show signal changes upon supramolecular binding.\n  - Suitability: Highly suitable as an indicator in this IDA system.\n\n- Tetrathiafulvalene (TTF):\n  - Structure: Neutral, electron-rich, planar molecule; not cationic.\n  - Properties: Poor water solubility; lacks a strong optical signal in the visible region; not a good fit for the anionic SCX4 cavity.\n  - Suitability: Unsuitable due to lack of charge, poor solubility, and no indicator properties.\n\n- PEDOT:PSS:\n  - Structure: Blend of two polymers; PEDOT (conjugated polymer), PSS (polyanion).\n  - Properties: Macromolecular, not a small molecule; not a discrete guest; not water-soluble as a small molecule; not an indicator.\n  - Suitability: Fundamentally unsuitable due to size, polymeric nature, and lack of indicator function.\n\n- YBCO (Yttrium Barium Copper Oxide):\n  - Structure: Inorganic, solid-state, complex oxide; not molecular.\n  - Properties: Insoluble in water; not a guest or indicator; not compatible with supramolecular host-guest chemistry.\n  - Suitability: Completely unsuitable due to physical state and chemical category.\n\n- Grubbs' Catalyst, 2nd Generation:\n  - Structure: Large, organometallic complex; neutral or weakly charged; not water-soluble.\n  - Properties: Not a small cationic guest; not an indicator; not compatible with SCX4.\n  - Suitability: Unsuitable due to size, charge, solubility, and lack of indicator properties.\n\n- Vancomycin:\n  - Structure: Large, rigid glycopeptide; multiple charges; not a small molecule.\n  - Properties: Too large for SCX4 cavity; not a typical indicator; complex structure not compatible with IDA requirements.\n  - Suitability: Unsuitable due to size, complexity, and lack of indicator function.\n\n4. Final Conclusion:\n\nThe most suitable unknown component is the Acridine Dye (AcH+). It is a small, cationic, water-soluble molecule with strong fluorescence, making it ideal for binding to the anionic SCX4 host and serving as a signal-responsive indicator in an IDA system. All other options are fundamentally unsuitable due to their size, charge, solubility, or lack of indicator properties.\n\n**Summary:** Acridine Dye (AcH+) is the correct choice because it meets all the chemical and functional req ...
#    'key_concepts': ['Indicator Displacement Assay (IDA)',
#     'Supramolecular chemistry',
#     'Host-guest interactions',
#     'p-sulfonatocalix[4]arene (SCX4): structure, charge, solubility, binding properties',
#     'Acetylcholine: structure, charge, binding to SCX4',
#     'Indicator: requirements (cationic, water-soluble, signal response, binding affinity)',
#     'Binding affinity and selectivity',
#     'Fluorescence and colorimetric indicators',
#     'Molecular size and compatibility with host cavity',
#     'Electrostatic and cation-π interactions',
#     'Acridine dye: structure, charge, fluorescence',
#     'Exclusion criteria: size, solubility, charge, chemical category, indicator function']},
#   'normalized_query': NormalizedQuery(intent='Analyze the chemical compatibility and functional requirements for the indicator in an Indicator Displacement Assay (IDA) system with p-sulfonatocalix(4)arene (SCX4) as host and acetylcholine (AcCh) as analyte, and select the most suitable indicator from a list of options, justifying the choice based on supramolecular chemistry principles.', relevant_entities=['indicator_displacement_assay(IDA)', 'supramolecular_chemistry', 'host-guest_interaction', 'p-sulfonatocalix(4)arene(SCX4)', 'acetylcholine(AcCh)', 'indicator', 'binding_affinity', 'fluorescence_indicator', 'fluorescence', 'electrostatic_interaction', 'cation-pi_interaction', 'acridine_dye'], relevant_properties=[], filters=None, query_type_suggestion='fact-finding, chemical reasoning, selection and justification'),
#   'query_strategy': 'tool_sequence',
#   'execution_plan': ToolPlan(steps=[ToolCallStep(tool='get_class_properties', params={'class_names': ['indicator']}), ToolCallStep(tool='get_class_properties', params={'class_names': ['p-sulfonatocalix(4)arene(SCX4)']}), ToolCallStep(tool='get_class_properties', params={'class_names': ['acetylcholine(AcCh)']}), ToolCallStep(tool='get_class_properties', params={'class_names': ['host-guest_interaction']}), ToolCallStep(tool='get_class_properties', params={'class_names': ['binding_affinity']}), ToolCallStep(tool='get_class_properties', params={'class_names': ['fluorescence_indicator']}), ToolCallStep(tool='get_class_properties', params={'class_names': ['acridine_dye']}), ToolCallStep(tool='get_class_info', params={'class_names': ['indicator_displacement_assay(IDA)']}), ToolCallStep(tool='get_class_info', params={'class_names': ['supramolecular_chemistry']}), ToolCallStep(tool='get_class_info', params={'class_names': ['electrostatic_interaction']}), ToolCallStep(tool='get_class_info', params={'class_names': ['cation-pi_interaction']}), ToolCallStep(tool='get_children', params={'class_names': ['indicator']})]),
#   'sparql_query': None,
#   'query_results': {'results': [{'tool': 'get_class_properties',
#      'params': {'class_names': ['indicator']},
#      'result': {'indicator': {'is_competitor_for': {'restrictions': [{'type': 'SOME',
#           'value': 'binding_site',
#           'raw_value': classes.binding_site},
#          {'type': 'SOME',
#           'value': 'binding_site',
#           'raw_value': classes.binding_site}],
#         'descriptions': []},
#        'has_induced_change': {'restrictions': [{'type': 'SOME',
#           'value': 'None',
#           'raw_value': None},
#          {'type': 'SOME',
#           'value': 'absorbance_change OR fluorescence_change',
#           'raw_value': classes.absorbance_change | classes.fluorescence_change}],
#         'descriptions': []},
#        'is_released_from': {'restrictions': [{'type': 'SOME',
#           'value': 'receptor',
#           'raw_value': classes.receptor},
#          {'type': 'SOME', 'value': 'receptor', 'raw_value': classes.receptor}],
#         'descriptions': []},
#        'is_type_of': {'restrictions': [{'type': 'SOME',
#           'value': 'None',
#           'raw_value': None},
#          {'type': 'SOME',
#           'value': 'isoquinoline_alkaloid OR dye',
#           'raw_value': classes.isoquinoline_alkaloid | classes.dye}],
#         'descriptions': []}}}},
#     {'tool': 'get_class_properties',
#      'params': {'class_names': ['p-sulfonatocalix(4)arene(SCX4)']},
#      'result': {'p-sulfonatocalix(4)arene(SCX4)': {'has_guest': {'restrictions': [{'type': 'SOME',
#           'value': 'None',
#           'raw_value': None},
#          {'type': 'SOME',
#           'value': 'acridine_dye(Ac) OR protonated_acridine_dye(AcH+)',
#           'raw_value': classes.acridine_dye(Ac) | classes.protonated_acridine_dye(AcH+)}],
#         'descriptions': []}}}},
#     {'tool': 'get_class_properties',
#      'params': {'class_names': ['acetylcholine(AcCh)']},
#      'result': {'acetylcholine(AcCh)': {'is_neurotransmitter_in': {'restrictions': [{'type': 'SOME',
#           'value': 'None',
#           'raw_value': None},
#          {'type': 'SOME',
#           'value': 'central_nervous_system OR peripheral_nervous_system',
#           'raw_value': classes.central_nervous_system | classes.peripheral_nervous_system}],
#         'descriptions': []},
#        'biological_importance': {'restrictions': [{'type': 'VALUE',
#           'value': 'biologically important',
#           'raw_value': 'biologically important'},
#          {'type': 'VALUE',
#           'value': 'biologically important',
#           'raw_value': 'biologically important'}],
#         'descriptions': []},
#        'is_sensed_by': {'restrictions': [{'type': 'SOME',
#           'value': 'fluorescence_sensor',
#           'raw_value': classes.fluorescence_sensor},
#          {'type': 'SOME',
#           'value': 'fluorescence_sensor',
#           'raw_value': classes.fluorescence_sensor}],
#         'descriptions': []},
#        'is_associated_with': {'restrictions': [{'type': 'SOME',
#           'value': 'None',
#           'raw_value': None},
#          {'type': 'SOME',
#           'value': 'body_temperature OR blood_pressure OR memory OR learning OR alertness',
#           'raw_value': classes.body_temperature | classes.blood_pressure | classes.memory | classes.learning | classes.alertness}],
#         'descriptions': []},
#        'competitive_binding_effect': {'restrictions': [{'type': 'VALUE',
#           'value': 'triggers dye release and fluorescence ON',
#           'raw_value': 'triggers dye release and fluorescence ON'},
#          {'type': 'VALUE',
#           'value': 'triggers dye release and fluorescence ON',
#           'raw_value': 'triggers dye release and fluorescence ON'}],
#         'descriptions': []},
#        'concentration': {'restrictions': [{'type': 'VALUE',
#           'value': '0.0 mM',
#           'raw_value': '0.0 mM'},
#          {'type': 'VALUE', 'value': '0.03 mM', 'raw_value': '0.03 mM'},
#          {'type': 'VALUE', 'value': '0.089 mM', 'raw_value': '0.089 mM'},
#          {'type': 'VALUE', 'value': '0.24 mM', 'raw_value': '0.24 mM'},
#          {'type': 'VALUE', 'value': '0.44 mM', 'raw_value': '0.44 mM'},
#          {'type': 'VALUE', 'value': '0.73 mM', 'raw_value': '0.73 mM'},
#          {'type': 'VALUE', 'value': '1.3 mM', 'raw_value': '1.3 mM'},
#          {'type': 'VALUE', 'value': '2.0 mM', 'raw_value': '2.0 mM'},
#          {'type': 'VALUE', 'value': '3.36 mM', 'raw_value': '3.36 mM'},
#          {'type': 'VALUE', 'value': '5.39 mM', 'raw_value': '5.39 mM'},
#          {'type': 'VALUE', 'value': '9.88 mM', 'raw_value': '9.88 mM'},
#          {'type': 'VALUE', 'value': '1.37 mM', 'raw_value': '1.37 mM'},
#          {'type': 'VALUE', 'value': '0.0 mM', 'raw_value': '0.0 mM'},
#          {'type': 'VALUE', 'value': '0.03 mM', 'raw_value': '0.03 mM'},
#          {'type': 'VALUE', 'value': '0.089 mM', 'raw_value': '0.089 mM'},
#          {'type': 'VALUE', 'value': '0.24 mM', 'raw_value': '0.24 mM'},
#          {'type': 'VALUE', 'value': '0.44 mM', 'raw_value': '0.44 mM'},
#          {'type': 'VALUE', 'value': '0.73 mM', 'raw_value': '0.73 mM'},
#          {'type': 'VALUE', 'value': '1.3 mM', 'raw_value': '1.3 mM'},
#          {'type': 'VALUE', 'value': '2.0 mM', 'raw_value': '2.0 mM'},
#          {'type': 'VALUE', 'value': '3.36 mM', 'raw_value': '3.36 mM'},
#          {'type': 'VALUE', 'value': '5.39 mM', 'raw_value': '5.39 mM'},
#          {'type': 'VALUE', 'value': '9.88 mM', 'raw_value': '9.88 mM'},
#          {'type': 'VALUE', 'value': '1.37 mM', 'raw_value': '1.37 mM'}],
#         'descriptions': []},
#        'has_binding_partner': {'restrictions': [{'type': 'SOME',
#           'value': 'sulfonatocalix(4)arene(SCX4)',
#           'raw_value': classes.sulfonatocalix(4)arene(SCX4)},
#          {'type': 'SOME',
#           'value': 'sulfonatocalix(4)arene(SCX4)',
#           'raw_value': classes.sulfonatocalix(4)arene(SCX4)}],
#         'descriptions': []},
#        'chemical_structure': {'restrictions': [{'type': 'VALUE',
#           'value': 'polyatomic_quaternary_ammonium_cation',
#           'raw_value': 'polyatomic_quaternary_ammonium_cation'},
#          {'type': 'VALUE',
#           'value': 'polyatomic_quaternary_ammonium_cation',
#           'raw_value': 'polyatomic_quaternary_ammonium_cation'}],
#         'descriptions': []},
#        'is_competitive_binder': {'restrictions': [{'type': 'SOME',
#           'value': 'p-sulfonatocalix(4)arene(SCX4)',
#           'raw_value': classes.p-sulfonatocalix(4)arene(SCX4)},
#          {'type': 'SOME',
#           'value': 'p-sulfonatocalix(4)arene(SCX4)',
#           'raw_value': classes.p-sulfonatocalix(4)arene(SCX4)}],
#         'descriptions': []},
#        'binding_constant': {'restrictions': [{'type': 'VALUE',
#           'value': '10^5 M^-1',
#           'raw_value': '10^5 M^-1'},
#          {'type': 'VALUE', 'value': '10^5 M^-1', 'raw_value': '10^5 M^-1'}],
#         'descriptions': []},
#        'is_competitive_binder_of': {'restrictions': [{'type': 'SOME',
#           'value': 'acridine_dye',
#           'raw_value': classes.acridine_dye},
#          {'type': 'SOME',
#           'value': 'acridine_dye',
#           'raw_value': classes.acridine_dye}],
#         'descriptions': []},
#        'disturbs_binding': {'restrictions': [{'type': 'SOME',
#           'value': 'None',
#           'raw_value': None},
#          {'type': 'SOME',
#           'value': 'acetate(Ac) OR acetylcholine_cation(AcH+) OR sulfonatocalix(4)arene(SCX4)',
#           'raw_value': classes.acetate(Ac) | classes.acetylcholine_cation(AcH+) | classes.sulfonatocalix(4)arene(SCX4)}],
#         'descriptions': []},
#        'is_contained_in': {'restrictions': [{'type': 'SOME',
#           'value': 'solution',
#           'raw_value': classes.solution},
#          {'type': 'SOME', 'value': 'solution', 'raw_value': classes.solution}],
#         'descriptions': []},
#        'neurotransmitter_role': {'restrictions': [{'type': 'VALUE',
#           'value': 'neurotransmitter',
#           'raw_value': 'neurotransmitter'},
#          {'type': 'VALUE',
#           'value': 'neurotransmitter',
#           'raw_value': 'neurotransmitter'}],
#         'descriptions': []},
#        'is_analyte_for_sensor': {'restrictions': [{'type': 'SOME',
#           'value': 'supramolecular_host_guest_sensor',
#           'raw_value': classes.supramolecular_host_guest_sensor},
#          {'type': 'SOME',
#           'value': 'supramolecular_host_guest_sensor',
#           'raw_value': classes.supramolecular_host_guest_sensor}],
#         'descriptions': []},
#        'is_detected_by': {'restrictions': [{'type': 'SOME',
#           'value': 'indicator_displacement_assay',
#           'raw_value': classes.indicator_displacement_assay},
#          {'type': 'SOME',
#           'value': 'indicator_displacement_assay',
#           'raw_value': classes.indicator_displacement_assay}],
#         'descriptions': []},
#        'has_binding_constant': {'restrictions': [{'type': 'SOME',
#           'value': 'binding_constant',
#           'raw_value': classes.binding_constant},
#          {'type': 'SOME',
#           'value': 'binding_constant',
#           'raw_value': classes.binding_constant}],
#         'descriptions': []},
#        'is_neurotransmitter': {'restrictions': [{'type': 'SOME',
#           'value': 'neurotransmitter',
#           'raw_value': classes.neurotransmitter},
#          {'type': 'SOME',
#           'value': 'neurotransmitter',
#           'raw_value': classes.neurotransmitter}],
#         'descriptions': []}}}},
#     {'tool': 'get_class_properties',
#      'params': {'class_names': ['host-guest_interaction']},
#      'result': {'host-guest_interaction': {'is_analyzed_in': {'restrictions': [{'type': 'SOME',
#           'value': 'd2o',
#           'raw_value': classes.d2o},
#          {'type': 'SOME', 'value': 'd2o', 'raw_value': classes.d2o}],
#         'descriptions': [{'content': 'single(d2o)',
#           'source': '10.1016/j.molliq.2018.05.081',
#           'file_path': None}]},
#        'is_effective_strategy_for_developing_new_disease_treatments': {'restrictions': [{'type': 'VALUE',
#           'value': 'true',
#           'raw_value': 'true'},
#          {'type': 'VALUE', 'value': 'true', 'raw_value': 'true'}],
#         'descriptions': []},
#        'is_analyzed_by': {'restrictions': [{'type': 'SOME',
#           'value': 'fluorescence_data',
#           'raw_value': classes.fluorescence_data},
#          {'type': 'SOME',
#           'value': 'fluorescence_data',
#           'raw_value': classes.fluorescence_data}],
#         'descriptions': [{'content': 'single(fluorescence_data)',
#           'source': '10.1016/j.molliq.2018.05.081',
#           'file_path': None}]},
#        'forms_complex': {'restrictions': [{'type': 'SOME',
#           'value': 'host-guest_complex',
#           'raw_value': classes.host-guest_complex},
#          {'type': 'SOME',
#           'value': 'host-guest_complex',
#           'raw_value': classes.host-guest_complex}],
#         'descriptions': [{'content': 'single(host-guest_complex)',
#           'source': '10.1016/j.molliq.2018.05.081',
#           'file_path': None}]},
#        'has_guest': {'restrictions': [{'type': 'SOME',
#           'value': '7-dccae',
#           'raw_value': classes.7-dccae},
#          {'type': 'SOME', 'value': '7-dccae', 'raw_value': classes.7-dccae}],
#         'descriptions': [{'content': 'single(7-dccae)',
#           'source': '10.1016/j.molliq.2018.05.081',
#           'file_path': None}]},
#        'has_participant': {'restrictions': [{'type': 'SOME',
#           'value': 'None',
#           'raw_value': None},
#          {'type': 'SOME',
#           'value': 'biomacromolecule OR cavity-bearing_synthetic_macrocycle',
#           'raw_value': classes.biomacromolecule | classes.cavity-bearing_synthetic_macrocycle}],
#         'descriptions': []},
#        'has_host': {'restrictions': [{'type': 'SOME',
#           'value': 'None',
#           'raw_value': None},
#          {'type': 'SOME',
#           'value': 'cb7 OR cb8',
#           'raw_value': classes.cb7 | classes.cb8}],
#         'descriptions': [{'content': 'union(cb7, cb8)',
#           'source': '10.1016/j.molliq.2018.05.081',
#           'file_path': None}]},
#        'is_effective_strategy_for_constructing_biomaterials': {'restrictions': [{'type': 'VALUE',
#           'value': 'true',
#           'raw_value': 'true'},
#          {'type': 'VALUE', 'value': 'true', 'raw_value': 'true'}],
#         'descriptions': []},
#        'host_guest_displacement': {'restrictions': [{'type': 'VALUE',
#           'value': 'quinine displaces MB from beta-CD cavity',
#           'raw_value': 'quinine displaces MB from beta-CD cavity'},
#          {'type': 'VALUE',
#           'value': 'quinine displaces MB from beta-CD cavity',
#           'raw_value': 'quinine displaces MB from beta-CD cavity'}],
#         'descriptions': []},
#        'solvent': {'restrictions': [{'type': 'VALUE',
#           'value': 'D2O',
#           'raw_value': 'D2O'},
#          {'type': 'VALUE', 'value': 'D2O', 'raw_value': 'D2O'}],
#         'descriptions': [{'content': 'D2O',
#           'source': '10.1016/j.molliq.2018.05.081',
#           'file_path': None}]},
#        'is_studied_by': {'restrictions': [{'type': 'SOME',
#           'value': 'None',
#           'raw_value': None},
#          {'type': 'SOME',
#           'value': 'uv_vis_spectroscopy OR 1h_nmr_spectroscopy',
#           'raw_value': classes.uv_vis_spectroscopy | classes.1h_nmr_spectroscopy}],
#         'descriptions': [{'content': 'union(uv_vis_spectroscopy, 1h_nmr_spectroscopy)',
#           'source': '10.1016/j.aca.2020.09.028',
#           'file_path': None}]},
#        'is_effective_strategy_for_preparing_biological_systems': {'restrictions': [{'type': 'VALUE',
#           'value': 'true',
#           'raw_value': 'true'},
#          {'type': 'VALUE', 'value': 'true', 'raw_value': 'true'}],
#         'descriptions': []},
#        'is_effective_strategy_for_deciphering_molecular_binding_modes': {'restrictions': [{'type': 'VALUE',
#           'value': 'true',
#           'raw_value': 'true'},
#          {'type': 'VALUE', 'value': 'true', 'raw_value': 'true'}],
#         'descriptions': []},
#        'is_occurring_in': {'restrictions': [{'type': 'SOME',
#           'value': 'cellular_environment',
#           'raw_value': classes.cellular_environment},
#          {'type': 'SOME',
#           'value': 'cellular_environment',
#           'raw_value': classes.cellular_environment}],
#         'descriptions': []}}}},
#     {'tool': 'get_class_properties',
#      'params': {'class_names': ['binding_affinity']},
#      'result': {'binding_affinity': {'is_demonstrated_by': {'restrictions': [{'type': 'SOME',
#           'value': 'delta_h(ΔH)',
#           'raw_value': classes.delta_h(ΔH)},
#          {'type': 'SOME',
#           'value': 'delta_h(ΔH)',
#           'raw_value': classes.delta_h(ΔH)}],
#         'descriptions': [{'content': 'single(delta_h(ΔH))',
#           'source': '10.1016/j.molliq.2019.111656',
#           'file_path': None}]},
#        'has_binding_affinity_dropoff': {'restrictions': [{'type': 'SOME',
#           'value': 'van_der_waals_length',
#           'raw_value': classes.van_der_waals_length},
#          {'type': 'SOME',
#           'value': 'van_der_waals_length',
#           'raw_value': classes.van_der_waals_length}],
#         'descriptions': [{'content': 'single(van_der_waals_length)',
#           'source': '10.1021/ja0727058',
#           'file_path': None}]},
#        'is_characterized_by': {'restrictions': [{'type': 'SOME',
#           'value': 'thermodynamic_signature',
#           'raw_value': classes.thermodynamic_signature},
#          {'type': 'SOME',
#           'value': 'thermodynamic_signature',
#           'raw_value': classes.thermodynamic_signature}],
#         'descriptions': [{'content': 'single(thermodynamic_signature)',
#           'source': '10.1021/jacs.6b04372',
#           'file_path': None}]},
#        'is_sequence_dependent_on': {'restrictions': [{'type': 'SOME',
#           'value': 'sequence_dependence',
#           'raw_value': classes.sequence_dependence},
#          {'type': 'SOME',
#           'value': 'sequence_dependence',
#           'raw_value': classes.sequence_dependence}],
#         'descriptions': [{'content': 'single(sequence_dependence)',
#           'source': '10.1016/j.molliq.2021.115479',
#           'file_path': None}]},
#        'is_influenced_by_condition': {'restrictions': [{'type': 'SOME',
#           'value': 'acidic_conditions',
#           'raw_value': classes.acidic_conditions},
#          {'type': 'SOME',
#           'value': 'acidic_conditions',
#           'raw_value': classes.acidic_conditions}],
#         'descriptions': [{'content': 'single(acidic_conditions)',
#           'source': None,
#           'file_path': None}]},
#        'is_analyzed_with': {'restrictions': [{'type': 'SOME',
#           'value': 'one_to_one_binding_model',
#           'raw_value': classes.one_to_one_binding_model},
#          {'type': 'SOME',
#           'value': 'one_to_one_binding_model',
#           'raw_value': classes.one_to_one_binding_model}],
#         'descriptions': [{'content': 'single(one_to_one_binding_model)',
#           'source': '10.1039/c8ob02180e',
#           'file_path': None}]},
#        'has_binding_affinity_affected_by': {'restrictions': [{'type': 'SOME',
#           'value': 'water',
#           'raw_value': classes.water},
#          {'type': 'SOME', 'value': 'water', 'raw_value': classes.water}],
#         'descriptions': [{'content': 'single(water)',
#           'source': '10.1021/jacs.6b04372',
#           'file_path': None}]},
#        'has_origin_in': {'restrictions': [{'type': 'SOME',
#           'value': 'entropic_term',
#           'raw_value': classes.entropic_term},
#          {'type': 'SOME',
#           'value': 'entropic_term',
#           'raw_value': classes.entropic_term}],
#         'descriptions': [{'content': 'single(entropic_term)',
#           'source': '10.1021/jacs.6b04372',
#           'file_path': None}]},
#        'is_measured_by': {'restrictions': [{'type': 'SOME',
#           'value': 'itc',
#           'raw_value': classes.itc},
#          {'type': 'SOME',
#           'value': 'fluorescent_ida(IDA)',
#           'raw_value': classes.fluorescent_ida(IDA)},
#          {'type': 'SOME',
#           'value': 'fluorescence_displacement_model',
#           'raw_value': classes.fluorescence_displacement_model},
#          {'type': 'SOME', 'value': 'itc', 'raw_value': classes.itc},
#          {'type': 'SOME',
#           'value': 'fluorescent_ida(IDA)',
#           'raw_value': classes.fluorescent_ida(IDA)},
#          {'type': 'SOME',
#           'value': 'fluorescence_displacement_model',
#           'raw_value': classes.fluorescence_displacement_model}],
#         'descriptions': [{'content': 'single(itc)',
#           'source': '10.1021/jacs.6b04372',
#           'file_path': None},
#          {'content': 'single(fluorescent_ida(IDA))',
#           'source': '10.1039/C7SC04989G',
#           'file_path': None},
#          {'content': 'single(fluorescence_displacement_model)',
#           'source': '10.1039/c8ob02180e',
#           'file_path': None}]},
#        'is_influenced_by': {'restrictions': [{'type': 'SOME',
#           'value': 'ionic_strength',
#           'raw_value': classes.ionic_strength},
#          {'type': 'SOME',
#           'value': 'ionic_strength',
#           'raw_value': classes.ionic_strength}],
#         'descriptions': [{'content': 'single(ionic_strength)',
#           'source': '10.1021/jacs.6b04372',
#           'file_path': None}]},
#        'binding_stoichiometry': {'restrictions': [{'type': 'VALUE',
#           'value': '1:1',
#           'raw_value': '1:1'},
#          {'type': 'VALUE', 'value': '1:1', 'raw_value': '1:1'}],
#         'descriptions': [{'content': '1:1',
#           'source': '10.1039/C7SC04989G',
#           'file_path': None}]},
#        'is_ruled_out_by': {'restrictions': [{'type': 'SOME',
#           'value': 'None',
#           'raw_value': None},
#          {'type': 'SOME',
#           'value': 'nmr_titration(NMR) OR calorimetric_titration',
#           'raw_value': classes.nmr_titration(NMR) | classes.calorimetric_titration}],
#         'descriptions': [{'content': 'union(nmr_titration(NMR), calorimetric_titration)',
#           'source': '10.1039/C7SC04989G',
#           'file_path': None}]},
#        'influencing_factor': {'restrictions': [{'type': 'VALUE',
#           'value': 'hydrophobicity dominates over electrostatics',
#           'raw_value': 'hydrophobicity dominates over electrostatics'},
#          {'type': 'VALUE',
#           'value': 'hydrophobicity dominates over electrostatics',
#           'raw_value': 'hydrophobicity dominates over electrostatics'}],
#         'descriptions': [{'content': 'hydrophobicity dominates over electrostatics',
#           'source': '10.1039/c6cc04771hHost',
#           'file_path': None}]},
#        'is_decreased_by_gly_insertion': {'restrictions': [{'type': 'SOME',
#           'value': 'gly',
#           'raw_value': classes.gly},
#          {'type': 'SOME', 'value': 'gly', 'raw_value': classes.gly}],
#         'descriptions': [{'content': 'single(gly)',
#           'source': '10.1016/j.molliq.2021.115479',
#           'file_path': None}]}}}},
#     {'tool': 'get_class_properties',
#      'params': {'class_names': ['fluorescence_indicator']},
#      'result': {'fluorescence_indicator': {'has_component': {'restrictions': [{'type': 'SOME',
#           'value': 'None',
#           'raw_value': None},
#          {'type': 'SOME',
#           'value': 'q(8) OR acridine_hydrochloride(ac)',
#           'raw_value': classes.q(8) | classes.acridine_hydrochloride(ac)}],
#         'descriptions': [{'content': 'union(q(8), acridine_hydrochloride(ac))',
#           'source': '10.1016/j.aca.2020.09.028',
#           'file_path': None}]},
#        'detectable_amino_acids': {'restrictions': [{'type': 'VALUE',
#           'value': 'phenylalanine(phe)',
#           'raw_value': 'phenylalanine(phe)'},
#          {'type': 'VALUE',
#           'value': 'tryptophan(trp)',
#           'raw_value': 'tryptophan(trp)'},
#          {'type': 'VALUE',
#           'value': 'basic_amino_acid',
#           'raw_value': 'basic_amino_acid'},
#          {'type': 'VALUE',
#           'value': 'unspecified_amino_acid_1',
#           'raw_value': 'unspecified_amino_acid_1'},
#          {'type': 'VALUE',
#           'value': 'unspecified_amino_acid_2',
#           'raw_value': 'unspecified_amino_acid_2'},
#          {'type': 'VALUE',
#           'value': 'phenylalanine(phe)',
#           'raw_value': 'phenylalanine(phe)'},
#          {'type': 'VALUE',
#           'value': 'tryptophan(trp)',
#           'raw_value': 'tryptophan(trp)'},
#          {'type': 'VALUE',
#           'value': 'basic_amino_acid',
#           'raw_value': 'basic_amino_acid'},
#          {'type': 'VALUE',
#           'value': 'unspecified_amino_acid_1',
#           'raw_value': 'unspecified_amino_acid_1'},
#          {'type': 'VALUE',
#           'value': 'unspecified_amino_acid_2',
#           'raw_value': 'unspecified_amino_acid_2'}],
#         'descriptions': [{'content': '(phenylalanine(phe), tryptophan(trp), basic_amino_acid, unspecified_amino_acid_1, unspecified_amino_acid_2)',
#           'source': '10.1016/j.aca.2020.09.028',
#           'file_path': None}]}}}},
#     {'tool': 'get_class_properties',
#      'params': {'class_names': ['acridine_dye']},
#      'result': {'acridine_dye': {'is_probe_for': {'restrictions': [{'type': 'SOME',
#           'value': 'None',
#           'raw_value': None},
#          {'type': 'SOME',
#           'value': 'micelle OR reverse_micelle OR macrocyclic_nanocavity',
#           'raw_value': classes.micelle | classes.reverse_micelle | classes.macrocyclic_nanocavity}],
#         'descriptions': []},
#        'ground_state_pka': {'restrictions': [{'type': 'VALUE',
#           'value': '5.4',
#           'raw_value': 5.4},
#          {'type': 'VALUE', 'value': '5.4', 'raw_value': 5.4}],
#         'descriptions': []},
#        'is_encapsulated_in': {'restrictions': [{'type': 'SOME',
#           'value': 'scx4_host_cavity',
#           'raw_value': classes.scx4_host_cavity},
#          {'type': 'SOME',
#           'value': 'scx4_host_cavity',
#           'raw_value': classes.scx4_host_cavity}],
#         'descriptions': []},
#        'absorbance_wavelength': {'restrictions': [{'type': 'VALUE',
#           'value': '356',
#           'raw_value': 356},
#          {'type': 'VALUE', 'value': '356', 'raw_value': 356}],
#         'descriptions': []},
#        'has_acid_dissociation_constant': {'restrictions': [{'type': 'SOME',
#           'value': 'acid_dissociation_constant(ka)',
#           'raw_value': classes.acid_dissociation_constant(ka)},
#          {'type': 'SOME',
#           'value': 'acid_dissociation_constant(ka)',
#           'raw_value': classes.acid_dissociation_constant(ka)}],
#         'descriptions': []},
#        'is_present_in': {'restrictions': [{'type': 'SOME',
#           'value': 'aqueous_solution',
#           'raw_value': classes.aqueous_solution},
#          {'type': 'SOME',
#           'value': 'aqueous_solution',
#           'raw_value': classes.aqueous_solution}],
#         'descriptions': []},
#        'electron_acceptor_character': {'restrictions': [{'type': 'VALUE',
#           'value': 'well-known electron acceptor',
#           'raw_value': 'well-known electron acceptor'},
#          {'type': 'VALUE',
#           'value': 'well-known electron acceptor',
#           'raw_value': 'well-known electron acceptor'}],
#         'descriptions': []},
#        'has_form': {'restrictions': [{'type': 'SOME',
#           'value': 'None',
#           'raw_value': None},
#          {'type': 'SOME',
#           'value': 'ach_plus OR ac',
#           'raw_value': classes.ach_plus | classes.ac}],
#         'descriptions': []},
#        'has_state': {'restrictions': [{'type': 'SOME',
#           'value': 'None',
#           'raw_value': None},
#          {'type': 'SOME',
#           'value': 'protonated_form OR neutral_form',
#           'raw_value': classes.protonated_form | classes.neutral_form}],
#         'descriptions': []},
#        'has_absorption_characteristic': {'restrictions': [{'type': 'SOME',
#           'value': 'absorption_characteristic',
#           'raw_value': classes.absorption_characteristic},
#          {'type': 'SOME',
#           'value': 'absorption_characteristic',
#           'raw_value': classes.absorption_characteristic}],
#         'descriptions': []},
#        'pH_condition': {'restrictions': [{'type': 'VALUE',
#           'value': 'suitable',
#           'raw_value': 'suitable'},
#          {'type': 'VALUE', 'value': 'suitable', 'raw_value': 'suitable'}],
#         'descriptions': []},
#        'pka': {'restrictions': [{'type': 'VALUE',
#           'value': '5.4',
#           'raw_value': 5.4},
#          {'type': 'VALUE', 'value': '5.4', 'raw_value': 5.4}],
#         'descriptions': []},
#        'is_under_condition': {'restrictions': [{'type': 'SOME',
#           'value': 'ph_condition',
#           'raw_value': classes.ph_condition},
#          {'type': 'SOME',
#           'value': 'ph_condition',
#           'raw_value': classes.ph_condition}],
#         'descriptions': []},
#        'dye_concentration': {'restrictions': [{'type': 'VALUE',
#           'value': '14',
#           'raw_value': 14},
#          {'type': 'VALUE', 'value': '14', 'raw_value': 14}],
#         'descriptions': []},
#        'has_electron_acceptor': {'restrictions': [{'type': 'SOME',
#           'value': 'electron_transfer',
#           'raw_value': classes.electron_transfer},
#          {'type': 'SOME',
#           'value': 'electron_transfer',
#           'raw_value': classes.electron_transfer}],
#         'descriptions': []},
#        'prototropic_form': {'restrictions': [{'type': 'VALUE',
#           'value': 'AcH_plus_form',
#           'raw_value': 'AcH_plus_form'},
#          {'type': 'VALUE', 'value': 'Ac_form', 'raw_value': 'Ac_form'},
#          {'type': 'VALUE',
#           'value': 'AcH_plus_form',
#           'raw_value': 'AcH_plus_form'},
#          {'type': 'VALUE', 'value': 'Ac_form', 'raw_value': 'Ac_form'}],
#         'descriptions': []},
#        'has_modulated_property': {'restrictions': [{'type': 'SOME',
#           'value': 'None',
#           'raw_value': None},
#          {'type': 'SOME',
#           'value': 'photophysical_property OR acid-base_property',
#           'raw_value': classes.photophysical_property | classes.acid-base_property}],
#         'descriptions': []},
#        'has_ground_state_pka': {'restrictions': [{'type': 'SOME',
#           'value': 'ground_state_pka',
#           'raw_value': classes.ground_state_pka},
#          {'type': 'SOME',
#           'value': 'ground_state_pka',
#           'raw_value': classes.ground_state_pka}],
#         'descriptions': []}}}},
#     {'tool': 'get_class_info',
#      'params': {'class_names': ['indicator_displacement_assay(IDA)']},
#      'result': {'indicator_displacement_assay(IDA)': {'name': 'indicator_displacement_assay(IDA)',
#        'information': ['Indicator displacement assay (IDA) is a method used for ultrasensitive fluorescence detection of LPA in aqueous media.',
#         'Through IDA coupled with differential sensing, we achieved the ultrasensitive and specific detection of LPA.']}}},
#     {'tool': 'get_class_info',
#      'params': {'class_names': ['supramolecular_chemistry']},
#      'result': {'supramolecular_chemistry': {'name': 'supramolecular_chemistry',
#        'information': ["Supramolecular chemistry, a frequent topic in the works of E. V. Anslyn and the journal 'Org. Biomol. Chem.', involves the study of chemical systems composed of a discrete number of assembled molecular subunits or components.",
#         'Supramolecular chemistry is the area of chemistry that focuses on the study of non-covalent interactions between molecules.',
#         'Cucurbiturils have proven as versatile receptors in supramolecular chemistry.',
#         'The unique rigid three-dimensional structures of triptycene and its derivatives enable them to be widely applied in supramolecular chemistry.',
#         'Supramolecular chemistry is a branch of chemistry that focuses on the study of non-covalent interactions and the assembly of molecular entities into larger, organized structures.',
#         'Supramolecular chemistry is the field of chemistry that studies non-covalent interactions between molecules, such as host-guest complexes.',
#         'Calixarenes have a very special place among the macrocyclic compounds of supramolecular chemistry due to their easy charge transfer properties.',
#         'Synthetic macrocyclic receptors play key roles in supramolecular chemistry.',
#         'Supramolecular chemistry is the area of chemistry that focuses on the study of non-covalent interactions and the assembly of molecular structures beyond individual molecules, as indicated by the journal Supramol. Chem.',
#         'Supramolecular chemistry is the field that studies non-covalent interactions and assemblies, such as those mediated by cucurbit(n)urils.',
#         'Ongoing exploration of novel molecular recognition systems in supramolecular chemistry endows the syntheses of various receptor compounds vital significance.',
#         'Supramolecular chemistry is the field focused on the study of non-covalent interactions and assemblies of molecules.',
#         'Supramolecular chemistry is the field enriched by the study of modulating classical and non-classical hydrophobic effects and controlling cooperativity of non-covalent interactions.',
#         'Supramolecular chemistry is a branch of chemistry that focuses on the study of non-covalent interactions between molecules.',
#         'The ability to regulate and control binding cooperativity will enrich the field of supramolecular chemistry.',
#         'Supramolecular chemistry is the field that studies the non-covalent interactions and assemblies, such as host-guest complexes, between molecules.',
#         'Supramolecular chemistry is a field of chemistry that focuses on the study of non-covalent interactions and the assembly of molecular structures beyond individual molecules.',
#         'These compounds have been widely used as a host molecule in the supramolecular chemistry, due to their ability to encapsulate organic compounds into their hydrophobic cavities.',
#         'Supramolecular chemistry is a branch of chemistry that focuses on the study of non-covalent interactions and the assembly of complex structures from molecular components.',
#         'Supramolecular chemistry has had a fruitful contribution to the development of new, multifunctional organic molecules.',
#         'Supramolecular chemistry is the field of chemistry that studies the non-covalent interactions and assemblies of molecules.',
#         'Supramolecular chemistry is a field that studies the chemistry of molecular assemblies and the non-covalent interactions that govern them.',
#         'Supramolecular chemistry is the field in which the effects of metal coordination on container molecules are studied.',
#         'Supramolecular chemistry is the field in which cucurbit(n)urils and their exceptional potentials for various suitable applications are highlighted.',
#         'Computational approaches have revolutionized supramolecular chemistry, have greatly helped us to understand host-guest binding, and will continue to do even more amazing things in the coming years.',
#         'Supramolecular chemistry involves the study of non-covalent interactions and assemblies between molecules, such as host-guest systems, which is a primary focus of many of the referenced works.',
#         'The design of artificial anion receptors is a challenge in supramolecular chemistry that has received great attention in recent years.',
#         'The development of novel macrocyclic hosts in supramolecular chemistry is a fundamental task for creating advanced molecular systems.',
#         'Supramolecular chemistry is the area of chemistry that focuses on the study of non-covalent interactions and assemblies between molecules.',
#         'This has important effects on how we practice supramolecular chemistry.',
#         'Supramolecular chemistry is the study of chemical systems composed of a discrete number of assembled molecular subunits or components.']}}},
#     {'tool': 'get_class_info',
#      'params': {'class_names': ['electrostatic_interaction']},
#      'result': {'electrostatic_interaction': {'name': 'electrostatic_interaction',
#        'information': ['Electrostatic interactions are a type of intermolecular force that are extremely sensitive to the environment and contribute to binding energetics.',
#         'Electrostatic interactions are primary drivers for the recognition events in binding studies.',
#         'The guests are included via concerted electrostatic and hydrophobic interactions.',
#         'Cucurbit(8)uril and Blue-Box: High-Energy Water Release Overwhelms Electrostatic Interactions.',
#         'Electrostatic interaction occurs between NBA and the monomer of SDS or ionic liquid, influencing the Q value.',
#         'Electrostatic interactions are forces between charged particles or molecules, significant in the binding of supramolecular complexes.',
#         'Electrostatic interactions contribute to the strong binding between CB8 and the perylene dyes.',
#         'Electrostatic interactions occur between the anionic sulfonate group of MTPPS4 and the cationic amino group of the lysine residue.',
#         'Electrostatic interaction is a key force in the binding between the cationic side group of PMI1 or PMI2 and cucurbit(8)uril (CB8).',
#         'Electrostatic interactions are one of the approaches used for the selective recognition of sulfate in aqueous solution.',
#         'For each inclusion complex of hydrophilic AAs (Glu, His, Asn, Lys, Arg and Gln), the ring-like structure is formed inside the cavity by the intramolecular electrostatic interaction of AA.',
#         'Electrostatic interactions between the hosts and myoglobin were not effectively performed, because the K value of anionic hosts was low.',
#         'Electrostatic interactions between the positive charge of the guests and the sulfonato groups of the host, along with CH-π and π-π interactions with the C4TS cavity, drive the host-guest complex formation.',
#         'Electrostatic interactions can influence the selectivity between receptor and analyte, but are negligible for zwitterionic and neutral side chains.',
#         'Electrostatic interactions are driving forces between carboxylate groups (COO-) and cationic side chains in the binding of amino acids by pillararene 31.',
#         'Electrostatic interactions occur between the quaternary ammonium cation of PMI1 and the carbonyl portal of CB8, enhancing binding affinity.',
#         'The binding forces between ET and SC4 molecules may contain hydrophobic, van der Waals, electrostatic interaction, hydrogen bonds, dipole-dipole attractions or combination of these forces.',
#         'The complexes established are stabilized mainly by cationπ interactions but also with the contribution of a variety of other electrostatic interactions.',
#         'Electrostatic interaction is a non-covalent interaction between charged species, such as between the cationic head of a micelle and cationic NBA.',
#         'Electrostatic interactions between the cationic protonated lysine residues of Trpzip and the anionic deprotonated sulfonate groups of MTPPS4 were evaluated theoretically.',
#         'Electrostatic interactions occur at the carbonyl portals and contribute to the binding affinities between t Q(14) and amino acids.',
#         'Electrostatic interactions are not expected to contribute to the observed entropy changes of solvation or desolvation (binding) because the large electrostatic solute-solvent and solvent reorganization entropies are canceling.',
#         'Electrostatic interaction refers to the interactions between charged groups on the surface of proteins and host molecules.',
#         'Electrostatic interactions are the forces via which supramolecules consisting of peptides and MTPPS4s are formed.',
#         'Electrostatic interactions contribute to the binding of LPA by GC5A.',
#         'Electrostatic interactions are non-covalent forces between charged species, contributing to the assembly and stability of nanoparticles.',
#         'The sulfate anion is bound to the receptor through electrostatic and hydrogen bonding interactions and at the same time, it induces conformational changes of the receptor structure that favor p p --interactions between dyes.',
#         'Electrostatic interactions are non-covalent forces that link cations to macrocyclic hosts in supramolecular assemblies.',
#         'Electrostatic interactions occur between the positively charged side chains of the amino acids and the polar carbonyl groups of t Q(14).',
#         'meso -tetra(4-sulfonatophenyl)porphyrins (MTPPS4), which are water-soluble porphyrins, is known to form a supramolecule with peptides via electrostatic interactions between the anionic sulfonate groups of MTPPS and the cationic amino 4 groups of lysine residues.',
#         'Multiple electrostatic interactions occur between the cationic trimethylammonium groups on the host and the anionic pyren-1-olate part of the guest.',
#         'Electrostatic interactions are mentioned as one of the types of interactions relevant to the selectivity of the receptor.',
#         'These water-soluble architectures may form thanks to concerted hydrophobic and electrostatic interactions between the positively charged host and the aromatic and dianionic guests.',
#         'Electrostatic interaction is a non-covalent force between charged groups, such as between the lysine residue of Trpzip and the sulfonate group of MTPPS.',
#         'Electrostatic interactions are one of the main driving forces in the formation of the (2)pseudorotaxane.',
#         'Electrostatic interaction is a type of non-covalent interaction that stabilizes the host-guest complex between the receptor and sulfate.',
#         'Electrostatic interactions occur between charged guests and calixarene hosts, often dominating over more specific interactions.',
#         'Electrostatic interactions contribute to the binding between the positively charged amino acids and iQ(7).',
#         'Electrostatic interactions among ions contribute to the dilution heat in the studied solutions.',
#         'Electrostatic interaction is the driving force for the N atoms of the guests to locate in the center of the host cavity.',
#         'Driven by the cooperativity of electrostatic interactions, p-stacking interactions and hydrophilic/hydrophobic interactions, the guest penetrated into the cavity of CWP7 to form a pseudorotaxane-type inclusion complex with relatively high binding affinity.',
#         'Electrostatic interactions are non-covalent forces between charged groups, represented by dashed lines in the CB8-(Tyr-Leu-Ala) complex structure.',
#         'Electrostatic interactions are significant for guest-recognition of compound 1.']}}},
#     {'tool': 'get_class_info',
#      'params': {'class_names': ['cation-pi_interaction']},
#      'result': {'cation-pi_interaction': {'name': 'cation-pi_interaction',
#        'information': ['The cation-pi interaction is a non-covalent interaction between a positively charged ion and the electron-rich pi system of an aromatic ring, important for contacts with N-CH3 and e-CH2 groups in trimethyllysine.',
#         'Cation-pi interaction is a type of non-covalent interaction involved in binding, particularly relevant in the context of protein-ligand recognition.',
#         'Cation-π interaction is a noncovalent interaction between a cationic species and the π-electron cloud of an aromatic ring, facilitating guest binding in macrocycles.']}}},
#     {'tool': 'get_children',
#      'params': {'class_names': ['indicator']},
#      'result': {'indicator': ['dye',
#        'fluorophore',
#        'indicator_dye',
#        'isoquinoline_alkaloid']}}]},
#   'validation_report': ValidationReport(valid=False, details=[DimensionReport(dimension='completeness', message="The query results provide extensive class properties and information for all relevant entities (indicator, p-sulfonatocalix(4)arene, acetylcholine, acridine dye, etc.), including their roles, binding properties, and chemical characteristics. However, there are notable redundancies (e.g., duplicate restrictions for many properties), and some expected properties for the 'indicator' class (such as explicit fluorescence or colorimetric response, or direct mention of acridine dye as a subclass or instance) are missing. The connection between 'indicator', 'fluorescence_indicator', and 'acridine_dye' is not made explicit, which is important for reasoning about the suitability of acridine dye as the indicator in this system."), DimensionReport(dimension='consistency', message='The results are internally consistent: the properties of SCX4, acetylcholine, and acridine dye align with their known chemical roles in supramolecular IDA systems. The host-guest relationships, binding constants, and relevant interactions (electrostatic, cation-pi) are all present and plausible. However, the presence of duplicate restrictions for nearly every property introduces unnecessary noise and could lead to confusion or misinterpretation.'), DimensionReport(dimension='accuracy', message="The chemical information provided is accurate and aligns with established supramolecular chemistry and IDA literature. SCX4 is correctly described as a host for cationic guests, acetylcholine is a suitable analyte, and acridine dye is a plausible indicator. However, the lack of explicit linkage between 'indicator' and 'acridine_dye' (e.g., as a subclass or instance) is a minor accuracy gap, as it requires the user to infer this connection rather than having it stated in the ontology output.")], message="The query results are generally valid and provide most of the necessary information for reasoning about the IDA system. However, there are issues with redundancy, lack of explicit subclass/instance relationships (especially between 'indicator', 'fluorescence_indicator', and 'acridine_dye'), and missing direct mention of the indicator's signal response properties. These gaps could hinder a user's ability to draw a fully justified conclusion without external inference.", improvement_suggestions=['Remove duplicate restrictions for each property to improve clarity and reduce noise.', "Explicitly state the subclass or instance relationship between 'indicator', 'fluorescence_indicator', and 'acridine_dye' to clarify that acridine dye is a suitable indicator.", "Add explicit properties to the 'indicator' class describing required signal response (e.g., fluorescence or color change) and its compatibility with SCX4 and acetylcholine.", "Include a property or description in 'indicator' or 'fluorescence_indicator' that directly references acridine dye as a canonical example."]),
#   'timestamp': '2025-07-17T23:20:35.542431',
#   'messages': [SystemMessage(content='Generated hypothetical document to aid in query understanding: This query is a chemistry reasoning problem focused on the design and function of an Indicator Displ...', additional_kwargs={}, response_metadata={}, id='9f7ad404-0424-4fd5-814d-6d4a54302324'),
#    SystemMessage(content="Query normalized: ### **Test # #1: Chemical Knowledge and Reasoning: Indicator Displacement Assay (IDA) System**\n\n**Scenario Description**\n\nAn Indicator Displacement Assay (IDA) is a powerful sensing method based on supramolecular chemistry, widely used for the detection of various analytes. A typical IDA system consists of three core components:\n\n1.  **Host (A):** A molecule possessing a recognition cavity or binding site.\n2.  **Indicator (B):** A guest molecule that exhibits a signal response (e.g., in its color or fluorescence).\n3.  **Analyte (C):** The target guest molecule to be detected.\n\nThe principle of operation involves two steps:\n\n1.  The Host (A) and Indicator (B) bind to form a supramolecular complex, `A·B`. This binding event causes a significant change in the indicator's signal (e.g., fluorescence quenching or a color change).\n2.  When the Analyte (C) is introduced, it competes for the host's cavity. If C binds to A more strongly than B does, it will displace the indicator, forming a new complex, `A·C`, and releasing the free indicator B. This displacement restores the indicator's signal to its original state, thus enabling the detection of the analyte C.\n\n------\n\n**Problem Statement**\n\nA given IDA system consists of the following components:\n\n* **Known Component 1:** p-sulfonatocalix[4]arene (SCX4): A water-soluble, anionic host molecule from the calixarene family. It consists of four phenol units cyclically linked by methylene bridges at their ortho-positions, creating a distinctive cup-shaped conformation. Each phenolic ring is functionalized with a sulfonate group (-SO₃⁻) at the para-position, which imparts high water solubility and creates a negatively charged rim for interacting with cationic guests. (Host A)\n* **Known Component 2:** Acetylcholine (AcCh): An ester derivative of choline and acetic acid. It is a small quaternary ammonium cation featuring a (2-acetoxyethyl)trimethylammonium structure. It has a flexible two-carbon chain connecting the ester group to the positively charged trimethylammonium head. (Analyte C)\n* **Unknown Component:** Indicator (B)\n\nIn this system, one component is now considered unknown.\n\n------\n\n**Your Task**\n\nFrom the options provided below, select the most suitable chemical substance to serve as the **Unknown Component** in the system.\n\n**Options:**\n\n* Acridine Dye (AcH⁺): The protonated form of the parent compound, acridine. It is a planar, tricyclic aromatic heterocycle where two benzene rings are fused to a central pyridine ring. The positive charge resides on the central nitrogen atom.\n* Tetrathiafulvalene (TTF): Its molecular structure consists of two sulfur-containing five-membered rings (1,3-dithiole rings) connected by a central carbon-carbon double bond, forming an electron-rich, conjugated planar system.\n* PEDOT:PSS: A physical blend of two polymers. One component is PEDOT, which has a conjugated polythiophene backbone, and the other is PSS, a polystyrene with a sulfonic acid group on each phenyl ring.\n* YBCO (Yttrium Barium Copper Oxide): An inorganic oxide with a complex, defect-laden, layered perovskite-like crystal structure, containing yttrium, barium, copper, and oxygen atoms in its unit cell.\n* Grubbs' Catalyst, 2nd Generation: An organometallic ruthenium (Ru) complex. Its central ruthenium atom is coordinated to two chloride ions, one tricyclohexylphosphine (PCy₃) ligand, one N-heterocyclic carbene (NHC) ligand, and a benzylidene (=CHPh) ligand.\n* Vancomycin: A complex glycopeptide. Its structural core is a heptapeptide chain that is highly cross-linked through phenol oxidative coupling, forming a rigid, chiral, cup-shaped scaffold which is also decorated with sugar moieties.\n\n------\n\n**Instructions for Analysis and Response**\n\nTo fully assess your chemical knowledge and logical reasoning, you are required to follow the steps below in your response:\n\n1.  **Analyze the Known Components: ...
#    SystemMessage(content='Query strategy determined: tool_sequence', additional_kwargs={}, response_metadata={}, id='e20e5062-3375-4374-a748-73ae13702c15'),
#    SystemMessage(content='Tool-based query executed.', additional_kwargs={}, response_metadata={}, id='85b6e865-6310-4587-b41d-cfab5d87d336')]}]

# %%
import os
import pprint

suffix = "717_ida_1"
folder_prefix = "ida_future_list"
os.makedirs(folder_prefix, exist_ok=True)

# --- Start of the solution ---

# 1. Create a PrettyPrinter instance. You can configure indentation.
#    indent=4 is a very common and readable choice.
pp = pprint.PrettyPrinter(indent=4, width=120) # width helps control line wrapping

save_indices = list(range(len(future_list)))

for idx in save_indices:
    # --- Save iteration_history ---
    file_path_history = os.path.join(folder_prefix, f"future_list_{idx}_iteration_history_{suffix}.txt")
    with open(file_path_history, "w", encoding="utf-8") as f:
        # 2. Use pp.pformat() to get the nicely formatted string
        formatted_string = pp.pformat(future_list[idx].get('iteration_history'))
        f.write(formatted_string)
    print(f"future_list[{idx}]['iteration_history'] has been saved to {file_path_history}")

    # --- Save formatted_results ---
    file_path_formatted = os.path.join(folder_prefix, f"future_list_{idx}_formatted_results_{suffix}.txt")
    with open(file_path_formatted, "w", encoding="utf-8") as f:
        # 2. Use it again for the other part of the data
        formatted_string = pp.pformat(future_list[idx].get('formatted_results'))
        f.write(formatted_string)
    print(f"future_list[{idx}]['formatted_results'] has been saved to {file_path_formatted}")
# Out:
# future_list[0]['iteration_history'] has been saved to ida_future_list\future_list_0_iteration_history_717_ida_1.txt
# future_list[0]['formatted_results'] has been saved to ida_future_list\future_list_0_formatted_results_717_ida_1.txt
# future_list[1]['iteration_history'] has been saved to ida_future_list\future_list_1_iteration_history_717_ida_1.txt
# future_list[1]['formatted_results'] has been saved to ida_future_list\future_list_1_formatted_results_717_ida_1.txt
# future_list[2]['iteration_history'] has been saved to ida_future_list\future_list_2_iteration_history_717_ida_1.txt
# future_list[2]['formatted_results'] has been saved to ida_future_list\future_list_2_formatted_results_717_ida_1.txt
# future_list[3]['iteration_history'] has been saved to ida_future_list\future_list_3_iteration_history_717_ida_1.txt
# future_list[3]['formatted_results'] has been saved to ida_future_list\future_list_3_formatted_results_717_ida_1.txt
# future_list[4]['iteration_history'] has been saved to ida_future_list\future_list_4_iteration_history_717_ida_1.txt
# future_list[4]['formatted_results'] has been saved to ida_future_list\future_list_4_formatted_results_717_ida_1.txt
# future_list[5]['iteration_history'] has been saved to ida_future_list\future_list_5_iteration_history_717_ida_1.txt
# future_list[5]['formatted_results'] has been saved to ida_future_list\future_list_5_formatted_results_717_ida_1.txt
# future_list[6]['iteration_history'] has been saved to ida_future_list\future_list_6_iteration_history_717_ida_1.txt
# future_list[6]['formatted_results'] has been saved to ida_future_list\future_list_6_formatted_results_717_ida_1.txt
# future_list[7]['iteration_history'] has been saved to ida_future_list\future_list_7_iteration_history_717_ida_1.txt
# future_list[7]['formatted_results'] has been saved to ida_future_list\future_list_7_formatted_results_717_ida_1.txt
# future_list[8]['iteration_history'] has been saved to ida_future_list\future_list_8_iteration_history_717_ida_1.txt
# future_list[8]['formatted_results'] has been saved to ida_future_list\future_list_8_formatted_results_717_ida_1.txt
# future_list[9]['iteration_history'] has been saved to ida_future_list\future_list_9_iteration_history_717_ida_1.txt
# future_list[9]['formatted_results'] has been saved to ida_future_list\future_list_9_formatted_results_717_ida_1.txt
# future_list[10]['iteration_history'] has been saved to ida_future_list\future_list_10_iteration_history_717_ida_1.txt
# future_list[10]['formatted_results'] has been saved to ida_future_list\future_list_10_formatted_results_717_ida_1.txt
# future_list[11]['iteration_history'] has been saved to ida_future_list\future_list_11_iteration_history_717_ida_1.txt
# future_list[11]['formatted_results'] has been saved to ida_future_list\future_list_11_formatted_results_717_ida_1.txt
# future_list[12]['iteration_history'] has been saved to ida_future_list\future_list_12_iteration_history_717_ida_1.txt
# future_list[12]['formatted_results'] has been saved to ida_future_list\future_list_12_formatted_results_717_ida_1.txt
# future_list[13]['iteration_history'] has been saved to ida_future_list\future_list_13_iteration_history_717_ida_1.txt
# future_list[13]['formatted_results'] has been saved to ida_future_list\future_list_13_formatted_results_717_ida_1.txt
# future_list[14]['iteration_history'] has been saved to ida_future_list\future_list_14_iteration_history_717_ida_1.txt
# future_list[14]['formatted_results'] has been saved to ida_future_list\future_list_14_formatted_results_717_ida_1.txt
# future_list[15]['iteration_history'] has been saved to ida_future_list\future_list_15_iteration_history_717_ida_1.txt
# future_list[15]['formatted_results'] has been saved to ida_future_list\future_list_15_formatted_results_717_ida_1.txt
# future_list[16]['iteration_history'] has been saved to ida_future_list\future_list_16_iteration_history_717_ida_1.txt
# future_list[16]['formatted_results'] has been saved to ida_future_list\future_list_16_formatted_results_717_ida_1.txt
# future_list[17]['iteration_history'] has been saved to ida_future_list\future_list_17_iteration_history_717_ida_1.txt
# future_list[17]['formatted_results'] has been saved to ida_future_list\future_list_17_formatted_results_717_ida_1.txt
# future_list[18]['iteration_history'] has been saved to ida_future_list\future_list_18_iteration_history_717_ida_1.txt
# future_list[18]['formatted_results'] has been saved to ida_future_list\future_list_18_formatted_results_717_ida_1.txt
# future_list[19]['iteration_history'] has been saved to ida_future_list\future_list_19_iteration_history_717_ida_1.txt
# future_list[19]['formatted_results'] has been saved to ida_future_list\future_list_19_formatted_results_717_ida_1.txt
# future_list[20]['iteration_history'] has been saved to ida_future_list\future_list_20_iteration_history_717_ida_1.txt
# future_list[20]['formatted_results'] has been saved to ida_future_list\future_list_20_formatted_results_717_ida_1.txt

# %%
# future_list = [future[2].result() for future in callback_futures]
# [future["formatted_results"] for future in future_list]
# future_list[0]["formatted_results"]
for i, future_item in enumerate(future_list):
    print(f"Processing item {i}:")
    try:
        # 尝试访问，看看哪个会出错
        formatted_res = future_item["formatted_results"]
        print(f"  Type of future_item: {type(future_item)}")
        print(f"  Keys in future_item: {future_item.keys() if hasattr(future_item, 'keys') else 'N/A'}")
        print(f"  Type of formatted_results: {type(formatted_res)}")
        print(f"  Value of formatted_results: {formatted_res}")
    except Exception as e:
        print(f"  Error accessing 'formatted_results' for item {i}: {e}")
        print(f"  Type of future_item that caused error: {type(future_item)}")
        if hasattr(future_item, 'keys'):
            print(f"  Keys in future_item: {future_item.keys()}")
        else:
            print(f"  future_item does not have 'keys' attribute.")
        # 如果需要，可以打印整个 problematic future_item
        # print(f"  Problematic future_item: {future_item}")
# Out:
# Processing item 0:
#   Type of future_item: <class 'langgraph.pregel.io.AddableValuesDict'>
#   Keys in future_item: dict_keys(['query', 'source_ontology', 'query_type', 'query_strategy', 'originating_team', 'originating_stage', 'available_classes', 'available_data_properties', 'available_object_properties', 'query_results', 'normalized_query', 'execution_plan', 'validation_report', 'status', 'stage', 'previous_stage', 'retry_count', 'hypothetical_document', 'formatted_results', 'iteration_history', 'messages'])
#   Type of formatted_results: <class 'dict'>
#   Value of formatted_results: {'summary': 'Electrochemical sensors using an Indicator Displacement Assay (IDA) for quinine detection demonstrate high stability and good reproducibility, retaining over 86% of their original signal after 21 days and showing low variability between electrodes.', 'key_points': [{'Stability': ['The sensor exhibits high stability, with negligible change in differential pulse voltammetry (DPV) signal during the first 7 days at 4°C.', '86.47% of the original DPV signal is retained after 21 days of storage.', 'Acceptable peak current decrease is observed within 21 days, indicating robust performance over time.']}, {'Reproducibility': ['Good reproducibility is demonstrated, with a relative standard deviation (RSD) of 2.06% across seven identical electrodes.', 'Five independent electrodes produced similar signals when detecting 30 μM quinine, confirming repeatability.']}, {'Sensor Construction and Operation': ['The sensor is constructed using an indicator displacement assay (IDA) and is based on a nanocomposite platform.', 'It is simple, cost-effective, and reusable.', 'The sensor shows superior selectivity over common interfering molecules and reasonable precision and accuracy (DOI: 10.1016/j.aca.2020.09.028).']}, {'Detection and Verification': ['Quinine detection is performed using differential pulse voltammetry (DPV).', 'Sensor performance is verified by multiple analytical techniques, including DPV, cyclic voltammetry (CV), electrochemical impedance spectroscopy (EIS), FTIR, H-NMR, and SEM.']}], 'relationships': ['There is a direct relationship between the use of nanocomposite-based IDA sensors and their high stability and reproducibility for quinine detection.', 'The combination of IDA with electrochemical techniques (such as DPV) enables sensitive, selective, and reliable detection of quinine.', 'Sensor stability and reproducibility are supported by both the material platform (nanocomposite) and the assay design (IDA), as evidenced by low signal drift and low electrode-to-electrode variability.']}

# %%
answers
# Out:
# {1: AIMessage(content='Electrochemical sensors employing an Indicator Displacement Assay (IDA) for quinine detection exhibit both high stability and excellent reproducibility, attributes that are fundamentally rooted in the principles of supramolecular chemistry and the robust design of the sensor platform.\n\n**Stability:**  \nThe stability of these sensors is notably high, a critical factor for practical analytical applications. Empirical data show that the sensor retains approximately 86% of its original differential pulse voltammetry (DPV) signal after 21 days of storage at 4°C, with negligible signal drift observed during the first week. This sustained performance is attributed to the use of a nanocomposite platform, which provides a chemically inert and physically stable environment for the supramolecular host-guest interactions central to the IDA mechanism. The modest decrease in peak current over three weeks is within acceptable limits for most analytical protocols, indicating that the sensor’s recognition elements and transduction interface are not prone to rapid degradation or fouling.\n\n**Reproducibility:**  \nReproducibility is a hallmark of well-designed supramolecular sensors. In this case, the sensor demonstrates a low relative standard deviation (RSD) of 2.06% across seven independently fabricated electrodes, and consistent responses are observed when detecting 30 μM quinine with five separate electrodes. This high degree of reproducibility is a direct consequence of the controlled assembly of the host-guest system on the electrode surface and the uniformity of the nanocomposite matrix, which minimizes batch-to-batch variability and ensures reliable molecular recognition events.\n\n**Mechanistic and Supramolecular Considerations:**  \nThe IDA approach leverages competitive binding equilibria: a supramolecular host (often a macrocyclic receptor or functionalized nanomaterial) is pre-complexed with an electroactive indicator. Upon introduction of quinine, which has a higher binding affinity for the host, the indicator is displaced, leading to a measurable change in the electrochemical signal. The selectivity and stability of this process are governed by the thermodynamics of host-guest interactions—typically characterized by binding constants (K_a) in the range of 10^4–10^6 M^–1 for well-matched systems. The non-covalent nature of these interactions (e.g., π–π stacking, hydrogen bonding, electrostatic forces) ensures reversibility and reusability, while the nanocomposite support enhances signal transduction and suppresses nonspecific adsorption.\n\n**Analytical Performance and Verification:**  \nThe sensor’s performance is validated using multiple electrochemical techniques (DPV, cyclic voltammetry, electrochemical impedance spectroscopy) and spectroscopic methods (FTIR, ^1H NMR, SEM), confirming both the integrity of the supramolecular assembly and the reliability of the analytical response. The IDA-based sensor also demonstrates superior selectivity for quinine over structurally related or potentially interfering molecules, a direct result of the tailored host-guest recognition.\n\n**Summary:**  \nIn summary, electrochemical sensors utilizing an IDA for quinine detection are both stable and highly reproducible, with minimal signal loss over several weeks and low electrode-to-electrode variability. These properties are underpinned by the robust supramolecular host-guest chemistry, the stability of the nanocomposite platform, and the precision of the indicator displacement mechanism. Such sensors are well-suited for reliable, selective, and repeatable quinine analysis in complex matrices.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 696, 'prompt_tokens': 941, 'total_tokens': 1637, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, ' ...

# %%
import yaml
from langchain_core.messages import AIMessage
from typing import Dict, List, Any

def save_qa_to_yaml(answers: Dict[int, Any], queries: List[str], output_path: str) -> None:
    """
    Processes a dictionary of answers and a list of queries, sorts them,
    and saves them to a YAML file with consistent multiline string formatting.

    Args:
        answers (Dict[int, Any]): A dictionary with integer keys and AIMessage objects as values.
        queries (List[str]): A list of query strings.
        output_path (str): The path to the output YAML file.
    """
    data_to_save = []
    
    # Sort keys to process the dictionary in order
    sorted_keys = sorted(answers.keys())
    
    for idx in sorted_keys:
        answer = answers.get(idx)
        if isinstance(answer, AIMessage):
            # The query index is assumed to be key - 1
            if idx > 0 and (idx - 1) < len(queries):
                query = queries[idx - 1]
                response = answer.content
                data_to_save.append({'query': query, 'response': response})
            else:
                print(f"Warning: No matching query found for answer key {idx} or key is out of bounds.")
        else:
            print(f"Warning: Item with key {idx} is not an AIMessage object.")

    # Define a custom Dumper to control string representation, avoiding global state changes.
    class MyDumper(yaml.SafeDumper):
        pass

    def str_presenter(dumper, data):
        """Custom string presenter to force literal block style for multiline strings."""
        # if '\n' in data:
        return dumper.represent_scalar('tag:yaml.org,2002:str', data, style='|')
        # return dumper.represent_scalar('tag:yaml.org,2002:str', data)

    MyDumper.add_representer(str, str_presenter)

    # Write the data to the YAML file using the custom Dumper
    with open(output_path, 'w', encoding='utf-8') as f:
        yaml.dump(data_to_save, f, Dumper=MyDumper, allow_unicode=True, default_flow_style=False, sort_keys=False, width=float('inf'))

    print(f"Successfully saved QA pairs to {output_path}") 

save_qa_to_yaml(answers, queries, '717_ida_1.yaml')
# Out:
# Successfully saved QA pairs to 717_ida_1.yaml

# %%
from langchain_core.messages import AIMessage
import json

# 你可以手动设置模型名称和md文件名
model_name = "temp-MOSES"
md_filename = model_name + ".md"
json_filename = model_name + ".json"

results = []
for idx, answer in answers.items():
    if isinstance(answer, AIMessage):
        q = queries[idx-1]
        print(f"{idx}.查询的最终答案: {answer.content}\n")
        results.append({"query": q, "response": answer.content})
    else:
        print("error")

# 将结果保存为JSON文件
with open(json_filename, "w", encoding="utf-8") as f:
    json.dump(results, f, ensure_ascii=False, indent=4)

# 生成Markdown内容，二级标题（query）带序号
markdown_output = f"# {model_name}\n\n"
for idx, result in enumerate(results, 1):
    markdown_output += f"## {idx}. {result['query']}\n\n"
    markdown_output += f"{result['response']}\n\n"

# 保存为Markdown文件
with open(md_filename, "w", encoding="utf-8") as f:
    f.write(markdown_output)
# Out:
# 1.查询的最终答案: Electrochemical sensors employing an Indicator Displacement Assay (IDA) for quinine detection exhibit both high stability and excellent reproducibility, attributes that are fundamentally rooted in the principles of supramolecular chemistry and the robust design of the sensor platform.
#
# **Stability:**
# The stability of these sensors is notably high, a critical factor for practical analytical applications. Empirical data show that the sensor retains approximately 86% of its original differential pulse voltammetry (DPV) signal after 21 days of storage at 4°C, with negligible signal drift observed during the first week. This sustained performance is attributed to the use of a nanocomposite platform, which provides a chemically inert and physically stable environment for the supramolecular host-guest interactions central to the IDA mechanism. The modest decrease in peak current over three weeks is within acceptable limits for most analytical protocols, indicating that the sensor’s recognition elements and transduction interface are not prone to rapid degradation or fouling.
#
# **Reproducibility:**
# Reproducibility is a hallmark of well-designed supramolecular sensors. In this case, the sensor demonstrates a low relative standard deviation (RSD) of 2.06% across seven independently fabricated electrodes, and consistent responses are observed when detecting 30 μM quinine with five separate electrodes. This high degree of reproducibility is a direct consequence of the controlled assembly of the host-guest system on the electrode surface and the uniformity of the nanocomposite matrix, which minimizes batch-to-batch variability and ensures reliable molecular recognition events.
#
# **Mechanistic and Supramolecular Considerations:**
# The IDA approach leverages competitive binding equilibria: a supramolecular host (often a macrocyclic receptor or functionalized nanomaterial) is pre-complexed with an electroactive indicator. Upon introduction of quinine, which has a higher binding affinity for the host, the indicator is displaced, leading to a measurable change in the electrochemical signal. The selectivity and stability of this process are governed by the thermodynamics of host-guest interactions—typically characterized by binding constants (K_a) in the range of 10^4–10^6 M^–1 for well-matched systems. The non-covalent nature of these interactions (e.g., π–π stacking, hydrogen bonding, electrostatic forces) ensures reversibility and reusability, while the nanocomposite support enhances signal transduction and suppresses nonspecific adsorption.
#
# **Analytical Performance and Verification:**
# The sensor’s performance is validated using multiple electrochemical techniques (DPV, cyclic voltammetry, electrochemical impedance spectroscopy) and spectroscopic methods (FTIR, ^1H NMR, SEM), confirming both the integrity of the supramolecular assembly and the reliability of the analytical response. The IDA-based sensor also demonstrates superior selectivity for quinine over structurally related or potentially interfering molecules, a direct result of the tailored host-guest recognition.
#
# **Summary:**
# In summary, electrochemical sensors utilizing an IDA for quinine detection are both stable and highly reproducible, with minimal signal loss over several weeks and low electrode-to-electrode variability. These properties are underpinned by the robust supramolecular host-guest chemistry, the stability of the nanocomposite platform, and the precision of the indicator displacement mechanism. Such sensors are well-suited for reliable, selective, and repeatable quinine analysis in complex matrices.

# %%
res_list = []
for i, ques in enumerate(revised_queries):
    response = answer_llm.invoke(ques)
    res_list.append(response)
    print(f"完成 {i+1} 个回答")
# Out:
# 完成 1 个回答
# 完成 2 个回答
# 完成 3 个回答
# 完成 4 个回答
# 完成 5 个回答
# 完成 6 个回答
# 完成 7 个回答
# 完成 8 个回答
# 完成 9 个回答
# 完成 10 个回答
# 完成 11 个回答
# 完成 12 个回答
# 完成 13 个回答
# 完成 14 个回答
# 完成 15 个回答
# 完成 16 个回答
# 完成 17 个回答
# 完成 18 个回答
# 完成 19 个回答
# 完成 20 个回答
# 完成 21 个回答
# 完成 22 个回答
# 完成 23 个回答
# 完成 24 个回答
# 完成 25 个回答
# 完成 26 个回答
# 完成 27 个回答

# %%
res_list
# Out:
# [AIMessage(content='Quinine is a naturally occurring alkaloid most famously derived from the bark of the cinchona tree, which is native to parts of Central and South America. It has been used for centuries for both medicinal and flavoring purposes. Below is an overview of some key points about quinine:\n\n1. Origin and History:\n• Traditional Use: Indigenous peoples in South America used cinchona bark to reduce fever. European colonists discovered its properties in the 17th century and introduced it widely for treating fevers.  \n• Malaria Treatment: Quinine became one of the foremost antimalarial drugs and played a significant historical role in controlling malaria in many parts of the world.\n\n2. Medicinal Use:\n• Antimalarial Properties: Quinine works by interfering with the life cycle of malaria parasites (Plasmodium species) within red blood cells. Although newer antimalarial medications exist, quinine may still be prescribed in certain cases.  \n• Leg Cramps: Quinine has sometimes been used off-label to alleviate nighttime leg cramps, but this practice has become less common due to concerns over side effects and FDA warnings.\n\n3. Mechanism of Action:  \n• Parasite Metabolism: Quinine disrupts the parasite’s ability to process and metabolize hemoglobin, ultimately harming or killing the parasite.  \n• Protozoal Toxicity: It is toxic to the parasites but can also come with a range of side effects in humans.\n\n4. Side Effects and Considerations:  \n• Common Side Effects: Nausea, upset stomach, headaches, ringing in the ears (tinnitus), and dizziness.  \n• Cinchonism: A term used to describe the constellation of symptoms (such as tinnitus, headache, nausea, and disturbed vision) associated with higher doses of quinine.  \n• Contraindications: People with certain conditions (e.g., tinnitus, hemolytic anemia, or allergies to quinine) should avoid it. Quinine may also interact with other medications, so a healthcare professional’s guidance is important.\n\n5. Non-medicinal Use:  \n• Tonic Water: Quinine has a distinctive bitter flavor, making it a key ingredient in tonic water and contributing to the characteristic taste of popular mixed drinks like gin and tonic.  \n• Flavoring Agent: Although used in beverages primarily for taste, the amount of quinine in consumer tonic water is typically quite small.\n\n6. Current Role:  \n• Ongoing Use: Quinine is less commonly used today than modern synthetic antimalarial agents like chloroquine or artemisinin-based combination therapies, largely due to its side effects and the possibility of parasite resistance. However, it may still be used in certain clinical contexts.  \n• Research: Scientists continue to study quinine and related compounds, both for antimalarial properties and possible new therapeutic uses.\n\nSummary\nQuinine is a historically significant compound for treating malaria and is known for its distinct bitter taste in tonic water. While its role as an antimalarial has largely been supplanted by newer medications, quinine remains important in selected clinical cases. As with any drug, it can have side effects, and medical guidance is essential if used for therapeutic purposes.\n\nDisclaimer: This information is for general knowledge and should not replace medical advice. If you have specific questions about quinine or any related health concerns, please consult a qualified healthcare professional.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 759, 'prompt_tokens': 12, 'total_tokens': 771, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--9bc42594-632a-4c4b-ba48-dcdf870662cc-0', usage_metadata={'input_tokens': 12, 'output_tokens': 759, 'total_tokens': 771, ' ...
#  AIMessage(content='An Indicator Displacement Assay (IDA) is a sensing strategy used in chemistry and biochemistry to detect and quantify the presence of a target analyte. The core principle relies on the competition between two species—a signaling molecule (an “indicator”) and the target analyte—for binding to a common receptor or host molecule. By observing changes in the indicator’s measurable signal (typically color or fluorescence), one can indirectly determine how much of the target analyte is present.\n\nHow it works:  \n1. A host molecule is pre-complexed with an indicator. The indicator is chosen because it provides a distinct optical response—such as a shift in color or emission—when bound to the host.  \n2. When an unknown sample containing the target analyte is introduced, the analyte competes with or displaces the indicator from the host receptor.  \n3. As the indicator is released (fully or partially) from the host, its optical properties change in a way that can be measured (e.g., observing an absorbance or emission shift). This shift correlates to the analyte concentration.\n\nBecause it is based on a straightforward, real-time change in the indicator’s signal, an IDA often eliminates the need for more complex instrumentation or procedures. Indicator displacement assays have a wide range of applications, including the detection of metal ions in environmental samples, biomolecules in clinical diagnostics, and small organic pollutants.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 551, 'prompt_tokens': 15, 'total_tokens': 566, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--7e05db70-93fe-4a3c-9e1e-4b9373c533bf-0', usage_metadata={'input_tokens': 15, 'output_tokens': 551, 'total_tokens': 566, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}}),
#  AIMessage(content='A variety of analytical methods are routinely employed to identify, characterize, and quantify quinine—both in raw materials (such as cinchona bark extracts) and in finished pharmaceutical or food/beverage products. Commonly used techniques include:\n\n1) High-Performance Liquid Chromatography (HPLC)  \n• One of the most widely used approaches to quantifying quinine in complex mixtures.  \n• Typically run in reversed-phase mode with either UV or fluorescence detection (fluorescence is especially popular because quinine is strongly fluorescent).  \n• Methods often specify an internal standard to improve accuracy and precision.  \n\n2) Fluorescence Spectroscopy  \n• Quinine exhibits strong fluorescence in acidic environments, which has made it a common standard in fluorescence measurements.  \n• Researchers often exploit this property for sensitive detection and quantification, especially in beverage testing (e.g., tonic water).  \n\n3) UV-Visible Spectrophotometry  \n• Quinine has characteristic absorbance peaks in the UV region.  \n• While less selective than fluorescence, UV-Vis methods are straightforward and can be used for routine checks if the matrices are not overly complex.  \n\n4) Mass Spectrometry (MS)  \n• Commonly used for confirmatory analysis of quinine’s molecular weight and structure, often coupled with HPLC (LC-MS).  \n• Capable of detecting impurities or related alkaloids present in cinchona bark or pharmaceutical formulations.  \n\n5) Nuclear Magnetic Resonance (NMR) Spectroscopy  \n• Enables definitive structural elucidation, especially important for verifying purity and identifying structural analogs such as quinidine.  \n• 1H NMR and 13C NMR can confirm key structural details such as stereochemistry and substituent positions.  \n\n6) Infrared (IR) Spectroscopy  \n• Although less specific for complex mixtures, IR can help verify functional groups in purified quinine samples.  \n• Often used alongside other techniques (e.g., NMR and MS) for complete characterization.  \n\n7) Classical (Titration) Methods  \n• Limit tests or simple acid-base titrations have historically been employed for approximate quinine quantification.  \n• Today they are largely supplanted by instrumental techniques for higher specificity and sensitivity.  \n\nChoice of technique depends on the sample matrix, the required sensitivity, and whether full structural confirmation or simple quantification is the goal. In practice, most modern regulatory or quality-control assays rely on HPLC (with UV or fluorescence detection) or LC-MS for reliable and accurate measurement of quinine content.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1099, 'prompt_tokens': 15, 'total_tokens': 1114, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--20e285c1-469f-494d-8b7e-e80586022f6a-0', usage_metadata={'input_tokens': 15, 'output_tokens': 1099, 'total_tokens': 1114, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}}),
#  AIMessage(content='An Indicator Displacement Assay (IDA) typically involves three main components:\n\n• Receptor (Host): A molecule (often a supramolecular host) that can bind both the indicator and the target analyte.  \n• Indicator (Reporter): A dye or fluorophore whose signal (color, fluorescence, etc.) changes upon binding to the receptor.  \n• Analyte (Guest): The target molecule whose binding to the receptor displaces the indicator, resulting in a measurable change in the indicator’s signal.  \n\nOverall, the receptor–indicator complex provides an initial baseline signal. When the analyte is introduced, it competitively binds to the receptor and displaces the indicator, altering the indicator’s signal in a way that can be detected and quantified.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 526, 'prompt_tokens': 18, 'total_tokens': 544, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--d2a0a299-a106-4e2e-ad6a-57274528760d-0', usage_metadata={'input_tokens': 18, 'output_tokens': 526, 'total_tokens': 544, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}}),
#  AIMessage(content='Indicator Displacement Assays (IDAs) are most commonly employed with spectroscopic (colorimetric or fluorescent) readouts, rather than electrochemical transduction. In principle, however, an IDA can be adapted to electrochemical detection if (1) a redox‐active “indicator” is displaced from its host or binding site by the target, and (2) that displacement is accompanied by a measurable change in current or potential. \n\nFor quinine in particular, there do not appear to be well‐established examples in the literature of an electrochemical sensor that directly uses an IDA mechanism. Most reported works on electrochemical quinine detection instead rely on methods such as:\n\n• Direct oxidation or reduction of quinine at (modified) electrodes, followed by techniques like cyclic voltammetry (CV) or differential pulse voltammetry (DPV).  \n• Host–guest systems (e.g., cyclodextrins) in which binding affects electron transfer, but without a separate “indicator” that is displaced.  \n• Other supramolecular or aptamer‐based approaches using electrochemical readouts that do not follow an IDA scheme.  \n\nIf your goal is specifically to use an IDA for quinine, you would need to design a redox‐active indicator whose binding to a receptor (or sensor surface) changes in the presence of quinine, thus altering the electrochemical signal. While such a design is theoretically feasible, it has not yet seen broad use or detailed reporting in the literature for quinine. You may find more examples of IDA‐type assays in the realm of colorimetric or fluorescence detection of quinine—those are significantly more common than electrochemical IDAs for this compound.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1449, 'prompt_tokens': 25, 'total_tokens': 1474, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1088, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--cf235136-dc2b-4ff0-9b53-7f1c01d14bed-0', usage_metadata={'input_tokens': 25, 'output_tokens': 1449, 'total_tokens': 1474, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1088}}),
#  AIMessage(content='A variety of macrocyclic (and related) host molecules have been leveraged for host–guest recognition in electrochemical assays. Common examples include:\n\n• Cyclodextrins: These cyclic oligosaccharides have a hydrophobic interior cavity and a hydrophilic exterior, enabling them to encapsulate small organic molecules (hydrophobic guests). Cyclodextrin‐modified electrodes are frequently used for chiral sensing and the detection of drugs, toxins, or biologically relevant compounds.\n\n• Calixarenes: Calix[n]arenes can be decorated with different functional groups on their upper or lower rims, providing selective binding sites for specific ions or molecules. Their ability to form stable complexes makes them popular for electrochemical ion sensing (e.g., heavy metals) and small‐molecule detection.\n\n• Crown ethers and cryptands: Known for their strong affinity for specific cations (e.g., alkaline or alkaline‐earth metals), crown ethers and cryptands have been used to design ion‐selective electrodes. Upon binding a target cation, the electrochemical signal (e.g., redox potential shift) can be correlated with analyte concentration.\n\n• Cucurbiturils: These barrel‐shaped macrocycles form highly stable host–guest complexes with positively charged and neutral guests. Modifying electrodes with cucurbiturils can enhance the selectivity and sensitivity of sensors, including those aimed at small organic molecules and pharmaceutical agents.\n\n• Pillar[n]arenes: A more recent class of pillar‐shaped macrocycles, pillararenes offer rigid, π‐rich cavities that can accommodate various guest molecules. Their tunable functionalization supports electrochemical detection of certain ions and small molecules.\n\nIn electrochemical assays, each of these hosts can be immobilized on an electrode surface (e.g., via self‐assembled monolayers or polymer films). When an analyte guest is bound in the cavity, it influences electron transfer kinetics or redox potentials, providing a measurable electrochemical signal that correlates with the presence or concentration of the analyte.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1131, 'prompt_tokens': 19, 'total_tokens': 1150, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--55e83f84-a0fb-44e1-8bec-d0410ea8e3c6-0', usage_metadata={'input_tokens': 19, 'output_tokens': 1131, 'total_tokens': 1150, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}}),
#  AIMessage(content='Indicator displacement assays (IDAs) for quinine—especially when adapted to an electrochemical readout—can be quite stable and reproducible provided a few key factors are well-controlled. Below are some of the considerations that influence their performance:\n\n1) Types of Molecular Receptor and Indicator:  \n   • In an IDA, the stability depends heavily on the specificity and robustness of the host–guest chemistry. If the receptor (for example, a cyclophane-based host or macrocyclic receptor) is well-designed and the indicator binds the receptor strongly yet reversibly, the sensor is more likely to maintain consistent behavior over multiple measurements.  \n   • The choice of electroactive indicator is also critical. Indicators that undergo well-defined redox processes at potentials readily accessible to the electrode of interest (e.g., carbon-based or metal electrodes) tend to yield reproducible electrochemical signals.\n\n2) Electrode Surface and Fouling:  \n   • One of the chief issues in repeated electrochemical measurements for organic analytes (like quinine) is electrode fouling. Quinine and other organic species can adsorb onto the electrode surface, gradually changing the electrode’s behavior.  \n   • Common mitigation strategies include using disposable screen-printed electrodes or employing surface-cleaning procedures (electrochemical cleaning steps, rinse protocols, or mild polishing for inert electrodes such as glassy carbon). Proper cleaning or using single-use electrodes helps maintain reproducibility.\n\n3) Measurement-to-Measurement Reproducibility:  \n   • Well-designed electrochemical IDAs for quinine typically exhibit relative standard deviations (RSDs) in the range of 2–10% between successive measurements under controlled lab conditions. Values toward the lower end of this range indicate a high level of reproducibility.  \n   • To achieve this reproducibility, both the binding step (where the dye binds to the host or is displaced by quinine) and the measuring step (where the electrochemical signal is read) need to be optimized. Maintaining a stable pH and buffer composition is particularly important for assays that rely on hydrogen bonding or protonation states of the host or indicator.\n\n4) Operational Stability (Shelf-Life and Reuse):  \n   • IDA-based electrochemical sensors tend to be stable for weeks to months if stored dry and protected from light (especially if the indicator is photosensitive) or extremes of temperature. The intrinsic stability of the sensors will depend on the host material and the electrode surface.  \n   • In many reported setups, the same sensor or electrode can be reused multiple times (often 10+ runs) with only minor signal degradation, provided it is regenerated (i.e., any displaced indicator is rinsed away and the receptor is reloaded with fresh indicator). If the electrode fouling becomes an issue, then single-use screen-printed electrodes may be preferred for high-fidelity measurements.\n\n5) Sources of Variation:  \n   • pH and ionic strength: Changes in pH can alter the protonation state of both quinine and the receptor, affecting affinity and thus reproducibility. Ionic strength changes can also alter electrostatic interactions in certain host–guest systems.  \n   • Electrolyte composition: Buffers that provide a stable ionic environment help improve reproducibility.  \n   • Indicator leakage or degradation: If the indicator leaches away from the receptor over time or undergoes unwanted redox side reactions, it can reduce stability. Choosing robust indicators helps minimize these effects.\n\nSummary:  \nAn electrochemical sensor that uses an IDA for quinine can be reliably stable and reproducible, often with <10% RSD for repeated measurements, when proper surface-cleaning and sample-handling procedures are followed. Good host–guest design and careful control of pH, temperature, and ionic strength also improve long-term stability. Sensors that employ ...
#  AIMessage(content='Indicator‐displacement assays (IDAs) for quinine are commonly verified by comparing the sensor’s results against a well‐established reference method—most often high‐performance liquid chromatography (HPLC)—and by performing standard “spike‐and‐recovery” measurements in real samples. In practice, researchers do the following:\n\n1) Calibration and Limit of Detection:  \n   • Prepare solutions of quinine at known concentrations and construct a calibration curve visualizing the electrochemical response versus concentration.  \n   • Evaluate the sensor’s sensitivity, limit of detection (LOD), and linear detection range using these standard solutions.\n\n2) Reference Method Comparison:  \n   • Analyze identical samples (e.g., spiked model solutions or beverages) with both the IDA‐based sensor and a reference method such as HPLC.  \n   • Compare the measured quinine concentrations to check for agreement. Good correlation (e.g., linear regression with an R² close to 1) supports the validity and accuracy of the IDA approach.\n\n3) Spike‐and‐Recovery Studies:  \n   • “Spike” real samples (such as tonic water) of unknown or low quinine content with known amounts of quinine, then test with the sensor.  \n   • Calculate the percentage of quinine recovered. Recoveries near 100% indicate that the sensor reliably measures quinine free of significant matrix effects.\n\n4) Selectivity Assessment:  \n   • Evaluate the sensor’s response to potential interfering species (e.g., other alkaloids or beverage components).  \n   • Verify that only quinine causes the indicator displacement that produces the distinct electrochemical signal.\n\nThrough calibration curves, standard addition/spike‐and‐recovery tests, and correlation with a reference technique (HPLC), the IDA‐based electrochemical sensor for quinine is validated and its accuracy and precision are established.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1029, 'prompt_tokens': 29, 'total_tokens': 1058, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--a411cb4f-a963-4ac2-8b45-15cec64d17c6-0', usage_metadata={'input_tokens': 29, 'output_tokens': 1029, 'total_tokens': 1058, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}}),
#  AIMessage(content='In an Indicator Displacement Assay (IDA) using beta-cyclodextrin (β-CD), Methylene Blue (MB) initially forms a host–guest complex with β-CD. When quinine is introduced, it binds more strongly to the hydrophobic cavity of β-CD than MB does. This stronger binding affinity of quinine to β-CD causes MB to be expelled (or “displaced”) from the β-CD cavity and return to the solution, where its electrochemical signal can be measured. The driving forces behind this displacement include hydrophobic interactions, hydrogen bonding, and complementary geometry that make the quinine–β-CD complex more stable than the MB–β-CD complex.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 849, 'prompt_tokens': 44, 'total_tokens': 893, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--02de8425-0c32-4d4b-87df-96e47a756d09-0', usage_metadata={'input_tokens': 44, 'output_tokens': 849, 'total_tokens': 893, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}}),
#  AIMessage(content='In electrochemical IDA‐type quinine sensors, graphene most often serves as a highly conductive, high‐surface‐area transducer material that enhances both the binding interactions and the electrochemical signal. More specifically:\n\n1. High Conductivity and Signal Amplification:  \n   • Graphene’s exceptional electrical conductivity facilitates efficient electron transfer between the electrode and the redox‐active indicator.  \n   • This increased conductivity amplifies the current change that occurs when the indicator is displaced by quinine, improving sensitivity and lowering the detection limit.\n\n2. Large Surface Area for Immobilization:  \n   • The wide, two‐dimensional surface of graphene offers numerous sites for immobilizing host molecules (cavity/binding units) or redox probes.  \n   • Because catalyst or receptor molecules can be densely packed on graphene, even subtle changes in indicator binding or displacement become more pronounced in the measured electrochemical signal.\n\n3. Rapid Electron Transfer Kinetics:  \n   • Graphene’s graphitic lattice allows for fast electron transport, helping to generate stable, swift response signals.  \n   • This contributes to reliable, reproducible measurements—an important factor in IDAs where small variations in indicator displacement must be precisely tracked.\n\nOverall, graphene functions as a high‐performance electrode modifier that boosts both the sensitivity and the selectivity of indicator‐displacement assays for quinine, enabling lower detection limits and more robust electrochemical readouts.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 875, 'prompt_tokens': 32, 'total_tokens': 907, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--cb5e0a46-0493-4555-b4f9-b926ff95da29-0', usage_metadata={'input_tokens': 32, 'output_tokens': 875, 'total_tokens': 907, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}}),
#  AIMessage(content='A cryptand is a type of synthetic, cage-like ligand that can encapsulate ions (particularly metal cations) within its three-dimensional framework. Structurally, cryptands are typically formed from polycyclic or bicyclic assemblies of donor atoms (such as nitrogen or oxygen). Because of their enclosed (“crypt”) nature and the multiple donor sites they provide, they bind cations more strongly and selectively than comparable open-chain ligands or even simpler ring ligands like crown ethers. This strong binding, often described as forming “guest–host” complexes, makes cryptands useful in areas such as ion-selective electrodes, separation processes, and studies of complexation reactions in solution.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 215, 'prompt_tokens': 12, 'total_tokens': 227, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--b741e636-5a9c-43d3-8277-0f9adfb62425-0', usage_metadata={'input_tokens': 12, 'output_tokens': 215, 'total_tokens': 227, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}),
#  AIMessage(content='Yes. Pyrrole is an aromatic heterocycle because the nitrogen’s lone pair participates in the conjugated π system, giving a total of six π-electrons in the ring (following Hückel’s rule, 4n + 2 = 6 when n = 1). This conjugation and the planar ring structure make pyrrole aromatic.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 237, 'prompt_tokens': 14, 'total_tokens': 251, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--ad78bfe6-9161-4abe-b41f-cf4e694dca7b-0', usage_metadata={'input_tokens': 14, 'output_tokens': 237, 'total_tokens': 251, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}),
#  AIMessage(content='In supramolecular chemistry, guests are typically molecules or ions whose shapes, sizes, and functional groups complement the structure and binding motifs of the host. Examples include:\n\n1) Metal Cations (e.g., alkali metals such as Na⁺, K⁺)  \n   • These often coordinate to crown ethers, cryptands, or other ligands containing heteroatoms (N, O) capable of donating electron density to metal centers.\n\n2) Ammonium Ions (e.g., NH₄⁺, primary amines, protonated amines)  \n   • These can hydrogen-bond with host molecules like crown ethers, cryptophanes, or cucurbiturils via hydrogen-bonding interactions.\n\n3) Anions (e.g., halides, oxyanions)  \n   • Anions often bind to hosts with positively charged sites, hydrogen-bond donors, or Lewis acid sites. Examples include calixarenes and urea/thiourea-based receptors.\n\n4) Neutral Organic Molecules  \n   • Aromatic guests (e.g., benzene derivatives, naphthalene, etc.) can be recognized by π–π stacking inside macrocycles such as calixarenes, porphyrins, or π-conjugated cavitands.  \n   • Polar molecules (e.g., alcohols, ketones, carboxylic acids) can be bound through directional hydrogen bonding.\n\n5) Other Macrocycles or Complexes  \n   • Larger entities with hydrophobic pockets, such as cyclodextrins or cavitands, can encapsulate smaller macrocycles or metal complexes if there are complementary steric and electronic interactions.\n\nOverall, the exact types of guest molecules vary widely, but they generally share structural and electronic features (size, shape, polarity, charge) that allow precise noncovalent interactions—hydrogen bonding, π stacking, electrostatic attraction, or metal coordination—with the corresponding host.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 670, 'prompt_tokens': 20, 'total_tokens': 690, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--91e4a323-93a6-4af0-a479-b06ea27adec8-0', usage_metadata={'input_tokens': 20, 'output_tokens': 670, 'total_tokens': 690, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}),
#  AIMessage(content='Macrocycles are ring-shaped molecules composed of a large number of atoms (commonly defined as rings with 12 or more atoms). They occupy a central place in supramolecular chemistry, medicinal chemistry, and materials science because of their unique structural properties and ability to form host-guest complexes. Below are some major classes of macrocycles, with brief descriptions and representative examples:\n\n1) Crown Ethers  \n• General Structure: Consist of repeating ethylene glycol units connected in a ring, forming multiple ether (–O–) linkages.  \n• Characteristics:  \n  – Known for binding metal cations (e.g., potassium, sodium) via coordination to the oxygen atoms.  \n  – Widely used in host-guest chemistry to study binding selectivity toward different ionic guests.  \n• Examples: 12-Crown-4, 15-Crown-5, 18-Crown-6.\n\n2) Calixarenes  \n• General Structure: Formed by linking phenolic subunits (commonly four, six, or eight) to create a “vase-shaped” macrocyclic framework.  \n• Characteristics:  \n  – The upper and lower rims can be selectively functionalized, enabling tailored binding interactions.  \n  – Often used as hosts for ions, neutral molecules, and for constructing more sophisticated supramolecular systems.  \n• Examples: p-tert-Butylcalix[4]arene, Calix[6]arene, Calix[8]arene.\n\n3) Cucurbiturils  \n• General Structure: Barrel-shaped macrocycles made up of glycoluril units (–C4H2N4O2–) linked by methylene bridges.  \n• Characteristics:  \n  – Possess two symmetric portals which can bind and encapsulate guest molecules (e.g., small organic molecules or cations).  \n  – Known for exceptionally high binding affinities and selectivities.  \n• Examples: Cucurbit[5]uril, Cucurbit[6]uril, Cucurbit[7]uril.\n\n4) Cyclodextrins  \n• General Structure: Cyclic oligosaccharides composed of α-(1→4)-linked D-glucopyranose units. They are torus-shaped “sugar rings.”  \n• Characteristics:  \n  – Classified by the number of glucose units: α-cyclodextrin (6 units), β-cyclodextrin (7 units), γ-cyclodextrin (8 units).  \n  – Hydrophobic cavity can encapsulate guest molecules, while the outer surface is hydrophilic.  \n  – Extensively used in drug delivery to increase solubility and stability of active agents.  \n• Examples: α-Cyclodextrin, β-Cyclodextrin, γ-Cyclodextrin.\n\n5) Porphyrins and Related Tetrapyrroles  \n• General Structure: Composed of four pyrrole rings interconnected by methine (–CH=) bridges, forming a highly conjugated macrocycle.  \n• Characteristics:  \n  – Often complexed with metal ions (e.g., Fe, Mg, Co) to form metalloporphyrins that play vital roles in biology (e.g., heme in hemoglobin).  \n  – Excellent chromophores with strong absorption in the visible region (the Soret band).  \n• Examples: Porphyrin, Chlorin, Corrin (e.g., vitamin B12), Phthalocyanine.\n\n6) Macrocyclic Antibiotics  \n• General Structure: Large ring molecules, often with peptide (amide) linkages. Some may include additional functional groups such as sugars or aromatic substituents.  \n• Characteristics:  \n  – Exhibit a range of biological activities, especially antibacterial and antiviral.  \n  – The rigid macrocyclic core can form specific interactions with cellular targets.  \n• Examples: Vancomycin, Erythromycin (though erythromycin is technically a macrolide), Rifamycin.\n\n7) Cyclophanes  \n• General Structure: Macrocycles that contain aromatic rings (e.g., benzene) bridged by aliphatic chains across non-adjacent ring positions, creating a “basket” or “cage” structure.  \n• Characteristics:  \n  – Constrained connectivity creates unusual electronic properties.  \n  – Used in studies of conjugation, strain, and host-guest chemistry.  \n• Examples: [2.2]Paracyclophane, Basketane derivatives.\n\n8) Cryptands (Related Polycycles)  \n• Although cryptands are not strictly single-ring macrocycles (they are often bicyclic or tricyclic), they are frequently discussed alongside macrocycles because of their similar bindin ...
#  AIMessage(content='In calixarenes bearing pyrrole groups, the dominant noncovalent interaction responsible for anion binding is hydrogen bonding from the pyrrole NH groups to the anion. Often, these hydrogen bonds are supplemented by additional electrostatic and/or anion–π interactions involving the aromatic rings of the calixarene, but the key interaction is the pyrrole NH···anion hydrogen bond.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 965, 'prompt_tokens': 31, 'total_tokens': 996, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--73fd9fbf-bf77-45ba-b406-130c38f551dd-0', usage_metadata={'input_tokens': 31, 'output_tokens': 965, 'total_tokens': 996, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}}),
#  AIMessage(content='Yes. Although the best‐known “pyrrolic calix” systems are the so‐called “calixpyrroles” (which are not, strictly speaking, phenol‐based calixarenes), there also exist true calixarene derivatives in which pyrrole units are appended as substituents (typically at the upper or lower rim) of a classical calix[ n ]arene. These systems have appeared in the literature as anion sensors, colorimetric detectors, and general supramolecular hosts. Below are a few representative examples and references:\n\n• Pyrrole‐functionalized calix[4]arenes:  \n  Chang, S.‐K. et al. reported calix[4]arene‐based colorimetric anion sensors bearing pyrrole units:  \n  – Chang, S.‐K.; Ko, J.‐I. “Calix[4]arene‐Based Colorimetric Anion Sensors Bearing Pyrrole Units.” Tetrahedron Letters 1997, 38, 7321–7324.  \n  In these hosts, the pyrrole moieties were appended at the phenolic (lower) rim of the calix[4]arene scaffold to enhance anion binding and enable colorimetric signaling.\n\n• Bis(pyrrole)‐tethered calixarenes:  \n  Some research groups have synthesized calix[4]arene‐based hosts bearing two or more pyrrole rings covalently attached to create rigid binding pockets suitable for charged guests (for example, carboxylates, halides, etc.). These derivatives often show enhanced selectivity via hydrogen‐bonding interactions from the pyrrole NH protons.\n\n• Comparison with calixpyrroles:  \n  Although “calixpyrrole” (the macrocycle consisting of four pyrrole subunits linked by –CH2– bridges) is a well‐known anion receptor, it is not a phenol‐derived calixarene. In contrast, the pyrrole‐appended calixarenes retain the classic phenol‐methylene macrocyclic framework of calix[n]arenes but incorporate pyrrole rings at one or more rims.\n\nIn short, whereas “calixpyrrole” itself is a separate macrocycle class, there are definitely “true” calixarene derivatives in which pyrrole rings are introduced as substituents. These hybrid systems have been investigated for their ability to bind anions, act as sensors, and participate in other host–guest chemistry typical of calixarene‐based receptors.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1821, 'prompt_tokens': 29, 'total_tokens': 1850, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1280, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--db3b81ee-33f4-4d4c-a60b-42d1f77a2445-0', usage_metadata={'input_tokens': 29, 'output_tokens': 1821, 'total_tokens': 1850, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1280}}),
#  AIMessage(content='Cage molecules and macrocycles are both classes of host-structure compounds used extensively in supramolecular chemistry, but their three‐dimensional (cage) versus ring‐like (macrocycle) architectures often lend them to somewhat different (though sometimes overlapping) sets of applications. Below are several common uses and areas of overlap:\n\n1) CAGE MOLECULES  \n• Host–Guest Chemistry and Molecular Encapsulation:  \n  – Cage molecules (also called “containers” or “capsules”) have discrete, three-dimensional cavities.  \n  – They are highly effective at encapsulating guest species (ions, small molecules) for studying binding interactions, carrying out catalytic transformations in confined spaces, and sensing.  \n\n• Catalysis in Constrained Environments:  \n  – Cages provide a microenvironment that can stabilize reactive intermediates and facilitate unique reaction pathways.  \n  – Metal–organic cage compounds in particular can serve as catalytic hosts for reactions that require precise positioning of active sites.  \n\n• Gas Storage and Separation:  \n  – Because they have defined internal voids, some porous cage structures are used for gas capture (e.g., CO₂, hydrocarbons).  \n  – They can distinguish and selectively bind certain gases, aiding in separation processes.  \n\n• Drug Delivery:  \n  – The robust 3D framework of certain cages allows them to protect and transport bioactive molecules.  \n  – Their ability to release payloads under specific conditions (e.g., pH changes) can be leveraged in targeted drug delivery.  \n\n2) MACROCYCLES  \n• Ion Binding and Transport:  \n  – Macrocycles, such as crown ethers and cryptands, are often used to selectively bind cations (alkali, alkaline earth, transition metals).  \n  – Their ring size and donor atom arrangement gives them predictable binding preferences.  \n\n• Sensing and Detection:  \n  – Many macrocycles are fluorescent or can be modified to emit a signal when a guest is bound.  \n  – They are frequently used as sensing platforms for detecting metal ions or other small molecules.  \n\n• Catalysis and Enzyme Mimics:  \n  – Porphyrins, phthalocyanines, and other macrocycles serve as excellent scaffolds for catalytic metal centers, mimicking enzymes or natural cofactors.  \n  – They can facilitate oxidation, reduction, and other redox processes.  \n\n• Drug Delivery and Pharmacology:  \n  – Cyclodextrins, a well‐known family of macrocycles, encapsulate drugs to improve solubility and stability.  \n  – Macrocyclic peptides (e.g., cyclic peptides) often exhibit enhanced bioavailability and receptor selectivity.  \n\n3) OVERLAPPING USES  \n• Host–Guest Chemistry:  \n  – Both cages and macrocycles can encapsulate guest molecules. The choice between a 3D cage or a ring‐like macrocycle often depends on the size and shape of the guest and the desired binding environment.  \n\n• Separation and Purification:  \n  – Both types of hosts can be leveraged for molecular separations, taking advantage of selective binding and/or size exclusion.  \n\n• Sensing:  \n  – By incorporating spectroscopic or electrochemical reporter groups, both cages and macrocycles can detect specific analytes via changes in fluorescence, color, or current.  \n\n• (Bio)Catalysis:  \n  – Many macrocycles (e.g., porphyrins) and metal–organic cages are used as catalytic platforms where the metal center performs the reaction in the confined space.  \n\nIn short, cage molecules excel at fully encapsulating guests and providing a well‐defined, three‐dimensional microenvironment useful for gas capture, encapsulation, and specialized catalysis. Macrocycles, on the other hand, often excel in highly selective ion or molecular binding, especially in planar or cylindrical ring arrangements, and find extensive applications in separations, sensors, and bioactive compound delivery. Despite their structural and functional differences, the two classes certainly share overlaps in areas of host–guest chemistr ...
#  AIMessage(content='A variety of electron‐poor, π‐acidic cavities and macrocycles have been shown to bind anions via anion–π interactions. Broadly speaking, these hosts feature aromatic panels rendered sufficiently electron‐deficient (often via perfluorination or incorporation of strongly electron‐withdrawing groups) to permit electrostatically favorable contacts to negatively charged guests. Common examples include:\n\n• Perfluorinated aromatic frameworks. Fluoroaromatic rings, such as hexafluorobenzene derivatives, are frequently employed because perfluorination lowers the electron density in the π‐system.  \n• Naphthalene and perylene diimides (NDI, PDI). These planar diimide scaffolds become strong π‐acceptors when substituted at key positions with electron‐withdrawing groups, enabling anion binding over their π‐surface.  \n• Tetracationic cyclophanes. Hosts such as cyclobis(paraquat‐p‐phenylene), sometimes called the Stoddart “blue box,” incorporate viologen (paraquat) units. Their overall positive charge and electron‐poor aromatic surfaces favor anion–π interactions in the cavity.  \n• Other electron‐deficient macrocycles and cavitands. Systems built from triazines, pyridinium rings, or other extended π‐cores with substituents that withdraw electron density can similarly present ‘π‐acidic’ surfaces to anions.\n\nAlthough many of these hosts also use additional contacts (e.g., hydrogen bonding, ion pairing), their distinctive feature is that the dominant stabilizing interaction is between the negatively charged guest and the π‐deficient aromatic ring (anion–π). These systems have been studied for binding halides, nitrate, carboxylates, and other anionic species, and have opened new design paradigms in supramolecular host–guest chemistry by exploiting noncovalent contacts beyond the more traditional hydrogen and halogen bonds.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1417, 'prompt_tokens': 27, 'total_tokens': 1444, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 896, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--8d19ad6e-a7ff-4c4f-bd84-7da38d542fa8-0', usage_metadata={'input_tokens': 27, 'output_tokens': 1417, 'total_tokens': 1444, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 896}}),
#  AIMessage(content='Supramolecular receptors incorporating pyrrole rings are often excellent anion binders largely because each pyrrole NH can serve as a hydrogen‐bond donor to the guest. In other words, the partially acidic hydrogen on the pyrrole nitrogen is well‐positioned to form strong (often directional) hydrogen bonds to negatively charged species. Furthermore, the extended π system of pyrrole rings can in some cases help stabilize bound anions through additional noncovalent interactions (e.g., anion–π interactions). These factors together make pyrrole‐containing hosts particularly well‐suited for selective and robust anion recognition.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 330, 'prompt_tokens': 23, 'total_tokens': 353, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--6ab5b231-b54b-41d8-a259-0dfe726fae7d-0', usage_metadata={'input_tokens': 23, 'output_tokens': 330, 'total_tokens': 353, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}),
# ...
#  AIMessage(content='IDA‐based (interdigitated array‐based) electrochemical sensors often rely on host–guest recognition motifs in which a suitably tailored “host” molecule selectively binds an analyte (“guest”) through noncovalent interactions. Common examples include:\n\n• Hydrogen Bonding: Many receptors (e.g., urea‐ or amide‐based hosts) form directional hydrogen bonds with analytes.  \n• π–π Stacking: Aromatic hosts (e.g., certain calixarenes, pyrene derivatives) can bind guests via face‐to‐face stacking.  \n• Electrostatic Interactions: Charged host frameworks (e.g., sulfonated calixarenes, crown ethers for cations) offer selective complementarity to oppositely charged guests.  \n• Metal–Ligand Coordination: Complexes formed by crown ethers or other chelating ligands around metal ions can trap specific analytes.  \n• Hydrophobic Cavitation: Macrocyclic hosts such as cyclodextrins, cucurbiturils, and calixarenes contain hydrophobic cavities that encapsulate suitably sized organic guests.  \n\nBy grafting or immobilizing these host structures onto the interdigitated electrodes, the resulting sensor transduces the binding event into a measurable electrochemical signal, creating a sensitive and selective detection platform.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1304, 'prompt_tokens': 25, 'total_tokens': 1329, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1024, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--feaa714a-51e2-46a5-9636-b34098253223-0', usage_metadata={'input_tokens': 25, 'output_tokens': 1304, 'total_tokens': 1329, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1024}}),
#  AIMessage(content='Indicator displacement assays (IDAs) rely on a reversible binding event in which an “indicator” dye is first bound to a receptor (host) and then is displaced by an analyte (guest) having a higher affinity for the same binding site. This displacement changes the indicator’s optical properties (color or fluorescence), providing a readout for the presence or quantity of the analyte. A wide range of noncovalent host–guest interactions can be used in IDA design for optical detection, including:\n\n1. Metal–ligand/coordination interactions.  \n   • Coordination to transition-metal centers (e.g., Zn²⁺, Cu²⁺, etc.)   \n   • Complex formation where a metal-binding dye can be displaced by a competing analyte.\n\n2. Hydrogen bonding.  \n   • Receptors with well-placed hydrogen-bond donor/acceptor groups can capture dyes or analytes through directional hydrogen bonds.  \n   • Displacement occurs when the analyte more strongly hydrogen-bonds to the host.\n\n3. Electrostatic or ionic interactions.  \n   • Oppositely charged species form electrostatic host–guest complexes (e.g., ammonium/cationic analytes binding to sulfonic acid/sulfonate hosts).  \n   • A charged dye is displaced by an analyte with stronger ionic interactions.\n\n4. π–π and other aromatic interactions.  \n   • Aromatic dyes can be intercalated or stacked with cavity-bearing hosts (e.g., calixarenes, cucurbiturils, pillararenes) or simply form π–π complexes in solution.  \n   • The guest analyte outcompetes the bound dye via stronger π–π or charge-transfer interactions.\n\n5. Hydrophobic encapsulation/inclusion.  \n   • Cyclodextrins, cavitands, cucurbiturils, and other “capsule” hosts can bind hydrophobic dyes by including them in their nonpolar cavities.  \n   • The analyte, if better suited for the host’s cavity, displaces the dye, changing the dye’s environment and hence its optical properties.\n\n6. Ion-pair complexation.  \n   • Where both host and guest have ionic sites that form distinctive charged complexes (e.g., crown ethers with alkali metal ions, calixcrowns, etc.).  \n   • Displacement occurs if the analyte ion forms a more stable ion pair with the host.\n\nIn practice, many IDA systems employ a combination of these binding forces to fine-tune selectivity, sensitivity, and the strength of the optical response upon indicator displacement. The overarching design principle is to ensure that the host binds the indicator dye in such a way that its optical signal is detectably modified upon displacement by the target analyte.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1088, 'prompt_tokens': 24, 'total_tokens': 1112, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--e6e053ef-d854-4788-b53b-8ab5684460d0-0', usage_metadata={'input_tokens': 24, 'output_tokens': 1088, 'total_tokens': 1112, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}}),
#  AIMessage(content='In supramolecular systems, a wide range of noncovalent host–guest interactions can trigger changes in a chromophore’s absorption or emission spectra (i.e., its “optical signals”). Some of the most common interaction types include:\n\n1. Hydrogen Bonding.  \n   • Complex formation via hydrogen bonds can modify the polarity and rigidity around a guest chromophore, changing its absorption/emission characteristics.  \n\n2. Electrostatic or Ionic Interactions.  \n   • Charged hosts (e.g., crown ethers with metal cations, calixarenes with anions) can stabilize or perturb excited states of a dye, leading to shifts in fluorescence or color.  \n\n3. Charge-Transfer Interactions.  \n   • When an electron donor and electron acceptor interact, new excited-state charge-transfer bands may appear, or existing ones may shift in energy, altering the observed spectrum.  \n\n4. π–π Stacking.  \n   • Aromatic ring systems in host and guest can stack, influencing the energy levels of conjugated chromophores and leading to quenching or enhancement of emission (such as aggregation-induced emission or excimer formation).  \n\n5. Coordination/Metal–Ligand Bonding.  \n   • Metallosupramolecular complexes formed via coordination can alter the guest’s ground and excited states, producing shifts in absorption or emission—a frequent design strategy in metal-based sensors.  \n\n6. Conformational Changes/Binding-Induced Rigidity.  \n   • Entrapment of a fluorophore by a rigid host (e.g., a macrocycle) can reduce nonradiative decay pathways and enhance emission intensity.  \n\nAny of these interactions can subtly or dramatically alter electronic transitions and, therefore, cause observable changes in color or fluorescence (emission intensity, lifetime, or wavelength), making them valuable in sensing and signal transduction applications.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 837, 'prompt_tokens': 20, 'total_tokens': 857, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--f4840a70-56bf-440d-abf0-88ff1dd0a781-0', usage_metadata={'input_tokens': 20, 'output_tokens': 837, 'total_tokens': 857, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}}),
#  AIMessage(content='A variety of molecular interactions between a host and a guest can give rise to measurable changes in electrochemical signals. Generally, any binding event that modifies the redox-active environment—or alters the electronic properties of the host, guest, or associated reporter—can shift potentials, peak currents, or electron‐transfer kinetics. Salient examples include:\n\n1. Hydrogen bonding:  \n   – Formation of hydrogen bonds may stabilize or destabilize certain redox states of the host or guest. This shift in the equilibrium can manifest as a change in redox potential.\n\n2. Electrostatic or ionic interactions:  \n   – Coulombic attractions or repulsions can affect the electron density at the redox‐active center. Changes in local charge environment often shift the formal potential or modify electron-transfer kinetics.\n\n3. Metal–ligand/coordination bonding:  \n   – When the guest binds through coordination to a metal center in the host (for example, complexes of transition metals), it can alter the redox properties of that center by influencing orbital energies.\n\n4. π–π stacking and other noncovalent interactions:  \n   – Stacking interactions (common in polyaromatic systems) or dipole–dipole/van der Waals contacts can change how easily electrons flow in or out of the redox‐active moieties, shifting the observed electrochemical signal.\n\n5. Conformational changes:  \n   – In some host structures—especially macrocyclic, supramolecular, or polymeric hosts—guest binding can trigger conformational rearrangements. Such structural changes can alter the electron-transfer pathways or surface accessibility of the redox sites.\n\nAll of these interactions effectively modify the local chemical or physical environment of the redox center. When such modifications are transduced into measurable potential shifts or current changes, they yield an electrochemical readout for the host–guest event.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 516, 'prompt_tokens': 21, 'total_tokens': 537, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--f7caa432-8719-4c61-a852-654ee965edec-0', usage_metadata={'input_tokens': 21, 'output_tokens': 516, 'total_tokens': 537, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}),
#  AIMessage(content='In supramolecular chemistry, cation–π interactions play a key role in the binding of cationic guests by hosts with electron-rich aromatic cavities. The most common classes of hosts that rely primarily on cation–π interactions include:\n\n1) Calix[n]arenes. Calixarenes are cup-shaped macrocycles composed of phenol units. Their π-rich rings and the spatial arrangement of these rings can create an electron-rich pocket that is well suited to binding positively charged species via cation–π interactions.\n\n2) Resorcin[4]arenes and Pyrogallolarenes. Like calixarenes, resorcinarenes and pyrogallolarenes are formed by the condensation of resorcinol (or pyrogallol) with aldehydes. Their bowl-shaped or vase-shaped cavities expose aromatic surfaces that stabilize cationic guests.\n\n3) Pillar[n]arenes. Pillararenes are rigid, pillar-shaped macrocycles assembled from 1,4-disubstituted hydroquinone units. Their cylindrical cavities present multiple electron-rich aromatic rings that can strongly bind a variety of cationic guests.\n\n4) Cyclophanes and Other Aromatic Cage Hosts. Cyclophanes (e.g., [n.n]cyclophanes) contain two or more aromatic rings bridged by aliphatic linkers, creating defined cavities or clefts. The facing aromatic rings enable cation–π interactions to stabilize bound cations.\n\nIn these systems, the aromatic rings of the host create a region of high electron density that favorably interacts with a positive charge, giving rise to strong noncovalent cation–π binding.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 918, 'prompt_tokens': 28, 'total_tokens': 946, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--4aa54c45-8111-413e-9a43-53c3c73f43df-0', usage_metadata={'input_tokens': 28, 'output_tokens': 918, 'total_tokens': 946, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}}),
#  AIMessage(content='Host–guest chemistry depends on a variety of interrelated factors that govern how well a “guest” molecule fits into (and is stabilized by) a “host” molecule or material. The main factors include:\n\n1. Noncovalent Interactions:\n   • Hydrogen bonding – Often the strongest and most directional of the noncovalent forces; crucial for binding specificity.  \n   • Electrostatic (ionic) interactions – Significant when charged or highly polar groups in the host and guest align.  \n   • Van der Waals/dispersion forces – Arise from transient dipoles and become especially important for closely fitting host–guest pairs with large surface contact.  \n   • π–π and π–cation interactions – Relevant in systems where aromatic rings (π systems) or positive charges can stack or align.\n\n2. Geometric/Steric Complementarity:\n   • Size and shape fit – Matching the cavity or pocket of the host to the guest is crucial for tight binding and enhanced selectivity.  \n   • Minimal steric hindrance – Bulky substituents or congestion can block or weaken the binding interaction.\n\n3. Electronic Complementarity:\n   • Polarity and hydrogen-bond donor/acceptor sites – Helps ensure that attractive forces (rather than repulsive ones) dominate.  \n   • Partial charge matching – Aligning complementary regions of electron density on the host and guest can improve stability.\n\n4. Solvent Effects and Environment:\n   • Solvent polarity – Affects the strength and type of noncovalent interactions (e.g., hydrogen bonds can be more or less effective in different solvents).  \n   • Solvent inclusion/exclusion – Changing the solvation environment around the host or guest can favor or disfavor complex formation (for example, the hydrophobic effect in aqueous solutions).\n\n5. Thermodynamic and Entropic Factors:\n   • Enthalpic contributions – Favorable interaction energies between host and guest.  \n   • Entropic contributions – Changes in the degrees of freedom upon binding (e.g., release of solvent molecules, reduction in translational/rotational freedom).  \n   • Overall balance – A sufficiently large net free energy (ΔG) favors complex formation.\n\nBy optimizing these factors—especially matching the host’s cavity to the guest’s size, shape, and functional groups—you can tailor host–guest systems for specific functions and improve selectivity and binding strength.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 813, 'prompt_tokens': 17, 'total_tokens': 830, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'o1-2024-12-17', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--e03fdba2-8cc2-43be-975f-91f0b8e85599-0', usage_metadata={'input_tokens': 17, 'output_tokens': 813, 'total_tokens': 830, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}})]

# %%
import json

# 你可以手动设置模型名称和md文件名
model_name = "o4-mini-final"
md_filename = model_name + ".md"
json_filename = model_name + ".json"

results = []
for i, res in enumerate(res_list):
    q = queries[i]
    print(f"{i+1}.查询 {q} 的答案是：{res.content}\n")
    results.append({"query": q, "response": res.content})

# 将结果保存为JSON文件
with open(json_filename, "w", encoding="utf-8") as f:
    json.dump(results, f, ensure_ascii=False, indent=4)

# 生成Markdown内容，二级标题（query）带序号
markdown_output = f"# {model_name}\n\n"
for idx, result in enumerate(results, 1):
    markdown_output += f"## {idx}. {result['query']}\n\n"
    markdown_output += f"{result['response']}\n\n"

# 保存为Markdown文件
with open(md_filename, "w", encoding="utf-8") as f:
    f.write(markdown_output)
# Out:
# 1.查询 Tell me about Quinine. 的答案是：Quinine is a naturally occurring alkaloid best known for its antimalarial properties. Below is an overview of its origin, chemistry, mechanism of action, clinical uses, side effects and historical importance.
#
# 1. Origin and Sources
# • Botanical source: Quinine is extracted from the bark of various Cinchona species (notably C. officinalis, C. ledgeriana and C. pubescens).
# • Historical discovery: Indigenous peoples of Peru and surrounding regions used “Jesuit’s bark” or “Peruvian bark” to treat fevers long before European colonists recognized its value in the 17th century.
#
# 2. Chemical Structure and Properties
# • Molecular formula: C20H24N2O2
# • Structural features: A quinoline nucleus linked to a quinuclidine bicyclic amine; it has two stereocenters.
# • Physical properties: White crystalline powder; bitter taste; slightly soluble in water, more soluble in ethanol.
#
# 3. Mechanism of Antimalarial Action
# • Plasmodium target: Blocks the parasite’s ability to dissolve and detoxify heme released during hemoglobin digestion in its food vacuole.
# • Heme polymerization inhibitor: Free heme is toxic; quinine binds heme and prevents its conversion to harmless hemozoin, leading to parasite death.
#
# 4. Clinical Uses
# • Malaria treatment: Particularly effective against chloroquine-resistant Plasmodium falciparum. Used in severe or complicated cases, often in combination with other antimalarials (e.g., doxycycline, clindamycin).
# • No longer first‐line in many regions due to newer drugs (artemisinin derivatives), but still vital where resistance patterns favor its use.
# • Off‐label and adjunct uses:
#   – Nocturnal leg cramps (though benefits are modest and outweighed by risk).
#   – Historically used as a general fever reducer (antipyretic) and analgesic, but now largely obsolete for these purposes.
#
# 5. Pharmacokinetics
# • Absorption: Well absorbed orally; peak plasma levels in 1–3 hours.
# • Distribution: Widely distributed, crosses the blood–brain and placental barriers; accumulates in liver, kidney and red blood cells.
# • Metabolism: Hepatic via cytochrome P450 (CYP3A4 predominant).
# • Elimination half‐life: Approximately 10–12 hours in adults (longer in children and those with hepatic impairment).
#
# 6. Adverse Effects and Toxicity (“Cinchonism”)
# Common mild symptoms (cinchonism)
# • Tinnitus, hearing loss, headache, nausea, visual disturbances (blurred vision, difficulty focusing)
# • Sweating, dizziness, flushing
# Serious toxicities (high doses or prolonged use)
# • Cardiac: QT‐interval prolongation, arrhythmias (torsades de pointes)
# • Hematologic: Hemolysis in G6PD‐deficient individuals
# • Hypersensitivity: Rare anaphylaxis, dermatitis
# • Overdose: Convulsions, respiratory depression, ventricular tachycardia, coma
#
# 7. Drug Interactions and Precautions
# • May potentiate the effects of other QT‐prolonging drugs (e.g., macrolide antibiotics, certain antipsychotics).
# • Caution with CYP3A4 inhibitors/inducers (e.g., ketoconazole, rifampin)—they can alter quinine plasma levels.
# • Contraindicated in known hypersensitivity to quinine or related compounds; use in pregnancy only if clearly needed (risk of fetal toxicity).
#
# 8. Non‐medical Uses and Cultural Impact
# • Tonic water flavoring: In low concentrations (typically 83 mg quinine per liter in U.S. tonic water), appreciated for its bitterness in cocktails such as gin and tonic.
# • Research tool: Because of its action on cation channels, quinine has been used experimentally to study K+ and other ion channels in physiology.
#
# 9. Historical Significance
# • 19th-century “miracle drug” against malaria, saving countless lives in colonial and military campaigns.
# • Inspired synthetic antimalarials: Quinine’s success propelled the search for related compounds, leading to chloroquine, primaquine and eventually artemisinin‐based therapies.
# • Named elements: The unit “quinine sulfate” saw widespread distribution; its use figures in colonization history, tropical medicine and even the etymology of “tonic.”
#
# Summary
# Quinine remains an important antimalarial agent despite increased use of newer drugs. Its distinctive chemistry, historical role in combating malaria and characteristic side effects (cinchonism) make it a classic example of a plant-derived therapeutic that paved the way for modern pharmacology.
#
# 2.查询 What is an Indicator Displacement Assay? 的答案是：An Indicator Displacement Assay (IDA) is a supramolecular, mix-and-measure sensing method in which a colored or fluorescent “indicator” dye is initially bound to a host (receptor) molecule, and then displaced when a target analyte with higher affinity for the host is introduced. The displacement event produces a measurable optical change (colorimetric or fluorimetric), providing a convenient readout of analyte concentration or presence.
#
# Key elements
# 1. Host (Receptor)
#    • A synthetic or biological binding site (cavity, metal center, hydrogen-bonding array, etc.)
#    • Selective but reversible binding toward both indicator and analyte
#
# 2. Indicator (Reporter)
#    • A small molecule whose optical properties (absorption, emission) change upon binding to the host
#    • Moderate affinity: tight enough to form a stable host–indicator complex, weak enough to be displaced by the analyte
#
# 3. Analyte
#    • The species to be detected (ion, small molecule, biomolecule, etc.)
#    • Binds more strongly to the host than the indicator does
#
# Operational principle
# 1. Mix host + indicator → host–indicator complex; measure its baseline optical signal.
# 2. Add analyte → analyte competes for the host’s binding site.
# 3. Indicator is released into solution → its free optical spectrum differs markedly from the bound form.
# 4. Monitor change in absorbance or fluorescence; correlate intensity or wavelength shift to analyte concentration.
#
# Advantages
# • No need to covalently modify host or analyte.
# • Modular: host and indicator can be chosen or tuned independently.
# • Simple “mix-and-read” format; amenable to high-throughput screening.
# • Ratiometric measurements possible if bound and free indicators have distinct spectra.
#
# Typical applications and examples
# – Sugar sensing: Boronic-acid hosts bind a catechol dye; addition of glucose displaces the dye and restores its fluorescence.
# – Phosphate/pyrophosphate detection: Zn-dipicolylamine receptors displace alizarin red S or calcein, giving a color change.
# – Anion recognition: Urea- or guanidinium-based hosts paired with anthracene or Nile red indicators for carboxylates, sulfate, nitrate, etc.
# – Protein assays: A dye initially bound in a hydrophobic pocket is displaced when a target protein binds.
#
# Design considerations
# – Choose an indicator whose spectral change is large and specific upon displacement.
# – Optimize host–indicator and host–analyte affinities so that the assay window (concentration range) matches the intended detection limits.
# – Control pH, ionic strength and competing species to maintain selectivity.
#
# In summary, the indicator displacement assay is a powerful, general approach in supramolecular chemistry for detecting a wide range of analytes by exploiting competitive host–guest binding and a built-in optical reporter.
#
# 3.查询 What techniques are used to analyze Quinine? 的答案是：Analytical methods for quinine span classical wet-chemistry assays, separation-based techniques, spectroscopic methods and electrochemical approaches.  Below is a non-exhaustive survey of what you’ll find in the literature and pharmacopeias.
#
# 1. Wet-chemical/titrimetric methods
#   • Acid–base titration (USP potentiometric or manual)
#   • Coulometric titration (British Pharmacopoeia)
#
# 2. UV-visible spectrophotometry
#   • Direct assay in acidic medium (λmax ≈ 331 nm)
#   • Derivative spectrophotometry
#   • Kinetic methods (e.g. rate of complex formation with Fe(III) or Al(III))
#
# 3. Fluorescence spectroscopy
#   • Quinine sulfate is a classical fluorimetric standard (excitation ca. 350 nm, emission ca. 450 nm)
#   • Sensitive enough for trace analysis in beverages or biological fluids
#
# 4. Infrared (IR) spectroscopy
#   • FT-IR for identification of characteristic C=C, C–O and quinuclidine ring bands
#   • ATR-IR for quick solid or liquid samples
#
# 5. Mass spectrometry
#   • Electron impact (EI) MS (typically GC-MS after derivatization)
#   • Electrospray ionization (ESI) LC-MS (for pharmaceuticals or bioanalysis)
#   • Tandem MS/MS for trace quantitation
#
# 6. Nuclear magnetic resonance (NMR)
#   • 1H and 13C for unambiguous structural confirmation
#   • 2D techniques (COSY, HSQC, HMBC) if analogues or impurities must be characterized
#
# 7. Chromatographic methods
#   a) Thin-layer chromatography (TLC/HPTLC)
#     – Silica or reverse-phase plates, visualized with UV or dragendorff’s reagent
#   b) High-performance liquid chromatography (HPLC/UPLC)
#     – Stationary phase: C18 or phenyl
#     – Mobile phase: mixtures of water (often phosphate buffer pH 2–4) + acetonitrile or methanol
#     – UV detection at 330–350 nm (or diode-array)
#     – LC-MS or LC-MS/MS for increased selectivity and sensitivity
#   c) Gas chromatography (GC-MS)
#     – Requires derivatization (e.g. silylation) to volatilize quinine
#   d) Capillary electrophoresis (CE)
#     – Simple buffer systems (phosphate, pH 2.5–4.5), direct UV or LIF detection
#
# 8. Electrochemical techniques
#   • Polarography and differential pulse voltammetry on mercury or carbon electrodes
#   • Amperometry/voltammetry in flow cells or modified electrodes (e.g. carbon nanotube)
#   • Potentiometric sensors (ion-selective electrodes for quinine)
#
# 9. Other methods
#   • Raman spectroscopy and SERS for rapid, non-destructive ID
#   • X-ray crystallography (to establish solid‐state structure, not routine assay)
#
# Typical choice depends on matrix and required sensitivity. For routine QC of tablets or tonic waters, HPLC-UV or pharmacopeial titrimetry/spectrophotometry are most common. For trace‐level or biological samples, LC-MS/MS and fluorimetry often offer the needed detection limits.
#
# 4.查询 What are the components of an Indicator Displacement Assay? 的答案是：An Indicator‐Displacement Assay (IDA) is a supramolecular sensing format in which a spectroscopically active indicator (dye or fluorophore) is non‐covalently bound to a host (receptor), and the addition of an analyte displaces the indicator, producing a detectable optical signal change. The minimal “parts list” for an IDA consists of:
#
# 1. The Host (Receptor)
#    • A synthetic or biological receptor (metal complex, macrocycle, cavitand, polymer, etc.) that has appreciable affinity both for the indicator and, more strongly, for the target analyte.
#    • Often designed to exploit noncovalent interactions (hydrogen bonding, electrostatics, hydrophobic effects, metal–ligand coordination).
#
# 2. The Indicator
#    • A molecule (dye or fluorophore) whose optical properties change when it is bound to the host vs. when it is free in solution.
#    • Common examples: phenolphthalein, Alizarin Red S, Evans blue, dansylated amines, boronic‐acid‐sensitive dyes, etc.
#    • Binding to the host typically shifts its absorption or fluorescence spectrum (λmax, intensity, lifetime).
#
# 3. The Analyte (Competitor)
#    • The species to be detected (ion, small molecule, biomolecule) that has higher affinity for the host than the indicator does.
#    • Upon addition, the analyte displaces the indicator from the host•indicator complex.
#
# 4. The Signal (Readout)
#    • Spectroscopic measurement of the free vs. bound indicator (UV–Vis absorbance, fluorescence intensity or wavelength shift, sometimes circular dichroism or NMR).
#    • The magnitude of signal change is proportional (ideally) to analyte concentration.
#
# 5. The Medium and Conditions
#    • Solvent (aqueous buffer, organic solvent, or mixed) chosen to optimize host–indicator and host–analyte binding.
#    • pH, ionic strength, temperature—all tuned to favor selective displacement.
#
# 6. Calibration and Controls
#    • Baseline measurement of host•indicator complex without analyte.
#    • Titration of analyte to generate a calibration curve (signal vs. [analyte]).
#    • Controls for interference (other competing species, indicator self‐aggregation, photobleaching).
#
# In practice you mix the host and indicator to form the colored (or fluorescent) host•indicator adduct, record its spectrum, then add your sample (containing analyte). As the analyte binds the host, the indicator is released, and you monitor the ensuing spectral change to quantify the analyte.
#
# 5.查询 Are there electrochemical sensors using Indicator Displacement Assay (IDA) to detect Quinine? 的答案是：Almost all of the quinine-IDA sensors in the literature are optical (fluorescence or colorimetric) – I could not find a single paper that combines an Indicator-Displacement Assay for quinine with purely electrochemical read-out.  That said, the electrochemical-IDA format is by now a rather mature technique for small-molecule sensing and could be carried over to quinine with very little extra invention.
#
# Below is a brief overview:
#
# 1.  Electrochemical IDA in general
#     •  You take a macrocyclic or molecular-receptor (e.g. β-cyclodextrin, cucurbit[7]uril, p-sulfonatocalix[4]arene) and immobilize it on an electrode (GC, Au, graphene, etc.).
#     •  You “load” the receptor with a redox-active indicator (methylene blue, ferrocene carboxylate, toluidine blue, etc.) so that the indicator gives a well-defined voltammetric or impedimetric signal.
#     •  When you add your analyte (here, quinine), it binds more strongly to the host than the indicator does, drives displacement of the indicator into solution, and you observe a decrease (or in some formats an increase) of the buried indicator’s redox signal by DPV, CV or EIS.
#     •  This has been used repeatedly for dopamine, histamine, ephedrine, atropine, cocaine, amantadine, metal ions, etc., with LODs typically in the 10⁻⁹–10⁻⁶ M range.
#
# 2.  Why you won’t find a “quinine” paper
#     •  Quinine is most often quantified by HPLC-UV or by fluorescence-IDA, so nobody has yet published *just* the electrochemical version.
#     •  But there is nothing about quinine’s binding chemistry (it binds quite well to CB7, to carboxyl-calixarenes and to CD’s) that would prevent a textbook electrochemical IDA.
#
# 3.  How you would build one for quinine
#     A.  Choose your host.  CB7 is attractive (Kq~10⁶–10⁷ M⁻¹ for quinine), or β-CD/γ-CD if you want a SAM on gold via a thiol linkage.
#     B.  Immobilize it on a transducer (glassy carbon, gold, graphene oxide, screen-printed carbon).
#     C.  Preload with an easily resolved redox probe – e.g. methylene blue (MB) or a ferrocenecarboxylate.  Confirm a sharp MB or Fc wave by DPV/CV.
#     D.  Titrate in quinine: as soon as it displaces MB (or Fc), the surface-bound probe decreases and your current peak drops proportionally to [quinine].
#     E.  Calibrate and test in tonic-water or biological matrix.
#
# 4.  Expected performance
#     •  LODs in the few 10⁻⁸–10⁻⁶ M range (nano- to sub-micromolar), depending on which host/indicator couple you pick.
#     •  Good selectivity against structurally unrelated alkaloids if the host is chosen to favor quinine’s size/shape.
#
# In summary, there are *no published examples* to date of an electrochemical IDA sensor *specifically* for quinine, but the architecture has been used hundreds of times for other drugs and small molecules.  Simply pick a high-affinity host for quinine (cucurbituril, calixarene or cyclodextrin), immobilize it, load a redox indicator, and follow displacement by DPV or EIS.
#
# 6.查询 Which host molecules use host-guest recognition in electrochemical assays? 的答案是：Typical macrocyclic hosts exploited in electrochemical “host–guest” assays are cyclodextrins, cucurbit[n]urils, calixarenes, pillararenes and (to a lesser extent) crown‐ethers and resorcinarenes.  Below is a brief survey of each class and how it’s used in voltammetric or amperometric sensing.
#
# 1. Cyclodextrins (CDs)
#   • α-, β- and γ-CDs have a truncated‐cone, hydrophobic cavity (outer rims bearing –OH).
#   • Immobilized on Au or carbon electrodes via thiol (–SH), silane or polymer linkers.
#   • Guests: phenols (catechol, hydroquinone), neurotransmitters (dopamine), aromatic drugs.
#   • Sensing principle: inclusion alters the redox potential or peak current of the guest; can also preconcentrate analyte for enhanced sensitivity.
#
# 2. Cucurbit[n]urils (CB[n], n = 6–8)
#   • Rigid carbonyl-lined portals; exceptionally high binding (Ka up to 10^12 M–1 for cationic guests).
#   • Surface attachment via electrografted linkers or host–guest “sandwich” assemblies with mediators (e.g. viologens, methylene blue).
#   • Guests: viologen derivatives, protonated amines, dyes; often used for signal amplification via redox‐active reporter in the cavity.
#
# 3. Calixarenes (CX[n], n = 4–8)
#   • Bowl-shaped phenolic macrocycles; top rim can be functionalized (e.g. sulfonate, carboxylate, thiol) for electrode grafting.
#   • Hosts for metal ions (Pb2+, Cd2+), nitrophenols, aromatic amines.
#   • Electrochemical readout: complexation shifts metal‐ion reduction potentials or modulates electron transfer of organic guests.
#
# 4. Pillar[n]arenes (P[n], n = 5–10)
#   • Rigid, pillar-shaped cavities with tunable portal substituents (–OH, –OMe, –COOH, –SH).
#   • Immobilized on gold or carbon by thiol or diazonium coupling.
#   • Guests: aliphatic dications, anionic dyes, carboxylates; used in redox “on–off” sensors with integrated redox probes.
#
# 5. Crown-ethers and Resorcinarenes
#   • Crown ethers (e.g. 18-crown-6) for alkali/alkaline earth ions or quaternary ammoniums, often in potentiometric electrodes but occasionally in voltammetry when complexation alters redox shifts.
#   • Resorcinarene cavitands (deeper, bowl-shaped): less common but applied to aromatic hydrocarbons and small organic amines with electrochemical tagging.
#
# General sensing strategies:
# • Direct voltammetry: host binding shifts the guest’s oxidation/reduction potential or changes peak currents.
# • Mediator‐coupled assays: a redox‐active guest (or reporter) is captured in the cavity; its redox signal indicates analyte presence or displacement.
# • Competitive/displacement formats: non-electroactive analyte displaces a redox‐tagged guest, causing a measurable signal change.
#
# By choosing the appropriate macrocycle, electrode‐attachment chemistry and guest species, one can tailor an electrochemical assay for selectivity, sensitivity and even multi‐analyte detection via orthogonal host–guest pairs.
#
# 7.查询 How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine? 的答案是：In most of the recent reports on electrochemical quinine sensors built around an Indicator‐Displacement Assay (IDA), authors emphasize two key figures of merit for practical use:
#   1. storage (or operational) stability, and
#   2. run‐to‐run (or electrode‐to‐electrode) reproducibility.
#
# Below is a summary of what you typically see in the literature—and what you should expect if you fabricate the sensing platform under the same protocols.
#
# 1. Storage/Operational Stability
#    • Retention of Signal over Time
#      – Many groups report that, when stored dry at 4 °C in the dark, their IDA‐based quinine sensors retain 90–95 % of their initial voltammetric response after 7–14 days, and still 80–85 % after 30 days.
#      – If stored in buffer (pH 7.0), long‐term stability tends to be a little lower (around 75–80 % retention after 14 days) because of slow leaching of the indicator or gradual drift in the surface chemistry.
#
#    • Cycling Stability
#      – Under continuous cycling or repeated “add quinine → measure → strip → rinse” protocols, most sensors hold better than 90 % of their initial peak‐current response for at least 50–100 consecutive measurements.
#      – Beyond 100 cycles, one typically sees a gradual drop (5–10 %), which is attributed mainly to partial desorption of the indicator or minor fouling of the electrode surface.
#
# 2. Reproducibility
#    • Intra‐Day (Repeatability)
#      – When the same electrode is used repeatedly in a single day (five to ten replicate measurements of a single quinine concentration), relative standard deviations (RSDs) of 2–4 % are routinely reported.
#      – This means that if you measure, for example, 10 µM quinine five times in succession, the standard deviation of those five current readings divided by the mean current will typically lie below 4 %.
#
#    • Inter‐Electrode
#      – When different electrodes are prepared independently but under nominally identical conditions (same modifier solution, same deposition protocol, same indicator loading), the RSD of the peak current for a single quinine level is usually in the 3–6 % range.
#      – A small handful of very carefully optimized systems claim sub-3 % inter-electrode RSD, but 5 % is a more typical, readily achievable figure.
#
# 3. What Drives Instability and Variability?
#    • Indicator Leaching
#      – Because the assay relies on a reversible host–guest or host–indicator interaction, some gradual loss of the indicator from the surface is inevitable unless it is covalently tethered or trapped in a crosslinked network.
#    • Surface Fouling/Degradation
#      – Quinine and its oxidation products are somewhat adsorptive; repeated redox cycling can slowly clog or poison the electrode surface if no anti-fouling layer is present.
#    • Preparation Variations
#      – Drop‐casting volume, drying time, mixing order of host/indicator, and precise control of pH in the immobilization step all influence batch‐to‐batch reproducibility.
#
# 4. Tips for Maximizing Stability & Reproducibility
#    • Dry Storage at Low Temperature
#      – Keep sensors desiccated and at 4 °C when not in use.
#    • Use a Protective Overlayer
#      – A thin Nafion or polyurethane coating can help trap the indicator and block fouling agents without substantially slowing analyte access.
#    • Standardize the Immobilization Protocol
#      – Precisely control concentration, incubation times, and rinsing steps for every sensor batch.
#    • Regular Calibration
#      – If you need month-long deployment, include quick checks with a standard quinine solution every few days to correct for any drift.
#
# Bottom line: with a well-optimized IDA sensor you should be able to demonstrate
#   – ≥ 90 % signal retention over at least two weeks of dry storage,
#   – ≥ 85 % over one month,
#   – intra-day RSDs around 2–4 %, and
#   – inter-electrode RSDs of 3–6 %.
#
# Those numbers represent the current state of the art and are perfectly adequate for routine quinine sensing in food or pharmaceutical quality control.
#
# 8.查询 How is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine verified? 的答案是：The “proof” that your quinine sensor really works comes in three parts: 1) physicochemical characterization of the indicator‐displacement mechanism, 2) electrochemical read-out and calibration, and 3) real‐sample/ interference studies.  Here is a sketch of each step:
#
# 1. Verifying the IDA mechanism in solution
#    – UV–vis (or fluorescence) titrations of the free indicator (e.g. a metallocene or a redox dye) with your host (cucurbit[7]uril, cyclodextrin, etc.) show a clear spectral change (shift or intensity drop) as you add host.  From these data you extract the host⋅indicator binding constant, KHI.
#    – A second UV–vis (or fluorescence) titration of the preformed host⋅indicator complex with quinine shows the reverse change (indicator is ejected and its original spectrum restored).  From that you obtain the host⋅quinine constant, KHQ, and demonstrate that quinine outcompetes the indicator.
#
# 2. Electrochemical characterization and calibration
#    a) Electrode preparation:
#       • Modify your carbon (or gold) electrode with a self-assembled monolayer or polymer film containing the host⋅indicator complex.
#       • Verify surface modification by cyclic voltammetry (CV)—you should see the redox couple of the indicator on the bare electrode, then a suppressed signal once the host⋅indicator is grafted on.
#    b) Indicator‐displacement step:
#       • Add quinine to the cell.  As quinine binds the host, the indicator is released, diffuses to (or back to) the electrode surface, and you recover the redox signal of the free indicator.
#       • Monitor the change in peak current (by CV, differential pulse voltammetry or square‐wave voltammetry).
#    c) Calibration curve:
#       • Run a series of quinine standards (usually in pH 7.0–7.4 buffer), plot Δip (indicator peak current increase) vs [quinine].
#       • From the linear region extract sensitivity (slope), limit of detection (3σblank/slope) and limit of quantitation.
#    d) Reproducibility and stability:
#       • Repeat measurements (n ≥ 5) at a mid-range quinine concentration; report the relative standard deviation (typically < 5 %).
#       • Test signal retention over days or weeks of storage at 4 °C (typically you should see < 10 % drift over 1–2 weeks).
#
# 3. Selectivity, interference tests and real sample analysis
#    – Spike potential interferents (caffeine, theobromine, nicotine, etc.) at equal or higher concentrations; show minimal current change versus quinine.
#    – Analyze a real sample (e.g. tonic water or a pharmaceutical formulation) by standard addition or direct calibration.
#    – Cross-validate: run the same samples by HPLC-UV (or another established method) and show agreement within ± 5 %.
#    – Perform spike‐and‐recovery (add known amounts of quinine to the real sample) and report recoveries (ideally 95–105 %).
#
# When you have:
# • A well‐defined host⋅indicator binding in solution,
# • A reproducible, quinine-concentration‐dependent electrochemical signal,
# • Good selectivity and low drift, and
# • Agreement with an orthogonal (e.g. HPLC) assay on real samples
# —then you have “verified” your electrochemical IDA sensor for quinine.
#
# 9.查询 In the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine, how does Quinine displace Methylene Blue from beta-Cyclodextrin? 的答案是：Quinine never “breaks” a covalent bond in the β-cyclodextrin–methylene blue complex – it simply competes for the same hydrophobic cavity.  In practice what happens on the sensor surface is this:
#
#  1. You start with methylene blue (MB) threaded into the β-cyclodextrin (β-CD) cavities that have been immobilized on your electrode.  That inclusion complex gives you a certain baseline redox signal from MB.
#  2. Quinine is then added to the solution.  Quinine’s rigid quinoline‐quinuclidine framework and its amphiphilic character make it a better fit for the β-CD cavity than MB (stronger π–π and van der Waals contacts, favourable hydrogen bonding to the rim hydroxyls, plus the usual hydrophobic‐effect driving out high-energy water).
#  3. Because quinine binds more tightly (higher association constant) than MB, it displaces MB from the β-CD cavity.  Free MB diffuses away (or at least into a different environment), and its redox current at the electrode drops (or shifts), producing the analytical signal.
#
# In short, quinine “kicks out” methylene blue purely by competitive host–guest chemistry: quinine forms a more stable inclusion complex with β-cyclodextrin, so MB is expelled and the change in the MB electrochemical signal reports the quinine concentration.
#
# 10.查询 What does Graphene do in the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine? 的答案是：In that particular quinine sensor the graphene is not there as a “second” receptor for quinine but rather as a high-performance electrode modifier whose main jobs are:
#
# 1.   Boosting the electrochemical signal
#      – Graphene’s exceptionally high electrical conductivity and large, two-dimensional surface area speed up electron transfer between the redox indicator and the underlying electrode.  When the indicator is bound to the receptor on the graphene surface you get a strong, well‐defined faradaic (current) signal; when quinine displaces the indicator and it diffuses away, the signal drops off sharply.
#
# 2.   Providing a high-density scaffold for the indicator–receptor complex
#      – You can noncovalently adsorb or covalently attach the macrocyclic receptor (and its bound redox‐active indicator) onto graphene or graphene oxide.  Because graphene sheets are so large and defect-rich you end up with a very high surface loading of receptor/indicator assemblies, which directly translates into higher sensitivity and lower limits of detection.
#
# 3.   Stabilizing the recognition interface
#      – The sp2 carbon network of graphene interacts favorably (via π–π stacking, hydrogen bonding to oxide groups, etc.) with both the macrocycle and the redox indicator.  This keeps the sensor surface well‐organized and ensures reproducible binding/displacement cycles.
#
# In short, graphene in the quinine IDA sensor is the “electrochemical amplifier” and solid support.  Without it you’d have sluggish electron transfer, far fewer binding sites, and a much noisier, less sensitive assay.
#
# 11.查询 What is a cryptand? 的答案是：A cryptand is a type of synthetic, three-dimensional polycyclic ligand designed to “wrap around” and bind a guest ion—most often an alkali or alkaline-earth metal cation—inside its cage-like cavity. Cryptands are sometimes called three-dimensional analogues of crown ethers (which are planar or slightly puckered rings of donor atoms); by contrast, a cryptand’s bridges form a fully enclosed or nearly enclosed “crypt” (from Greek kryptos, “hidden”).
#
# 1. Structure
#  • Composed of two or more macrocyclic rings or “faces” interconnected by flexible or semi-rigid chains (bridges).
#  • Typical donor atoms are oxygen or nitrogen; a common example is the so-called [2.2.2]cryptand, which has three –(CH2–CH2–O)– linkers joining two nitrogen atoms at each end.
#  • The three bridges meet to form an approximately spherical cavity whose size, shape and donor-atom arrangement can be tuned by varying linker length or heteroatom type.
#
# 2. Binding properties
#  • Encapsulation: A cation sits inside the cavity and coordinates simultaneously to several donor atoms—often six or more—resulting in very high thermodynamic stability constants (far exceeding those of comparable crown ethers).
#  • Selectivity: By adjusting cavity size and donor arrangement, cryptands can be made highly selective for particular cation sizes (e.g. Na+, K+, Cs+, Ca2+).
#  • Solubility and phase transfer: Some cryptands impart lipophilicity to the encapsulated ion, enabling “phase-transfer” of otherwise water-soluble salts into organic solvents.
#
# 3. History and applications
#  • First reported in the 1960s by J.-M. Lehn and coworkers, cryptands helped establish the field of supramolecular chemistry and earned Lehn a share of the 1987 Nobel Prize in Chemistry.
#  • Applications include phase-transfer catalysis, stabilization of unusual anions (“naked” anions with cryptand-encapsulated countercations), molecular recognition studies, ion-selective electrodes, and the design of artificial ion channels.
#
# 4. Cryptates vs. Cryptands
#  • The free ligand is called a cryptand; the host–guest complex with a trapped ion is called a cryptate. For example, K+@[2.2.2]cryptand denotes the potassium cryptate.
#
# In summary, cryptands are tailor-made molecular cages whose strong and selective binding of metal ions has made them indispensable tools in supramolecular chemistry, ion-sensing, and phase-transfer processes.
#
# 12.查询 Is pyrrole considered an aromatic system? 的答案是：Yes. Pyrrole is a classic example of a 6π aromatic system.  In pyrrole:
#
#  • The ring is planar and fully conjugated (every atom has an unhybridized p orbital).
#  • There are two C=C double bonds contributing 4 π electrons.
#  • The nitrogen’s lone pair occupies its p orbital and contributes 2 more π electrons.
#
# That gives a total of 6 π electrons, satisfying Hückel’s 4n + 2 rule (with n = 1), so pyrrole is aromatic.  (The N–H bond ensures that the other nitrogen lone pair resides in an sp² orbital in the molecular plane and does not enter the π system.)
#
# 13.查询 What types of molecules typically act as guests for supramolecular hosts? 的答案是：In host–guest supramolecular chemistry the “guest” is almost always a small to medium-sized molecule or ion whose size, shape and functionality complement the host’s cavity or binding site.  Broadly speaking, guests fall into four main classes:
#
#  1. Metal cations
#     – Alkali and alkaline-earth ions (Na⁺, K⁺, Ca²⁺) in crown ethers and cryptands
#     – Transition-metal or lanthanide ions in tailored chelators or metal-organic cages
#
#  2. Organic cations/ammonium species
#     – Protonated amines and ammonium salts in cucurbiturils, pillar[n]arenes, calixarenes
#     – Quaternary phosphonium or sulfonium ions
#
#  3. Neutral organic molecules
#     – Hydrophobic hydrocarbons or aromatics (benzene, naphthalene, adamantane) in cyclodextrins or cyclophanes
#     – Dyes and fluorophores (pyrene, fluorescein derivatives)
#     – Small drugs, steroids, fatty acids or other natural products
#
#  4. Small polar or anionic species
#     – Carboxylates and sulfonates in positively charged hosts
#     – Anions (Cl⁻, NO₃⁻, H₂PO₄⁻) in metallacages or H-bonding macrocycles
#     – Small guests such as CO₂, N₂, H₂ in porous coordination polymers or metal-organic frameworks
#
# Key factors that make a molecule a good guest are:
#  • Size and shape match to the host cavity
#  • Favorable noncovalent interactions (hydrophobic effect, hydrogen bonds, π–π stacking, ion–dipole, electrostatics)
#  • Appropriate solubility (e.g. hydrophobic guests for water-soluble hosts like cyclodextrin)
#
# In practice, you will see everyday examples such as:
#  – 18-crown-6 binding K⁺
#  – β-cyclodextrin encapsulating an adamantane derivative or a drug molecule
#  – Cucurbit[7]uril binding methyl viologen or protonated ammonium salts
#  – Metal-organic cages sequestering small anions or neutral aromatics
#
# All of these share the same principle: complementarity of size/shape plus a web of weak, reversible interactions.
#
# 14.查询 What are some specific types of macrocycles? 的答案是：Macrocycles show up in many areas of chemistry—from host–guest receptors to drugs and materials.  Below is a non‐exhaustive list of well-known families and examples:
#
# 1. Crown Ethers and Related “Crowns”
#    • 12-crown-4, 15-crown-5, 18-crown-6
#    • Thia- and aza-crowns (e.g. 18-thia-6 or aza-15-crown-5)
#
# 2. Cryptands
#    • [2.2.1], [2.2.2] and larger bicyclic or tricyclic polyethers that encapsulate cations
#
# 3. Cyclodextrins
#    • α-(6 units), β-(7 units) and γ-(8 units) cyclodextrin (glucose rings)
#    • Used for solubilizing drugs, controlled release
#
# 4. Calixarenes, Resorcinarenes, Pillararenes
#    • Calix[n]arenes (n = 4, 6, 8) – phenolic macrocycles with tunable upper/lower rims
#    • Resorcin[n]arenes – similar, built from resorcinol units
#    • Pillar[n]arenes (n = 5, 6) – 1,4-disubstituted benzene “pillars”
#
# 5. Cucurbiturils (CB[n])
#    • CB6, CB7, CB8 – glycoluril-based, rigid barrels with high affinity for guests
#
# 6. Cyclophanes
#    • Paracyclophanes (e.g. [2.2]paracyclophane) – aromatic rings bridged by methylene chains
#
# 7. Porphyrins and Phthalocyanines
#    • Tetraphenylporphyrin, heme, chlorophyll (metal-binding macrocycles)
#    • Metal phthalocyanines (e.g. copper phthalocyanine dyes)
#
# 8. Macrocyclic Natural Products & Drugs
#    • Macrolide antibiotics: erythromycin, azithromycin, bafilomycin
#    • Cyclic peptides/depsipeptides: cyclosporin A, valinomycin, gramicidin S
#    • Cyclotides and other ribosomally synthesized cyclic peptides
#
# 9. Other Specialized Classes
#    • Cyclophosphazenes (P–N ring backbones)
#    • Crown thioethers, aza-ethers and mixed donor macrocycles for metal coordination
#    • Non-peptidic macrocycles in drug discovery (e.g. cyclic β-turn mimics)
#
# Each class can be further diversified by varying ring size, heteroatom content, substitution patterns and appended functional groups to tune binding, solubility, redox properties and biological activity.
#
# 15.查询 When a calixarene containing pyrrole groups binds an anion, what specific non-covalent interactions are typically involved? 的答案是：Anion binding by pyrrole‐decorated calixarenes is almost entirely driven by a network of directional H-bonds supplemented by complementary electrostatics and dispersive contacts.  In practice you almost always see:
#
#   1. Pyrrole N–H···X⁻ hydrogen bonds
#      – The inward‐pointing pyrrole NH groups act as classical H-bond donors to the anion.
#      – Typically 3–4 N–H···Cl⁻ or N–H···F⁻ contacts, with N–H···X angles close to 170°–180° and H···X distances in the 2.0–2.5 Å range.
#
#   2. Secondary C–H···X⁻ interactions
#      – The calixarene methylene and aromatic CHs often sit close to the bound anion, giving weaker but still useful C–H···X⁻ hydrogen bonds.
#
#   3. Anion–π (and π–π) interactions
#      – The electron‐deficient aryl rings of the calixarene can engage the anion face-on (anion–π), helping preorganize it in the cavity.
#      – If a second aromatic guest or co‐receptor is present, you can even get π–π stacking further stabilizing the overall complex.
#
#   4. Electrostatic (ion–dipole) and van der Waals contacts
#      – Long-range Coulombic attraction between the negative charge and polarized π clouds of the macrocycle
#      – Close‐fit shape complementarity gives additional dispersion stabilization
#
# In most crystal structures and solution studies of pyrrole-functionalized calixarenes, the dominant feature is the complementary array of N–H···X⁻ hydrogen bonds, with C–H donors, anion–π effects, electrostatics and packing forces all playing supporting roles.
#
# 16.查询 Are there known supramolecular hosts that are derivatives of calixarenes and also feature pyrrole functional groups? 的答案是：Yes – although most of the “classic” calixarenes (phenol‐based macrocycles) and the “classic” calix-pyrroles (pyrrole‐based macrocycles) have each been studied exhaustively in their own right, there are in fact a number of hybrid systems in which a calix[ n ]arene (usually n = 4) is functionalized with one or more pyrrolic units.  Many of these have been developed as anion receptors, taking advantage of the N–H hydrogen bonds of the pyrroles.  A few representative examples are:
#
# 1) Lower‐rim pyrrolyl–calix[4]arenes (tetra-pyrrolyl hosts)
#    • Synthesis by SNAr or alkylation of the four phenolic oxygens, e.g.
#      – 5,11,17,23-Tetrakis(pyrrol-2-ylmethyl)-25,26,27,28-tetrahydroxycalix[4]arene
#        (J. Org. Chem. 2005, 70, 2826–2834).
#    • These adopt a rigid cone conformation and bind halides, phosphates, etc., by four convergent pyrrole N–H hydrogen bonds.
#
# 2) Upper‐rim pyrrole substitution
#    • Mesityl‐ or tert-butyl‐calix[4]arenes derivatized at the para (upper) positions with pyrrolyl-aryl linkers, e.g.
#      – p-Ter t‐Butylcalix[4]arene tetra(4-pyrrolylphenyl) (Org. Lett. 2007, 9, 829–832).
#    • These have been shown to bind oxoanions (acetate, dihydrogen phosphate) selectively in solution.
#
# 3) Calix[4]arene–calix[4]pyrrole hybrids
#    • Sessler and co-workers have prepared “strap” or “pocket” systems in which a classic calix[4]arene is linked by short spacers to a calix[4]pyrrole unit.  The result is a deep, dual‐faced binding cleft for anions (Chem. Commun. 2008, 5117–5120).
#
# 4) Calix[6]arene with multiple pyrrole arms
#    • Li et al. reported a flexible calix[6]arene platform bearing six pyrrole pendants; this “pyrrole‐brush” host shows very high affinity for sulfate and phosphate (Chem. Commun. 2014, 50, 9488–9490).
#
# In each of these systems the phenolic calixarene scaffold provides shape-persistence and preorganization, while the appended pyrrole N–H units furnish strong, directional hydrogen bonds to anionic guests.  If you are looking for a starting point, the J. Org. Chem. 2005, 70, 2826 paper (tetrakis(pyrrol-2-ylmethyl)calix[4]arene) and the Org. Lett. 2007, 9, 829 example are among the simplest to adapt.
#
# 17.查询 What are common applications for cage molecules compared to macrocycles, and do they have any overlapping uses? 的答案是：Cage molecules and macrocycles are both classes of “host” structures in supramolecular chemistry, but they tend to find their sweet spots in rather different areas.  Below is a brief outline of their most common applications and where they overlap.
#
# 1. Macrocycles
#    • Ion binding and phase‐transfer catalysis
#      – Crown ethers for alkali and alkaline-earth cations
#      – Cryptands (2D analogs) for tighter cation complexation in water
#    • Molecular recognition/sensing
#      – Calixarenes, resorcinarenes, cucurbiturils as selective sensors (fluorescence, colorimetry) for ions, small organics, explosives
#    • Separation and purification
#      – Cyclodextrins for chiral separations (HPLC stationary phases), selective extraction of pollutants or metal ions
#    • Drug formulation and delivery
#      – β-Cyclodextrin and derivatives to solubilize hydrophobic drugs, control release profiles
#    • Catalysis and photocatalysis
#      – Porphyrins/ phthalocyanines in oxidation reactions, photodynamic therapy
#    • Materials and electronics
#      – Macrocyclic π-systems (e.g. phthalocyanine films) in organic semiconductors and light-harvesting
#
# 2. Cage Molecules
#    • Guest encapsulation and stabilization
#      – Carcerands to isolate reactive intermediates (radicals, carbocations) at low temperature
#      – Organic cages (e.g. imine-based polyhedra) to trap small dyes or gases
#    • Nanoreactors / biomimetic catalysis
#      – Metal–organic cages (MOCs) that bring substrates together in a confined space, accelerate multistep or tandem reactions, or invert reaction selectivity
#    • Gas storage and separation
#      – Porous organic cages (POCs) and discrete coordination cages for selective uptake of CO2, H2, CH4, or hydrocarbons
#    • Drug delivery and imaging
#      – Water-soluble cages as carriers for anticancer drugs or MRI contrast agents; triggered release through pH or light
#    • Supramolecular assembly and templating
#      – Cages as building blocks for higher-order frameworks (polymers, MOF-like networks)
#
# 3. Overlapping Uses
#    • Host–guest chemistry and sensing
#      – Both macrocycles and cages can bind small molecules or ions selectively, leading to sensors (fluorescent probes, color changes)
#    • Catalysis
#      – Crown ethers or cyclodextrins can mimic enzyme pockets; cages often do the same on a more three-dimensional scale
#    • Drug encapsulation/delivery
#      – Cyclodextrins and some small organic cages both solubilize and protect therapeutic agents, though cages can offer a fully enclosed environment and more tunable release triggers
#    • Separation technologies
#      – Macrocycles in chromatography/supports, cages in pressure-swing or membrane separation of gases
#
# In practice, the choice between macrocycle and cage often boils down to how “deep” or restrictive the cavity must be, whether one needs permanent porosity (as in gas sorption), and which binding kinetics or stimuli-responses are required.
#
# 18.查询 What types of supramolecular hosts are known to bind anions primarily through anion-π interactions? 的答案是：Anion–π binding is still a relatively young addition to the supramolecular toolkit, but over the last 10–15 years a number of quite different host architectures have been shown to bind halides, oxyanions or even oxoanions almost exclusively by placing them over the π‐faces of electron‐poor aromatics.  Below is a broad (and by no means exhaustive) survey of the main “families” of hosts that rely primarily on anion–π rather than H-bonds, electrostatics or metal coordination:
#
# 1. Fluorinated or cyano‐substituted cyclophanes and cyclophane‐like macrocycles
#    – All‐perfluorobenzene‐bridged cyclophanes (Schmidbaur, Flood, Nangia)
#    – Tetracyanobenzene or tetracyanoquinodimethane (TCNQ) cyclophanes
#    – “Box”‐type macrocycles in which two or more electron‐poor aryl faces define the binding cavity
#
# 2. π-Acidic cryptands, cryptophanes and “molecular clefts”
#    – Matile’s anion–π cryptands built around hexafluorobenzene or perfluoronaphthalene
#    – Cryptophane capsules whose portals are capped by electron‐poor arenes
#    – Tweezer‐type hosts with two facing perfluoroaromatic panels
#
# 3. Calix- and resorcinarene derivatives bearing π-acidic sidewalls or straps
#    – Calix[4]pyrroles or calix[4]arenes “strapped” with pentafluorophenyl or tetrafluorothiophene units
#    – Resorcinarene bowls with pentacyanophenyl walls
#
# 4. Naphthalene diimide (NDI) and perylene diimide (PDI)–based receptors
#    – Bis-NDI clips or macrocycles that stack to form a π-acidic pocket
#    – Rotaxanes or catenanes whose “stations” are NDI/PDI units and which selectively complex halides
#
# 5. Foldamers incorporating electron‐poor aromatic repeat units
#    – Oligo(arylene ethynylene)s or oligoureas containing perfluoroaryl segments
#    – Helical foldamers whose inner ridge presents a concave π‐acidic surface
#
# 6. Porous organic cages and metal–organic cages (MOCs) with π-acidic walls
#    – Discrete organic cages (e.g. from Mastalerz, Cooper) whose windows are defined by perfluoroaryl linkers
#    – Coordination capsules assembled from 4,4′-bipyridine or tripyridyl ligands bearing cyano or perfluoroaryl substituents
#
# 7. Catenanes, rotaxanes and mechanically interlocked architectures
#    – [2]Catenanes in which both rings are electron‐poor wherever they cross an anion
#    – Rotaxanes whose axle-stations are tetracyanobenzene or perfluorophenylene units
#
# In each of these systems the common theme is that an anion “sits” over an aromatic face that has been made strongly electron‐deficient (by –F, –CN, imide or quinone C═O substitution), so that the quadrupole moment of the ring becomes attractive rather than repulsive to the guest.  Many of the above scaffolds will, of course, feature additional secondary interactions (C–H···X⁻ hydrogen bonds, co-ordination to H-bonds donors or to appended metal sites), but directional anion–π attraction is typically what controls selectivity for halides versus oxoanions or for small versus large anions.
#
# 19.查询 Why are supramolecular hosts containing pyrrole units generally effective at binding anions? 的答案是：Supramolecular receptors built around pyrrole rings (for example calix[4]pyrroles, porphyrins, dipyrrin‐based cages, etc.) are among the most successful anion hosts largely for the following reasons:
#
# 1) Strong, directional N–H⋯anion hydrogen bonds
#    – In pyrrole the nitrogen lone pair is tied up in the aromatic sextet, so the N–H bond is relatively polarized (i.e. “acidic”) and makes a very good H-bond donor.
#    – Typical pyrrole N–H pKa’s (in aprotic solvents) are in the mid‐teens, comparable to ureas and amides, so they form strong H-bonds with halides, oxoanions and carboxylates.
#
# 2) Multivalency and preorganization
#    – By linking four (or more) pyrrole units into a macrocycle or cage you bring multiple N–H donors into a well‐defined pocket.
#    – Preorganization means the receptor only pays a small entropic penalty on binding—each additional H-bond reinforces the complex cooperatively.
#
# 3) Shape and size complementarity
#    – Many pyrrole‐based hosts fold into a cup or bowl shape that matches the size and geometry of common anions (e.g. Cl–, Br–, NO3–, H2PO4–), further strengthening binding.
#
# 4) Secondary interactions
# ...
#
# 5. Molecularly imprinted polymers (MIPs)
#    • A synthetic polymer is cast in the presence of the target, then the guest is removed, leaving complementary cavities.
#    • MIP films coated on the IDA selectively rebind the analyte; rebinding hinders electron transfer or changes capacitance.
#
# 6. Biorecognition elements (aptamers, antibodies, enzymes)
#    • DNA/RNA aptamers fold upon target binding; the conformational change can gate redox‐mediator access or move a redox tag closer/further from the electrode.
#    • Antibodies (or fragments) capture antigens; the formation of the immunocomplex increases steric hindrance and impedance.
#    • Enzymes convert substrate to an electroactive product; the local concentration of the product between fingers is directly sensed by redox cycling.
#
# 7. Metal–ligand coordination (porphyrins, terpyridines, MOFs)
#    • Surface-anchored porphyrins or terpyridine complexes selectively bind small molecules (O₂, CO, NO, small organics) via coordination.
#    • Metal–organic frameworks (MOFs) grown on IDAs can trap gases or organics in their pores; analyte uptake alters the electron‐transfer kinetics.
#
# Design considerations for an IDA sensor:
# – Gap size (1–10 μm) must match the size of host/guest plus any blocking layer.
# – Host density and orientation on the fingers control the magnitude of the signal change.
# – Choice of redox mediator (diffusional vs. surface‐confined) determines whether you monitor redox cycling current, impedance or capacitance.
# – Regeneration (guest removal) may require pH or competitive‐binding swings.
#
# By choosing your host–guest pair (e.g. β-CD/ferrocene, CB[7]/viologen, crown ether/K⁺, MIP/glucose, aptamer/thrombin, antibody/PSA), you can tailor the selectivity of an IDA sensor to virtually any small molecule, ion or biomarker.
#
# 23.查询 What types of host-guest interaction can be used to design IDA using optical detection? 的答案是：Indicator Displacement Assays (IDAs) rely on two complementary equilibria—the host·indicator complex and the host·analyte complex—and monitor the optical change (colour or fluorescence) when the analyte displaces the indicator.  In principle any reversible host–guest interaction that is strong enough to give a well-defined host·indicator complex, yet labile enough to be displaced by the target, can be employed.  The most commonly exploited binding modes and their representative host families are:
#
# 1.  Hydrophobic (inclusion) interactions
#    •  Cyclodextrins (α, β, γ-CD) with aromatic or aliphatic dyes
#    •  Cucurbit[n]urils (especially CB7, CB8) binding cationic or neutral aromatics
#    •  Pillar[n]arenes in aqueous or organic media
#    •  Calixarenes (especially water-soluble sulfonato-calix[4]arenes)
#
# 2.  Electrostatic (ion-pairing) and Coulombic interactions
#    •  Crown ethers and cryptands binding ammonium or metal cations (e.g. dibenzo-18-crown-6)
#    •  Anion receptors (ureas, thioureas, guanidiniums) binding carboxylates, phosphates, sulfates
#
# 3.  Hydrogen‐bonding networks
#    •  Urea/thiourea or squaramide hosts for oxyanions
#    •  Diol/boronic acid hosts for cis-diols (dynamic covalent boronate esters serve as “reversible” bonds)
#
# 4.  π–π stacking and charge‐transfer complexes
#    •  Electron-rich hosts (e.g. porphyrins, perylene diimides) interacting with electron-poor dyes or analytes
#    •  Aromatic calixarenes or actinometric hosts in organic solvents
#
# 5.  Metal–ligand (coordination) bonds
#    •  Metal complexes (Zn²⁺, Cu²⁺, lanthanides) that serve both as the optical reporter and as a binding site for the analyte
#    •  Metalloporphyrins or salens that bind anions or neutral Lewis bases
#
# 6.  Halogen‐bonding and anion-π interactions
#    •  Perfluorinated iodotriazoles or bromotriazoles that form strong, directional halogen bonds to halides or oxyanions
#    •  Electron-deficient aromatic rings that bind anions above the π-face
#
# 7.  C–H–π and van der Waals contacts
#    •  Substitution-patterned resorcinarene or cavitand hosts that match the shape and C–H patterns of small hydrocarbons or pharmaceuticals
#
# In practice one chooses a host–indicator pair whose optical signal (absorption, emission or FRET) changes markedly upon displacement by the analyte. By selecting the appropriate primary interaction (hydrophobic, electrostatic, hydrogen bonding, coordination, etc.) one can tune the assay for different classes of targets (cations, anions, neutral organics, biomolecules) and for different read-out modes (colorimetric, fluorimetric or ratiometric FRET).
#
# 24.查询 What types of host-guest interaction can induce changes in optical signals? 的答案是：Host–guest complexation can perturb virtually every aspect of a guest’s photophysics—its absorption spectrum, fluorescence intensity, emission wavelength, lifetime and even chirality—simply by changing the local environment, enforcing a new geometry or providing a new electronic partner.  In practice the most commonly invoked interactions and signal‐transduction mechanisms are:
#
# 1. Noncovalent binding modes
#    • Hydrogen bonding
#    • Electrostatic/ion–dipole and ion–ion interactions
#    • Hydrophobic/solvophobic effects
#    • π–π‐stacking (face‐to‐face or edge‐to‐face aromatic interactions)
#    • Cation–π and anion–π interactions
#    • Halogen bonding
#    • Van der Waals forces
#    • Metal‐coordination to donor sites on organic hosts or to macrocyclic ligands
#
# 2. Photophysical/photoelectronic response mechanisms
#    a) Photoinduced electron transfer (PET)
#      – A donor (host or guest) and an acceptor form on binding, turning fluorescence “off” (quenching) or “on” (inhibited quenching).
#    b) Intramolecular charge‐transfer (ICT)/solvatochromism
#      – The host cavity’s changed polarity shifts absorption and emission maxima.
#    c) Charge‐transfer (CT) complex formation
#      – New broad CT bands appear in the visible and often give rise to new (sometimes red‐shifted) emission.
#    d) Förster resonance energy transfer (FRET)
#      – A fluorophore in the host can act as donor or acceptor to a bound guest, changing emission intensities and lifetimes.
#    e) Excimer/exciplex formation
#      – Close stacking inside a host can produce excimer/exciplex fluorescence at longer wavelengths.
#    f) Aggregation‐induced emission (AIE/AIEE)
#      – Binding can rigidify or aggregate guest chromophores, blocking non‐radiative decay and “turning on” emission.
#    g) Twisted intramolecular charge transfer (TICT) and restricted intramolecular rotation (RIR)
#      – Conformational locking by the host alters non‐radiative decay pathways, shifting both intensity and wavelength.
#    h) Metal‐sensitized luminescence (MLCT/LMCT)
#      – Hosts containing transition‐metal or lanthanide centers can be sensitized by guest binding, giving phosphorescence or narrow-line lanthanide emission.
#    i) Chiroptical effects (induced CD/CPL)
#      – A chiral host can impose its handedness on an achiral fluorophore, producing induced circular dichroism or circularly polarized luminescence.
#
# By choosing the right host architecture (e.g. cyclodextrin, calixarene, cucurbituril, MOF, MIP, metal–organic cage, etc.) and a guest with the desired redox, electronic or structural characteristics, one can exploit any of the above noncovalent binding modes together with one or more of these photophysical mechanisms to engineer turn‐on/turn‐off, ratiometric, wavelength‐shifted or chiroptical sensors.
#
# 25.查询 What types of host-guest interaction can induce changes in electrochemical signals? 的答案是：Host–guest complexation at an electrode interface can perturb mass transport, interfacial charge density and/or electron‐transfer kinetics, and thereby show up as changes in peak currents, peak potentials, impedance or capacitance.  In practice the most common supramolecular interaction modes are:
#
# 1. Inclusion (hydrophobic) complexation
#    • hosts: cyclodextrins, calixarenes, pillararenes, cucurbiturils
#    • guest effect: partial or full blockage of the diffusion pathway, local concentration changes, altered dielectric environment
#    • electrochemical signatures: decreased or enhanced faradaic currents; shifts in redox peak potentials; increased interfacial capacitance or charge‐transfer resistance (Rct)
#
# 2. Electrostatic (ion-pair) interactions
#    • hosts: charged crown ethers, cryptands, sulfonated calixarenes, cucurbiturils
#    • guest effect: preconcentration of cationic or anionic species at the electrode; screening of surface charge
#    • electrochemical signatures: changes in voltammetric peak currents; altered double-layer capacitance; shifts in half-wave potentials
#
# 3. Hydrogen-bonding
#    • hosts: urea/thiourea‐derivatized calixarenes, squaraines, boronic acids, triazoles, peptide‐based macrocycles
#    • guest effect: modulation of binding strength in response to pH or competing solvents; can induce conformational change of the host layer
#    • electrochemical signatures: potentiometric shifts; modulated electron‐transfer kinetics; distinct impedance spectra
#
# 4. π–π stacking and charge-transfer complexes
#    • hosts: graphene or carbon‐nanotube platforms, porphyrins, phthalocyanines
#    • guest effect: aromatic guests intercalate or stack, altering the local density of states and electron‐transfer pathways
#    • electrochemical signatures: potential shifts of redox couples; changes in heterogeneous electron‐transfer rate constants; altered capacitive currents
#
# 5. Metal-coordination (chelation)
#    • hosts: metalloporphyrins, crown ether–metal complexes, cryptands with bound transition metals
#    • guest effect: specific coordination of small molecules or ions (NO, CO₂, heavy metals), often coupled to a redox reaction at the metal center
#    • electrochemical signatures: appearance/disappearance of metal‐center redox waves; shifts in metal-ion redox potentials; changes in catalytic current
#
# 6. Conformational (induced-fit) binding
#    • hosts: redox‐tagged oligonucleotide aptamers, peptide receptors, molecularly imprinted polymers (MIPs)
#    • guest effect: target binding triggers folding/unfolding or swelling/shrinking of the receptor layer, modulating access of redox probes or electron‐transfer mediators
#    • electrochemical signatures: “signal‐on” or “signal-off” behavior in square‐wave or differential pulse voltammetry; large Rct changes in EIS
#
# 7. Van der Waals and dipole interactions
#    • hosts: self-assembled monolayers (SAMs) with tailored terminal groups, dendrimers
#    • guest effect: weak, nonspecific adsorption can still alter the interfacial dielectric and thus double-layer capacitance or small faradaic currents
#    • electrochemical signatures: subtle baseline shifts in cyclic voltammetry; slight changes in capacitive currents
#
# By choosing the right host scaffold and electrochemical readout (e.g. cyclic voltammetry, differential‐pulse voltammetry, electrochemical impedance spectroscopy, capacitance measurements), one can exploit any of these interaction modes to sense, characterize or control guest molecules at electrodes.
#
# 26.查询 What types of supramolecular hosts are known to bind to their guests primarily through cation-π interactions? 的答案是：Many of the most successful “synthetic cavitands” and macrocycles that recognize cationic guests do so largely by cradling them against π‐rich surfaces.  In rough order of historical development, the major families are
#
# 1. Cyclophanes (aromatic “tubes” or “boxes”)
#    – e.g. cyclobis(paraquat–p-phenylene) (“blue box”) and related paraquat hosts
#    – molecular tweezers/clefts built from two facing naphthalene or pyrene walls (Klärner’s tweezers, Diederich’s clefts, etc.)
#
# 2. Calixarenes and resorcinarenes
#    – especially the “upper‐rim” phenolic calix[4]arenes and p-sulfonatocalixarenes binding quaternary ammonium ions by cation-π
#    – cavitands derived from resorcinarene bowls
#
# 3. Pillar[n]arenes
#    – pillar[5]- and pillar[6]-arene cavities are lined with electron‐rich hydroquinone units that bind alkylammoniums primarily via cation-π
#
# 4. Cyclotriveratrylenes (CTV) and related benzene‐trimers
#    – shallow bowls whose π-rich interior binds small ammoniums
#
# 5. Aromatic crown ethers and “benzocrowns”
#    – e.g. dibenzo-18-crown-6 and larger “aromatic‐flanked” crown ethers that use π-faces to boost cation affinity
#
# 6. Porphyrins and phthalocyanines
#    – flat π‐systems that bind alkali and ammonium cations above or below the macrocycle plane
#
# 7. Cucurbit[n]urils (CB[n])
#    – although carbonyl portals contribute strong ion–dipole interactions, the hydrophobic, π-rich interior makes a major cation-π contribution to binding many ammonium guests
#
# 8. Metal–organic cages and capsules with aromatic walls
#    – M4L6 or M2L4 assemblies (Rebek capsules, Fujita cages, etc.) whose inward-directed aromatics stabilize encapsulated cations by cation-π
#
# In all of these cases the defining feature is an electron-rich π‐surface lining a preorganized cavity.  A cation (alkali metal, ammonium, pyridinium, etc.) sits in close contact with six to eight aromatic rings and picks up a very large fraction of its binding energy from cation-π rather than from simple electrostatics or hydrogen‐bonding.
#
# 27.查询 What are the main factors controlling host-guest interaction? 的答案是：The strength and selectivity of a host–guest complex in supramolecular chemistry are governed by a combination of structural, electronic, thermodynamic and environmental factors.  Broadly speaking, you can group them as follows:
#
# 1. Geometric (Size/Shape) Complementarity
#    • Cavity size vs. guest dimensions (“lock-and-key”)
#    • Shape complementarity (cylindrical, spherical, bowl-shaped, etc.)
#    • Degree of preorganization (rigid hosts lose less entropy on binding)
#
# 2. Non-covalent Interactions
#    • Hydrogen bonds (directional, moderate strength)
#    • Electrostatic (ion-dipole, ion–ion) interactions
#    • Van der Waals (dispersion) contacts—key in close‐fit systems
#    • π–π stacking, C–H···π interactions (especially with aromatics)
#    • Metal coordination bonds (in metallosupramolecular hosts)
#    • Hydrophobic effect (in water): release of ordered water molecules upon binding
#
# 3. Thermodynamics (ΔG = ΔH – TΔS)
#    • Enthalpic terms (ΔH): number and strength of individual non-covalent contacts; desolvation of charged or polar groups
#    • Entropic terms (ΔS):
#      – Release of solvent molecules (positive ΔS in water)
#      – Loss of host/guest conformational freedom (negative ΔS)
#      – Release of counter-ions in ionic systems (positive ΔS)
#
# 4. Solvent and Medium Effects
#    • Solvent polarity and its ability to solvate host and guest
#    • Competition of solvent with host–guest hydrogen bonds or ionic interactions
#    • Ionic strength and pH (protonation states of host/guest)
#
# 5. Host and Guest Flexibility
#    • More flexible hosts/guests adapt but pay an entropic penalty
#    • Rigid, preorganized scaffolds often bind more strongly but can be less adaptable
#
# 6. External Conditions
#    • Temperature (shifts ΔH vs. TΔS balance)
#    • Pressure (can favor inclusion of larger guests)
#    • Concentration (mass‐action effects)
#
# 7. Kinetics vs. Thermodynamics
#    • Association/dissociation rates (controlled by energy barriers, diffusion, and “gates” in the host)
#    • Kinetic traps (metastable complexes) vs. thermodynamic products
#
# 8. Secondary and Cooperative Effects
#    • Allosteric or cooperative binding in multi‐site hosts
#    • Templating effects during host synthesis or assembly
#
# In practice, designing a high-affinity, selective host involves optimizing the sum of these contributions—maximizing favorable enthalpic contacts and solvent release, minimizing conformational penalties, and tuning host rigidity and functionality for the target guest.

# %%
# 获取环境变量中的BEARER_TOKEN
import os
import json
bearer_token = os.environ.get("BEARER_TOKEN", "")
print(f"--- 读取到的令牌是: '{bearer_token}' ---") 
import requests
import json

url = 'https://chat.intern-ai.org.cn/api/v1/chat/completions'
url_health = 'https://chat.intern-ai.org.cn/health'
url_model = 'https://chat.intern-ai.org.cn/api/v1/models'

auth = "Bearer eyJ0eXBlIjoiSldUIiwiYWxnIjoiSFM1MTIifQ..B69K4tY900t5Yt7ZV0rgLOX4T36S0IQxDxDxPrQQEA56XFgCUyWsa6O3H6GOMVJhIwiIH2lNdrwXIQfhlnzU3w"

headers = {
    "Authorization": auth
}
data = {
    "model": "internvl2_5_chemvlm20250306",  
    "messages": [{
        "role": "user",
        "content": "Hello!"
    }],
    "n": 1,
    "temperature": 0,
}
res = requests.get(url_model, headers)
available_models = res.json()
print("可用模型列表:")
print(json.dumps(available_models, indent=2, ensure_ascii=False))
# Out:
# --- 读取到的令牌是: 'eyJ0eXBlIjoiSldUIiwiYWxnIjoiSFM1MTIifQ..B69K4tY900t5Yt7ZV0rgLOX4T36S0IQxDxDxPrQQEA56XFgCUyWsa6O3H6GOMVJhIwiIH2lNdrwXIQfhlnzU3w' ---
# 可用模型列表:
# {
#   "code": -10002,
#   "msg": "参数错误",
#   "data": {}
# }

# %%
res = requests.post(url, headers=headers, data=json.dumps(data))
print(res.status_code)
print(res.json())
print(res.json()["choices"][0]['message']["content"])

# %%
# 将结果保存为JSON文件
with open("intern_responses.json", "w", encoding="utf-8") as f:
    json.dump(intern_results, f, ensure_ascii=False, indent=4)

# %% [markdown]
# **Note on Streaming with QueryManager:**
#
# The standard `QueryManager.submit_query()` returns a `Future` that resolves to the *final* state of the LangGraph execution. It doesn't inherently provide access to the intermediate states generated by each node.
#
# To observe the step-by-step execution and intermediate state changes, you would typically need to interact directly with the LangGraph instance using its `stream()` method, as demonstrated in Part 2 below. Modifying the `QueryManager` to expose this stream would require significant changes to its asynchronous task handling and result reporting.

# %% [markdown]
# ## Part 2: Direct Execution via Graph Stream

# %%
if not llm:
    print("Skipping Direct Graph Stream test due to LLM initialization failure.")
else:
    print("\n--- Starting Direct Graph Stream Test ---")

    # 1. Create graph instance
    print("Creating graph instance...")
    graph = create_query_graph()
    print("Graph instance created.")

    # 2. Manually create initial state dictionary
    print("Creating initial state...")
    # Use the same query as Part 1 for comparison
    # query_text_stream = "What proteins does DrugA bind to?"

    for query_text_stream in [queries[4]]:

        try:
            # Ensure we get a list of strings
            available_classes_stream = sorted([cls.name for cls in test_onto.classes() if isinstance(cls, ThingClass)])
            available_data_props_stream = sorted([dp.name for dp in test_onto.data_properties() if isinstance(dp, DataPropertyClass)])
            available_object_props_stream = sorted([op.name for op in test_onto.object_properties() if isinstance(op, ObjectPropertyClass)])
        except Exception as e:
            print(f"Error getting class names: {e}")
            available_classes_stream = []

        initial_state = {
            "query": query_text_stream,
            "source_ontology": test_ontology_settings, # Pass the actual ontology object
            "available_classes": available_classes_stream,
            "available_data_properties": available_data_props_stream,
            "available_object_properties": available_object_props_stream,
            "query_type": "information_retrieval",
            "query_strategy": None,
            "originating_team": "test_notebook_stream",
            "originating_stage": "manual_stream_test",
            "query_results": {},
            "normalized_query": None,
            "execution_plan": None,
            "validation_report": None,
            "sparql_query": None,
            "status": "initialized",
            "stage": "initialized",
            "previous_stage": None,
            "error": None,
            "messages": [] # LangGraph expects messages field
        }
        print("Initial state prepared.")
        # print(json.dumps(initial_state, indent=2, default=str)) # Optionally print initial state (ontology won't serialize well)

        # 3. Execute and iterate stream
        print("\n--- Streaming Graph Execution --- ")
        try:
            stream_counter = 0
            # Use stream method to get intermediate steps
            for chunk in graph.stream(initial_state, config={"recursion_limit": 50}):
                stream_counter += 1
                print(f"\n--- Chunk {stream_counter} --- ")
                # Chunks are dictionaries where keys are node names that just ran
                # and values are the outputs (state updates) returned by that node
                # Use default=str to handle potential non-serializable objects in the state
                print(json.dumps(chunk, indent=2, default=str))
                print("-" * 30)
            print("\n--- Graph Stream Finished --- ")
        except Exception as e:
            print(f"\nError during graph stream: {e}")
            import traceback
            traceback.print_exc() # Print full traceback for stream errors
        
        print(f"query:{query_text_stream} has been finished.")

    print("--- Direct Graph Stream Test Finished ---")
# Out:
# --- Starting Direct Graph Stream Test ---
# Creating graph instance...
# Graph instance created.
# Creating initial state...
# Initial state prepared.
#
# --- Streaming Graph Execution ---
# Retry count: 1
#
# --- Chunk 1 ---
# {
#   "normalize": {
#     "normalized_query": "intent='find information' relevant_entities=['electrochemical_sensor', 'indicator_displacement_assay(IDA)', 'quinine'] relevant_properties=[] filters=None query_type_suggestion='fact-finding'",
#     "status": "parsing_complete",
#     "stage": "normalized",
#     "previous_stage": "initialized",
#     "retry_count": 1,
#     "messages": [
#       "content='Query normalized: Are there electrochemical sensors using Indicator Displacement Assay (IDA) to detect Quinine?' additional_kwargs={} response_metadata={} id='767013f5-1244-430d-82ad-d8c7b8f57278'"
#     ]
#   }
# }
# ------------------------------
# Retry count: 1
#
# --- Chunk 2 ---
# {
#   "strategy": {
#     "query_strategy": "tool_sequence",
#     "status": "strategy_determined",
#     "stage": "strategy",
#     "previous_stage": "normalized",
#     "messages": [
#       "content='Query strategy determined: tool_sequence' additional_kwargs={} response_metadata={} id='c09b083e-189e-403c-b162-3296938e3e36'"
#     ]
#   }
# }
# ------------------------------
# http://www.test.org/chem_ontologies/meta/
# http://www.test.org/chem_ontologies/classes/
# http://www.test.org/chem_ontologies/object_properties/
# http://www.test.org/chem_ontologies/data_properties/
# Retry count: 1
#
# --- Chunk 3 ---
# {
#   "execute": {
#     "query_results": {
#       "results": [
#         {
#           "tool": "get_class_info",
#           "params": {
#             "class_names": [
#               "electrochemical_sensor",
#               "indicator_displacement_assay(IDA)",
#               "quinine"
#             ]
#           },
#           "result": {
#             "electrochemical_sensor": {
#               "name": "electrochemical_sensor",
#               "information": [
#                 "Electrochemical sensors belong to the established methods of nucleotide detection.",
#                 "Nanocomposite based electrochemical sensor properties of polyaniline decorated with silver nanoparticles were utilized for the determination of 5-FU.",
#                 "An electrochemical sensor employing host-guest interactions of Q(8) was applied to the determination of tryptophan in real samples."
#               ]
#             },
#             "indicator_displacement_assay(IDA)": {
#               "name": "indicator_displacement_assay(IDA)",
#               "information": [
#                 "Through IDA coupled with differential sensing, we achieved the ultrasensitive and specific detection of LPA.",
#                 "Indicator displacement assay (IDA) is a method used for ultrasensitive fluorescence detection of LPA in aqueous media."
#               ]
#             },
#             "quinine": {
#               "name": "quinine",
#               "information": []
#             }
#           }
#         }
#       ]
#     },
#     "execution_plan": "steps=[ToolCallStep(tool='get_class_info', params={'class_names': ['electrochemical_sensor', 'indicator_displacement_assay(IDA)', 'quinine']})]",
#     "status": "executed",
#     "stage": "executed",
#     "previous_stage": "strategy",
#     "messages": [
#       "content='Tool-based query executed.' additional_kwargs={} response_metadata={} id='818284c9-275a-4936-b0c8-563612d6cbe2'"
#     ]
#   }
# }
# ------------------------------
# {
#   "results": [
#     {
#       "tool": "get_class_info",
#       "params": {
#         "class_names": [
#           "electrochemical_sensor",
#           "indicator_displacement_assay(IDA)",
#           "quinine"
#         ]
#       },
#       "result": {
#         "electrochemical_sensor": {
#           "name": "electrochemical_sensor",
#           "information": [
#             "Electrochemical sensors belong to the established methods of nucleotide detection.",
#             "Nanocomposite based electrochemical sensor properties of polyaniline decorated with silver nanoparticles were utilized for the determination of 5-FU.",
#             "An electrochemical sensor employing host-guest interactions of Q(8) was applied to the determination of tryptophan in real samples."
#           ]
#         },
#         "indicator_displacement_assay(IDA)": {
#           "name": "indicator_displacement_assay(IDA)",
#           "information": [
#             "Through IDA coupled with differential sensing, we achieved the ultrasensitive and specific detection of LPA.",
#             "Indicator displacement assay (IDA) is a method used for ultrasensitive fluorescence detection of LPA in aqueous media."
#           ]
#         },
#         "quinine": {
#           "name": "quinine",
#           "information": []
#         }
#       }
#     }
#   ]
# }
# Retry count: 1
# In retry logic, Retry count: 1
#
# --- Chunk 4 ---
# {
#   "validate": {
#     "validation_report": "valid=False details=[DimensionReport(dimension='completeness', score=2, valid=False, message=\"The results provide general information about 'electrochemical_sensor' and 'indicator_displacement_assay(IDA)', but do not address the specific query regarding the use of IDA-based electrochemical sensors for detecting quinine. No information is provided about quinine in this context, and there is no linkage between the three entities as required by the query intent.\"), DimensionReport(dimension='consistency', score=4, valid=True, message='The information presented is internally consistent and correctly attributed to the respective entities. There are no contradictions or mismatches in the data.'), DimensionReport(dimension='accuracy', score=3, valid=False, message='While the information about electrochemical sensors and IDA is accurate in a general sense, it does not accurately answer the specific question about quinine detection using IDA-based electrochemical sensors. The absence of relevant data for quinine reduces the accuracy with respect to the query intent.')] message='The query results are incomplete and do not accurately address the specific question about the use of Indicator Displacement Assay (IDA) in electrochemical sensors for detecting quinine. The results lack any information linking all three entities, especially regarding quinine detection.' improvement_suggestions=['Expand the query or data retrieval to explicitly search for instances or literature where electrochemical sensors using IDA have been applied to quinine detection.', 'Ensure that the results include information that links all three entities: electrochemical_sensor, indicator_displacement_assay(IDA), and quinine.', 'If no direct results exist, provide a statement indicating the absence of such information.'] issue_aspects=['entity_linking', 'property_selection', 'result_interpretation']",
#     "status": "warning",
#     "stage": "validated",
#     "previous_stage": "executed",
#     "messages": [
#       "content='Results validation warning: The query results are incomplete and do not accurately address the specific question about the use of Indicator Displacement Assay (IDA) in electrochemical sensors for detecting quinine. The results lack any information linking all three entities, especially regarding quinine detection.' additional_kwargs={} response_metadata={} id='6caff264-c40c-446c-aeb4-27b1cbf86b8a'"
#     ]
#   }
# }
# ------------------------------
# Retry count: 2
#
# --- Chunk 5 ---
# {
#   "normalize": {
#     "normalized_query": "intent='find information' relevant_entities=['electrochemical_sensor', 'indicator_displacement_assay(IDA)', 'quinine'] relevant_properties=[] filters=None query_type_suggestion='fact-finding'",
#     "status": "parsing_complete",
#     "stage": "normalized",
#     "previous_stage": "validated",
#     "retry_count": 2,
#     "messages": [
#       "content='Query normalized: Are there electrochemical sensors using Indicator Displacement Assay (IDA) to detect Quinine?' additional_kwargs={} response_metadata={} id='d72765bd-9831-4af9-9ec1-d7c0052ff2a4'"
#     ]
#   }
# }
# ------------------------------
# Retry count: 2
#
# --- Chunk 6 ---
# {
#   "strategy": {
#     "query_strategy": "tool_sequence",
#     "status": "strategy_determined",
#     "stage": "strategy",
#     "previous_stage": "normalized",
#     "messages": [
#       "content='Query strategy determined: tool_sequence' additional_kwargs={} response_metadata={} id='c7de9d41-843c-4b6f-b0bb-2f8834b6f3e2'"
#     ]
#   }
# }
# ------------------------------
# http://www.test.org/chem_ontologies/meta/
# http://www.test.org/chem_ontologies/classes/
# http://www.test.org/chem_ontologies/object_properties/
# http://www.test.org/chem_ontologies/data_properties/
# Retry count: 2
#
# --- Chunk 7 ---
# {
#   "execute": {
#     "query_results": {
#       "results": [
#         {
#           "tool": "get_class_info",
#           "params": {
#             "class_names": [
#               "electrochemical_sensor",
#               "indicator_displacement_assay(IDA)",
#               "quinine"
#             ]
#           },
#           "result": {
#             "electrochemical_sensor": {
#               "name": "electrochemical_sensor",
#               "information": [
#                 "Electrochemical sensors belong to the established methods of nucleotide detection.",
#                 "Nanocomposite based electrochemical sensor properties of polyaniline decorated with silver nanoparticles were utilized for the determination of 5-FU.",
#                 "An electrochemical sensor employing host-guest interactions of Q(8) was applied to the determination of tryptophan in real samples."
#               ]
#             },
#             "indicator_displacement_assay(IDA)": {
#               "name": "indicator_displacement_assay(IDA)",
#               "information": [
#                 "Through IDA coupled with differential sensing, we achieved the ultrasensitive and specific detection of LPA.",
#                 "Indicator displacement assay (IDA) is a method used for ultrasensitive fluorescence detection of LPA in aqueous media."
#               ]
#             },
#             "quinine": {
#               "name": "quinine",
#               "information": []
#             }
#           }
#         }
#       ]
#     },
#     "execution_plan": "steps=[ToolCallStep(tool='get_class_info', params={'class_names': ['electrochemical_sensor', 'indicator_displacement_assay(IDA)', 'quinine']})]",
#     "status": "executed",
#     "stage": "executed",
#     "previous_stage": "strategy",
#     "messages": [
#       "content='Tool-based query executed.' additional_kwargs={} response_metadata={} id='e0638f47-5994-4d23-a935-c84253e79cb2'"
#     ]
#   }
# }
# ------------------------------
# {
#   "results": [
#     {
#       "tool": "get_class_info",
#       "params": {
#         "class_names": [
#           "electrochemical_sensor",
#           "indicator_displacement_assay(IDA)",
#           "quinine"
#         ]
#       },
#       "result": {
#         "electrochemical_sensor": {
#           "name": "electrochemical_sensor",
#           "information": [
#             "Electrochemical sensors belong to the established methods of nucleotide detection.",
#             "Nanocomposite based electrochemical sensor properties of polyaniline decorated with silver nanoparticles were utilized for the determination of 5-FU.",
#             "An electrochemical sensor employing host-guest interactions of Q(8) was applied to the determination of tryptophan in real samples."
#           ]
#         },
#         "indicator_displacement_assay(IDA)": {
#           "name": "indicator_displacement_assay(IDA)",
#           "information": [
#             "Through IDA coupled with differential sensing, we achieved the ultrasensitive and specific detection of LPA.",
#             "Indicator displacement assay (IDA) is a method used for ultrasensitive fluorescence detection of LPA in aqueous media."
#           ]
#         },
#         "quinine": {
#           "name": "quinine",
#           "information": []
#         }
#       }
#     }
#   ]
# }
# Retry count: 2
# In retry logic, Retry count: 2
#
# --- Chunk 8 ---
# {
#   "validate": {
#     "validation_report": "valid=False details=[DimensionReport(dimension='completeness', score=2, valid=False, message=\"The results provide general information about 'electrochemical_sensor' and 'indicator_displacement_assay(IDA)', but do not address the specific query regarding the use of IDA-based electrochemical sensors for quinine detection. The entry for 'quinine' is empty, and there is no evidence of a connection between all three entities as required by the query.\"), DimensionReport(dimension='consistency', score=4, valid=True, message='The information presented is internally consistent and correctly attributed to the respective classes. There are no contradictions or mismatches in the data.'), DimensionReport(dimension='accuracy', score=3, valid=False, message=\"While the information about electrochemical sensors and IDA is accurate in a general sense, it does not specifically address the detection of quinine using IDA-based electrochemical sensors. The absence of relevant data for 'quinine' and the lack of explicit linkage between the three entities reduces the accuracy with respect to the query intent.\")] message='The query results are incomplete and do not accurately address the specific question about electrochemical sensors using IDA for quinine detection. While the information is consistent and generally accurate, it fails to establish the required relationship among the three entities.' improvement_suggestions=['Expand the query or data retrieval to explicitly search for instances or literature where electrochemical sensors using IDA have been applied to quinine detection.', \"Ensure that the result for 'quinine' includes relevant information or references to detection methods, especially those involving electrochemical sensors and IDA.\", 'Consider using a relation extraction or triple-based approach to directly link the three entities in the results.'] issue_aspects=['completeness', 'property_selection', 'strategy']",
#     "status": "warning",
#     "stage": "validated",
#     "previous_stage": "executed",
#     "messages": [
#       "content='Results validation warning: The query results are incomplete and do not accurately address the specific question about electrochemical sensors using IDA for quinine detection. While the information is consistent and generally accurate, it fails to establish the required relationship among the three entities.' additional_kwargs={} response_metadata={} id='10eb2ded-8925-4a42-8649-45231bb3f018'"
#     ]
#   }
# }
# ------------------------------
# Retry count: 3
#
# --- Chunk 9 ---
# {
#   "normalize": {
#     "normalized_query": "intent='find information about the use of electrochemical sensors based on Indicator Displacement Assay (IDA) for detecting Quinine' relevant_entities=['electrochemical_sensor', 'indicator_displacement_assay(IDA)', 'quinine'] relevant_properties=[] filters=None query_type_suggestion='fact-finding'",
#     "status": "parsing_complete",
#     "stage": "normalized",
#     "previous_stage": "validated",
#     "retry_count": 3,
#     "messages": [
#       "content='Query normalized: Are there electrochemical sensors using Indicator Displacement Assay (IDA) to detect Quinine?' additional_kwargs={} response_metadata={} id='9a36da8e-2b46-4592-b143-4c1898c3fa5a'"
#     ]
#   }
# }
# ------------------------------
# Retry count: 3
#
# --- Chunk 10 ---
# {
#   "strategy": {
#     "query_strategy": "tool_sequence",
#     "status": "strategy_determined",
#     "stage": "strategy",
#     "previous_stage": "normalized",
#     "messages": [
#       "content='Query strategy determined: tool_sequence' additional_kwargs={} response_metadata={} id='e050b065-dbd3-4c59-b362-3c65352fde59'"
#     ]
#   }
# }
# ------------------------------
# http://www.test.org/chem_ontologies/meta/
# http://www.test.org/chem_ontologies/classes/
# http://www.test.org/chem_ontologies/object_properties/
# http://www.test.org/chem_ontologies/data_properties/
# Retry count: 3
#
# --- Chunk 11 ---
# {
#   "execute": {
#     "query_results": {
#       "results": [
#         {
#           "tool": "get_class_info",
#           "params": {
#             "class_names": [
#               "electrochemical_sensor",
#               "indicator_displacement_assay(IDA)",
#               "quinine"
#             ]
#           },
#           "result": {
#             "electrochemical_sensor": {
#               "name": "electrochemical_sensor",
#               "information": [
#                 "Electrochemical sensors belong to the established methods of nucleotide detection.",
#                 "Nanocomposite based electrochemical sensor properties of polyaniline decorated with silver nanoparticles were utilized for the determination of 5-FU.",
#                 "An electrochemical sensor employing host-guest interactions of Q(8) was applied to the determination of tryptophan in real samples."
#               ]
#             },
#             "indicator_displacement_assay(IDA)": {
#               "name": "indicator_displacement_assay(IDA)",
#               "information": [
#                 "Through IDA coupled with differential sensing, we achieved the ultrasensitive and specific detection of LPA.",
#                 "Indicator displacement assay (IDA) is a method used for ultrasensitive fluorescence detection of LPA in aqueous media."
#               ]
#             },
#             "quinine": {
#               "name": "quinine",
#               "information": []
#             }
#           }
#         },
#         {
#           "tool": "get_class_properties",
#           "params": {
#             "class_names": [
#               "electrochemical_sensor",
#               "indicator_displacement_assay(IDA)",
#               "quinine"
#             ]
#           },
#           "result": {
#             "electrochemical_sensor": {
#               "is_verified_by": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "None",
#                     "raw_value": null
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "differential_pulse_voltammetry(DPV) OR cyclic_voltammetry(CV) OR proton_nuclear_magnetic_resonance(H_NMR) OR scanning_electron_microscopy(SEM) OR electrochemical_impedance_analysis(EIS) OR fourier_transform_infrared(FTIR)",
#                     "raw_value": "classes.differential_pulse_voltammetry(DPV) | classes.cyclic_voltammetry(CV) | classes.proton_nuclear_magnetic_resonance(H_NMR) | classes.scanning_electron_microscopy(SEM) | classes.electrochemical_impedance_analysis(EIS) | classes.fourier_transform_infrared(FTIR)"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "precision": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "reasonable",
#                     "raw_value": "reasonable"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "reasonable",
#                     "raw_value": "reasonable"
#                   }
#                 ],
#                 "descriptions": [
#                   {
#                     "content": "reasonable",
#                     "source": "10.1016/j.aca.2020.09.028",
#                     "file_path": null
#                   }
#                 ]
#               },
#               "stability": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "high stability with acceptable peak current decrease within 21 days",
#                     "raw_value": "high stability with acceptable peak current decrease within 21 days"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "Negligible change in DPV signal during first 7 days at 4\u00b0C; 86.47% of original value retained up to 21 days.",
#                     "raw_value": "Negligible change in DPV signal during first 7 days at 4\u00b0C; 86.47% of original value retained up to 21 days."
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "high stability with acceptable peak current decrease within 21 days",
#                     "raw_value": "high stability with acceptable peak current decrease within 21 days"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "Negligible change in DPV signal during first 7 days at 4\u00b0C; 86.47% of original value retained up to 21 days.",
#                     "raw_value": "Negligible change in DPV signal during first 7 days at 4\u00b0C; 86.47% of original value retained up to 21 days."
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "is_realized_as": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "sensing_platform",
#                     "raw_value": "classes.sensing_platform"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "sensing_platform",
#                     "raw_value": "classes.sensing_platform"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "cost_effectiveness": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "cost-effective",
#                     "raw_value": "cost-effective"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "cost-effective",
#                     "raw_value": "cost-effective"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "repeatability": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "Five independent electrodes displayed similar signals when detecting 30 \u03bcM quinine.",
#                     "raw_value": "Five independent electrodes displayed similar signals when detecting 30 \u03bcM quinine."
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "Five independent electrodes displayed similar signals when detecting 30 \u03bcM quinine.",
#                     "raw_value": "Five independent electrodes displayed similar signals when detecting 30 \u03bcM quinine."
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "has_detection_target": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "quinine",
#                     "raw_value": "classes.quinine"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "quinine",
#                     "raw_value": "classes.quinine"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "reproducibility": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "good reproducibility",
#                     "raw_value": "good reproducibility"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "Relative standard deviation of 2.06% across seven identical electrodes.",
#                     "raw_value": "Relative standard deviation of 2.06% across seven identical electrodes."
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "good reproducibility",
#                     "raw_value": "good reproducibility"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "Relative standard deviation of 2.06% across seven identical electrodes.",
#                     "raw_value": "Relative standard deviation of 2.06% across seven identical electrodes."
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "simplicity": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "simple",
#                     "raw_value": "simple"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "simple",
#                     "raw_value": "simple"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "selectivity": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "superior selectivity over common interfering molecules",
#                     "raw_value": "superior selectivity over common interfering molecules"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "superior selectivity over common interfering molecules",
#                     "raw_value": "superior selectivity over common interfering molecules"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "is_constructed_by": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "indicator_displacement_assay(IDA)",
#                     "raw_value": "classes.indicator_displacement_assay(IDA)"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "indicator_displacement_assay(IDA)",
#                     "raw_value": "classes.indicator_displacement_assay(IDA)"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "is_used_for": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "nucleotide",
#                     "raw_value": "classes.nucleotide"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "nucleotide",
#                     "raw_value": "classes.nucleotide"
#                   }
#                 ],
#                 "descriptions": [
#                   {
#                     "content": "single(nucleotide)",
#                     "source": null,
#                     "file_path": null
#                   }
#                 ]
#               },
#               "is_used_for_detection_of": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "tryptophan(Trp)",
#                     "raw_value": "classes.tryptophan(Trp)"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "tryptophan(Trp)",
#                     "raw_value": "classes.tryptophan(Trp)"
#                   }
#                 ],
#                 "descriptions": [
#                   {
#                     "content": "single(tryptophan(Trp))",
#                     "source": "10.1016/j.aca.2020.09.028",
#                     "file_path": null
#                   }
#                 ]
#               },
#               "is_based_on": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "nanocomposite",
#                     "raw_value": "classes.nanocomposite"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "nanocomposite",
#                     "raw_value": "classes.nanocomposite"
#                   }
#                 ],
#                 "descriptions": [
#                   {
#                     "content": "single(nanocomposite)",
#                     "source": "10.1007/s00706-021-02736-4",
#                     "file_path": null
#                   }
#                 ]
#               },
#               "value_retention": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "86.47% of original DPV signal value retained up to 21 days.",
#                     "raw_value": "86.47% of original DPV signal value retained up to 21 days."
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "86.47% of original DPV signal value retained up to 21 days.",
#                     "raw_value": "86.47% of original DPV signal value retained up to 21 days."
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "has_property": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "None",
#                     "raw_value": null
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "sensor_selectivity OR sensor_reusability OR sensor_reproducibility OR sensor_stability",
#                     "raw_value": "classes.sensor_selectivity | classes.sensor_reusability | classes.sensor_reproducibility | classes.sensor_stability"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "accuracy": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "reasonable",
#                     "raw_value": "reasonable"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "reasonable",
#                     "raw_value": "reasonable"
#                   }
#                 ],
#                 "descriptions": [
#                   {
#                     "content": "reasonable",
#                     "source": "10.1016/j.aca.2020.09.028",
#                     "file_path": null
#                   }
#                 ]
#               },
#               "reusability": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "reusable",
#                     "raw_value": "reusable"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "reusable",
#                     "raw_value": "reusable"
#                   }
#                 ],
#                 "descriptions": []
#               }
#             },
#             "indicator_displacement_assay(IDA)": {
#               "has_sensing_target": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "None",
#                     "raw_value": null
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "analyte OR metal_cation OR anion OR drug OR biological_molecule",
#                     "raw_value": "classes.analyte | classes.metal_cation | classes.anion | classes.drug | classes.biological_molecule"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "is_performed_in": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "live_cell",
#                     "raw_value": "classes.live_cell"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "live_cell",
#                     "raw_value": "classes.live_cell"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "has_analyte": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "analyte",
#                     "raw_value": "classes.analyte"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "analyte",
#                     "raw_value": "classes.analyte"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "has_receptor": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "synthetic_receptor",
#                     "raw_value": "classes.synthetic_receptor"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "synthetic_receptor",
#                     "raw_value": "classes.synthetic_receptor"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "has_component": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "None",
#                     "raw_value": null
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "beta-cyclodextrin(beta-CD) OR poly(N-acetylaniline) OR graphene",
#                     "raw_value": "classes.beta-cyclodextrin(beta-CD) | classes.poly(N-acetylaniline) | classes.graphene"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "assay_type": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "indicator displacement assay",
#                     "raw_value": "indicator displacement assay"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "indicator displacement assay",
#                     "raw_value": "indicator displacement assay"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "is_coupled_with": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "differential_sensing",
#                     "raw_value": "classes.differential_sensing"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "differential_sensing",
#                     "raw_value": "classes.differential_sensing"
#                   }
#                 ],
#                 "descriptions": [
#                   {
#                     "content": "single(differential_sensing)",
#                     "source": "10.1039/C7SC04989G",
#                     "file_path": null
#                   }
#                 ]
#               },
#               "has_indicator": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "indicator",
#                     "raw_value": "classes.indicator"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "indicator",
#                     "raw_value": "classes.indicator"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "interaction_type": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "non-covalent",
#                     "raw_value": "non-covalent"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "non-covalent",
#                     "raw_value": "non-covalent"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "has_signaling_unit": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "signaling_unit",
#                     "raw_value": "classes.signaling_unit"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "signaling_unit",
#                     "raw_value": "classes.signaling_unit"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "has_monitoring_target": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "hypoxia",
#                     "raw_value": "classes.hypoxia"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "hypoxia",
#                     "raw_value": "classes.hypoxia"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "sensor_conversion_capability": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "yes",
#                     "raw_value": "yes"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "yes",
#                     "raw_value": "yes"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "biological_location": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "inside live cells",
#                     "raw_value": "inside live cells"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "inside live cells",
#                     "raw_value": "inside live cells"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "has_sensor_output": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "optical_sensor",
#                     "raw_value": "classes.optical_sensor"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "optical_sensor",
#                     "raw_value": "classes.optical_sensor"
#                   }
#                 ],
#                 "descriptions": []
#               }
#             },
#             "quinine": {
#               "is_diluted_in": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "phosphate_buffer_solution(pbs)",
#                     "raw_value": "classes.phosphate_buffer_solution(pbs)"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "phosphate_buffer_solution(pbs)",
#                     "raw_value": "classes.phosphate_buffer_solution(pbs)"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "molar_ratio": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "1:1 (with \u03b2-CD)",
#                     "raw_value": "1:1 (with \u03b2-CD)"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "1:1 (with \u03b2-CD)",
#                     "raw_value": "1:1 (with \u03b2-CD)"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "is_analyzed_by": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "electrochemical_technique",
#                     "raw_value": "classes.electrochemical_technique"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "high_performance_liquid_chromatography(hplc)",
#                     "raw_value": "classes.high_performance_liquid_chromatography(hplc)"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "colorimetric_assay",
#                     "raw_value": "classes.colorimetric_assay"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "fluorescence_assay",
#                     "raw_value": "classes.fluorescence_assay"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "high_resolution_mass_spectrometry(hrms)",
#                     "raw_value": "classes.high_resolution_mass_spectrometry(hrms)"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "electrochemical_technique",
#                     "raw_value": "classes.electrochemical_technique"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "high_performance_liquid_chromatography(hplc)",
#                     "raw_value": "classes.high_performance_liquid_chromatography(hplc)"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "colorimetric_assay",
#                     "raw_value": "classes.colorimetric_assay"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "fluorescence_assay",
#                     "raw_value": "classes.fluorescence_assay"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "high_resolution_mass_spectrometry(hrms)",
#                     "raw_value": "classes.high_resolution_mass_spectrometry(hrms)"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "incubation_time": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "40 min",
#                     "raw_value": "40 min"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "40",
#                     "raw_value": 40
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "40 min",
#                     "raw_value": "40 min"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "40",
#                     "raw_value": 40
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "recovery": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "98.3% to 109.3%",
#                     "raw_value": "98.3% to 109.3%"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "98.3% to 109.3%",
#                     "raw_value": "98.3% to 109.3%"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "stock_solution_concentration": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "10 mM",
#                     "raw_value": "10 mM"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "10 mM",
#                     "raw_value": "10 mM"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "adverse_health_effect": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "thrombocytopenia",
#                     "raw_value": "thrombocytopenia"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "thrombotic_microangiopathy",
#                     "raw_value": "thrombotic_microangiopathy"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "blindness",
#                     "raw_value": "blindness"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "acute_kidney_injury",
#                     "raw_value": "acute_kidney_injury"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "thrombocytopenia",
#                     "raw_value": "thrombocytopenia"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "thrombotic_microangiopathy",
#                     "raw_value": "thrombotic_microangiopathy"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "blindness",
#                     "raw_value": "blindness"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "acute_kidney_injury",
#                     "raw_value": "acute_kidney_injury"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "proton_peak_shift": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "slight shift",
#                     "raw_value": "slight shift"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "slight shift",
#                     "raw_value": "slight shift"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "is_dissolved_in": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "ethanol",
#                     "raw_value": "classes.ethanol"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "ethanol",
#                     "raw_value": "classes.ethanol"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "solvent_for_stock_solution": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "ethanol",
#                     "raw_value": "ethanol"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "ethanol",
#                     "raw_value": "ethanol"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "hydrophobicity": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "hydrophobic",
#                     "raw_value": "hydrophobic"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "hydrophobic",
#                     "raw_value": "hydrophobic"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "solubility_in_water": {
#                 "restrictions": [
#                   {
#                     "type": "VALUE",
#                     "value": "low",
#                     "raw_value": "low"
#                   },
#                   {
#                     "type": "VALUE",
#                     "value": "low",
#                     "raw_value": "low"
#                   }
#                 ],
#                 "descriptions": []
#               },
#               "is_detected_by": {
#                 "restrictions": [
#                   {
#                     "type": "SOME",
#                     "value": "quantitative_electrochemical_method",
#                     "raw_value": "classes.quantitative_electrochemical_method"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "ion_transfer_voltammetry(itv)",
#                     "raw_value": "classes.ion_transfer_voltammetry(itv)"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "electrochemiluminescence_biosensor",
#                     "raw_value": "classes.electrochemiluminescence_biosensor"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "quantitative_electrochemical_method",
#                     "raw_value": "classes.quantitative_electrochemical_method"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "ion_transfer_voltammetry(itv)",
#                     "raw_value": "classes.ion_transfer_voltammetry(itv)"
#                   },
#                   {
#                     "type": "SOME",
#                     "value": "electrochemiluminescence_biosensor",
#                     "raw_value": "classes.electrochemiluminescence_biosensor"
#                   }
#                 ],
#                 "descriptions": []
#               },
# ...
#                 "value": "low",
#                 "raw_value": "low"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "low",
#                 "raw_value": "low"
#               }
#             ],
#             "descriptions": []
#           },
#           "is_detected_by": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "quantitative_electrochemical_method",
#                 "raw_value": "classes.quantitative_electrochemical_method"
#               },
#               {
#                 "type": "SOME",
#                 "value": "ion_transfer_voltammetry(itv)",
#                 "raw_value": "classes.ion_transfer_voltammetry(itv)"
#               },
#               {
#                 "type": "SOME",
#                 "value": "electrochemiluminescence_biosensor",
#                 "raw_value": "classes.electrochemiluminescence_biosensor"
#               },
#               {
#                 "type": "SOME",
#                 "value": "quantitative_electrochemical_method",
#                 "raw_value": "classes.quantitative_electrochemical_method"
#               },
#               {
#                 "type": "SOME",
#                 "value": "ion_transfer_voltammetry(itv)",
#                 "raw_value": "classes.ion_transfer_voltammetry(itv)"
#               },
#               {
#                 "type": "SOME",
#                 "value": "electrochemiluminescence_biosensor",
#                 "raw_value": "classes.electrochemiluminescence_biosensor"
#               }
#             ],
#             "descriptions": []
#           },
#           "induces": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "thrombocytopenia",
#                 "raw_value": "classes.thrombocytopenia"
#               },
#               {
#                 "type": "SOME",
#                 "value": "thrombotic_microangiopathy",
#                 "raw_value": "classes.thrombotic_microangiopathy"
#               },
#               {
#                 "type": "SOME",
#                 "value": "blindness",
#                 "raw_value": "classes.blindness"
#               },
#               {
#                 "type": "SOME",
#                 "value": "acute_kidney_injury",
#                 "raw_value": "classes.acute_kidney_injury"
#               },
#               {
#                 "type": "SOME",
#                 "value": "thrombocytopenia",
#                 "raw_value": "classes.thrombocytopenia"
#               },
#               {
#                 "type": "SOME",
#                 "value": "thrombotic_microangiopathy",
#                 "raw_value": "classes.thrombotic_microangiopathy"
#               },
#               {
#                 "type": "SOME",
#                 "value": "blindness",
#                 "raw_value": "classes.blindness"
#               },
#               {
#                 "type": "SOME",
#                 "value": "acute_kidney_injury",
#                 "raw_value": "classes.acute_kidney_injury"
#               }
#             ],
#             "descriptions": []
#           },
#           "use_as_bittering_agent": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "bittering_agent",
#                 "raw_value": "bittering_agent"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "bittering_agent",
#                 "raw_value": "bittering_agent"
#               }
#             ],
#             "descriptions": []
#           },
#           "role_in_detection_scheme": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "target",
#                 "raw_value": "target"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "target",
#                 "raw_value": "target"
#               }
#             ],
#             "descriptions": []
#           },
#           "is_used_for": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "malaria",
#                 "raw_value": "classes.malaria"
#               },
#               {
#                 "type": "SOME",
#                 "value": "lupus",
#                 "raw_value": "classes.lupus"
#               },
#               {
#                 "type": "SOME",
#                 "value": "arthritis",
#                 "raw_value": "classes.arthritis"
#               },
#               {
#                 "type": "SOME",
#                 "value": "muscle_cramp",
#                 "raw_value": "classes.muscle_cramp"
#               },
#               {
#                 "type": "SOME",
#                 "value": "bittering_agent",
#                 "raw_value": "classes.bittering_agent"
#               },
#               {
#                 "type": "SOME",
#                 "value": "malaria",
#                 "raw_value": "classes.malaria"
#               },
#               {
#                 "type": "SOME",
#                 "value": "lupus",
#                 "raw_value": "classes.lupus"
#               },
#               {
#                 "type": "SOME",
#                 "value": "arthritis",
#                 "raw_value": "classes.arthritis"
#               },
#               {
#                 "type": "SOME",
#                 "value": "muscle_cramp",
#                 "raw_value": "classes.muscle_cramp"
#               },
#               {
#                 "type": "SOME",
#                 "value": "bittering_agent",
#                 "raw_value": "classes.bittering_agent"
#               }
#             ],
#             "descriptions": []
#           },
#           "has_component": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "alkaloid",
#                 "raw_value": "classes.alkaloid"
#               },
#               {
#                 "type": "SOME",
#                 "value": "cinchona_tree_bark",
#                 "raw_value": "classes.cinchona_tree_bark"
#               },
#               {
#                 "type": "SOME",
#                 "value": "alkaloid",
#                 "raw_value": "classes.alkaloid"
#               },
#               {
#                 "type": "SOME",
#                 "value": "cinchona_tree_bark",
#                 "raw_value": "classes.cinchona_tree_bark"
#               }
#             ],
#             "descriptions": []
#           },
#           "application": {
#             "restrictions": [
#               {
#                 "type": "VALUE",
#                 "value": "malaria",
#                 "raw_value": "malaria"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "lupus",
#                 "raw_value": "lupus"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "arthritis",
#                 "raw_value": "arthritis"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "muscle_cramp",
#                 "raw_value": "muscle_cramp"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "malaria",
#                 "raw_value": "malaria"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "lupus",
#                 "raw_value": "lupus"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "arthritis",
#                 "raw_value": "arthritis"
#               },
#               {
#                 "type": "VALUE",
#                 "value": "muscle_cramp",
#                 "raw_value": "muscle_cramp"
#               }
#             ],
#             "descriptions": []
#           },
#           "is_determined_by": {
#             "restrictions": [
#               {
#                 "type": "SOME",
#                 "value": "differential_pulse_voltammetry(DPV)",
#                 "raw_value": "classes.differential_pulse_voltammetry(DPV)"
#               },
#               {
#                 "type": "SOME",
#                 "value": "differential_pulse_voltammetry(DPV)",
#                 "raw_value": "classes.differential_pulse_voltammetry(DPV)"
#               }
#             ],
#             "descriptions": []
#           }
#         }
#       }
#     },
#     {
#       "tool": "get_related_classes",
#       "params": {
#         "class_names": [
#           "electrochemical_sensor"
#         ]
#       },
#       "result": {
#         "electrochemical_sensor": {
#           "is_verified_by": [
#             "cyclic_voltammetry(CV)",
#             "differential_pulse_voltammetry(DPV)",
#             "electrochemical_impedance_analysis(EIS)",
#             "fourier_transform_infrared(FTIR)",
#             "proton_nuclear_magnetic_resonance(H_NMR)",
#             "scanning_electron_microscopy(SEM)"
#           ],
#           "is_realized_as": [
#             "sensing_platform"
#           ],
#           "has_detection_target": [
#             "quinine"
#           ],
#           "is_constructed_by": [
#             "indicator_displacement_assay(IDA)"
#           ],
#           "is_used_for": [
#             "nucleotide"
#           ],
#           "is_used_for_detection_of": [
#             "tryptophan(Trp)"
#           ],
#           "is_based_on": [
#             "nanocomposite"
#           ],
#           "has_property": [
#             "sensor_reproducibility",
#             "sensor_reusability",
#             "sensor_selectivity",
#             "sensor_stability"
#           ]
#         }
#       }
#     }
#   ]
# }
# Retry count: 4
# In retry logic, Retry count: 4
# Exceeded maximum retry attempts (4)
#
# --- Chunk 17 ---
# {
#   "validate": {
#     "validation_report": "valid=False details=[DimensionReport(dimension='completeness', score=3, valid=False, message=\"The results provide substantial information about electrochemical sensors, indicator displacement assays, and quinine, including their properties and relationships. However, there is a critical gap: there is no explicit evidence or statement confirming that an electrochemical sensor using an indicator displacement assay (IDA) has been used specifically for quinine detection. The closest link is that 'electrochemical_sensor' has 'has_detection_target: quinine' and 'is_constructed_by: indicator_displacement_assay(IDA)', but there is no direct assertion or example tying all three together in a single instance. The 'information' field for 'quinine' is also empty, missing context or examples.\"), DimensionReport(dimension='consistency', score=4, valid=True, message=\"The relationships and properties across the results are internally consistent. The properties and related classes for 'electrochemical_sensor' and 'indicator_displacement_assay' align with the ontology structure, and there are no contradictory statements. However, some redundancy is present in property values, and the lack of direct linkage between all three entities (sensor, IDA, quinine) is a minor consistency concern.\"), DimensionReport(dimension='accuracy', score=4, valid=True, message='The factual content about the properties and relationships of each class appears accurate and is supported by references where provided. The methods, targets, and components are plausible and match domain knowledge. However, the absence of a direct, explicit example or reference for an electrochemical sensor using IDA for quinine detection means the answer is not fully accurate for the specific query intent.')] message=\"The query results are generally consistent and accurate regarding the ontology's structure and the properties of the involved classes. However, they are incomplete for the user's intent: there is no explicit evidence or example confirming the existence of an electrochemical sensor using an indicator displacement assay (IDA) for quinine detection. The results only imply this possibility through separate relationships, not a direct instance or literature-backed example.\" improvement_suggestions=['Explicitly search for and include evidence (e.g., literature references, ontology instances, or example descriptions) that directly confirm the existence of an electrochemical sensor using an indicator displacement assay (IDA) for quinine detection.', 'If such an example does not exist, clearly state this in the results and provide the closest related information.', \"Populate the 'information' field for 'quinine' with relevant context, such as its detection by electrochemical sensors or its use in IDA-based assays.\", 'Reduce redundancy in property values and ensure each property is only listed once unless justified by multiple sources.'] issue_aspects=['completeness', 'evidence_linkage', 'result_explanation']",
#     "status": "warning",
#     "stage": "validated",
#     "previous_stage": "executed",
#     "messages": [
#       "content=\"Results validation warning: The query results are generally consistent and accurate regarding the ontology's structure and the properties of the involved classes. However, they are incomplete for the user's intent: there is no explicit evidence or example confirming the existence of an electrochemical sensor using an indicator displacement assay (IDA) for quinine detection. The results only imply this possibility through separate relationships, not a direct instance or literature-backed example.\" additional_kwargs={} response_metadata={} id='56f9f942-36b4-4c97-9885-22955d6af917'"
#     ]
#   }
# }
# ------------------------------
# Retry count: 4
#
# --- Chunk 18 ---
# {
#   "format_results": {
#     "status": "completed",
#     "stage": "completed",
#     "previous_stage": "validated",
#     "formatted_results": {
#       "summary": "Electrochemical sensors utilizing the Indicator Displacement Assay (IDA) have been developed for the detection of quinine. These sensors demonstrate good selectivity, reproducibility, and stability, and are based on nanocomposite materials.",
#       "key_points": [
#         "Electrochemical sensors constructed using the Indicator Displacement Assay (IDA) are capable of detecting quinine.",
#         "These sensors are based on nanocomposite materials, such as polyaniline decorated with silver nanoparticles.",
#         "Detection of quinine is verified by techniques including differential pulse voltammetry (DPV), cyclic voltammetry (CV), and other electrochemical methods.",
#         "The sensors show high stability, retaining 86.47% of their original DPV signal after 21 days at 4\u00b0C, with negligible change in the first 7 days.",
#         "Reproducibility is high, with a relative standard deviation of 2.06% across seven identical electrodes.",
#         "Repeatability is demonstrated, as five independent electrodes produced similar signals when detecting 30 \u03bcM quinine.",
#         "The sensors exhibit superior selectivity over common interfering molecules.",
#         "They are cost-effective, simple to use, and reusable.",
#         "Quinine is typically detected in phosphate buffer solution (PBS), with a 1:1 molar ratio to \u03b2-cyclodextrin (\u03b2-CD) in some assays.",
#         "Recovery rates for quinine detection range from 98.3% to 109.3%."
#       ],
#       "relationships": [
#         "The use of IDA in electrochemical sensors enables selective and sensitive detection of quinine by leveraging host-guest chemistry and indicator dye displacement.",
#         "Nanocomposite-based sensor platforms enhance the performance (stability, selectivity, reproducibility) of IDA-based electrochemical quinine sensors.",
#         "Electrochemical techniques such as DPV and CV are standard for verifying sensor performance in quinine detection."
#       ]
#     },
#     "messages": [
#       "content='Results formatted: Electrochemical sensors utilizing the Indicator Displacement Assay (IDA) have been developed for the detection of quinine. These sensors demonstrate good selectivity, reproducibility, and stability, and are based on nanocomposite materials.' additional_kwargs={} response_metadata={} id='64b03b95-0ef1-49bf-b7a7-a19e5de83837'"
#     ]
#   }
# }
# ------------------------------
#
# --- Graph Stream Finished ---
# query:Are there electrochemical sensors using Indicator Displacement Assay (IDA) to detect Quinine? has been finished.
# --- Direct Graph Stream Test Finished ---

# %%
print(graph["normalized_query"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(graph["normalized_query"])
#
# TypeError: 'CompiledStateGraph' object is not subscriptable

# %% [markdown]
# # QueryManager 检查

# %%
import threading
import traceback
import sys

def check_threads():
    """检查当前进程中的活跃线程"""
    print(f"当前活跃线程数: {threading.active_count()}")
    
    print("\n当前活跃线程:")
    for t in threading.enumerate():
        print(f"- {t.name} (daemon: {t.daemon}, 活动: {t.is_alive()})")
    
    print("\n线程调用栈:")
    query_manager_threads = []
    for thread_id, frame in sys._current_frames().items():
        thread_name = "Unknown"
        for t in threading.enumerate():
            if t.ident == thread_id:
                thread_name = t.name
                break
        
        # 检查是否是QueryManager相关线程
        is_query_thread = False
        stack_trace = traceback.extract_stack(frame)
        for filename, _, _, _ in stack_trace:
            if "query_manager" in filename or "ThreadPool" in filename:
                is_query_thread = True
                query_manager_threads.append(thread_name)
                break
        
        print(f"线程ID: {thread_id}, 名称: {thread_name}{' (QueryManager相关)' if is_query_thread else ''}")
        for filename, lineno, name, line in stack_trace[-10:]:  # 只显示最近10个调用
            print(f"  文件: {filename.split('/')[-1]}, 行: {lineno}, 函数: {name}")
            if line:
                print(f"    代码: {line}")
        print("")
    
    if query_manager_threads:
        print(f"\n发现 {len(query_manager_threads)} 个QueryManager相关线程: {', '.join(query_manager_threads)}")
    else:
        print("\n未发现QueryManager相关线程")

# 执行检查
check_threads()
# Out:
# 当前活跃线程数: 6
#
# 当前活跃线程:
# - MainThread (daemon: False, 活动: True)
# - IOPub (daemon: True, 活动: True)
# - Heartbeat (daemon: True, 活动: True)
# - Control (daemon: True, 活动: True)
# - IPythonHistorySavingThread (daemon: True, 活动: True)
# - Thread-1 (daemon: True, 活动: True)
#
# 线程调用栈:
# 线程ID: 13768, 名称: Thread-1
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\threading.py, 行: 1012, 函数: _bootstrap
#     代码: self._bootstrap_inner()
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\threading.py, 行: 1041, 函数: _bootstrap_inner
#     代码: self.run()
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\ipykernel\parentpoller.py, 行: 93, 函数: run
#     代码: result = ctypes.windll.kernel32.WaitForMultipleObjects(  # type:ignore[attr-defined]
#
# 线程ID: 33716, 名称: IPythonHistorySavingThread
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\threading.py, 行: 1012, 函数: _bootstrap
#     代码: self._bootstrap_inner()
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\threading.py, 行: 1041, 函数: _bootstrap_inner
#     代码: self.run()
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\decorator.py, 行: 232, 函数: fun
#     代码: return caller(func, *(extras + args), **kw)
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\IPython\core\history.py, 行: 61, 函数: only_when_enabled
#     代码: return f(self, *a, **kw)
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\IPython\core\history.py, 行: 908, 函数: run
#     代码: self.history_manager.writeout_cache(self.db)
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\decorator.py, 行: 232, 函数: fun
#     代码: return caller(func, *(extras + args), **kw)
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\IPython\core\history.py, 行: 61, 函数: only_when_enabled
#     代码: return f(self, *a, **kw)
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\IPython\core\history.py, 行: 853, 函数: writeout_cache
#     代码: self._writeout_input_cache(conn)
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\IPython\core\history.py, 行: 834, 函数: _writeout_input_cache
#     代码: with conn:
#
# 线程ID: 10172, 名称: Control
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\ipykernel\kernelbase.py, 行: 304, 函数: poll_control_queue
#     代码: msg = await self.control_queue.get()
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\concurrent\futures\_base.py, 行: 550, 函数: set_result
#     代码: self._invoke_callbacks()
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\concurrent\futures\_base.py, 行: 338, 函数: _invoke_callbacks
#     代码: for callback in self._done_callbacks:
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\asyncio\futures.py, 行: 402, 函数: _call_set_state
#     代码: dest_loop.call_soon_threadsafe(_set_state, destination, source)
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\asyncio\base_events.py, 行: 881, 函数: call_soon_threadsafe
#     代码: return handle
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\asyncio\selector_events.py, 行: 152, 函数: _write_to_self
#     代码: csock.send(b'\0')
#
# 线程ID: 4588, 名称: Heartbeat
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\threading.py, 行: 1012, 函数: _bootstrap
#     代码: self._bootstrap_inner()
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\threading.py, 行: 1041, 函数: _bootstrap_inner
#     代码: self.run()
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\ipykernel\heartbeat.py, 行: 106, 函数: run
#     代码: zmq.device(zmq.QUEUE, self.socket, self.socket)
#
# 线程ID: 20960, 名称: IOPub
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\asyncio\events.py, 行: 105, 函数: _run
#     代码: self = None  # Needed to break cycles when an exception occurs.
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\tornado\platform\asyncio.py, 行: 202, 函数: _handle_events
#     代码: handler_func(fileobj, events)
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\zmq\eventloop\zmqstream.py, 行: 619, 函数: _handle_events
#     代码: self._rebuild_io_state()
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\zmq\eventloop\zmqstream.py, 行: 639, 函数: _handle_recv
#     代码: self._run_callback(callback, msg)
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\zmq\eventloop\zmqstream.py, 行: 571, 函数: _run_callback
#     代码: if f is not None:
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\ipykernel\iostream.py, 行: 168, 函数: _handle_event
#     代码: for _ in range(n_events):
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\ipykernel\iostream.py, 行: 276, 函数: <lambda>
#     代码: self.schedule(lambda: self._really_send(*args, **kwargs))
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\ipykernel\iostream.py, 行: 287, 函数: _really_send
#     代码: self.socket.send_multipart(msg, *args, **kwargs)
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\zmq\sugar\socket.py, 行: 754, 函数: send_multipart
#     代码: return self.send(msg_parts[-1], flags, copy=copy, track=track)
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\zmq\sugar\socket.py, 行: 701, 函数: send
#     代码: return super().send(data, flags=flags, copy=copy, track=track)
#
# 线程ID: 7572, 名称: MainThread
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\ipykernel\ipkernel.py, 行: 449, 函数: do_execute
#     代码: res = shell.run_cell(
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\ipykernel\zmqshell.py, 行: 549, 函数: run_cell
#     代码: return super().run_cell(*args, **kwargs)
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\IPython\core\interactiveshell.py, 行: 3075, 函数: run_cell
#     代码: result = self._run_cell(
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\IPython\core\interactiveshell.py, 行: 3130, 函数: _run_cell
#     代码: result = runner(coro)
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\IPython\core\async_helpers.py, 行: 128, 函数: _pseudo_sync_runner
#     代码: coro.send(None)
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\IPython\core\interactiveshell.py, 行: 3334, 函数: run_cell_async
#     代码: has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\IPython\core\interactiveshell.py, 行: 3517, 函数: run_ast_nodes
#     代码: if await self.run_code(code, result, async_=asy):
#   文件: d:\AnacondaEnPs\envs\OntologyConstruction\Lib\site-packages\IPython\core\interactiveshell.py, 行: 3577, 函数: run_code
#     代码: exec(code_obj, self.user_global_ns, self.user_ns)
#   文件: C:\Users\SYK\AppData\Local\Temp\ipykernel_10876\312767565.py, 行: 44, 函数: <module>
#     代码: check_threads()
#   文件: C:\Users\SYK\AppData\Local\Temp\ipykernel_10876\312767565.py, 行: 24, 函数: check_threads
#     代码: stack_trace = traceback.extract_stack(frame)
#
#
# 未发现QueryManager相关线程

# %%
# 查看缓存内容（如果有缓存的查询）
cache_content = query_manager.query_queue_manager.cache.cache
print(f"缓存中的查询数量: {len(cache_content)}")

# 查看缓存的时间戳信息
timestamps = query_manager.query_queue_manager.cache.timestamps
if timestamps:
    print("\n缓存时间戳:")
    for key, timestamp in timestamps.items():
        print(f"查询: {key[:50]}... - 时间: {timestamp}")
        # 计算剩余有效时间
        ttl = query_manager.query_queue_manager.cache.ttl  # 默认3600秒（1小时）
        from datetime import datetime, timedelta
        remaining = timestamp + timedelta(seconds=ttl) - datetime.now()
        print(f"  剩余有效时间: {remaining}")

# 如果需要手动清除缓存
# query_manager.query_queue_manager.cache.clear()
# print("缓存已清除")
# Out:
# 缓存中的查询数量: 0

# %%
import os
import re

def reorder_md_by_queries_and_save_new(md_path, queries, output_path):
    """
    读取md文件，按照queries顺序重新组织问答对，并存为新的md文件。
    :param md_path: md文件路径
    :param queries: 问题列表（字符串列表，顺序即为目标顺序）
    :param output_path: 新的md文件路径
    """
    # 读取原始md内容
    with open(md_path, "r", encoding="utf-8") as f:
        lines = f.readlines()

    # 解析所有问答对
    qa_blocks = []
    cur_q = None
    cur_a = []
    q_pattern = re.compile(r"^##\s*\d+\.\s+(.+)")
    for line in lines:
        m = q_pattern.match(line.strip())
        if m:
            # 新问题开始
            if cur_q is not None:
                qa_blocks.append((cur_q, cur_a))
            cur_q = m.group(1).strip()  # 只保留问题正文
            cur_a = []
        elif cur_q is not None:
            cur_a.append(line)
    if cur_q is not None:
        qa_blocks.append((cur_q, cur_a))

    # 构建问题到问答对的映射
    q2block = {q: (q, a) for q, a in qa_blocks}

    # 重新排序
    new_blocks = []
    for q in queries:
        if q in q2block:
            new_blocks.append(q2block[q])
        else:
            print(f"警告: 未找到问题: {q}")

    # 写入新的md文件
    with open(output_path, "w", encoding="utf-8") as f:
        for idx, (q, a) in enumerate(new_blocks, 1):
            f.write(f"## {idx}. {q}\n")
            for line in a:
                f.write(line)

# 处理MOSES-final.md和MOSES-nano-final.md，存为新文件
for mdfile in ["MOSES-final.md", "MOSES-nano-final.md"]:
    md_path = os.path.join( os.getcwd(), mdfile)
    output_path = os.path.join( os.getcwd(), f"reordered_{mdfile}")
    if os.path.exists(md_path):
        reorder_md_by_queries_and_save_new(md_path, queries, output_path)
        print(f"已生成新文件: {output_path}")
    else:
        print(f"未找到文件: {md_path}")
# Out:
# 已生成新文件: d:\CursorProj\Chem-Ontology-Constructor\tests\unit_test\query\test\reordered_MOSES-final.md
# 已生成新文件: d:\CursorProj\Chem-Ontology-Constructor\tests\unit_test\query\test\reordered_MOSES-nano-final.md

# %%
import os

def reorder_md_by_queries_h2(md_path, queries, output_path):
    """
    读取md文件，按照queries顺序重新组织问答对，并存为新的md文件。
    假设每个问题是H2标题（即以'## '开头），两个H2标题之间的内容为该问题的答案。
    :param md_path: 原始md文件路径
    :param queries: 问题列表（字符串列表，顺序即为目标顺序）
    :param output_path: 新的md文件路径
    """
    # 读取原始md内容
    with open(md_path, "r", encoding="utf-8") as f:
        lines = f.readlines()

    # 解析所有问答对（H2标题为问题）
    qa_blocks = []
    cur_q = None
    cur_a = []
    for line in lines:
        if line.strip().startswith("## "):
            # 新问题开始
            if cur_q is not None:
                qa_blocks.append((cur_q, cur_a))
            cur_q = line.strip()[3:].strip()  # 去掉'## '和首尾空格
            cur_a = []
        elif cur_q is not None:
            cur_a.append(line)
    if cur_q is not None:
        qa_blocks.append((cur_q, cur_a))

    # 构建问题到问答对的映射
    q2block = {q: (q, a) for q, a in qa_blocks}

    # 重新排序
    new_blocks = []
    for q in queries:
        if q in q2block:
            new_blocks.append(q2block[q])
        else:
            print(f"警告: 未找到问题: {q}")

    # 写入新的md文件
    with open(output_path, "w", encoding="utf-8") as f:
        for q, a in new_blocks:
            f.write(f"## {q}\n")
            for line in a:
                f.write(line)

# 假设queries变量已定义，内容为问题字符串列表，顺序为目标顺序
# 例如:
# queries = [
#     "What techniques are used to analyze Quinine?",
#     "Are there electrochemical sensors using Indicator Displacement Assay (IDA) to detect Quinine?",
#     ...
# ]

# 处理MOSES-final.md和MOSES-nano-final.md，输出为新文件
for mdfile in ["MOSES-final.md", "MOSES-nano-final.md"]:
    md_path = os.path.join( os.getcwd(), mdfile)
    output_path = os.path.join( os.getcwd(), f"reordered_{mdfile}")
    if os.path.exists(md_path):
        reorder_md_by_queries_h2(md_path, queries, output_path)
        print(f"已生成新文件: {output_path}")
    else:
        print(f"未找到文件: {md_path}")
# Out:
# 警告: 未找到问题: Tell me about Quinine.
# 警告: 未找到问题: What is an Indicator Displacement Assay?
# 警告: 未找到问题: What techniques are used to analyze Quinine?
# 警告: 未找到问题: What are the components of an Indicator Displacement Assay?
# 警告: 未找到问题: Are there electrochemical sensors using Indicator Displacement Assay (IDA) to detect Quinine?
# 警告: 未找到问题: Which host molecules use host-guest recognition in electrochemical assays?
# 警告: 未找到问题: How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?
# 警告: 未找到问题: How is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine verified?
# 警告: 未找到问题: In the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine, how does Quinine displace Methylene Blue from beta-Cyclodextrin?
# 警告: 未找到问题: What does Graphene do in the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?
# 警告: 未找到问题: What is a cryptand?
# 警告: 未找到问题: Is pyrrole considered an aromatic system?
# 警告: 未找到问题: What types of molecules typically act as guests for supramolecular hosts?
# 警告: 未找到问题: What are some specific types of macrocycles?
# 警告: 未找到问题: When a calixarene containing pyrrole groups binds an anion, what specific non-covalent interactions are typically involved?
# 警告: 未找到问题: Are there known supramolecular hosts that are derivatives of calixarenes and also feature pyrrole functional groups?
# 警告: 未找到问题: What are common applications for cage molecules compared to macrocycles, and do they have any overlapping uses?
# 警告: 未找到问题: What types of supramolecular hosts are known to bind anions primarily through anion-π interactions?
# 警告: 未找到问题: Why are supramolecular hosts containing pyrrole units generally effective at binding anions?
# 警告: 未找到问题: What is the role of non-covalent interactions like hydrogen bonds and anion-π interactions in the formation of supramolecular host-guest complexes?
# 警告: 未找到问题: What types of molecules can be detected by IDA?
# 警告: 未找到问题: What types of host-guest interaction can be used to design IDA-based electrochemical sensors?
# 警告: 未找到问题: What types of host-guest interaction can be used to design IDA using optical detection?
# 警告: 未找到问题: What types of host-guest interaction can induce changes in optical signals?
# 警告: 未找到问题: What types of host-guest interaction can induce changes in electrochemical signals?
# 警告: 未找到问题: What types of supramolecular hosts are known to bind to their guests primarily through cation-π interactions?
# 警告: 未找到问题: What are the main factors controlling host-guest interaction?
# 已生成新文件: d:\CursorProj\Chem-Ontology-Constructor\tests\unit_test\query\test\reordered_MOSES-final.md
# 警告: 未找到问题: Tell me about Quinine.
# 警告: 未找到问题: What is an Indicator Displacement Assay?
# 警告: 未找到问题: What techniques are used to analyze Quinine?
# 警告: 未找到问题: What are the components of an Indicator Displacement Assay?
# 警告: 未找到问题: Are there electrochemical sensors using Indicator Displacement Assay (IDA) to detect Quinine?
# 警告: 未找到问题: Which host molecules use host-guest recognition in electrochemical assays?
# 警告: 未找到问题: How stable and reproducible is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?
# 警告: 未找到问题: How is the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine verified?
# 警告: 未找到问题: In the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine, how does Quinine displace Methylene Blue from beta-Cyclodextrin?
# 警告: 未找到问题: What does Graphene do in the electrochemical sensor that uses an Indicator Displacement Assay (IDA) for detecting Quinine?
# 警告: 未找到问题: What is a cryptand?
# 警告: 未找到问题: Is pyrrole considered an aromatic system?
# 警告: 未找到问题: What types of molecules typically act as guests for supramolecular hosts?
# 警告: 未找到问题: What are some specific types of macrocycles?
# 警告: 未找到问题: When a calixarene containing pyrrole groups binds an anion, what specific non-covalent interactions are typically involved?
# 警告: 未找到问题: Are there known supramolecular hosts that are derivatives of calixarenes and also feature pyrrole functional groups?
# 警告: 未找到问题: What are common applications for cage molecules compared to macrocycles, and do they have any overlapping uses?
# 警告: 未找到问题: What types of supramolecular hosts are known to bind anions primarily through anion-π interactions?
# 警告: 未找到问题: Why are supramolecular hosts containing pyrrole units generally effective at binding anions?
# 警告: 未找到问题: What is the role of non-covalent interactions like hydrogen bonds and anion-π interactions in the formation of supramolecular host-guest complexes?
# 警告: 未找到问题: What types of molecules can be detected by IDA?
# 警告: 未找到问题: What types of host-guest interaction can be used to design IDA-based electrochemical sensors?
# 警告: 未找到问题: What types of host-guest interaction can be used to design IDA using optical detection?
# 警告: 未找到问题: What types of host-guest interaction can induce changes in optical signals?
# 警告: 未找到问题: What types of host-guest interaction can induce changes in electrochemical signals?
# 警告: 未找到问题: What types of supramolecular hosts are known to bind to their guests primarily through cation-π interactions?
# 警告: 未找到问题: What are the main factors controlling host-guest interaction?
# 已生成新文件: d:\CursorProj\Chem-Ontology-Constructor\tests\unit_test\query\test\reordered_MOSES-nano-final.md
